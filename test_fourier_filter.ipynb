# %%
import numpy as np
import scipy

import iefc_2dm 
import utils
from imshows import *

from importlib import reload

# %%
reload(utils)

command = np.random.randn(48,48)
# imshow1(command)

command_filtered = utils.fourier_filter_command(command, 5,21)
imshow3(command, command_filtered.real, command_filtered.imag)
