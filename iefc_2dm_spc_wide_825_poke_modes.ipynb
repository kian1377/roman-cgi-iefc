# %%
import numpy as np
import scipy

import cupy as cp
import cupyx.scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output, display, HTML
display(HTML("<style>.container { width:90% !important; }</style>")) # just making the notebook cells wider
from datetime import datetime
today = int(datetime.today().strftime('%Y%m%d'))

from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy
    
from math_module import xp, ensure_np_array
import iefc_2dm 
import utils
from imshows import *

data_dir = iefc_2dm.iefc_data_dir
response_dir = data_dir/'response-data'

dm1_flat = fits.getdata(cgi_phasec_poppy.data_dir/'dm-acts'/'flatmaps'/'spc_wide_band4_flattened_dm1.fits')
dm2_flat = fits.getdata(cgi_phasec_poppy.data_dir/'dm-acts'/'flatmaps'/'spc_wide_band4_flattened_dm2.fits')
# Out:
# <style>.container { width:90% !important; }</style>
# INFO:numexpr.utils:Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
mode = cgi_phasec_poppy.cgi.CGI(cgi_mode='spc-wide', npsf=150,
                                use_pupil_defocus=True, 
                                use_opds=True,
                                dm1_ref=2*dm1_flat, 
                                # dm2_ref=dm2_flat,
                                )
mode.exp_times_list = None

mode.use_fpm = False
ref_unocc_im = mode.snap()
imshow1(ref_unocc_im, pxscl=mode.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)

mode.Imax_ref = ref_unocc_im.get().max()
mode.use_fpm = True

ref_im = mode.snap()
imshow1(ref_im, 'SPC-WFOV Initial Coronagraphic Image\nfor iEFC',
        pxscl=mode.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True, vmin=1e-11)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(utils)
control_mask = utils.create_annular_focal_plane_mask(mode, inner_radius=5.4, outer_radius=20.6, edge=None, plot=True)

imshow1(control_mask*ref_im, lognorm=True)
mean_ni = xp.mean(ref_im[control_mask])
print(mean_ni)
# Out:
# 1.105575444465351e-06

# %% [markdown]
# # Create calibration and probe modes

# %%
probe_amp = 20e-9
# probe_modes = utils.create_poke_probes([(11,31), (38,34), (24,10)], plot=True)
# probe_modes = utils.create_poke_probes([(11,31), (36,31), (23,9)], plot=True)
# probe_modes = utils.create_poke_probes([(10,34), (10,35), (9, 34)], plot=True)
probe_modes = utils.create_fourier_probes(mode, control_mask, fourier_sampling=0.25,
                                          shift=[(-12,7), (12,7),(0,-14)], nprobes=3,
                                          use_weighting=True)
imshow3(probe_modes[0], probe_modes[1], probe_modes[2])

calib_modes = utils.create_all_poke_modes(mode.dm_mask, ndms=2)
Nmodes = calib_modes.shape[0]
print(calib_modes.shape)
i = 8
imshow2(calib_modes[i,:mode.Nact**2].reshape(mode.Nact,mode.Nact), calib_modes[i+mode.Nacts,mode.Nact**2:].reshape(mode.Nact,mode.Nact))
# Out:
# (3608, 4608)

# %%
reload(iefc_2dm)

mode.exp_times_list = None
differential_images, single_images = iefc_2dm.take_measurement(mode, probe_modes, probe_amp, return_all=True, plot=True)
ims = differential_images.reshape(probe_modes.shape[0], mode.npsf, mode.npsf)
imshow3(ims[0]-ims[1], ims[0]-ims[2], ims[1]-ims[2])

# %%
reload(iefc_2dm)

calib_amp = 5e-9

response_matrix, response_cube = iefc_2dm.calibrate(mode, 
                                                    control_mask,
                                                    probe_amp, probe_modes, 
                                                     calib_amp, calib_modes[:2], 
                                                     return_all=True, 
#                                                     plot_responses=False,
                                                   )

utils.save_fits(response_dir/f'test_response_matrix_{today}.fits', response_matrix)
utils.save_fits(response_dir/f'test_response_cube_{today}.fits', response_cube)
# Out:
# Calibrating iEFC...
# 	Calibrated mode 2/2 in 7.000s
# Calibration complete.
# Saved data to:  /home/kianmilani/Projects/roman-cgi-iefc-data/response-data/test_response_matrix_20231013.fits
# Saved data to:  /home/kianmilani/Projects/roman-cgi-iefc-data/response-data/test_response_cube_20231013.fits

# %%
date = 20230912
date = 20230913
date = 20230918
date = 20230920
date = 20230921
date = 20231013
date = 20240121
date = 20240130
response_matrix = xp.array(fits.getdata(response_dir/f'spc_wide_825_poke_modes_response_matrix_{date}.fits'))
# response_cube = xp.array(fits.getdata(data_dir/response_dir/f'spc_wide_825_poke_modes_response_cube_{date}.fits'))

dm_response = xp.sqrt(xp.mean(response_matrix.dot(xp.array(calib_modes))**2, axis=0))
dm1_response = dm_response[:mode.Nact**2].reshape(mode.Nact, mode.Nact)/dm_response.max()
dm2_response = dm_response[mode.Nact**2:].reshape(mode.Nact, mode.Nact)/dm_response.max()

print(dm_response.max())
imshow2(dm1_response, dm2_response, 
        'RMS Response of DM1\nActuators with Poke Modes', 'RMS Response of DM2\nActuators with Poke Modes',
        lognorm=True, vmax1=1, vmax2=1, vmin1=0.01, vmin2=0.01,
        )
# Out:
# 4779844201.247509

# %%
response_matrix.shape


dm_response = xp.sqrt(xp.mean(response_matrix.dot(xp.array(calib_modes))**2, axis=0))
dm1_response = dm_response[:mode.Nact**2].reshape(mode.Nact, mode.Nact)/dm_response.max()
dm2_response = dm_response[mode.Nact**2:].reshape(mode.Nact, mode.Nact)/dm_response.max()

print(dm_response.max())
imshow2(dm1_response, dm2_response, 
        'RMS Response of DM1\nActuators with Poke Modes', 'RMS Response of DM2\nActuators with Poke Modes',
        lognorm=True, vmax1=1, vmax2=1, vmin1=0.01, vmin2=0.01,
        )
# Out:
# 1956832869.4219265

# %% [markdown]
# # Run IEFC

# %%
mode.reset_dms()

images = xp.array([ref_im])
dm1_commands = xp.array([mode.get_dm1()])
dm2_commands = xp.array([mode.get_dm2()])
regs = xp.array([])

# %%
reload(iefc_2dm)
reload(utils)

reg_fun = utils.beta_reg
reg_conds = -2.5
reg_conds = -4
# reg_conds = -5
# reg_conds = -6

probe_amp = 2.5e-9

images, dm1_commands, dm2_commands, regs = iefc_2dm.run(mode, 
                                                        # control_matrix,
                                                        response_matrix,
                                                        reg_fun, reg_conds,
                                                        probe_modes, 
                                                        probe_amp, 
                                                        calib_modes,
                                                        control_mask, 
                                                        num_iterations=3, 
                                                        loop_gain=0.5, 
                                                        leakage=0,
                #                                                   use_fourier_filter=True,
                                                        plot_all=True,
                                                        plot_radial_contrast=False,
                                                        old_images=images,
                                                        old_dm1_commands=dm1_commands,
                                                        old_dm2_commands=dm2_commands,
                                                        old_regs=regs,
                                         )
# Out:
# Running iEFC...
# 	Closed-loop iteration 28 / 30
# False
# False
# 	Closed-loop iteration 29 / 30
# False
# False
# 	Closed-loop iteration 30 / 30
# False
# False
# Closed loop for given control matrix completed in 8.677s.

# %%
regs
# Out:
# array([-2.5, -2.5, -2.5, -6. , -6. , -6. , -2.5, -2.5, -2.5, -5. , -5. ,
#        -5. , -2.5, -2.5, -2.5, -6. , -6. , -6. , -2.5, -2.5, -2.5, -5. ,
#        -5. , -5. , -2.5, -2.5, -2.5, -4. , -4. , -4. ])

# %%
utils.save_fits(response_dir/f'spc_wfov_825_poke_dm1_commands_{today}.fits', dm1_commands)
utils.save_fits(response_dir/f'spc_wfov_825_poke_dm2_commands_{today}.fits', dm2_commands)
utils.save_fits(response_dir/f'spc_wfov_825_poke_images_{today}.fits', images)
utils.save_fits(response_dir/f'spc_wfov_825_poke_regs_{today}.fits', regs)
# Out:
# Saved data to:  /home/kianmilani/Projects/roman-cgi-iefc-data/response-data/spc_wfov_825_poke_dm1_commands_20240131.fits
# Saved data to:  /home/kianmilani/Projects/roman-cgi-iefc-data/response-data/spc_wfov_825_poke_dm2_commands_20240131.fits
# Saved data to:  /home/kianmilani/Projects/roman-cgi-iefc-data/response-data/spc_wfov_825_poke_images_20240131.fits
# Saved data to:  /home/kianmilani/Projects/roman-cgi-iefc-data/response-data/spc_wfov_825_poke_regs_20240131.fits
