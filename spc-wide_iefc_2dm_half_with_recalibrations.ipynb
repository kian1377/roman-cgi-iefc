# %%
import numpy as np
import scipy

import cupy as cp
import cupyx.scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output, display, HTML
display(HTML("<style>.container { width:90% !important; }</style>")) # just making the notebook cells wider

from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import wfsc_tests as wfsc
wfsc.math_module.update_np(cp)
wfsc.math_module.update_scipy(cupyx.scipy)

from wfsc_tests.math_module import xp, _scipy

import cgi_phasec_poppy as cgi
reload(cgi)

from matplotlib.colors import ListedColormap
#Blue to Red Color scale for S1 and S2
colmap = np.zeros((255,3));
# Red
colmap[126:183,0]= np.linspace(0,1,57);
colmap[183:255,0]= 1;
# Green
colmap[0:96,1] = np.linspace(1,0,96);
colmap[158:255,1]= np.linspace(0,1,97);
# Blue
colmap[0:71,2] = 1;
colmap[71:128,2]= np.linspace(1,0,57);
colmap2 = colmap[128:,:]
colmap = ListedColormap(colmap)

# iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
iefc_dir = Path('/home/kianmilani/Projects/roman-cgi-iefc-data')

# dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
# dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')
# Out:
# <style>.container { width:90% !important; }</style>

# %%
reload(cgi)

source_flux = 2.0208517e8 * u.ph/u.s/u.m**2 # flux of 47 UMa at 575nm with 10% bandpass

c = cgi.CGI(cgi_mode='spc-wide', npsf=150,
              use_pupil_defocus=True, 
              use_opds=True,
              source_flux=source_flux,
            exp_time=5)

# c.set_dm1(dm1_flat)
# c.set_dm2(dm2_flat)

npsf = c.npsf
Nact = c.Nact

c.use_fpm = False
ref_unocc_im = c.snap()
wfsc.imshow1(ref_unocc_im, pxscl=c.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)

max_ref = ref_unocc_im.get().max()
display(max_ref)

c.use_fpm = True
c.source_flux = source_flux/max_ref # divide the source flux to get nominal contrast images
ref_im = c.snap()
wfsc.imshow1(ref_im, pxscl=c.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)
# Out:
# 3826008.430443306

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(wfsc)
reload(wfsc.utils)
reload(wfsc.imshows)
xfp = (xp.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*c.psf_pixelscale_lamD
fpx,fpy = xp.meshgrid(xfp,xfp)
  
iwa = 6
owa = 20
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 3,
        'rotation':0,
        'full':True,
    }
roi1 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

iwa = 5.4
owa = 20.6
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 3,
        'rotation':0,
        'full':True,
    }
roi2 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

iwa = 6
owa = 11
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 3,
        'rotation':0,
        'full':True,
    }
roi3 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

relative_weight_1 = 0.9
relative_weight_2 = 0.2
weight_map = roi3 + relative_weight_1*(roi1*~roi3) + relative_weight_2*(roi2*~roi1*~roi3)
control_mask = weight_map>0
wfsc.imshow1(weight_map)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(wfsc.utils)
calib_amp = 5e-9
fourier_modes, fs = wfsc.utils.select_fourier_modes(c, control_mask*(fpx>0), fourier_sampling=1) 
nmodes = fourier_modes.shape[0]
nf = nmodes//2
print(fourier_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
wfsc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD, patches=patches)
# Out:
# (1084, 2304) (542, 2)

# %%
for i in range(fourier_modes.shape[0]//2):
    try:
        wfsc.imshow2(fourier_modes[i].reshape(Nact,Nact), ref_im, 
                       'Frequency Sampled: ({:.3f}, {:.3f})'.format(fs[i][0], fs[i][1]),
                       lognorm2=True,
                       pxscl2=c.psf_pixelscale_lamD, 
                       patches2=[Circle(fs[i], 0.25, fill=True, color='g'),
                                 Circle(-fs[i], 0.25, fill=True, color='g')])
        clear_output(wait=True)
        time.sleep(0.25)
    except KeyboardInterrupt:
        break

# %%
reload(wfsc.utils)
# probe_modes_1 = wfsc.utils.create_fourier_probes(fourier_modes, plot=True)
# probe = 1/np.sqrt(2) * np.sum((fourier_modes[:nf] + fourier_modes[nf:]), axis=0).reshape(Nact,Nact)
# probe /= probe.max()
# wfsc.imshow1(probe)

# probe_modes = np.array([probe_modes_1[0], probe, probe_modes_1[1]])
# wfsc.imshow3(probe_modes[0], probe_modes[1], probe_modes[2])

probe_modes = wfsc.utils.create_probe_poke_modes(Nact, 
                                                 poke_indices=[(Nact//5, Nact//2), (Nact//5+1, Nact//2)], 
                                                 plot=True)

# probe_modes = wfsc.utils.create_probe_poke_modes(Nact, 
#                                                  poke_indices=[(Nact//4, Nact//4), 
#                                                                (3*Nact//4, Nact//4), 
#                                                                (Nact//2, 3*Nact//4)], 
#                                                  plot=True)


# probe_modes = probe_modes_1 + probe_modes_2

# wfsc.imshow2(probe_modes[0], probe_modes[1])

# %%
reload(wfsc.iefc)

probe_amp = 5e-8
calib_amp = 5e-9

# c.texp = 1

c.set_dm1(dm1_flat)
c.set_dm2(dm2_flat)

differential_images, single_images = wfsc.iefc_2dm.take_measurement(c, 
                                                                   probe_modes, probe_amp, 
                                                                   return_all=True)
ims = differential_images.reshape(2, c.npsf, c.npsf)
wfsc.imshow3(ims[0], ims[1], ims[0]-ims[1], wspace=0.35)

# %%
# !nvidia-smi
# Out:
# Tue Jun 20 12:18:51 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe           On | 00000000:25:00.0 Off |                    0 |
# | N/A   36C    P0               84W / 300W|  13127MiB / 81920MiB |     27%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      4938      G   /usr/lib/xorg/Xorg                            4MiB |
# |    0   N/A  N/A    921019      C   ...iniconda3/envs/gpu311env/bin/python     2090MiB |
# |    0   N/A  N/A    927929      C   ...iniconda3/envs/gpu311env/bin/python     2216MiB |
# |    0   N/A  N/A    932998      C   python                                     2226MiB |
# |    0   N/A  N/A    934780      C   ...iniconda3/envs/gpu311env/bin/python     6588MiB |
# +---------------------------------------------------------------------------------------+

# %%
reload(wfsc.iefc_2dm)
response_matrix, response_cube = wfsc.iefc_2dm.calibrate(c, 
                                                         control_mask.ravel(),
                                                         probe_amp, probe_modes, 
                                                         calib_amp, fourier_modes, 
                                                         return_all=True)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 10 / 1084 in 80.764s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 reload(wfsc.iefc_2dm)
# ----> 2 response_matrix, response_cube = wfsc.iefc_2dm.calibrate(c,
#       3                                                          control_mask.ravel(),
#       4                                                          probe_amp, probe_modes,
#       5                                                          calib_amp, fourier_modes,
#       6                                                          return_all=True)
#
# File ~/Projects/wfsc-tests/wfsc_tests/twodm/iefc_2dm.py:79, in calibrate(sysi, control_mask, probe_amplitude, probe_modes, calibration_amplitude, calibration_modes, start_mode, return_all)
#      77 # DM2: Set the DM to the correct state
#      78 sysi.add_dm2(s * calibration_amplitude * calibration_mode.reshape(sysi.Nact, sysi.Nact))
# ---> 79 diff_ims_2 = take_measurement(sysi, probe_modes, probe_amplitude, DM=1)
#      80 response_2 += s * diff_ims_2 / (2 * calibration_amplitude)
#      81 sysi.add_dm2(-s * calibration_amplitude * calibration_mode.reshape(sysi.Nact, sysi.Nact))
#
# File ~/Projects/wfsc-tests/wfsc_tests/twodm/iefc_2dm.py:32, in take_measurement(sysi, probe_cube, probe_amplitude, DM, return_all, pca_modes, display)
#      30 if DM==1:
#      31     sysi.add_dm1(amp*probe)
# ---> 32     image = sysi.snap()
#      33     images.append(image.flatten())
#      34     sysi.add_dm1(-amp*probe)
#
# File ~/Projects/cgi_phasec_poppy/cgi_phasec_poppy/cgi.py:438, in CGI.snap(self)
#     436             wfs = hlc.run(self, return_intermediates=False)
#     437         else:
# --> 438             wfs = spc.run(self, return_intermediates=False)
#     440         im = wfs[-1].intensity
#     442 #         if self.EMCCD is not None and self.exp_time is not None:
#     443 #             if isinstance(im, np.ndarray):
#     444 #                 im = self.EMCCD.sim_sub_frame(im, self.exp_time.to_value(u.s))
#     445 #             else: # convert to numpy array and back to cupy to use EMCCD with GPU
#     446 #                 im = xp.array(self.EMCCD.sim_sub_frame(im.get(), self.exp_time.to_value(u.s)))
#
# File ~/Projects/cgi_phasec_poppy/cgi_phasec_poppy/spc.py:212, in run(SPC, return_intermediates)
#     209 fosys.add_optic(SPC.detector, distance=d_fold4_image)
#     211 # Calculate the PSF of the FresnelOpticalSystem
# --> 212 psf_hdu, wfs = fosys.calc_psf(wavelength=SPC.wavelength, inwave=SPC.inwave, normalize=SPC.normalize,
#     213                               return_intermediates=return_intermediates, return_final=True)
#     215 return wfs
#
# File ~/Projects/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/poppy_core.py:1729, in BaseOpticalSystem.calc_psf(self, wavelength, weight, save_intermediates, save_intermediates_what, display, return_intermediates, return_final, source, normalize, display_intermediates, inwave)
#    1727     plt.clf()
#    1728 for wlen, wave_weight in zip(wavelength, normwts):
# -> 1729     mono_psf, mono_intermediate_wfs = self.propagate_mono(
#    1730         wlen,
#    1731         retain_intermediates=retain_intermediates,
#    1732         retain_final=return_final,
#    1733         display_intermediates=display_intermediates,
#    1734         normalize=normalize,
#    1735         inwave=inwave
#    1736     )
#    1738     if outfits is None:
#    1739         # for the first wavelength processed, set up the arrays where we accumulate the output
#    1740         outfits = mono_psf
#
# File ~/Projects/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/poppy_core.py:1867, in BaseOpticalSystem.propagate_mono(self, wavelength, normalize, retain_intermediates, retain_final, display_intermediates, inwave)
#    1865     wavefront, intermediate_wfs = self.propagate(wavefront, **kwargs)
#    1866 else:
# -> 1867     wavefront = self.propagate(wavefront, **kwargs)
#    1868     intermediate_wfs = []
#    1870 if (not retain_intermediates) & retain_final:  # return the full complex wavefront of the last plane.
#
# File ~/Projects/poppy/poppy/fresnel.py:1297, in FresnelOpticalSystem.propagate(self, wavefront, normalize, return_intermediates, display_intermediates)
#    1295 # The actual propagation:
#    1296 wavefront.propagate_to(optic, distance)
# -> 1297 wavefront *= optic
#    1299 # Normalize if appropriate:
#    1300 if normalize.lower() == 'first' and wavefront.current_plane_index == 1:  # set entrance plane to 1.
#
# File ~/Projects/poppy/poppy/fresnel.py:917, in FresnelWavefront.__imul__(self, optic)
#     914     return self
#     915 else:
#     916     # Otherwise fall back to the parent class
# --> 917     return super(FresnelWavefront, self).__imul__(optic)
#
# File ~/Projects/poppy/poppy/poppy_core.py:177, in BaseWavefront.__imul__(self, optic)
#     174     self.location = 'at ' + optic.name
#     175     return self
# --> 177 phasor = optic.get_phasor(self)
#     179 if not np.isscalar(phasor) and phasor.size > 1:
#     180     assert self.wavefront.shape == phasor.shape, "Phasor shape {} does not match wavefront shape {}".format(
#     181         phasor.shape, self.wavefront.shape)
#
# File ~/Projects/poppy/poppy/optics.py:143, in AnalyticOpticalElement.get_phasor(self, wave)
#     140         return xp.asarray(result, _complex())
#     142 else:
# --> 143     return self.get_transmission(wave) * xp.exp(1.j * self.get_opd(wave) * scale)
#
# File ~/Projects/poppy/poppy/dms.py:556, in ContinuousDeformableMirror.get_transmission(self, wave)
#     554 if hasattr(self, 'shift_y'):
#     555     self._aperture.shift_y = self.shift_y
# --> 556 return self._aperture.get_transmission(wave)
#
# File ~/Projects/poppy/poppy/optics.py:1183, in CircularAperture.get_transmission(self, wave)
#    1181 if self._use_gray_pixel:
#    1182     pixscale = wave.pixelscale.to(u.meter/u.pixel).value
# -> 1183     self.transmission = geometry.filled_circle_aa(wave.shape, 0, 0, radius/pixscale, x/pixscale, y/pixscale)
#    1184 else:
#    1185     r = _r(x, y)
#
# File ~/Projects/poppy/poppy/geometry.py:212, in filled_circle_aa(shape, xcenter, ycenter, radius, xarray, yarray, fillvalue, clip, cliprange)
#     208 border = xp.where( xp.abs(r-radius) < pixscale)
#     210 weights = pixwt(xcenter, ycenter, radius, xarray[border], yarray[border])
# --> 212 array[border] = weights *fillvalue/area_per_pix
#     215 if clip:
#     216     assert len(cliprange) == 2
#
# File cupy/_core/core.pyx:1597, in cupy._core.core._ndarray_base.__setitem__()
#
# File cupy/_core/_routines_indexing.pyx:52, in cupy._core._routines_indexing._ndarray_setitem()
#
# File cupy/_core/_routines_indexing.pyx:1013, in cupy._core._routines_indexing._scatter_op()
#
# File cupy/_core/_routines_indexing.pyx:866, in cupy._core._routines_indexing._scatter_op_single()
#
# File cupy/_core/_routines_manipulation.pyx:479, in cupy._core._routines_manipulation.broadcast_to()
#
# File ~/miniconda3/envs/gpu311env/lib/python3.11/site-packages/numpy/lib/function_base.py:346, in iterable(y)
#     342         indexer = tuple(indexer)
#     343     return m[indexer]
# --> 346 @set_module('numpy')
#     347 def iterable(y):
#     348     """
#     349     Check whether or not an object can be iterated over.
#     350
#    (...)
#     382
#     383     """
#     384     try:
#
# KeyboardInterrupt:

# %%
response_matrix = xp.array(fits.getdata(iefc_dir/'response-data'/'hlc_iefc_2dm_response_matrix_20230619.fits'))
response_cube = xp.array(fits.getdata(iefc_dir/'response-data'/'hlc_iefc_2dm_response_cube_20230619.fits'))

# %%
response_sum = xp.sum(abs(response_cube), axis=(0,1))
wfsc.imshow1(response_sum.reshape(npsf, npsf), lognorm=True)

# %% [markdown]
# # Run IEFC

# %%
reload(wfsc.iefc_2dm)
reload(wfsc.utils)

c.set_dm1(dm1_flat)
c.set_dm2(dm2_flat)

Wmatrix = np.diag(np.concatenate((weight_map[control_mask], weight_map[control_mask])))

reg_cond = 1e-2
cm_wls = wfsc.utils.WeightedLeastSquares(response_matrix, Wmatrix, rcond=reg_cond)
    
images, dm1_commands, dm2_commands = wfsc.iefc_2dm.run(c, 
                                          cm_wls,
                                          probe_modes, 
                                          probe_amp, 
                                          fourier_modes,
                                          control_mask, 
                                          num_iterations=10, 
                                          loop_gain=0.5, 
                                          leakage=0.0,
                                          plot_all=True,
                                         )
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 10
# (472,)
# 	Closed-loop iteration 2 / 10
# (472,)
# 	Closed-loop iteration 3 / 10
# (472,)
# 	Closed-loop iteration 4 / 10
# (472,)
# 	Closed-loop iteration 5 / 10
# (472,)
# 	Closed-loop iteration 6 / 10
# (472,)
# 	Closed-loop iteration 7 / 10
# (472,)
# 	Closed-loop iteration 8 / 10
# (472,)
# 	Closed-loop iteration 9 / 10
# (472,)
# 	Closed-loop iteration 10 / 10
# (472,)
# I-EFC loop completed in 24.452s.

# %% [markdown]
# # Run iEFC with recalibrations after a given number of iterations

# %%
reload(wfsc.iefc_2dm)
reload(wfsc.utils)

c.set_dm1(dm1_flat)
c.set_dm2(dm2_flat)

reg_cond = 1e-2

Wmatrix = np.diag(np.concatenate((weight_map[control_mask], weight_map[control_mask])))

Ncalibs = 3
for i in range(Ncalibs):
    print('Calibrations {:d}/{:d}'.format(i+1, Ncalibs))
    response_matrix, response_cube = wfsc.iefc_2dm.calibrate(c, 
                                                             control_mask.ravel(),
                                                             probe_amp, probe_modes, 
                                                             calib_amp, fourier_modes, 
                                                             return_all=True)
    
    response_sum = xp.sum(abs(response_cube), axis=(0,1))
    wfsc.imshow1(response_sum.reshape(npsf, npsf), lognorm=True)
    
    misc.save_fits(iefc_dir/'response-data'/'hlc_iefc_2dm_response_matrix_{:d}_{:d}_20230619.fits'.format(i+1, Ncalibs), 
               wfsc.utils.ensure_np_array(response_matrix))
    misc.save_fits(iefc_dir/'response-data'/'hlc_iefc_2dm_response_cube_{:d}_{:d}_20230619.fits'.format(i+1, Ncalibs), 
                   wfsc.utils.ensure_np_array(response_cube))
    
    cm_wls = wfsc.utils.WeightedLeastSquares(response_matrix, Wmatrix, rcond=reg_conds[i][0])
    
    images, dm1_commands, dm2_commands = wfsc.iefc_2dm.run(c, 
                                              cm_wls,
                                              probe_modes, 
                                              probe_amp, 
                                              fourier_modes,
                                              control_mask, 
                                              num_iterations=reg_conds[i][1], 
                                              loop_gain=0.1, 
                                              leakage=0.0,
                                              plot_all=True,
                                             )
    misc.save_fits(iefc_dir/'images'/'hlc_iefc_2dm_images_{:d}_{:d}_20230619.fits'.format(i+1, Ncalibs), 
                   wfsc.utils.ensure_np_array(images))
    misc.save_fits(iefc_dir/'dm-commands'/'hlc_iefc_2dm_dm1_{:d}_{:d}_20230619.fits'.format(i+1, Ncalibs), 
                   wfsc.utils.ensure_np_array(dm1_commands))
    misc.save_fits(iefc_dir/'dm-commands'/'hlc_iefc_2dm_dm2_{:d}_{:d}_20230619.fits'.format(i+1, Ncalibs), 
                   wfsc.utils.ensure_np_array(dm2_commands))
# Out:
# Calibrations 1/3
# Calibrating I-EFC...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 14
#      12 for i in range(Ncalibs):
#      13     print('Calibrations {:d}/{:d}'.format(i+1, Ncalibs))
# ---> 14     response_matrix, response_cube = wfsc.iefc_2dm.calibrate(c,
#      15                                                              control_mask.ravel(),
#      16                                                              probe_amp, probe_modes,
#      17                                                              calib_amp, fourier_modes,
#      18                                                              return_all=True)
#      20     response_sum = xp.sum(abs(response_cube), axis=(0,1))
#      21     wfsc.imshow1(response_sum.reshape(npsf, npsf), lognorm=True)
#
# File ~/Projects/wfsc-tests/wfsc_tests/twodm/iefc_2dm.py:73, in calibrate(sysi, control_mask, probe_amplitude, probe_modes, calibration_amplitude, calibration_modes, start_mode, return_all)
#      70 for s in [-1, 1]: # We need a + and - probe to estimate the jacobian
#      71     # DM1: Set the DM to the correct state
#      72     sysi.add_dm1(s * calibration_amplitude * calibration_mode.reshape(sysi.Nact, sysi.Nact))
# ---> 73     diff_ims_1 = take_measurement(sysi, probe_modes, probe_amplitude, DM=1)
#      74     response_1 += s * diff_ims_1 / (2 * calibration_amplitude)
#      75     sysi.add_dm1(-s * calibration_amplitude * calibration_mode.reshape(sysi.Nact, sysi.Nact)) # remove the mode
#
# File ~/Projects/wfsc-tests/wfsc_tests/twodm/iefc_2dm.py:32, in take_measurement(sysi, probe_cube, probe_amplitude, DM, return_all, pca_modes, display)
#      30 if DM==1:
#      31     sysi.add_dm1(amp*probe)
# ---> 32     image = sysi.snap()
#      33     images.append(image.flatten())
#      34     sysi.add_dm1(-amp*probe)
#
# File ~/Projects/cgi_phasec_poppy/cgi_phasec_poppy/cgi.py:436, in CGI.snap(self)
#     434 self.init_inwave()
#     435 if self.cgi_mode=='hlc':
# --> 436     wfs = hlc.run(self, return_intermediates=False)
#     437 else:
#     438     wfs = spc.run(self, return_intermediates=False)
#
# File ~/Projects/cgi_phasec_poppy/cgi_phasec_poppy/hlc.py:229, in run(HLC, return_intermediates)
#     224     fosys2.add_optic(HLC.detector, distance=d_fold4_image)
#     226 #     fosys2.add_optic(HLC.detector, distance=d_lens_2_pp2_fold4 + d_fold4_image)
#     227
#     228     # Calculate a psf from the first optical system to retrieve the final wavefront at the FPM plane
# --> 229     fpm_hdu, wfs_to_fpm = fosys1.calc_psf(wavelength=HLC.wavelength, inwave=HLC.inwave, normalize=HLC.normalize,
#     230                                           return_final=True, return_intermediates=return_intermediates)
#     231     inwave2 = copy.deepcopy(wfs_to_fpm[-1]) # copy Wavefront object for use in the post FPM system
#     233     if HLC.use_fpm:
#
# File ~/Projects/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/poppy_core.py:1729, in BaseOpticalSystem.calc_psf(self, wavelength, weight, save_intermediates, save_intermediates_what, display, return_intermediates, return_final, source, normalize, display_intermediates, inwave)
#    1727     plt.clf()
#    1728 for wlen, wave_weight in zip(wavelength, normwts):
# -> 1729     mono_psf, mono_intermediate_wfs = self.propagate_mono(
#    1730         wlen,
#    1731         retain_intermediates=retain_intermediates,
#    1732         retain_final=return_final,
#    1733         display_intermediates=display_intermediates,
#    1734         normalize=normalize,
#    1735         inwave=inwave
#    1736     )
#    1738     if outfits is None:
#    1739         # for the first wavelength processed, set up the arrays where we accumulate the output
#    1740         outfits = mono_psf
#
# File ~/Projects/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/poppy_core.py:1867, in BaseOpticalSystem.propagate_mono(self, wavelength, normalize, retain_intermediates, retain_final, display_intermediates, inwave)
#    1865     wavefront, intermediate_wfs = self.propagate(wavefront, **kwargs)
#    1866 else:
# -> 1867     wavefront = self.propagate(wavefront, **kwargs)
#    1868     intermediate_wfs = []
#    1870 if (not retain_intermediates) & retain_final:  # return the full complex wavefront of the last plane.
#
# File ~/Projects/poppy/poppy/fresnel.py:1296, in FresnelOpticalSystem.propagate(self, wavefront, normalize, return_intermediates, display_intermediates)
#    1293     s0 = time.time()
#    1295 # The actual propagation:
# -> 1296 wavefront.propagate_to(optic, distance)
#    1297 wavefront *= optic
#    1299 # Normalize if appropriate:
#
# File ~/Projects/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/fresnel.py:662, in FresnelWavefront.propagate_to(self, optic, distance)
#     659 # Apply Fresnel propagation for the specified distance, regardless of
#     660 # what type of plane is next
#     661 if distance != 0 * u.m:
# --> 662     self.propagate_fresnel(distance)
#     664 self.current_plane_index += 1
#     666 # Now we may do some further manipulations depending on the next plane
#
# File ~/Projects/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/fresnel.py:898, in FresnelWavefront.propagate_fresnel(self, delta_z, display_intermed)
#     895     plt.figure()
#     896     self.display('both', colorbar=True)
# --> 898 self.wavefront = accel_math._fftshift(self.wavefront)
#     899 self.planetype = PlaneType.intermediate
#     900 _log.debug("------ Propagated to plane of type " + str(self.planetype) + " at z = {0:0.2e} ------".format(z))
#
# File ~/Projects/poppy/poppy/accel_math.py:145, in _fftshift(x)
#     134 def _fftshift(x):
#     135     """ FFT shifts of array contents, using CUDA/CuPY if available.
#     136     Otherwise defaults to numpy.
#     137
#    (...)
#     143     See also ifftshift
#     144     """
# --> 145     return xp.fft.fftshift(x)
#
# File ~/miniconda3/envs/gpu311env/lib/python3.11/site-packages/cupy/fft/_fft.py:1082, in fftshift(x, axes)
#    1080 elif isinstance(axes, np.compat.integer_types):
#    1081     axes = (axes,)
# -> 1082 return cupy.roll(x, [x.shape[axis] // 2 for axis in axes], axes)
#
# File ~/miniconda3/envs/gpu311env/lib/python3.11/site-packages/cupy/_manipulation/rearrange.py:143, in roll(a, shift, axis)
#     141 for indices in itertools.product(*rolls):
#     142     arr_index, res_index = zip(*indices)
# --> 143     result[res_index] = a[arr_index]
#     145 return result
#
# KeyboardInterrupt:
