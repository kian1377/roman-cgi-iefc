# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import efc_1dm_broad as efc
from wfsc import utils

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')
# Out:
# INFO:numexpr.utils:Note: detected 96 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 96 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.

# %%
nlam = 3
wavelength_c = 575e-9*u.m
bw = 0.05
wavelengths = np.linspace(wavelength_c*(1-bw/2), wavelength_c*(1+bw/2), nlam)
wavelengths
# Out:
# <Quantity [5.60625e-07, 5.75000e-07, 5.89375e-07] m>

# %%
reload(cgi)
sys_unocc = cgi.CGI(cgi_mode='hlc', 
              use_fpm=False,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )

unocc_psf = 0
for wavelength in wavelengths:
    sys_unocc.wavelength = wavelength
    unocc_psf += sys_unocc.snap()/len(wavelengths)

Imax_unocc = unocc_psf.max()
print(Imax_unocc)

sys = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )

npsf = sys.npsf
Nact = sys.Nact

ref_psf = 0
for wavelength in wavelengths:
    sys.wavelength = wavelength
    ref_psf += sys.snap()/len(wavelengths)

sys.show_dms()
misc.myimshow2(unocc_psf, ref_psf, lognorm1=True, lognorm2=True)

reload(utils)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * sys.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 2
iwa = 3
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
    'full':False
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params)

nmask = dh_mask.sum()
print(nmask)

misc.myimshow2(dh_mask, ref_psf*dh_mask,  
               pxscl1=sys.psf_pixelscale_lamD, pxscl2=sys.psf_pixelscale_lamD,
               lognorm2=True)
# Out:
# 0.020126611135658824
# 436

# %% [markdown]
# # Create/load Jacobian

# %%
reload(efc)

epsilon = 1e-9 # poke amplitudes (DM surface)
jac = efc.build_jacobian(sys, wavelengths, epsilon, dh_mask.flatten(), display=False)
# Out:
# Building Jacobian.
# Calculating sensitivity for wavelength 5.606e-07 m
# 	Calculated response for mode 1/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 2/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 3/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 4/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 5/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 6/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 7/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 8/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 9/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 10/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 11/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 12/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 13/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 14/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 15/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 16/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 17/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 18/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 19/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 20/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 21/2304. Elapsed time=0.004 sec.
# 	Calculated response for mode 22/2304. Elapsed time=0.643 sec.
# 	Calculated response for mode 23/2304. Elapsed time=1.271 sec.
# 	Calculated response for mode 24/2304. Elapsed time=1.897 sec.
# 	Calculated response for mode 25/2304. Elapsed time=2.523 sec.
# 	Calculated response for mode 26/2304. Elapsed time=3.150 sec.
# 	Calculated response for mode 27/2304. Elapsed time=3.779 sec.
# 	Calculated response for mode 28/2304. Elapsed time=3.779 sec.
# 	Calculated response for mode 29/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 30/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 31/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 32/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 33/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 34/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 35/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 36/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 37/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 38/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 39/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 40/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 41/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 42/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 43/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 44/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 45/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 46/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 47/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 48/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 49/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 50/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 51/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 52/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 53/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 54/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 55/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 56/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 57/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 58/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 59/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 60/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 61/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 62/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 63/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 64/2304. Elapsed time=3.780 sec.
# 	Calculated response for mode 65/2304. Elapsed time=4.405 sec.
# 	Calculated response for mode 66/2304. Elapsed time=5.029 sec.
# 	Calculated response for mode 67/2304. Elapsed time=5.656 sec.
# 	Calculated response for mode 68/2304. Elapsed time=6.282 sec.
# 	Calculated response for mode 69/2304. Elapsed time=6.905 sec.
# 	Calculated response for mode 70/2304. Elapsed time=7.528 sec.
# 	Calculated response for mode 71/2304. Elapsed time=8.156 sec.
# 	Calculated response for mode 72/2304. Elapsed time=8.780 sec.
# 	Calculated response for mode 73/2304. Elapsed time=9.403 sec.
# 	Calculated response for mode 74/2304. Elapsed time=10.028 sec.
# 	Calculated response for mode 75/2304. Elapsed time=10.650 sec.
# 	Calculated response for mode 76/2304. Elapsed time=11.283 sec.
# 	Calculated response for mode 77/2304. Elapsed time=11.909 sec.
# 	Calculated response for mode 78/2304. Elapsed time=12.531 sec.
# 	Calculated response for mode 79/2304. Elapsed time=13.153 sec.
# 	Calculated response for mode 80/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 81/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 82/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 83/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 84/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 85/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 86/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 87/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 88/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 89/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 90/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 91/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 92/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 93/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 94/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 95/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 96/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 97/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 98/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 99/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 100/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 101/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 102/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 103/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 104/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 105/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 106/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 107/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 108/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 109/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 110/2304. Elapsed time=13.780 sec.
# 	Calculated response for mode 111/2304. Elapsed time=14.404 sec.
# 	Calculated response for mode 112/2304. Elapsed time=15.027 sec.
# 	Calculated response for mode 113/2304. Elapsed time=15.651 sec.
# 	Calculated response for mode 114/2304. Elapsed time=16.277 sec.
# 	Calculated response for mode 115/2304. Elapsed time=16.910 sec.
# 	Calculated response for mode 116/2304. Elapsed time=17.534 sec.
# 	Calculated response for mode 117/2304. Elapsed time=18.158 sec.
# 	Calculated response for mode 118/2304. Elapsed time=18.782 sec.
# 	Calculated response for mode 119/2304. Elapsed time=19.404 sec.
# 	Calculated response for mode 120/2304. Elapsed time=20.027 sec.
# 	Calculated response for mode 121/2304. Elapsed time=20.650 sec.
# 	Calculated response for mode 122/2304. Elapsed time=21.272 sec.
# 	Calculated response for mode 123/2304. Elapsed time=21.895 sec.
# 	Calculated response for mode 124/2304. Elapsed time=22.526 sec.
# 	Calculated response for mode 125/2304. Elapsed time=23.150 sec.
# 	Calculated response for mode 126/2304. Elapsed time=23.774 sec.
# 	Calculated response for mode 127/2304. Elapsed time=24.399 sec.
# 	Calculated response for mode 128/2304. Elapsed time=25.028 sec.
# 	Calculated response for mode 129/2304. Elapsed time=25.654 sec.
# 	Calculated response for mode 130/2304. Elapsed time=26.278 sec.
# 	Calculated response for mode 131/2304. Elapsed time=26.278 sec.
# 	Calculated response for mode 132/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 133/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 134/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 135/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 136/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 137/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 138/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 139/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 140/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 141/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 142/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 143/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 144/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 145/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 146/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 147/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 148/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 149/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 150/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 151/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 152/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 153/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 154/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 155/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 156/2304. Elapsed time=26.279 sec.
# 	Calculated response for mode 157/2304. Elapsed time=26.903 sec.
# 	Calculated response for mode 158/2304. Elapsed time=27.532 sec.
# 	Calculated response for mode 159/2304. Elapsed time=28.156 sec.
# 	Calculated response for mode 160/2304. Elapsed time=28.780 sec.
# 	Calculated response for mode 161/2304. Elapsed time=29.404 sec.
# 	Calculated response for mode 162/2304. Elapsed time=30.029 sec.
# 	Calculated response for mode 163/2304. Elapsed time=30.652 sec.
# 	Calculated response for mode 164/2304. Elapsed time=31.274 sec.
# 	Calculated response for mode 165/2304. Elapsed time=31.899 sec.
# 	Calculated response for mode 166/2304. Elapsed time=32.825 sec.
# 	Calculated response for mode 167/2304. Elapsed time=33.458 sec.
# 	Calculated response for mode 168/2304. Elapsed time=34.081 sec.
# 	Calculated response for mode 169/2304. Elapsed time=34.705 sec.
# 	Calculated response for mode 170/2304. Elapsed time=35.327 sec.
# 	Calculated response for mode 171/2304. Elapsed time=35.949 sec.
# 	Calculated response for mode 172/2304. Elapsed time=36.571 sec.
# 	Calculated response for mode 173/2304. Elapsed time=37.194 sec.
# 	Calculated response for mode 174/2304. Elapsed time=37.816 sec.
# 	Calculated response for mode 175/2304. Elapsed time=38.439 sec.
# 	Calculated response for mode 176/2304. Elapsed time=39.066 sec.
# 	Calculated response for mode 177/2304. Elapsed time=39.686 sec.
# 	Calculated response for mode 178/2304. Elapsed time=40.309 sec.
# 	Calculated response for mode 179/2304. Elapsed time=40.929 sec.
# 	Calculated response for mode 180/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 181/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 182/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 183/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 184/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 185/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 186/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 187/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 188/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 189/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 190/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 191/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 192/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 193/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 194/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 195/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 196/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 197/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 198/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 199/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 200/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 201/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 202/2304. Elapsed time=41.550 sec.
# 	Calculated response for mode 203/2304. Elapsed time=42.170 sec.
# 	Calculated response for mode 204/2304. Elapsed time=42.789 sec.
# 	Calculated response for mode 205/2304. Elapsed time=43.414 sec.
# 	Calculated response for mode 206/2304. Elapsed time=44.043 sec.
# 	Calculated response for mode 207/2304. Elapsed time=44.666 sec.
# 	Calculated response for mode 208/2304. Elapsed time=45.292 sec.
# 	Calculated response for mode 209/2304. Elapsed time=45.915 sec.
# 	Calculated response for mode 210/2304. Elapsed time=46.537 sec.
# 	Calculated response for mode 211/2304. Elapsed time=47.164 sec.
# 	Calculated response for mode 212/2304. Elapsed time=47.785 sec.
# 	Calculated response for mode 213/2304. Elapsed time=48.409 sec.
# 	Calculated response for mode 214/2304. Elapsed time=49.032 sec.
# 	Calculated response for mode 215/2304. Elapsed time=49.660 sec.
# 	Calculated response for mode 216/2304. Elapsed time=50.284 sec.
# 	Calculated response for mode 217/2304. Elapsed time=50.907 sec.
# 	Calculated response for mode 218/2304. Elapsed time=51.530 sec.
# 	Calculated response for mode 219/2304. Elapsed time=52.155 sec.
# 	Calculated response for mode 220/2304. Elapsed time=52.779 sec.
# 	Calculated response for mode 221/2304. Elapsed time=53.406 sec.
# 	Calculated response for mode 222/2304. Elapsed time=54.033 sec.
# 	Calculated response for mode 223/2304. Elapsed time=54.658 sec.
# 	Calculated response for mode 224/2304. Elapsed time=55.289 sec.
# 	Calculated response for mode 225/2304. Elapsed time=55.913 sec.
# 	Calculated response for mode 226/2304. Elapsed time=56.538 sec.
# 	Calculated response for mode 227/2304. Elapsed time=57.164 sec.
# 	Calculated response for mode 228/2304. Elapsed time=57.789 sec.
# 	Calculated response for mode 229/2304. Elapsed time=58.416 sec.
# 	Calculated response for mode 230/2304. Elapsed time=59.042 sec.
# 	Calculated response for mode 231/2304. Elapsed time=59.042 sec.
# 	Calculated response for mode 232/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 233/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 234/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 235/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 236/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 237/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 238/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 239/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 240/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 241/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 242/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 243/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 244/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 245/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 246/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 247/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 248/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 249/2304. Elapsed time=59.043 sec.
# 	Calculated response for mode 250/2304. Elapsed time=59.668 sec.
# 	Calculated response for mode 251/2304. Elapsed time=60.296 sec.
# 	Calculated response for mode 252/2304. Elapsed time=60.927 sec.
# 	Calculated response for mode 253/2304. Elapsed time=61.555 sec.
# 	Calculated response for mode 254/2304. Elapsed time=62.181 sec.
# 	Calculated response for mode 255/2304. Elapsed time=62.805 sec.
# 	Calculated response for mode 256/2304. Elapsed time=63.430 sec.
# 	Calculated response for mode 257/2304. Elapsed time=64.055 sec.
# 	Calculated response for mode 258/2304. Elapsed time=64.679 sec.
# 	Calculated response for mode 259/2304. Elapsed time=65.305 sec.
# 	Calculated response for mode 260/2304. Elapsed time=65.931 sec.
# 	Calculated response for mode 261/2304. Elapsed time=66.563 sec.
# 	Calculated response for mode 262/2304. Elapsed time=67.188 sec.
# 	Calculated response for mode 263/2304. Elapsed time=67.812 sec.
# 	Calculated response for mode 264/2304. Elapsed time=68.439 sec.
# 	Calculated response for mode 265/2304. Elapsed time=69.065 sec.
# 	Calculated response for mode 266/2304. Elapsed time=69.689 sec.
# 	Calculated response for mode 267/2304. Elapsed time=70.316 sec.
# 	Calculated response for mode 268/2304. Elapsed time=70.942 sec.
# 	Calculated response for mode 269/2304. Elapsed time=71.577 sec.
# 	Calculated response for mode 270/2304. Elapsed time=72.202 sec.
# 	Calculated response for mode 271/2304. Elapsed time=72.831 sec.
# 	Calculated response for mode 272/2304. Elapsed time=73.456 sec.
# 	Calculated response for mode 273/2304. Elapsed time=74.082 sec.
# 	Calculated response for mode 274/2304. Elapsed time=74.709 sec.
# 	Calculated response for mode 275/2304. Elapsed time=75.333 sec.
# 	Calculated response for mode 276/2304. Elapsed time=75.958 sec.
# 	Calculated response for mode 277/2304. Elapsed time=76.584 sec.
# 	Calculated response for mode 278/2304. Elapsed time=77.222 sec.
# 	Calculated response for mode 279/2304. Elapsed time=77.846 sec.
# 	Calculated response for mode 280/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 281/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 282/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 283/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 284/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 285/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 286/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 287/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 288/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 289/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 290/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 291/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 292/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 293/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 294/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 295/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 296/2304. Elapsed time=77.847 sec.
# 	Calculated response for mode 297/2304. Elapsed time=78.472 sec.
# 	Calculated response for mode 298/2304. Elapsed time=79.097 sec.
# 	Calculated response for mode 299/2304. Elapsed time=79.723 sec.
# 	Calculated response for mode 300/2304. Elapsed time=80.348 sec.
# 	Calculated response for mode 301/2304. Elapsed time=80.975 sec.
# 	Calculated response for mode 302/2304. Elapsed time=81.599 sec.
# 	Calculated response for mode 303/2304. Elapsed time=82.225 sec.
# 	Calculated response for mode 304/2304. Elapsed time=82.856 sec.
# 	Calculated response for mode 305/2304. Elapsed time=83.484 sec.
# 	Calculated response for mode 306/2304. Elapsed time=84.242 sec.
# 	Calculated response for mode 307/2304. Elapsed time=84.867 sec.
# 	Calculated response for mode 308/2304. Elapsed time=85.493 sec.
# 	Calculated response for mode 309/2304. Elapsed time=86.115 sec.
# 	Calculated response for mode 310/2304. Elapsed time=86.738 sec.
# 	Calculated response for mode 311/2304. Elapsed time=87.365 sec.
# 	Calculated response for mode 312/2304. Elapsed time=87.988 sec.
# 	Calculated response for mode 313/2304. Elapsed time=88.618 sec.
# 	Calculated response for mode 314/2304. Elapsed time=89.242 sec.
# 	Calculated response for mode 315/2304. Elapsed time=89.869 sec.
# 	Calculated response for mode 316/2304. Elapsed time=90.494 sec.
# 	Calculated response for mode 317/2304. Elapsed time=91.117 sec.
# 	Calculated response for mode 318/2304. Elapsed time=91.740 sec.
# 	Calculated response for mode 319/2304. Elapsed time=92.366 sec.
# 	Calculated response for mode 320/2304. Elapsed time=92.991 sec.
# 	Calculated response for mode 321/2304. Elapsed time=93.625 sec.
# 	Calculated response for mode 322/2304. Elapsed time=94.250 sec.
# 	Calculated response for mode 323/2304. Elapsed time=94.876 sec.
# 	Calculated response for mode 324/2304. Elapsed time=95.502 sec.
# 	Calculated response for mode 325/2304. Elapsed time=96.125 sec.
# 	Calculated response for mode 326/2304. Elapsed time=96.748 sec.
# 	Calculated response for mode 327/2304. Elapsed time=97.374 sec.
# 	Calculated response for mode 328/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 329/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 330/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 331/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 332/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 333/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 334/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 335/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 336/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 337/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 338/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 339/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 340/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 341/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 342/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 343/2304. Elapsed time=97.999 sec.
# 	Calculated response for mode 344/2304. Elapsed time=98.626 sec.
# 	Calculated response for mode 345/2304. Elapsed time=99.255 sec.
# 	Calculated response for mode 346/2304. Elapsed time=99.879 sec.
# 	Calculated response for mode 347/2304. Elapsed time=100.504 sec.
# 	Calculated response for mode 348/2304. Elapsed time=101.130 sec.
# 	Calculated response for mode 349/2304. Elapsed time=101.756 sec.
# 	Calculated response for mode 350/2304. Elapsed time=102.378 sec.
# 	Calculated response for mode 351/2304. Elapsed time=103.003 sec.
# 	Calculated response for mode 352/2304. Elapsed time=103.627 sec.
# 	Calculated response for mode 353/2304. Elapsed time=104.252 sec.
# 	Calculated response for mode 354/2304. Elapsed time=104.883 sec.
# 	Calculated response for mode 355/2304. Elapsed time=105.508 sec.
# 	Calculated response for mode 356/2304. Elapsed time=106.135 sec.
# 	Calculated response for mode 357/2304. Elapsed time=106.759 sec.
# 	Calculated response for mode 358/2304. Elapsed time=107.386 sec.
# 	Calculated response for mode 359/2304. Elapsed time=108.012 sec.
# 	Calculated response for mode 360/2304. Elapsed time=108.634 sec.
# 	Calculated response for mode 361/2304. Elapsed time=109.257 sec.
# 	Calculated response for mode 362/2304. Elapsed time=109.885 sec.
# 	Calculated response for mode 363/2304. Elapsed time=110.512 sec.
# 	Calculated response for mode 364/2304. Elapsed time=111.140 sec.
# 	Calculated response for mode 365/2304. Elapsed time=111.764 sec.
# 	Calculated response for mode 366/2304. Elapsed time=112.390 sec.
# 	Calculated response for mode 367/2304. Elapsed time=113.013 sec.
# 	Calculated response for mode 368/2304. Elapsed time=113.638 sec.
# 	Calculated response for mode 369/2304. Elapsed time=114.263 sec.
# 	Calculated response for mode 370/2304. Elapsed time=114.886 sec.
# 	Calculated response for mode 371/2304. Elapsed time=115.515 sec.
# 	Calculated response for mode 372/2304. Elapsed time=116.139 sec.
# 	Calculated response for mode 373/2304. Elapsed time=116.763 sec.
# 	Calculated response for mode 374/2304. Elapsed time=117.389 sec.
# 	Calculated response for mode 375/2304. Elapsed time=118.016 sec.
# 	Calculated response for mode 376/2304. Elapsed time=118.643 sec.
# 	Calculated response for mode 377/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 378/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 379/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 380/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 381/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 382/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 383/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 384/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 385/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 386/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 387/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 388/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 389/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 390/2304. Elapsed time=119.269 sec.
# 	Calculated response for mode 391/2304. Elapsed time=119.894 sec.
# 	Calculated response for mode 392/2304. Elapsed time=120.517 sec.
# 	Calculated response for mode 393/2304. Elapsed time=121.147 sec.
# 	Calculated response for mode 394/2304. Elapsed time=121.775 sec.
# 	Calculated response for mode 395/2304. Elapsed time=122.400 sec.
# 	Calculated response for mode 396/2304. Elapsed time=123.029 sec.
# 	Calculated response for mode 397/2304. Elapsed time=123.655 sec.
# 	Calculated response for mode 398/2304. Elapsed time=124.281 sec.
# 	Calculated response for mode 399/2304. Elapsed time=124.905 sec.
# 	Calculated response for mode 400/2304. Elapsed time=125.530 sec.
# 	Calculated response for mode 401/2304. Elapsed time=126.157 sec.
# 	Calculated response for mode 402/2304. Elapsed time=126.786 sec.
# 	Calculated response for mode 403/2304. Elapsed time=127.412 sec.
# 	Calculated response for mode 404/2304. Elapsed time=128.036 sec.
# 	Calculated response for mode 405/2304. Elapsed time=128.663 sec.
# 	Calculated response for mode 406/2304. Elapsed time=129.286 sec.
# 	Calculated response for mode 407/2304. Elapsed time=129.909 sec.
# 	Calculated response for mode 408/2304. Elapsed time=130.536 sec.
# 	Calculated response for mode 409/2304. Elapsed time=131.159 sec.
# 	Calculated response for mode 410/2304. Elapsed time=131.783 sec.
# 	Calculated response for mode 411/2304. Elapsed time=132.412 sec.
# 	Calculated response for mode 412/2304. Elapsed time=133.152 sec.
# 	Calculated response for mode 413/2304. Elapsed time=133.777 sec.
# 	Calculated response for mode 414/2304. Elapsed time=134.402 sec.
# 	Calculated response for mode 415/2304. Elapsed time=135.024 sec.
# 	Calculated response for mode 416/2304. Elapsed time=135.647 sec.
# 	Calculated response for mode 417/2304. Elapsed time=136.270 sec.
# 	Calculated response for mode 418/2304. Elapsed time=136.897 sec.
# 	Calculated response for mode 419/2304. Elapsed time=137.527 sec.
# 	Calculated response for mode 420/2304. Elapsed time=138.150 sec.
# 	Calculated response for mode 421/2304. Elapsed time=138.776 sec.
# 	Calculated response for mode 422/2304. Elapsed time=139.400 sec.
# 	Calculated response for mode 423/2304. Elapsed time=140.027 sec.
# 	Calculated response for mode 424/2304. Elapsed time=140.651 sec.
# 	Calculated response for mode 425/2304. Elapsed time=141.274 sec.
# 	Calculated response for mode 426/2304. Elapsed time=141.896 sec.
# 	Calculated response for mode 427/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 428/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 429/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 430/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 431/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 432/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 433/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 434/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 435/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 436/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 437/2304. Elapsed time=141.897 sec.
# 	Calculated response for mode 438/2304. Elapsed time=142.524 sec.
# 	Calculated response for mode 439/2304. Elapsed time=143.154 sec.
# 	Calculated response for mode 440/2304. Elapsed time=143.776 sec.
# 	Calculated response for mode 441/2304. Elapsed time=144.399 sec.
# 	Calculated response for mode 442/2304. Elapsed time=145.080 sec.
# 	Calculated response for mode 443/2304. Elapsed time=145.701 sec.
# 	Calculated response for mode 444/2304. Elapsed time=146.323 sec.
# 	Calculated response for mode 445/2304. Elapsed time=146.950 sec.
# 	Calculated response for mode 446/2304. Elapsed time=147.576 sec.
# 	Calculated response for mode 447/2304. Elapsed time=148.202 sec.
# 	Calculated response for mode 448/2304. Elapsed time=148.830 sec.
# 	Calculated response for mode 449/2304. Elapsed time=149.455 sec.
# 	Calculated response for mode 450/2304. Elapsed time=150.078 sec.
# 	Calculated response for mode 451/2304. Elapsed time=150.705 sec.
# 	Calculated response for mode 452/2304. Elapsed time=151.330 sec.
# 	Calculated response for mode 453/2304. Elapsed time=151.959 sec.
# 	Calculated response for mode 454/2304. Elapsed time=152.583 sec.
# 	Calculated response for mode 455/2304. Elapsed time=153.207 sec.
# 	Calculated response for mode 456/2304. Elapsed time=153.833 sec.
# 	Calculated response for mode 457/2304. Elapsed time=154.461 sec.
# 	Calculated response for mode 458/2304. Elapsed time=155.086 sec.
# 	Calculated response for mode 459/2304. Elapsed time=155.711 sec.
# 	Calculated response for mode 460/2304. Elapsed time=156.341 sec.
# 	Calculated response for mode 461/2304. Elapsed time=156.966 sec.
# 	Calculated response for mode 462/2304. Elapsed time=157.590 sec.
# 	Calculated response for mode 463/2304. Elapsed time=158.216 sec.
# 	Calculated response for mode 464/2304. Elapsed time=158.839 sec.
# 	Calculated response for mode 465/2304. Elapsed time=159.461 sec.
# 	Calculated response for mode 466/2304. Elapsed time=160.087 sec.
# 	Calculated response for mode 467/2304. Elapsed time=160.710 sec.
# 	Calculated response for mode 468/2304. Elapsed time=161.332 sec.
# 	Calculated response for mode 469/2304. Elapsed time=161.955 sec.
# 	Calculated response for mode 470/2304. Elapsed time=162.579 sec.
# 	Calculated response for mode 471/2304. Elapsed time=163.202 sec.
# 	Calculated response for mode 472/2304. Elapsed time=163.828 sec.
# 	Calculated response for mode 473/2304. Elapsed time=164.453 sec.
# 	Calculated response for mode 474/2304. Elapsed time=165.077 sec.
# 	Calculated response for mode 475/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 476/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 477/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 478/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 479/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 480/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 481/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 482/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 483/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 484/2304. Elapsed time=165.700 sec.
# 	Calculated response for mode 485/2304. Elapsed time=166.324 sec.
# 	Calculated response for mode 486/2304. Elapsed time=166.950 sec.
# 	Calculated response for mode 487/2304. Elapsed time=167.576 sec.
# 	Calculated response for mode 488/2304. Elapsed time=168.199 sec.
# 	Calculated response for mode 489/2304. Elapsed time=168.826 sec.
# 	Calculated response for mode 490/2304. Elapsed time=169.448 sec.
# 	Calculated response for mode 491/2304. Elapsed time=170.070 sec.
# 	Calculated response for mode 492/2304. Elapsed time=170.694 sec.
# 	Calculated response for mode 493/2304. Elapsed time=171.315 sec.
# 	Calculated response for mode 494/2304. Elapsed time=171.941 sec.
# 	Calculated response for mode 495/2304. Elapsed time=172.566 sec.
# 	Calculated response for mode 496/2304. Elapsed time=173.190 sec.
# 	Calculated response for mode 497/2304. Elapsed time=173.818 sec.
# 	Calculated response for mode 498/2304. Elapsed time=174.443 sec.
# 	Calculated response for mode 499/2304. Elapsed time=175.066 sec.
# 	Calculated response for mode 500/2304. Elapsed time=175.688 sec.
# 	Calculated response for mode 501/2304. Elapsed time=176.313 sec.
# 	Calculated response for mode 502/2304. Elapsed time=176.938 sec.
# 	Calculated response for mode 503/2304. Elapsed time=177.561 sec.
# 	Calculated response for mode 504/2304. Elapsed time=178.194 sec.
# 	Calculated response for mode 505/2304. Elapsed time=178.817 sec.
# 	Calculated response for mode 506/2304. Elapsed time=179.446 sec.
# 	Calculated response for mode 507/2304. Elapsed time=180.069 sec.
# 	Calculated response for mode 508/2304. Elapsed time=180.692 sec.
# 	Calculated response for mode 509/2304. Elapsed time=181.320 sec.
# 	Calculated response for mode 510/2304. Elapsed time=181.944 sec.
# 	Calculated response for mode 511/2304. Elapsed time=182.567 sec.
# 	Calculated response for mode 512/2304. Elapsed time=183.191 sec.
# 	Calculated response for mode 513/2304. Elapsed time=183.816 sec.
# 	Calculated response for mode 514/2304. Elapsed time=184.440 sec.
# 	Calculated response for mode 515/2304. Elapsed time=185.064 sec.
# 	Calculated response for mode 516/2304. Elapsed time=185.689 sec.
# 	Calculated response for mode 517/2304. Elapsed time=186.314 sec.
# 	Calculated response for mode 518/2304. Elapsed time=186.941 sec.
# 	Calculated response for mode 519/2304. Elapsed time=187.566 sec.
# 	Calculated response for mode 520/2304. Elapsed time=188.192 sec.
# 	Calculated response for mode 521/2304. Elapsed time=188.817 sec.
# 	Calculated response for mode 522/2304. Elapsed time=189.443 sec.
# 	Calculated response for mode 523/2304. Elapsed time=190.070 sec.
# 	Calculated response for mode 524/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 525/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 526/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 527/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 528/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 529/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 530/2304. Elapsed time=190.695 sec.
# 	Calculated response for mode 531/2304. Elapsed time=190.696 sec.
# 	Calculated response for mode 532/2304. Elapsed time=190.696 sec.
# 	Calculated response for mode 533/2304. Elapsed time=191.321 sec.
# 	Calculated response for mode 534/2304. Elapsed time=191.949 sec.
# 	Calculated response for mode 535/2304. Elapsed time=192.575 sec.
# 	Calculated response for mode 536/2304. Elapsed time=193.200 sec.
# 	Calculated response for mode 537/2304. Elapsed time=193.826 sec.
# 	Calculated response for mode 538/2304. Elapsed time=194.450 sec.
# 	Calculated response for mode 539/2304. Elapsed time=195.192 sec.
# 	Calculated response for mode 540/2304. Elapsed time=195.816 sec.
# 	Calculated response for mode 541/2304. Elapsed time=196.442 sec.
# 	Calculated response for mode 542/2304. Elapsed time=197.071 sec.
# 	Calculated response for mode 543/2304. Elapsed time=197.699 sec.
# 	Calculated response for mode 544/2304. Elapsed time=198.325 sec.
# 	Calculated response for mode 545/2304. Elapsed time=198.949 sec.
# 	Calculated response for mode 546/2304. Elapsed time=199.573 sec.
# 	Calculated response for mode 547/2304. Elapsed time=200.199 sec.
# 	Calculated response for mode 548/2304. Elapsed time=200.827 sec.
# 	Calculated response for mode 549/2304. Elapsed time=201.453 sec.
# 	Calculated response for mode 550/2304. Elapsed time=202.079 sec.
# 	Calculated response for mode 551/2304. Elapsed time=202.704 sec.
# 	Calculated response for mode 552/2304. Elapsed time=203.327 sec.
# 	Calculated response for mode 553/2304. Elapsed time=203.955 sec.
# 	Calculated response for mode 554/2304. Elapsed time=204.577 sec.
# 	Calculated response for mode 555/2304. Elapsed time=205.201 sec.
# 	Calculated response for mode 556/2304. Elapsed time=205.825 sec.
# 	Calculated response for mode 557/2304. Elapsed time=206.450 sec.
# 	Calculated response for mode 558/2304. Elapsed time=207.076 sec.
# 	Calculated response for mode 559/2304. Elapsed time=207.702 sec.
# 	Calculated response for mode 560/2304. Elapsed time=208.327 sec.
# 	Calculated response for mode 561/2304. Elapsed time=208.951 sec.
# 	Calculated response for mode 562/2304. Elapsed time=209.582 sec.
# 	Calculated response for mode 563/2304. Elapsed time=210.208 sec.
# 	Calculated response for mode 564/2304. Elapsed time=210.831 sec.
# 	Calculated response for mode 565/2304. Elapsed time=211.457 sec.
# 	Calculated response for mode 566/2304. Elapsed time=212.087 sec.
# 	Calculated response for mode 567/2304. Elapsed time=212.715 sec.
# 	Calculated response for mode 568/2304. Elapsed time=213.339 sec.
# 	Calculated response for mode 569/2304. Elapsed time=213.963 sec.
# 	Calculated response for mode 570/2304. Elapsed time=214.586 sec.
# 	Calculated response for mode 571/2304. Elapsed time=215.212 sec.
# 	Calculated response for mode 572/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 573/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 574/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 575/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 576/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 577/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 578/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 579/2304. Elapsed time=215.839 sec.
# 	Calculated response for mode 580/2304. Elapsed time=216.466 sec.
# 	Calculated response for mode 581/2304. Elapsed time=217.091 sec.
# 	Calculated response for mode 582/2304. Elapsed time=217.715 sec.
# 	Calculated response for mode 583/2304. Elapsed time=218.341 sec.
# 	Calculated response for mode 584/2304. Elapsed time=218.973 sec.
# 	Calculated response for mode 585/2304. Elapsed time=219.597 sec.
# 	Calculated response for mode 586/2304. Elapsed time=220.224 sec.
# 	Calculated response for mode 587/2304. Elapsed time=220.848 sec.
# 	Calculated response for mode 588/2304. Elapsed time=221.472 sec.
# 	Calculated response for mode 589/2304. Elapsed time=222.094 sec.
# 	Calculated response for mode 590/2304. Elapsed time=222.717 sec.
# 	Calculated response for mode 591/2304. Elapsed time=223.343 sec.
# 	Calculated response for mode 592/2304. Elapsed time=223.968 sec.
# 	Calculated response for mode 593/2304. Elapsed time=224.592 sec.
# 	Calculated response for mode 594/2304. Elapsed time=225.216 sec.
# 	Calculated response for mode 595/2304. Elapsed time=225.841 sec.
# 	Calculated response for mode 596/2304. Elapsed time=226.471 sec.
# 	Calculated response for mode 597/2304. Elapsed time=227.096 sec.
# 	Calculated response for mode 598/2304. Elapsed time=227.723 sec.
# 	Calculated response for mode 599/2304. Elapsed time=228.347 sec.
# 	Calculated response for mode 600/2304. Elapsed time=228.969 sec.
# 	Calculated response for mode 601/2304. Elapsed time=229.596 sec.
# 	Calculated response for mode 602/2304. Elapsed time=230.222 sec.
# 	Calculated response for mode 603/2304. Elapsed time=230.846 sec.
# 	Calculated response for mode 604/2304. Elapsed time=231.469 sec.
# 	Calculated response for mode 605/2304. Elapsed time=232.092 sec.
# 	Calculated response for mode 606/2304. Elapsed time=232.718 sec.
# 	Calculated response for mode 607/2304. Elapsed time=233.344 sec.
# 	Calculated response for mode 608/2304. Elapsed time=233.971 sec.
# 	Calculated response for mode 609/2304. Elapsed time=234.598 sec.
# 	Calculated response for mode 610/2304. Elapsed time=235.223 sec.
# 	Calculated response for mode 611/2304. Elapsed time=235.849 sec.
# 	Calculated response for mode 612/2304. Elapsed time=236.475 sec.
# 	Calculated response for mode 613/2304. Elapsed time=237.100 sec.
# 	Calculated response for mode 614/2304. Elapsed time=237.726 sec.
# 	Calculated response for mode 615/2304. Elapsed time=238.353 sec.
# 	Calculated response for mode 616/2304. Elapsed time=238.977 sec.
# 	Calculated response for mode 617/2304. Elapsed time=239.603 sec.
# 	Calculated response for mode 618/2304. Elapsed time=240.230 sec.
# 	Calculated response for mode 619/2304. Elapsed time=240.854 sec.
# 	Calculated response for mode 620/2304. Elapsed time=241.479 sec.
# 	Calculated response for mode 621/2304. Elapsed time=242.102 sec.
# 	Calculated response for mode 622/2304. Elapsed time=242.102 sec.
# 	Calculated response for mode 623/2304. Elapsed time=242.103 sec.
# 	Calculated response for mode 624/2304. Elapsed time=242.103 sec.
# 	Calculated response for mode 625/2304. Elapsed time=242.103 sec.
# 	Calculated response for mode 626/2304. Elapsed time=242.103 sec.
# 	Calculated response for mode 627/2304. Elapsed time=242.103 sec.
# 	Calculated response for mode 628/2304. Elapsed time=242.727 sec.
# 	Calculated response for mode 629/2304. Elapsed time=243.349 sec.
# 	Calculated response for mode 630/2304. Elapsed time=243.975 sec.
# 	Calculated response for mode 631/2304. Elapsed time=244.601 sec.
# 	Calculated response for mode 632/2304. Elapsed time=245.226 sec.
# 	Calculated response for mode 633/2304. Elapsed time=245.849 sec.
# 	Calculated response for mode 634/2304. Elapsed time=246.476 sec.
# 	Calculated response for mode 635/2304. Elapsed time=247.104 sec.
# 	Calculated response for mode 636/2304. Elapsed time=247.850 sec.
# 	Calculated response for mode 637/2304. Elapsed time=248.472 sec.
# 	Calculated response for mode 638/2304. Elapsed time=249.094 sec.
# 	Calculated response for mode 639/2304. Elapsed time=249.720 sec.
# 	Calculated response for mode 640/2304. Elapsed time=250.346 sec.
# 	Calculated response for mode 641/2304. Elapsed time=250.971 sec.
# 	Calculated response for mode 642/2304. Elapsed time=251.596 sec.
# 	Calculated response for mode 643/2304. Elapsed time=252.219 sec.
# 	Calculated response for mode 644/2304. Elapsed time=252.842 sec.
# 	Calculated response for mode 645/2304. Elapsed time=253.464 sec.
# 	Calculated response for mode 646/2304. Elapsed time=254.088 sec.
# 	Calculated response for mode 647/2304. Elapsed time=254.715 sec.
# 	Calculated response for mode 648/2304. Elapsed time=255.339 sec.
# 	Calculated response for mode 649/2304. Elapsed time=255.964 sec.
# 	Calculated response for mode 650/2304. Elapsed time=256.591 sec.
# 	Calculated response for mode 651/2304. Elapsed time=257.218 sec.
# 	Calculated response for mode 652/2304. Elapsed time=257.844 sec.
# 	Calculated response for mode 653/2304. Elapsed time=258.469 sec.
# 	Calculated response for mode 654/2304. Elapsed time=259.092 sec.
# 	Calculated response for mode 655/2304. Elapsed time=259.719 sec.
# 	Calculated response for mode 656/2304. Elapsed time=260.344 sec.
# 	Calculated response for mode 657/2304. Elapsed time=260.972 sec.
# 	Calculated response for mode 658/2304. Elapsed time=261.598 sec.
# 	Calculated response for mode 659/2304. Elapsed time=262.225 sec.
# 	Calculated response for mode 660/2304. Elapsed time=262.848 sec.
# 	Calculated response for mode 661/2304. Elapsed time=263.471 sec.
# 	Calculated response for mode 662/2304. Elapsed time=264.097 sec.
# 	Calculated response for mode 663/2304. Elapsed time=264.720 sec.
# 	Calculated response for mode 664/2304. Elapsed time=265.348 sec.
# 	Calculated response for mode 665/2304. Elapsed time=265.973 sec.
# 	Calculated response for mode 666/2304. Elapsed time=266.598 sec.
# 	Calculated response for mode 667/2304. Elapsed time=267.224 sec.
# 	Calculated response for mode 668/2304. Elapsed time=267.847 sec.
# 	Calculated response for mode 669/2304. Elapsed time=268.473 sec.
# 	Calculated response for mode 670/2304. Elapsed time=268.473 sec.
# 	Calculated response for mode 671/2304. Elapsed time=268.473 sec.
# 	Calculated response for mode 672/2304. Elapsed time=268.473 sec.
# 	Calculated response for mode 673/2304. Elapsed time=268.473 sec.
# 	Calculated response for mode 674/2304. Elapsed time=268.473 sec.
# 	Calculated response for mode 675/2304. Elapsed time=269.096 sec.
# 	Calculated response for mode 676/2304. Elapsed time=269.722 sec.
# 	Calculated response for mode 677/2304. Elapsed time=270.346 sec.
# 	Calculated response for mode 678/2304. Elapsed time=270.971 sec.
# 	Calculated response for mode 679/2304. Elapsed time=271.599 sec.
# 	Calculated response for mode 680/2304. Elapsed time=272.228 sec.
# 	Calculated response for mode 681/2304. Elapsed time=272.852 sec.
# 	Calculated response for mode 682/2304. Elapsed time=273.475 sec.
# 	Calculated response for mode 683/2304. Elapsed time=274.103 sec.
# 	Calculated response for mode 684/2304. Elapsed time=274.730 sec.
# 	Calculated response for mode 685/2304. Elapsed time=275.354 sec.
# 	Calculated response for mode 686/2304. Elapsed time=275.979 sec.
# 	Calculated response for mode 687/2304. Elapsed time=276.603 sec.
# 	Calculated response for mode 688/2304. Elapsed time=277.229 sec.
# 	Calculated response for mode 689/2304. Elapsed time=277.854 sec.
# 	Calculated response for mode 690/2304. Elapsed time=278.479 sec.
# 	Calculated response for mode 691/2304. Elapsed time=279.103 sec.
# 	Calculated response for mode 692/2304. Elapsed time=279.727 sec.
# 	Calculated response for mode 693/2304. Elapsed time=280.350 sec.
# 	Calculated response for mode 694/2304. Elapsed time=280.974 sec.
# 	Calculated response for mode 695/2304. Elapsed time=281.599 sec.
# 	Calculated response for mode 696/2304. Elapsed time=282.222 sec.
# 	Calculated response for mode 697/2304. Elapsed time=282.846 sec.
# 	Calculated response for mode 698/2304. Elapsed time=283.469 sec.
# 	Calculated response for mode 699/2304. Elapsed time=284.097 sec.
# 	Calculated response for mode 700/2304. Elapsed time=284.839 sec.
# 	Calculated response for mode 701/2304. Elapsed time=285.464 sec.
# 	Calculated response for mode 702/2304. Elapsed time=286.092 sec.
# 	Calculated response for mode 703/2304. Elapsed time=286.716 sec.
# 	Calculated response for mode 704/2304. Elapsed time=287.343 sec.
# 	Calculated response for mode 705/2304. Elapsed time=287.965 sec.
# 	Calculated response for mode 706/2304. Elapsed time=288.590 sec.
# 	Calculated response for mode 707/2304. Elapsed time=289.217 sec.
# 	Calculated response for mode 708/2304. Elapsed time=289.840 sec.
# 	Calculated response for mode 709/2304. Elapsed time=290.466 sec.
# 	Calculated response for mode 710/2304. Elapsed time=291.088 sec.
# 	Calculated response for mode 711/2304. Elapsed time=291.713 sec.
# 	Calculated response for mode 712/2304. Elapsed time=292.339 sec.
# 	Calculated response for mode 713/2304. Elapsed time=292.963 sec.
# 	Calculated response for mode 714/2304. Elapsed time=293.589 sec.
# 	Calculated response for mode 715/2304. Elapsed time=294.217 sec.
# 	Calculated response for mode 716/2304. Elapsed time=294.840 sec.
# 	Calculated response for mode 717/2304. Elapsed time=295.463 sec.
# 	Calculated response for mode 718/2304. Elapsed time=296.089 sec.
# 	Calculated response for mode 719/2304. Elapsed time=296.089 sec.
# 	Calculated response for mode 720/2304. Elapsed time=296.089 sec.
# 	Calculated response for mode 721/2304. Elapsed time=296.089 sec.
# 	Calculated response for mode 722/2304. Elapsed time=296.089 sec.
# 	Calculated response for mode 723/2304. Elapsed time=296.715 sec.
# 	Calculated response for mode 724/2304. Elapsed time=297.340 sec.
# 	Calculated response for mode 725/2304. Elapsed time=297.965 sec.
# 	Calculated response for mode 726/2304. Elapsed time=298.592 sec.
# 	Calculated response for mode 727/2304. Elapsed time=299.219 sec.
# 	Calculated response for mode 728/2304. Elapsed time=299.842 sec.
# 	Calculated response for mode 729/2304. Elapsed time=300.466 sec.
# 	Calculated response for mode 730/2304. Elapsed time=301.090 sec.
# 	Calculated response for mode 731/2304. Elapsed time=301.713 sec.
# 	Calculated response for mode 732/2304. Elapsed time=302.337 sec.
# 	Calculated response for mode 733/2304. Elapsed time=302.962 sec.
# 	Calculated response for mode 734/2304. Elapsed time=303.587 sec.
# ...
# 	Calculated response for mode 2071/2304. Elapsed time=3274.606 sec.
# 	Calculated response for mode 2072/2304. Elapsed time=3274.606 sec.
# 	Calculated response for mode 2073/2304. Elapsed time=3274.606 sec.
# 	Calculated response for mode 2074/2304. Elapsed time=3274.606 sec.
# 	Calculated response for mode 2075/2304. Elapsed time=3275.226 sec.
# 	Calculated response for mode 2076/2304. Elapsed time=3275.846 sec.
# 	Calculated response for mode 2077/2304. Elapsed time=3276.462 sec.
# 	Calculated response for mode 2078/2304. Elapsed time=3277.080 sec.
# 	Calculated response for mode 2079/2304. Elapsed time=3277.696 sec.
# 	Calculated response for mode 2080/2304. Elapsed time=3278.317 sec.
# 	Calculated response for mode 2081/2304. Elapsed time=3278.937 sec.
# 	Calculated response for mode 2082/2304. Elapsed time=3279.553 sec.
# 	Calculated response for mode 2083/2304. Elapsed time=3280.171 sec.
# 	Calculated response for mode 2084/2304. Elapsed time=3280.790 sec.
# 	Calculated response for mode 2085/2304. Elapsed time=3281.409 sec.
# 	Calculated response for mode 2086/2304. Elapsed time=3282.028 sec.
# 	Calculated response for mode 2087/2304. Elapsed time=3282.646 sec.
# 	Calculated response for mode 2088/2304. Elapsed time=3283.266 sec.
# 	Calculated response for mode 2089/2304. Elapsed time=3283.888 sec.
# 	Calculated response for mode 2090/2304. Elapsed time=3284.510 sec.
# 	Calculated response for mode 2091/2304. Elapsed time=3285.128 sec.
# 	Calculated response for mode 2092/2304. Elapsed time=3285.753 sec.
# 	Calculated response for mode 2093/2304. Elapsed time=3286.372 sec.
# 	Calculated response for mode 2094/2304. Elapsed time=3287.107 sec.
# 	Calculated response for mode 2095/2304. Elapsed time=3287.728 sec.
# 	Calculated response for mode 2096/2304. Elapsed time=3288.346 sec.
# 	Calculated response for mode 2097/2304. Elapsed time=3288.965 sec.
# 	Calculated response for mode 2098/2304. Elapsed time=3289.585 sec.
# 	Calculated response for mode 2099/2304. Elapsed time=3290.203 sec.
# 	Calculated response for mode 2100/2304. Elapsed time=3290.825 sec.
# 	Calculated response for mode 2101/2304. Elapsed time=3291.444 sec.
# 	Calculated response for mode 2102/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2103/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2104/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2105/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2106/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2107/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2108/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2109/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2110/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2111/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2112/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2113/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2114/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2115/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2116/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2117/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2118/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2119/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2120/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2121/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2122/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2123/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2124/2304. Elapsed time=3292.062 sec.
# 	Calculated response for mode 2125/2304. Elapsed time=3292.684 sec.
# 	Calculated response for mode 2126/2304. Elapsed time=3293.302 sec.
# 	Calculated response for mode 2127/2304. Elapsed time=3293.919 sec.
# 	Calculated response for mode 2128/2304. Elapsed time=3294.539 sec.
# 	Calculated response for mode 2129/2304. Elapsed time=3295.158 sec.
# 	Calculated response for mode 2130/2304. Elapsed time=3295.779 sec.
# 	Calculated response for mode 2131/2304. Elapsed time=3296.397 sec.
# 	Calculated response for mode 2132/2304. Elapsed time=3297.014 sec.
# 	Calculated response for mode 2133/2304. Elapsed time=3297.635 sec.
# 	Calculated response for mode 2134/2304. Elapsed time=3298.251 sec.
# 	Calculated response for mode 2135/2304. Elapsed time=3298.871 sec.
# 	Calculated response for mode 2136/2304. Elapsed time=3299.494 sec.
# 	Calculated response for mode 2137/2304. Elapsed time=3300.114 sec.
# 	Calculated response for mode 2138/2304. Elapsed time=3300.733 sec.
# 	Calculated response for mode 2139/2304. Elapsed time=3301.358 sec.
# 	Calculated response for mode 2140/2304. Elapsed time=3301.977 sec.
# 	Calculated response for mode 2141/2304. Elapsed time=3302.596 sec.
# 	Calculated response for mode 2142/2304. Elapsed time=3303.215 sec.
# 	Calculated response for mode 2143/2304. Elapsed time=3303.832 sec.
# 	Calculated response for mode 2144/2304. Elapsed time=3304.452 sec.
# 	Calculated response for mode 2145/2304. Elapsed time=3305.069 sec.
# 	Calculated response for mode 2146/2304. Elapsed time=3305.688 sec.
# 	Calculated response for mode 2147/2304. Elapsed time=3306.308 sec.
# 	Calculated response for mode 2148/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2149/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2150/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2151/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2152/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2153/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2154/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2155/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2156/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2157/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2158/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2159/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2160/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2161/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2162/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2163/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2164/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2165/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2166/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2167/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2168/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2169/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2170/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2171/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2172/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2173/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2174/2304. Elapsed time=3306.926 sec.
# 	Calculated response for mode 2175/2304. Elapsed time=3307.543 sec.
# 	Calculated response for mode 2176/2304. Elapsed time=3308.160 sec.
# 	Calculated response for mode 2177/2304. Elapsed time=3308.777 sec.
# 	Calculated response for mode 2178/2304. Elapsed time=3309.398 sec.
# 	Calculated response for mode 2179/2304. Elapsed time=3310.019 sec.
# 	Calculated response for mode 2180/2304. Elapsed time=3310.638 sec.
# 	Calculated response for mode 2181/2304. Elapsed time=3311.261 sec.
# 	Calculated response for mode 2182/2304. Elapsed time=3311.888 sec.
# 	Calculated response for mode 2183/2304. Elapsed time=3312.508 sec.
# 	Calculated response for mode 2184/2304. Elapsed time=3313.129 sec.
# 	Calculated response for mode 2185/2304. Elapsed time=3313.749 sec.
# 	Calculated response for mode 2186/2304. Elapsed time=3314.368 sec.
# 	Calculated response for mode 2187/2304. Elapsed time=3314.987 sec.
# 	Calculated response for mode 2188/2304. Elapsed time=3315.606 sec.
# 	Calculated response for mode 2189/2304. Elapsed time=3316.224 sec.
# 	Calculated response for mode 2190/2304. Elapsed time=3316.843 sec.
# 	Calculated response for mode 2191/2304. Elapsed time=3317.462 sec.
# 	Calculated response for mode 2192/2304. Elapsed time=3318.084 sec.
# 	Calculated response for mode 2193/2304. Elapsed time=3318.704 sec.
# 	Calculated response for mode 2194/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2195/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2196/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2197/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2198/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2199/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2200/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2201/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2202/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2203/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2204/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2205/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2206/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2207/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2208/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2209/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2210/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2211/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2212/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2213/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2214/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2215/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2216/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2217/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2218/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2219/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2220/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2221/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2222/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2223/2304. Elapsed time=3319.323 sec.
# 	Calculated response for mode 2224/2304. Elapsed time=3319.324 sec.
# 	Calculated response for mode 2225/2304. Elapsed time=3319.945 sec.
# 	Calculated response for mode 2226/2304. Elapsed time=3320.563 sec.
# 	Calculated response for mode 2227/2304. Elapsed time=3321.184 sec.
# 	Calculated response for mode 2228/2304. Elapsed time=3321.802 sec.
# 	Calculated response for mode 2229/2304. Elapsed time=3322.465 sec.
# 	Calculated response for mode 2230/2304. Elapsed time=3323.086 sec.
# 	Calculated response for mode 2231/2304. Elapsed time=3323.708 sec.
# 	Calculated response for mode 2232/2304. Elapsed time=3324.326 sec.
# 	Calculated response for mode 2233/2304. Elapsed time=3324.946 sec.
# 	Calculated response for mode 2234/2304. Elapsed time=3325.567 sec.
# 	Calculated response for mode 2235/2304. Elapsed time=3326.186 sec.
# 	Calculated response for mode 2236/2304. Elapsed time=3326.808 sec.
# 	Calculated response for mode 2237/2304. Elapsed time=3327.432 sec.
# 	Calculated response for mode 2238/2304. Elapsed time=3328.054 sec.
# 	Calculated response for mode 2239/2304. Elapsed time=3328.675 sec.
# 	Calculated response for mode 2240/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2241/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2242/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2243/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2244/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2245/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2246/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2247/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2248/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2249/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2250/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2251/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2252/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2253/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2254/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2255/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2256/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2257/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2258/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2259/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2260/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2261/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2262/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2263/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2264/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2265/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2266/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2267/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2268/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2269/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2270/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2271/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2272/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2273/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2274/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2275/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2276/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2277/2304. Elapsed time=3329.295 sec.
# 	Calculated response for mode 2278/2304. Elapsed time=3329.917 sec.
# 	Calculated response for mode 2279/2304. Elapsed time=3330.538 sec.
# 	Calculated response for mode 2280/2304. Elapsed time=3331.158 sec.
# 	Calculated response for mode 2281/2304. Elapsed time=3331.782 sec.
# 	Calculated response for mode 2282/2304. Elapsed time=3332.403 sec.
# 	Calculated response for mode 2283/2304. Elapsed time=3333.022 sec.
# 	Calculated response for mode 2284/2304. Elapsed time=3333.022 sec.
# 	Calculated response for mode 2285/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2286/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2287/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2288/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2289/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2290/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2291/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2292/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2293/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2294/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2295/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2296/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2297/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2298/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2299/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2300/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2301/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2302/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2303/2304. Elapsed time=3333.023 sec.
# 	Calculated response for mode 2304/2304. Elapsed time=3333.023 sec.
# Jacobian built in 3333.034 sec

# %%
jac_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/jacobians')
fname = 'hlc_39_opds_flatmaps_broad'

misc.save_pickle(jac_dir/fname, jac, quiet=False)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/jacobians/hlc_39_opds_flatmaps_broad

# %%
jac_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/jacobians')
fname = 'hlc_39_opds_flatmaps_broad'

jac = misc.load_pickle(jac_dir/fname)
jac.shape
# Out:
# (2616, 2304)

# %% [markdown]
# # Setup regularization scheme

# %%
reload(utils)
reg_fun = utils.beta_reg

reg_conds = np.array([[0, 15, 25, 35, 40, 45, 55, 65, 70, 75, 80, 85, 90, 95, 100, 110, 115, 125],
                      [0, -2, -1, -4, -1, -2, -1, -4, 0, -1, -2, 0, -1, -3, 0, -1, -2, -4]])

# %% [markdown]
# # Run EFC with perfect model

# %%
reload(efc)
reload(utils)
sys.reset_dms()
commands1, efields1 = efc.run_efc_perfect(sys,
                                          wavelengths,
                                         jac,
                                         reg_fun,
                                         reg_conds,
                                         dh_mask, 
                                         Imax_unocc,
                                         iterations=110, 
                                         display_current=True, 
#                                           display_all=True,
                                         plot_sms=True)
# Out:
# EFC completed in 210.686 sec.

# %% [markdown]
# # Generate probes and test PWP

# %%
reload(efc)

Npairs = 2
probe_amp = 0.025*sys.wavelength_c.value
probe_radius = 12
probe_offset = (8,8)

probes = efc.create_sinc_probes(Npairs, Nact, sys.dm_mask, probe_amp, probe_radius, probe_offset, display=True)
# Out:
# Generating probe with amplitude=1.438e-08, radius=12.0, phase=0.000, offset=(8.0,8.0), with discontinuity along x axis.
# Generating probe with amplitude=1.438e-08, radius=12.0, phase=1.571, offset=(8.0,8.0), with discontinuity along y axis.

# %%
def run_pwp(sysi, wavelengths, probes, jacobian, dark_mask, use_noise=False, display=False):
    nmask = dark_mask.sum()
    nwaves = len(wavelengths)
    nprobes = probes.shape[0]
    
    dm_ref = sysi.get_dm1()
    amps = np.linspace(-1, 1, 2) # for generating a negative and positive probe
    
    Ip = []
    In = []
    for i,probe in enumerate(probes):
        for amp in amps:
            sysi.add_dm1(amp*probe)
            
            bb_im = 0
            for wavelength in wavelengths:
                sysi.wavelength = wavelength
                bb_im += sysi.snap()
                
            if amp==-1: 
                In.append(bb_im)
            else: 
                Ip.append(bb_im)
                
            sysi.add_dm1(-amp*probe) # remove probe from DM
            
        if display:
            misc.myimshow3(Ip[i], In[i], Ip[i]-In[i],
                           'Probe {:d} Positive Image'.format(i+1), 'Probe {:d} Negative Image'.format(i+1),
                           'Intensity Difference',
                           lognorm1=True, lognorm2=True, vmin1=Ip[i].max()/1e6, vmin2=In[i].max()/1e6,
                          )
        
#     E_probes = np.zeros((probes.shape[0], 2*nmask))
#     I_diff = np.zeros((probes.shape[0], nmask))
#     for i in range(len(probes)):
#         E_probe_all_waves = jacobian.dot(np.array(probes[i].flatten()))

#         E_probe_waves = []
#         for i in range(len(wavelengths)):
#             E_probe_one_wave = E_probe_all_waves[2*nmask*i:2*nmask*(i+1)]
#             E_probe = E_probe_one_wave[:nmask] + 1j*E_probe_one_wave[nmask:]
            
#             E_probe_waves.append(E_probe)
            
#             E_probes[i, :nmask] += E_probe.real
#             E_probes[i, nmask:] += E_probe.imag

    E_probes = np.zeros((2*nmask*nwaves*nprobes,))
    I_diff = np.zeros((nprobes*nmask,))
    for i in range(nprobes):
        I_diff[i*nmask:(i+1)*nmask] = (Ip[i] - In[i])[dark_mask]
        
        E_probe_all_waves = jacobian.dot(np.array(probes[i].flatten()))
        E_probes[ i*2*nmask*nwaves : (i+1)*2*nmask*nwaves ] = E_probe_all_waves
        
        for j in range(nwaves):
            E_probe_2d = np.zeros((sysi.npsf,sysi.npsf), dtype=np.complex128)
#             np.place(E_probe_2d, mask=dh_mask, 
#                      vals=E_probe_all_waves[j*2*nmask:(j+1)*2*nmask][:nmask] \
#                      + 1j*E_probe_all_waves[j*2*nmask:(j+1)*2*nmask][nmask:])
            np.place(E_probe_2d, mask=dh_mask, 
                     vals=E_probes[i*nmask + j*nmask:i*nmask + j*nmask + 2*nmask][:nmask] \
                     + 1j*E_probes[i*nmask + j*nmask:i*nmask + j*nmask + 2*nmask][nmask:])
            misc.myimshow2(np.abs(E_probe_2d), np.angle(E_probe_2d))
        
    B = np.diag(np.ones((nmask,2*nmask))[0], k=0)[:nmask,:2*nmask] + np.diag(np.ones((nmask,2*nmask))[0], k=nmask)[:nmask,:2*nmask]
    Bfull = np.tile(B, nwaves )
    misc.myimshow(Bfull)
    print('B.shape, Bfull.shape', B.shape, Bfull.shape)
    
    for i in range(nprobes):
        h = 4 * Bfull @ np.diag( E_probes[ i*2*nmask*nwaves : (i+1)*2*nmask*nwaves ] )
        Hinv = h if i==0 else np.vstack((Hinv,h))
    
    print('Hinv.shape', Hinv.shape)
    
    H = np.linalg.inv(Hinv.T@Hinv)@Hinv.T
    print('H.shape', H.shape)
    
    E_est = H.dot(I_diff)
        
    E_est_2d = np.zeros((sysi.npsf,sysi.npsf), dtype=np.complex128)
    np.place(E_est_2d, mask=dark_mask, vals=E_est)
    
    return E_est_2d

# %%
reload(efc)

sys.reset_dms()
E_est = run_pwp(sys, wavelengths, probes, jac, dh_mask, use_noise=False, display=True)
diff = abs(ref_psf*dh_mask - np.abs(E_est)**2)

vmin = ref_psf.max()/1e6
vmax = ref_psf.max()
misc.myimshow3(np.abs(E_est)**2, 
               ref_psf*dh_mask, diff,
               'Estimated Intensity', 'Exact Intensity', 'Intensity Difference',
               lognorm1=True, lognorm2=True, lognorm3=True,
#                vmin1=vmin, vmin2=vmin, vmin3=vmin,
#                vmax1=vmax, vmax2=vmax, vmax3=vmax,
              )

np.mean(diff[dh_mask])
# Out:
# B.shape, Bfull.shape (436, 872) (436, 2616)
# Hinv.shape (872, 2616)
# H.shape (2616, 872)
# 0.002171446605641028
