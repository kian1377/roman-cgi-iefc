# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

from roman_cgi_iefc_2.poppy_roman_cgi_phasec import cgi
from roman_cgi_iefc_2 import iefc_utils as iefcu
from roman_cgi_iefc_2 import iefc_sim_2dm as iefc2

import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
flatmaps_dir = Path.home()/'src/pyfalco/roman/flatmaps'

dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')

hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)
misc.myimshow2(hlci.inwave.intensity.get(), hlci.inwave.phase.get())

npsf = hlci.npsf
Nact = hlci.Nact

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)
ref_psf = hlci.calc_psf()[-1]
misc.myimshow(ref_psf.intensity, lognorm=True)
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 1.192s

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)
ref_psf = hlci.calc_psfs()[0][-1]
misc.myimshow(ref_psf.intensity, lognorm=True)
# Out:
# (calc_psf pid=28879) 2022-04-05 10:48:20,854	ERROR serialization.py:311 -- Out of memory allocating 512 bytes (allocated so far: 0 bytes).
# (calc_psf pid=28879) Traceback (most recent call last):
# (calc_psf pid=28879)   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 309, in deserialize_objects
# (calc_psf pid=28879)     obj = self._deserialize_object(data, metadata, object_ref)
# (calc_psf pid=28879)   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 215, in _deserialize_object
# (calc_psf pid=28879)     return self._deserialize_msgpack_data(data, metadata_fields)
# (calc_psf pid=28879)   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 174, in _deserialize_msgpack_data
# (calc_psf pid=28879)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (calc_psf pid=28879)   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 162, in _deserialize_pickle5_data
# (calc_psf pid=28879)     obj = pickle.loads(in_band, buffers=buffers)
# (calc_psf pid=28879)   File "/home/u21/kianmilani/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/cgi.py", line 20, in <module>
# (calc_psf pid=28879)     from . import hlc, spc, polmap
# (calc_psf pid=28879)   File "/home/u21/kianmilani/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/hlc.py", line 12, in <module>
# (calc_psf pid=28879)     from . import hlc_opd_maps as opds
# (calc_psf pid=28879)   File "/home/u21/kianmilani/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/hlc_opd_maps.py", line 11, in <module>
# (calc_psf pid=28879)     primary_opd = poppy.FITSOpticalElement('Primary OPD', opd=str(opddir/'roman_phasec_PRIMARY_synthetic_phase_error_V1.0.fits'),
# (calc_psf pid=28879)   File "/home/u21/kianmilani/src/poppy/poppy/poppy_core.py", line 2873, in __init__
# (calc_psf pid=28879)     OpticalElement.__init__(self, name=name, **kwargs)
# (calc_psf pid=28879)   File "/home/u21/kianmilani/src/poppy/poppy/poppy_core.py", line 2405, in __init__
# (calc_psf pid=28879)     self.amplitude = np.asarray([1.])
# (calc_psf pid=28879)   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/cupy/_creation/from_data.py", line 76, in asarray
# (calc_psf pid=28879)     return _core.array(a, dtype, False, order)
# (calc_psf pid=28879)   File "cupy/_core/core.pyx", line 2250, in cupy._core.core.array
# (calc_psf pid=28879)   File "cupy/_core/core.pyx", line 2271, in cupy._core.core.array
# (calc_psf pid=28879)   File "cupy/_core/core.pyx", line 2403, in cupy._core.core._array_default
# (calc_psf pid=28879)   File "cupy/_core/core.pyx", line 171, in cupy._core.core.ndarray.__init__
# (calc_psf pid=28879)   File "cupy/cuda/memory.pyx", line 698, in cupy.cuda.memory.alloc
# (calc_psf pid=28879)   File "cupy/cuda/memory.pyx", line 1375, in cupy.cuda.memory.MemoryPool.malloc
# (calc_psf pid=28879)   File "cupy/cuda/memory.pyx", line 1396, in cupy.cuda.memory.MemoryPool.malloc
# (calc_psf pid=28879)   File "cupy/cuda/memory.pyx", line 1076, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc
# (calc_psf pid=28879)   File "cupy/cuda/memory.pyx", line 1097, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc
# (calc_psf pid=28879)   File "cupy/cuda/memory.pyx", line 1335, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc
# (calc_psf pid=28879) cupy.cuda.memory.OutOfMemoryError: Out of memory allocating 512 bytes (allocated so far: 0 bytes).
# ---------------------------------------------------------------------------
# RayTaskError                              Traceback (most recent call last)
# Input In [5], in <module>
#       1 hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)
# ----> 2 ref_psf = hlci.calc_psfs()[0][-1]
#       3 misc.myimshow(ref_psf.intensity, lognorm=True)
#
# File ~/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/cgi.py:274, in CGI_POPPY.calc_psfs(self, wavelengths, dm_commands, offsets)
#     272                 ref = self._calc_psf.remote(self)
#     273             pending_results.append(ref)
# --> 274 wfs = ray.get(pending_results)
#     275 if not self.quiet: print('All PSFs calculated in {:.3f}s'.format(time.time()-start))
#     277 return wfs
#
# File ~/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/worker.py:1763, in get(object_refs, timeout)
#    1761     worker.core_worker.dump_object_store_memory_usage()
#    1762 if isinstance(value, RayTaskError):
# -> 1763     raise value.as_instanceof_cause()
#    1764 else:
#    1765     raise value
#
# RayTaskError: ray::calc_psf() (pid=28879, ip=10.141.18.21)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RaySystemError: System error: Out of memory allocating 512 bytes (allocated so far: 0 bytes).
# traceback: Traceback (most recent call last):
#   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 309, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 215, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 174, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/serialization.py", line 162, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band, buffers=buffers)
#   File "/home/u21/kianmilani/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/cgi.py", line 20, in <module>
#     from . import hlc, spc, polmap
#   File "/home/u21/kianmilani/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/hlc.py", line 12, in <module>
#     from . import hlc_opd_maps as opds
#   File "/home/u21/kianmilani/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/hlc_opd_maps.py", line 11, in <module>
#     primary_opd = poppy.FITSOpticalElement('Primary OPD', opd=str(opddir/'roman_phasec_PRIMARY_synthetic_phase_error_V1.0.fits'),
#   File "/home/u21/kianmilani/src/poppy/poppy/poppy_core.py", line 2873, in __init__
#     OpticalElement.__init__(self, name=name, **kwargs)
#   File "/home/u21/kianmilani/src/poppy/poppy/poppy_core.py", line 2405, in __init__
#     self.amplitude = np.asarray([1.])
#   File "/home/u21/kianmilani/anaconda3/envs/poppy-env/lib/python3.9/site-packages/cupy/_creation/from_data.py", line 76, in asarray
#     return _core.array(a, dtype, False, order)
#   File "cupy/_core/core.pyx", line 2250, in cupy._core.core.array
#   File "cupy/_core/core.pyx", line 2271, in cupy._core.core.array
#   File "cupy/_core/core.pyx", line 2403, in cupy._core.core._array_default
#   File "cupy/_core/core.pyx", line 171, in cupy._core.core.ndarray.__init__
#   File "cupy/cuda/memory.pyx", line 698, in cupy.cuda.memory.alloc
#   File "cupy/cuda/memory.pyx", line 1375, in cupy.cuda.memory.MemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1396, in cupy.cuda.memory.MemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1076, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc
#   File "cupy/cuda/memory.pyx", line 1097, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc
#   File "cupy/cuda/memory.pyx", line 1335, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc
# cupy.cuda.memory.OutOfMemoryError: Out of memory allocating 512 bytes (allocated so far: 0 bytes).

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlci.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 0
iwa = 3
owa = 9
direction = ''
# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : direction
}
dh_mask = iefcu.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
    'direction' : direction
}
control_mask = iefcu.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.99
weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask

misc.myimshow2(dh_mask.reshape(npsf,npsf), control_mask.reshape(npsf,npsf), 
               pxscl1=hlci.psf_pixelscale_lamD, pxscl2=hlci.psf_pixelscale_lamD)
misc.myimshow(weights.reshape(npsf,npsf), lognorm=True, pxscl=hlci.psf_pixelscale_lamD)

# %% [markdown]
# # Create probe and fourier modes

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)

probe_modes = iefcu.create_probe_poke_modes(Nact, 3*Nact//4, Nact//2, 3*Nact//4-1, Nact//2)
calibration_modes, fx, fy = iefcu.create_fourier_modes(xfp, control_mask.reshape((npsf,npsf)), Nact, circular_mask=False)

calibration_amplitude = 0.006 * hlci.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * hlci.wavelength_c.to(u.m).value
nmodes = calibration_modes.shape[0]

print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow2((probe_modes[0] - probe_modes[1]).reshape((Nact,Nact)), calibration_modes[0].reshape(Nact,Nact))

isinstance(probe_modes, np.ndarray), isinstance(calibration_modes, np.ndarray)
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 624
# (True, True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
fname = 'annular_Nopds_polaxis{:d}_iwa{:.1f}_owa{:.1f}'.format(hlci.polaxis, 
                                                               dh_params['inner_radius'], 
                                                               dh_params['outer_radius'])
fname = 'dshaped_2dms_Nopds_polaxis{:d}_iwa{:.1f}_owa{:.1f}'.format(hlci.polaxis, 
                                                                    dh_params['inner_radius'], 
                                                                    dh_params['outer_radius'])
print(fname)
# Out:
# dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0

# %%
hlci = reset(quiet=True)

response_cube, calibration_cube = iefc2.calibrate(hlci, probe_amplitude, probe_modes, 
                                                  calibration_amplitude, calibration_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 92 in 5.239s
# 	Calibrated mode 2 / 92 in 8.966s
# 	Calibrated mode 3 / 92 in 12.669s
# 	Calibrated mode 4 / 92 in 16.378s
# 	Calibrated mode 5 / 92 in 20.062s
# 	Calibrated mode 6 / 92 in 23.782s
# 	Calibrated mode 7 / 92 in 27.494s
# 	Calibrated mode 8 / 92 in 31.203s
# 	Calibrated mode 9 / 92 in 34.923s
# 	Calibrated mode 10 / 92 in 38.632s
# 	Calibrated mode 11 / 92 in 42.324s
# 	Calibrated mode 12 / 92 in 46.032s
# 	Calibrated mode 13 / 92 in 49.758s
# 	Calibrated mode 14 / 92 in 53.484s
# 	Calibrated mode 15 / 92 in 57.192s
# 	Calibrated mode 16 / 92 in 60.906s
# 	Calibrated mode 17 / 92 in 64.647s
# 	Calibrated mode 18 / 92 in 68.360s
# 	Calibrated mode 19 / 92 in 72.053s
# 	Calibrated mode 20 / 92 in 75.796s
# 	Calibrated mode 21 / 92 in 79.537s
# 	Calibrated mode 22 / 92 in 83.283s
# 	Calibrated mode 23 / 92 in 87.043s
# 	Calibrated mode 24 / 92 in 90.833s
# 	Calibrated mode 25 / 92 in 94.589s
# 	Calibrated mode 26 / 92 in 98.347s
# 	Calibrated mode 27 / 92 in 102.108s
# 	Calibrated mode 28 / 92 in 105.875s
# 	Calibrated mode 29 / 92 in 109.636s
# 	Calibrated mode 30 / 92 in 113.383s
# 	Calibrated mode 31 / 92 in 117.124s
# 	Calibrated mode 32 / 92 in 120.892s
# 	Calibrated mode 33 / 92 in 124.672s
# 	Calibrated mode 34 / 92 in 128.424s
# 	Calibrated mode 35 / 92 in 132.174s
# 	Calibrated mode 36 / 92 in 135.926s
# 	Calibrated mode 37 / 92 in 139.669s
# 	Calibrated mode 38 / 92 in 143.425s
# 	Calibrated mode 39 / 92 in 147.207s
# 	Calibrated mode 40 / 92 in 150.977s
# 	Calibrated mode 41 / 92 in 154.744s
# 	Calibrated mode 42 / 92 in 158.496s
# 	Calibrated mode 43 / 92 in 162.245s
# 	Calibrated mode 44 / 92 in 165.999s
# 	Calibrated mode 45 / 92 in 169.753s
# 	Calibrated mode 46 / 92 in 173.496s
# 	Calibrated mode 47 / 92 in 177.247s
# 	Calibrated mode 48 / 92 in 181.119s
# 	Calibrated mode 49 / 92 in 184.872s
# 	Calibrated mode 50 / 92 in 188.573s
# 	Calibrated mode 51 / 92 in 192.266s
# 	Calibrated mode 52 / 92 in 195.991s
# 	Calibrated mode 53 / 92 in 199.726s
# 	Calibrated mode 54 / 92 in 203.465s
# 	Calibrated mode 55 / 92 in 207.257s
# 	Calibrated mode 56 / 92 in 211.048s
# 	Calibrated mode 57 / 92 in 214.836s
# 	Calibrated mode 58 / 92 in 218.643s
# 	Calibrated mode 59 / 92 in 222.452s
# 	Calibrated mode 60 / 92 in 226.284s
# 	Calibrated mode 61 / 92 in 230.118s
# 	Calibrated mode 62 / 92 in 233.898s
# 	Calibrated mode 63 / 92 in 237.667s
# 	Calibrated mode 64 / 92 in 241.411s
# 	Calibrated mode 65 / 92 in 245.161s
# 	Calibrated mode 66 / 92 in 248.931s
# 	Calibrated mode 67 / 92 in 252.670s
# 	Calibrated mode 68 / 92 in 256.417s
# 	Calibrated mode 69 / 92 in 260.177s
# 	Calibrated mode 70 / 92 in 263.945s
# 	Calibrated mode 71 / 92 in 267.704s
# 	Calibrated mode 72 / 92 in 271.411s
# 	Calibrated mode 73 / 92 in 275.160s
# 	Calibrated mode 74 / 92 in 278.910s
# 	Calibrated mode 75 / 92 in 282.663s
# 	Calibrated mode 76 / 92 in 286.429s
# 	Calibrated mode 77 / 92 in 290.186s
# 	Calibrated mode 78 / 92 in 293.921s
# 	Calibrated mode 79 / 92 in 297.703s
# 	Calibrated mode 80 / 92 in 301.513s
# 	Calibrated mode 81 / 92 in 305.299s
# 	Calibrated mode 82 / 92 in 309.143s
# 	Calibrated mode 83 / 92 in 312.994s
# 	Calibrated mode 84 / 92 in 316.827s
# 	Calibrated mode 85 / 92 in 320.665s
# 	Calibrated mode 86 / 92 in 324.471s
# 	Calibrated mode 87 / 92 in 328.294s
# 	Calibrated mode 88 / 92 in 332.098s
# 	Calibrated mode 89 / 92 in 335.900s
# 	Calibrated mode 90 / 92 in 339.735s
# 	Calibrated mode 91 / 92 in 343.540s
# 	Calibrated mode 92 / 92 in 347.352s
# Calibration complete.

# %%
hlci = reset(quiet=True)
iefcu.save_pickle(data_dir/'response-data'/fname, response_cube)
iefcu.save_pickle(data_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0

# %%
response_cube = iefcu.load_pickle(data_dir/'response-data'/fname)
calibration_cube = iefcu.load_pickle(data_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
hlci = reset()

# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

rcond1 = 0.01
rcond2 = 0.01
control_matrix_1 = iefc2.construct_control_matrix(response_cube, cp.array(weights), 
                                                  rcond1=rcond1, rcond2=rcond2, WLS=True,) 
control_matrix_2 = iefc2.construct_control_matrix(response_cube, cp.array(weights), 
                                                  rcond1=rcond1, rcond2=rcond2, WLS=False,)
# Out:
# Using Weighted Least Squares
# Using Tikhonov Inverse

# %%
control_matrix_1.shape, control_matrix_2.shape, type(control_matrix_1), type(control_matrix_2)
# Out:
# ((184, 416), (184, 416), cupy._core.core.ndarray, cupy._core.core.ndarray)

# %% [markdown]
# # Run IEFC

# %%
hlci = reset(quiet=True)

images, dm1_commands, dm2_commands = iefc2.run(hlci, control_matrix_1, probe_modes, probe_amplitude, 
                                               calibration_modes, cp.array(weights), 
                                               num_iterations=10, gain=-0.5, leakage=0.0,
                                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 10
# 	Closed-loop iteration 2 / 10
# 	Closed-loop iteration 3 / 10
# 	Closed-loop iteration 4 / 10
# 	Closed-loop iteration 5 / 10
# 	Closed-loop iteration 6 / 10
# 	Closed-loop iteration 7 / 10
# 	Closed-loop iteration 8 / 10
# 	Closed-loop iteration 9 / 10
# 	Closed-loop iteration 10 / 10
# I-EFC loop completed in 22.402s.

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/(fname+'_dm1'), dm1_commands)
iefcu.save_pickle(data_dir/'dm-results'/(fname+'_dm2'), dm2_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0_dm1
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0_dm2

# %%
for i in range(len(images)):
#     patches = iefcu.create_circ_patches(dh_params)
    misc.myimshow(dm1_commands[i]-dm2_commands[i], 'Iteration {:d}: DM Difference'.format(i+1))

# %%
for i in range(len(images)):
    patches = iefcu.create_circ_patches(dh_params)
    misc.myimshow2(dm1_commands[i], dm2_commands[i], 
                   'Iteration {:d}: DM1 Actuators'.format(i+1), 'DM2 Actuators',)
    misc.myimshow(images[i].intensity, 'PSF', lognorm=True, pxscl=hlci.psf_pixelscale_lamD, patches=patches)
