# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

from roman_cgi_iefc_2.poppy_roman_cgi_phasec import cgi
from roman_cgi_iefc_2 import iefc_utils as iefcu
from roman_cgi_iefc_2 import iefc_sim_2dm_3probes as iefc2
reload(cgi)
reload(iefcu)
reload(iefc2)


import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
flatmaps_dir = Path.home()/'src/pyfalco/roman/flatmaps'

dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')

hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)
misc.myimshow2(hlci.inwave.intensity.get(), hlci.inwave.phase.get())

npsf = hlci.npsf
Nact = hlci.Nact

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=True, quiet=False, ngpus=1/4)
ref_psf = hlci.calc_psf()[-1]
misc.myimshow(ref_psf.intensity, lognorm=True)
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 1.444s

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=True, quiet=False, ngpus=1)
ref_psf = hlci.calc_psfs()[0][-1]
misc.myimshow(ref_psf.intensity, lognorm=True)
# Out:
# (calc_psf pid=6518) Propagating wavelength 575.000 nm.
# (calc_psf pid=6518) PSF calculated in 0.426s
# All PSFs calculated in 0.457s

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=True, quiet=False, ngpus=1/4)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlci.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1
iwa = 3
owa = 6
direction = ''
# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : direction
}
dh_mask = iefcu.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
    'direction' : direction
}
control_mask = iefcu.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.99
weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask

misc.myimshow2(dh_mask.reshape(npsf,npsf), control_mask.reshape(npsf,npsf), 
               pxscl1=hlci.psf_pixelscale_lamD, pxscl2=hlci.psf_pixelscale_lamD)
misc.myimshow(weights.reshape(npsf,npsf), lognorm=True, pxscl=hlci.psf_pixelscale_lamD)

# %%
control_mask.sum()*3
# Out:
# 1812

# %% [markdown]
# # Create probe and fourier modes

# %%
calibration_modes = calibration_modes[:calibration_modes.shape[0]//2, :]
calibration_modes.shape
# Out:
# (136, 2304)

# %%
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=False, ngpus=1/4)

probe_modes_1 = iefcu.create_probe_poke_modes(Nact, 1*Nact//4, 2*Nact//3, 3*Nact//4-1, 2*Nact//3)
probe_modes_2 = iefcu.create_probe_poke_modes(Nact, 1*Nact//2, 1*Nact//4, 3*Nact//4-1, Nact//2)
probe_modes = np.vstack((probe_modes_1, probe_modes_2[0]))
calibration_modes, fx, fy = iefcu.create_fourier_modes(xfp, control_mask.reshape((npsf,npsf)), Nact, circular_mask=False)
calibration_modes = calibration_modes[:calibration_modes.shape[0]//2-1, :]

calibration_amplitude = 0.006 * hlci.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * hlci.wavelength_c.to(u.m).value
nmodes = calibration_modes.shape[0]

print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow2((probe_modes[0] + probe_modes[1] + probe_modes[2]).reshape((Nact,Nact)), 
               calibration_modes[0].reshape(Nact,Nact))

isinstance(probe_modes, np.ndarray), isinstance(calibration_modes, np.ndarray)
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 135
# (True, True)

# %%
mode_1 = calibration_modes[0].reshape(Nact,Nact)
mode_2 = calibration_modes[134].reshape(Nact,Nact)
misc.myimshow2(mode_1, mode_2)
misc.myimshow(mode_1-mode_2)

# %%
reload(iefc2)
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=True, quiet=True, ngpus=1/6)
diff_images, images = iefc2.take_measurement(hlci, probe_modes, probe_amplitude, DM=1, return_all=True, pca_modes=None)

diff_images.shape, images.shape
# Out:
# ((3, 4096), (6, 4096))

# %%
misc.myimshow2(diff_images[0].reshape(npsf,npsf), diff_images[1].reshape(npsf,npsf))
misc.myimshow(diff_images[2].reshape(npsf,npsf))

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
fname = 'annular_Nopds_3probes_polaxis{:d}_iwa{:.1f}_owa{:.1f}'.format(hlci.polaxis, 
                                                               dh_params['inner_radius'], 
                                                               dh_params['outer_radius'])
# fname = 'dshaped_2dms_3probes_Nopds_polaxis{:d}_iwa{:.1f}_owa{:.1f}'.format(hlci.polaxis, 
#                                                                     dh_params['inner_radius'], 
#                                                                     dh_params['outer_radius'])
print(fname)
# Out:
# annular_Nopds_3probes_polaxis0_iwa3.0_owa6.0

# %%
reload(iefc2)
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=False, quiet=True, ngpus=1/6)

response_cube, calibration_cube = iefc2.calibrate(hlci, probe_amplitude, probe_modes, 
                                                  calibration_amplitude, calibration_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 135 in 5.286s
# 	Calibrated mode 2 / 135 in 10.505s
# 	Calibrated mode 3 / 135 in 15.702s
# 	Calibrated mode 4 / 135 in 20.956s
# 	Calibrated mode 5 / 135 in 26.192s
# 	Calibrated mode 6 / 135 in 31.430s
# 	Calibrated mode 7 / 135 in 36.654s
# 	Calibrated mode 8 / 135 in 41.877s
# 	Calibrated mode 9 / 135 in 47.113s
# 	Calibrated mode 10 / 135 in 52.382s
# 	Calibrated mode 11 / 135 in 57.760s
# 	Calibrated mode 12 / 135 in 63.114s
# 	Calibrated mode 13 / 135 in 68.460s
# 	Calibrated mode 14 / 135 in 73.734s
# 	Calibrated mode 15 / 135 in 78.972s
# 	Calibrated mode 16 / 135 in 84.199s
# 	Calibrated mode 17 / 135 in 89.417s
# 	Calibrated mode 18 / 135 in 94.659s
# 	Calibrated mode 19 / 135 in 99.878s
# 	Calibrated mode 20 / 135 in 105.101s
# 	Calibrated mode 21 / 135 in 110.322s
# 	Calibrated mode 22 / 135 in 115.552s
# 	Calibrated mode 23 / 135 in 120.775s
# 	Calibrated mode 24 / 135 in 126.005s
# 	Calibrated mode 25 / 135 in 131.240s
# 	Calibrated mode 26 / 135 in 136.467s
# 	Calibrated mode 27 / 135 in 141.730s
# 	Calibrated mode 28 / 135 in 146.953s
# 	Calibrated mode 29 / 135 in 152.153s
# 	Calibrated mode 30 / 135 in 157.404s
# 	Calibrated mode 31 / 135 in 162.635s
# 	Calibrated mode 32 / 135 in 167.872s
# 	Calibrated mode 33 / 135 in 173.113s
# 	Calibrated mode 34 / 135 in 178.355s
# 	Calibrated mode 35 / 135 in 183.565s
# 	Calibrated mode 36 / 135 in 188.814s
# 	Calibrated mode 37 / 135 in 194.062s
# 	Calibrated mode 38 / 135 in 199.303s
# 	Calibrated mode 39 / 135 in 204.565s
# 	Calibrated mode 40 / 135 in 209.796s
# 	Calibrated mode 41 / 135 in 215.001s
# 	Calibrated mode 42 / 135 in 220.254s
# 	Calibrated mode 43 / 135 in 225.504s
# 	Calibrated mode 44 / 135 in 230.725s
# 	Calibrated mode 45 / 135 in 235.961s
# 	Calibrated mode 46 / 135 in 241.206s
# 	Calibrated mode 47 / 135 in 246.424s
# 	Calibrated mode 48 / 135 in 251.661s
# 	Calibrated mode 49 / 135 in 256.891s
# 	Calibrated mode 118 / 135 in 618.953s
# 	Calibrated mode 119 / 135 in 624.212s
# 	Calibrated mode 120 / 135 in 629.435s
# 	Calibrated mode 121 / 135 in 634.688s
# 	Calibrated mode 122 / 135 in 640.063s
# 	Calibrated mode 123 / 135 in 645.488s
# 	Calibrated mode 124 / 135 in 650.908s
# 	Calibrated mode 125 / 135 in 656.277s
# 	Calibrated mode 126 / 135 in 661.719s
# 	Calibrated mode 127 / 135 in 667.118s
# 	Calibrated mode 128 / 135 in 672.590s
# 	Calibrated mode 129 / 135 in 677.984s
# 	Calibrated mode 130 / 135 in 683.410s
# 	Calibrated mode 131 / 135 in 688.841s
# 	Calibrated mode 132 / 135 in 694.289s
# 	Calibrated mode 133 / 135 in 699.761s
# 	Calibrated mode 134 / 135 in 705.163s
# 	Calibrated mode 135 / 135 in 710.598s
# Calibration complete.

# %%
iefcu.save_pickle(data_dir/'response-data'/fname, response_cube)
iefcu.save_pickle(data_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/annular_Nopds_3probes_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/annular_Nopds_3probes_polaxis0_iwa3.0_owa6.0

# %%
response_cube = iefcu.load_pickle(data_dir/'response-data'/fname)
calibration_cube = iefcu.load_pickle(data_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

np.min(response_cube)
# Out:
# array(-1.05163239e+10)

# %%
calibration_modes.shape, response_cube.shape, control_matrix_1.shape
# Out:
# ((128, 2304), (256, 3, 4096), (256, 798))

# %% [markdown]
# # Create control matrix

# %%
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

rcond1 = 0.01
rcond2 = 0.01
control_matrix_1 = iefc2.construct_control_matrix(response_cube, cp.array(weights), 
                                                  rcond1=rcond1, rcond2=rcond2, WLS=True,) 
control_matrix_2 = iefc2.construct_control_matrix(response_cube, cp.array(weights), 
                                                  rcond1=rcond1, rcond2=rcond2, WLS=False,) 

control_matrix_1.shape, control_matrix_2.shape, type(control_matrix_1), type(control_matrix_2)
# Out:
# Using Weighted Least Squares
# Using Tikhonov Inverse
# ((270, 1812), (270, 1812), cupy._core.core.ndarray, cupy._core.core.ndarray)

# %% [markdown]
# # Run IEFC

# %%
reload(iefc2)
hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=True, quiet=True, ngpus=1/6)

images, dm1_commands, dm2_commands = iefc2.run(hlci, control_matrix_2, probe_modes, probe_amplitude, 
                                               calibration_modes, cp.array(weights), 
                                               num_iterations=5, gain=-0.5, leakage=0.0,
                                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 5
# 	Closed-loop iteration 2 / 5
# 	Closed-loop iteration 3 / 5
# 	Closed-loop iteration 4 / 5
# 	Closed-loop iteration 5 / 5
# I-EFC loop completed in 13.193s.

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/(fname+'_dm1'), dm1_commands)
iefcu.save_pickle(data_dir/'dm-results'/(fname+'_dm2'), dm2_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0_dm1
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_2dms_Nopds_polaxis0_iwa3.0_owa6.0_dm2

# %%
for i in range(len(images)):
#     patches = iefcu.create_circ_patches(dh_params)
    misc.myimshow(dm1_commands[i]-dm2_commands[i], 'Iteration {:d}: DM Difference'.format(i+1))

# %%
for i in range(len(images)):
    patches = iefcu.create_circ_patches(dh_params)
    misc.myimshow2(dm1_commands[i], dm2_commands[i], 
                   'Iteration {:d}: DM1 Actuators'.format(i+1), 'DM2 Actuators',)
    misc.myimshow(images[i].intensity, 'PSF', lognorm=True, pxscl=hlci.psf_pixelscale_lamD, patches=patches)
