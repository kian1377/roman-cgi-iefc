# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import warnings
warnings.filterwarnings("ignore")

import poppy

import hcipy as hci

from wfsc import iefc_1dm, iefc_2dm
from wfsc import utils

import misc_funs as misc

from matplotlib.colors import ListedColormap
#Blue to Red Color scale for S1 and S2
colmap = np.zeros((255,3));
# Red
colmap[126:183,0]= np.linspace(0,1,57);
colmap[183:255,0]= 1;
# Green
colmap[0:96,1] = np.linspace(1,0,96);
colmap[158:255,1]= np.linspace(0,1,97);
# Blue
colmap[0:71,2] = 1;
colmap[71:128,2]= np.linspace(1,0,57);
colmap2 = colmap[128:,:]
colmap = ListedColormap(colmap)

# %%
display(c.z_talbot)
# Out:
# <Quantity 90.46956522 m>

# %%
class CORO():

    def __init__(self, 
                 wavelength=None, 
                ):
        
        self.wavelength_c = 575e-9*u.m
        self.wavelength = self.wavelength_c if wavelength is None else wavelength
        self.f = 500*u.mm
        
        self.dm_diam = 10.2*u.mm
        self.dm1_dm2 = 200e-3*u.m
        
        self.FN = (self.dm_diam**2/self.dm1_dm2/self.wavelength).decompose()
        self.z_talbot = (self.dm_diam**2/2/self.wavelength).decompose()
        
        # define the grids
        self.npix = 256
        self.oversample = 2
        self.spatial_resolution = self.f.to_value(u.m) * self.wavelength.to_value(u.m) / self.dm_diam.to_value(u.m)
        self.npsf = 64
        self.psf_pixelscale_lamD = self.spatial_resolution/self.f.to_value(u.m)*(self.dm_diam/self.wavelength_c).decompose()/2
        
        self.pupil_grid = hci.make_pupil_grid(self.npix*self.oversample, self.dm_diam.to_value(u.m) * self.oversample)
        self.focal_grid = hci.make_focal_grid(2, 16, spatial_resolution=self.spatial_resolution)
        self.prop = hci.FraunhoferPropagator(self.pupil_grid, self.focal_grid, self.f.to_value(u.m))

        self.aperture = hci.Field(np.exp(-(self.pupil_grid.as_('polar').r / (0.5 * self.dm_diam.to_value(u.m)))**30), self.pupil_grid)
        
        # define the DMs
        self.Nact = 34
        actuator_spacing = 1.00 / self.Nact * self.dm_diam.to_value(u.m)
        
#         influence_functions = hci.make_xinetics_influence_functions(self.pupil_grid, self.Nact, actuator_spacing)
        influence_functions = hci.make_gaussian_influence_functions(self.pupil_grid, self.Nact, actuator_spacing)
        
        self.DM1 = hci.DeformableMirror(influence_functions)
        self.DM2 = hci.DeformableMirror(influence_functions)

        self.prop_between_dms = hci.FresnelPropagator(self.pupil_grid, self.dm1_dm2.to_value(u.m))
        
        self.dm_mask = np.ones((self.Nact,self.Nact), dtype=bool)
        xx = (np.linspace(0, self.Nact-1, self.Nact) - self.Nact/2 + 1/2) * actuator_spacing*2
        x,y = np.meshgrid(xx,xx)
        r = np.sqrt(x**2 + y**2)
        self.dm_mask[r>0.0105] = 0 # had to set the threshold to 10.5 instead of 10.2 to include edge actuators
        
#         self.dm_zernikes = poppy.zernike.arbitrary_basis(self.dm_mask, nterms=15, outside=0)
        self.dm_zernikes = poppy.zernike.arbitrary_basis(cp.array(self.dm_mask), nterms=15, outside=0).get()
        
        # make the aberrations of the system (make sure to remove tip-tilt)
        aberration_ptv = 0.02 * self.wavelength.to_value(u.m)
        tip_tilt = hci.make_zernike_basis(3, self.dm_diam.to_value(u.m), self.pupil_grid, starting_mode=2)
        wfe = hci.SurfaceAberration(self.pupil_grid, aberration_ptv, self.dm_diam.to_value(u.m), remove_modes=tip_tilt, exponent=-3)
        aberration_distance_m = 100e-3
        self.wfe_at_distance = hci.SurfaceAberrationAtDistance(wfe, aberration_distance_m)
        
        # make the coronagraph model
        self.coronagraph = hci.PerfectCoronagraph(self.aperture, order=6)
        
        
    def set_dm1(self, command):
        self.DM1.actuators = command.ravel()
        
    def set_dm2(self, command):
        self.DM2.actuators = command.ravel()
        
    def add_dm1(self, command):
        self.DM1.actuators += command.ravel()
        
    def add_dm2(self, command):
        self.DM2.actuators += command.ravel()
        
    def get_dm1(self):
        return self.DM1.actuators.reshape(self.Nact, self.Nact)
        
    def get_dm2(self):
        return self.DM2.actuators.reshape(self.Nact, self.Nact)
    
    def reset_dms(self):
        self.DM1.actuators = np.zeros((self.Nact, self.Nact)).ravel()
        self.DM2.actuators = np.zeros((self.Nact, self.Nact)).ravel()
    
    def show_dms(self):
        misc.imshow2(self.DM1.actuators.reshape(c.Nact, c.Nact),
                     self.DM2.actuators.reshape(c.Nact, c.Nact))
        
    def calc_psf(self):
        wf = hci.Wavefront(self.aperture, self.wavelength.to_value(u.m))
        wf = self.wfe_at_distance(wf) # apply aberrations to wavefront
        wf = self.prop_between_dms.backward(self.DM2(self.prop_between_dms.forward(self.DM1(wf)))) # apply DMs
        wf = self.prop(self.coronagraph(wf))
        psf_wf = wf.real.shaped + 1j*wf.imag.shaped

        return np.array(psf_wf)

    def snap(self):
        wf = hci.Wavefront(self.aperture, self.wavelength.to_value(u.m))
        wf = self.wfe_at_distance(wf) # apply aberrations to wavefront
        wf = self.prop_between_dms.backward(self.DM2(self.prop_between_dms.forward(self.DM1(wf)))) # apply DMs
        im = self.prop(self.coronagraph(wf))

        return np.array(im.intensity.shaped)
    
c = CORO()

# %%
c.reset_dms()
ref_im = c.snap()

misc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD)

# %% [markdown]
# # define the dark hole region

# %%
reload(utils)

xfp = (np.linspace(-c.npsf/2, c.npsf/2-1, c.npsf) + 1/2)*c.psf_pixelscale_lamD
fpx,fpy = np.meshgrid(xfp,xfp)
fpr = np.sqrt(fpx**2 + fpy**2)
    
iwa = 3
owa = 9
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge_position' : 0,
        'rotation':0,
        'full':True,
    }
roi1 = utils.create_annular_focal_plane_mask(fpx, fpy, roi_params)

iwa = (3-1)
owa = (9+0.5)
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge_position' : 0,
        'rotation':0,
        'full':True,
    }
roi2 = utils.create_annular_focal_plane_mask(fpx, fpy, roi_params)

misc.imshow2(roi1, roi2)
weight_map = roi1 + 0.2*(roi2 * ~roi1)
control_mask = weight_map>0
misc.imshow2(weight_map, control_mask)

probe_amp = 3e-8
calib_amp = 5e-9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 16>()
#       8 owa = 9
#       9 roi_params = {
#      10         'inner_radius' : iwa,
#      11         'outer_radius' : owa,
#    (...)
#      14         'full':True,
#      15     }
# ---> 16 roi1 = utils.create_annular_focal_plane_mask(fpx, fpy, roi_params)
#      18 iwa = (3-1)
#      19 owa = (9+0.5)
#
# File ~/Documents/roman-cgi-iefc/wfsc/utils.py:76, in create_annular_focal_plane_mask(x, y, params)
#      75 def create_annular_focal_plane_mask(x, y, params):
# ---> 76     r = xp.hypot(x, y)
#      77     mask = (r < params['outer_radius']) * (r > params['inner_radius'])
#      78     if 'edge_position' in params: mask *= (x > params['edge_position'])
#
# File cupy/_core/_kernel.pyx:1218, in cupy._core._kernel.ufunc.__call__()
#
# File cupy/_core/_kernel.pyx:138, in cupy._core._kernel._preprocess_args()
#
# File cupy/_core/_kernel.pyx:124, in cupy._core._kernel._preprocess_arg()
#
# TypeError: Unsupported type <class 'astropy.units.quantity.Quantity'>

# %%
reload(utils)
calib_modes, fs = utils.select_fourier_modes(c, control_mask*(fpx>0), fourier_sampling=0.9) 
nmodes = calib_modes.shape[0]
display(calib_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
misc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD, patches=patches)
# Out:
# (356, 1156)
# (178, 2)

# %%
reload(utils)
probe_modes = utils.create_probe_poke_modes(c.Nact, 
                                            xinds=[c.Nact//4, c.Nact//4+1], 
                                            yinds=[c.Nact//4, c.Nact//4], 
                                            display=True)

# %%
reload(iefc)

probe_amp = 3e-8
calib_amp = 5e-9

c.reset_dms()
differential_images, single_images = iefc.take_measurement(c, 
                                                           probe_modes, probe_amp, 
                                                           return_all=True)
ims = differential_images.reshape(2, c.npsf, c.npsf)
misc.imshow3(ims[0], ims[1], ims[0]-ims[1], wspace=0.35)

# %%
reload(iefc)
c.reset_dms()
response_cube, calibration_cube = iefc.calibrate(c, 
                                                 probe_amp, probe_modes, 
                                                 calib_amp, calib_modes)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 356 in 2.715s
# 	Calibrated mode 2 / 356 in 5.433s
# 	Calibrated mode 3 / 356 in 8.147s
# 	Calibrated mode 4 / 356 in 10.863s
# 	Calibrated mode 5 / 356 in 13.571s
# 	Calibrated mode 6 / 356 in 16.284s
# 	Calibrated mode 7 / 356 in 18.992s
# 	Calibrated mode 8 / 356 in 21.700s
# 	Calibrated mode 9 / 356 in 24.407s
# 	Calibrated mode 10 / 356 in 27.115s
# 	Calibrated mode 11 / 356 in 29.826s
# 	Calibrated mode 12 / 356 in 32.526s
# 	Calibrated mode 13 / 356 in 35.236s
# 	Calibrated mode 14 / 356 in 37.945s
# 	Calibrated mode 15 / 356 in 40.651s
# 	Calibrated mode 16 / 356 in 43.360s
# 	Calibrated mode 17 / 356 in 46.069s
# 	Calibrated mode 18 / 356 in 48.773s
# 	Calibrated mode 19 / 356 in 51.482s
# 	Calibrated mode 20 / 356 in 54.195s
# 	Calibrated mode 21 / 356 in 56.898s
# 	Calibrated mode 22 / 356 in 59.605s
# 	Calibrated mode 23 / 356 in 62.305s
# 	Calibrated mode 24 / 356 in 65.012s
# 	Calibrated mode 25 / 356 in 67.720s
# 	Calibrated mode 26 / 356 in 70.427s
# 	Calibrated mode 27 / 356 in 73.118s
# 	Calibrated mode 28 / 356 in 75.820s
# 	Calibrated mode 29 / 356 in 78.528s
# 	Calibrated mode 30 / 356 in 81.233s
# 	Calibrated mode 31 / 356 in 83.938s
# 	Calibrated mode 32 / 356 in 86.641s
# 	Calibrated mode 33 / 356 in 89.346s
# 	Calibrated mode 34 / 356 in 92.047s
# 	Calibrated mode 35 / 356 in 94.747s
# 	Calibrated mode 36 / 356 in 97.448s
# 	Calibrated mode 37 / 356 in 100.148s
# 	Calibrated mode 38 / 356 in 102.850s
# 	Calibrated mode 39 / 356 in 105.559s
# 	Calibrated mode 40 / 356 in 108.264s
# 	Calibrated mode 41 / 356 in 110.968s
# 	Calibrated mode 42 / 356 in 113.672s
# 	Calibrated mode 43 / 356 in 116.367s
# 	Calibrated mode 44 / 356 in 119.072s
# 	Calibrated mode 45 / 356 in 121.772s
# 	Calibrated mode 46 / 356 in 124.473s
# 	Calibrated mode 47 / 356 in 127.172s
# 	Calibrated mode 48 / 356 in 129.872s
# 	Calibrated mode 49 / 356 in 132.582s
# 	Calibrated mode 50 / 356 in 135.288s
# 	Calibrated mode 51 / 356 in 137.980s
# 	Calibrated mode 52 / 356 in 140.681s
# 	Calibrated mode 53 / 356 in 143.382s
# 	Calibrated mode 54 / 356 in 146.082s
# 	Calibrated mode 55 / 356 in 148.788s
# 	Calibrated mode 56 / 356 in 151.497s
# 	Calibrated mode 57 / 356 in 154.205s
# 	Calibrated mode 58 / 356 in 156.909s
# 	Calibrated mode 59 / 356 in 159.613s
# 	Calibrated mode 60 / 356 in 162.314s
# 	Calibrated mode 61 / 356 in 165.018s
# 	Calibrated mode 62 / 356 in 167.707s
# 	Calibrated mode 63 / 356 in 170.411s
# 	Calibrated mode 64 / 356 in 173.117s
# 	Calibrated mode 65 / 356 in 175.841s
# 	Calibrated mode 66 / 356 in 178.544s
# 	Calibrated mode 67 / 356 in 181.239s
# 	Calibrated mode 68 / 356 in 183.936s
# 	Calibrated mode 69 / 356 in 186.634s
# 	Calibrated mode 70 / 356 in 189.339s
# 	Calibrated mode 71 / 356 in 192.047s
# 	Calibrated mode 72 / 356 in 194.745s
# 	Calibrated mode 73 / 356 in 197.423s
# 	Calibrated mode 74 / 356 in 200.100s
# 	Calibrated mode 75 / 356 in 202.771s
# 	Calibrated mode 76 / 356 in 205.443s
# 	Calibrated mode 77 / 356 in 208.116s
# 	Calibrated mode 78 / 356 in 210.785s
# 	Calibrated mode 79 / 356 in 213.447s
# 	Calibrated mode 80 / 356 in 216.109s
# 	Calibrated mode 81 / 356 in 218.771s
# 	Calibrated mode 82 / 356 in 221.438s
# 	Calibrated mode 83 / 356 in 224.102s
# 	Calibrated mode 84 / 356 in 226.766s
# 	Calibrated mode 85 / 356 in 229.439s
# 	Calibrated mode 86 / 356 in 232.119s
# 	Calibrated mode 87 / 356 in 234.796s
# 	Calibrated mode 88 / 356 in 237.476s
# 	Calibrated mode 89 / 356 in 240.150s
# 	Calibrated mode 90 / 356 in 242.841s
# 	Calibrated mode 91 / 356 in 245.533s
# 	Calibrated mode 92 / 356 in 248.212s
# 	Calibrated mode 93 / 356 in 250.878s
# 	Calibrated mode 94 / 356 in 253.549s
# 	Calibrated mode 95 / 356 in 256.254s
# 	Calibrated mode 96 / 356 in 258.973s
# 	Calibrated mode 97 / 356 in 261.695s
# 	Calibrated mode 98 / 356 in 264.425s
# 	Calibrated mode 99 / 356 in 267.152s
# 	Calibrated mode 100 / 356 in 269.878s
# 	Calibrated mode 101 / 356 in 272.604s
# 	Calibrated mode 102 / 356 in 275.334s
# 	Calibrated mode 103 / 356 in 278.060s
# 	Calibrated mode 104 / 356 in 280.786s
# 	Calibrated mode 105 / 356 in 283.516s
# 	Calibrated mode 106 / 356 in 286.244s
# 	Calibrated mode 107 / 356 in 288.970s
# 	Calibrated mode 108 / 356 in 291.704s
# 	Calibrated mode 109 / 356 in 294.433s
# 	Calibrated mode 110 / 356 in 297.165s
# 	Calibrated mode 111 / 356 in 299.889s
# 	Calibrated mode 112 / 356 in 302.618s
# 	Calibrated mode 113 / 356 in 305.331s
# 	Calibrated mode 114 / 356 in 308.061s
# 	Calibrated mode 115 / 356 in 310.778s
# 	Calibrated mode 116 / 356 in 313.491s
# 	Calibrated mode 117 / 356 in 316.195s
# 	Calibrated mode 118 / 356 in 318.892s
# 	Calibrated mode 119 / 356 in 321.591s
# 	Calibrated mode 120 / 356 in 324.283s
# 	Calibrated mode 121 / 356 in 326.970s
# 	Calibrated mode 122 / 356 in 329.657s
# 	Calibrated mode 123 / 356 in 332.344s
# 	Calibrated mode 124 / 356 in 335.028s
# 	Calibrated mode 125 / 356 in 337.718s
# 	Calibrated mode 126 / 356 in 340.403s
# 	Calibrated mode 127 / 356 in 343.086s
# 	Calibrated mode 128 / 356 in 345.771s
# 	Calibrated mode 129 / 356 in 348.457s
# 	Calibrated mode 130 / 356 in 351.144s
# 	Calibrated mode 131 / 356 in 353.811s
# 	Calibrated mode 132 / 356 in 356.496s
# 	Calibrated mode 133 / 356 in 359.175s
# 	Calibrated mode 134 / 356 in 361.863s
# 	Calibrated mode 135 / 356 in 364.545s
# 	Calibrated mode 136 / 356 in 367.220s
# 	Calibrated mode 137 / 356 in 369.903s
# 	Calibrated mode 138 / 356 in 372.588s
# 	Calibrated mode 139 / 356 in 375.263s
# 	Calibrated mode 140 / 356 in 377.945s
# 	Calibrated mode 141 / 356 in 380.636s
# 	Calibrated mode 142 / 356 in 383.340s
# 	Calibrated mode 143 / 356 in 386.052s
# 	Calibrated mode 144 / 356 in 388.768s
# 	Calibrated mode 145 / 356 in 391.470s
# 	Calibrated mode 146 / 356 in 394.196s
# 	Calibrated mode 147 / 356 in 396.868s
# 	Calibrated mode 148 / 356 in 399.539s
# 	Calibrated mode 149 / 356 in 402.205s
# 	Calibrated mode 150 / 356 in 404.869s
# 	Calibrated mode 151 / 356 in 407.536s
# 	Calibrated mode 152 / 356 in 410.201s
# 	Calibrated mode 153 / 356 in 412.865s
# 	Calibrated mode 154 / 356 in 415.528s
# 	Calibrated mode 155 / 356 in 418.191s
# 	Calibrated mode 156 / 356 in 420.855s
# 	Calibrated mode 157 / 356 in 423.574s
# 	Calibrated mode 158 / 356 in 426.296s
# 	Calibrated mode 159 / 356 in 429.021s
# 	Calibrated mode 160 / 356 in 431.735s
# 	Calibrated mode 161 / 356 in 434.453s
# 	Calibrated mode 162 / 356 in 437.165s
# 	Calibrated mode 163 / 356 in 439.883s
# 	Calibrated mode 164 / 356 in 442.598s
# 	Calibrated mode 165 / 356 in 445.321s
# 	Calibrated mode 166 / 356 in 448.044s
# 	Calibrated mode 167 / 356 in 450.771s
# 	Calibrated mode 168 / 356 in 453.479s
# 	Calibrated mode 169 / 356 in 456.199s
# 	Calibrated mode 170 / 356 in 458.919s
# 	Calibrated mode 171 / 356 in 461.646s
# 	Calibrated mode 172 / 356 in 464.364s
# 	Calibrated mode 173 / 356 in 467.091s
# 	Calibrated mode 174 / 356 in 469.814s
# 	Calibrated mode 175 / 356 in 472.545s
# 	Calibrated mode 176 / 356 in 475.281s
# 	Calibrated mode 177 / 356 in 478.008s
# 	Calibrated mode 178 / 356 in 480.736s
# 	Calibrated mode 179 / 356 in 483.467s
# 	Calibrated mode 180 / 356 in 486.194s
# 	Calibrated mode 181 / 356 in 488.930s
# 	Calibrated mode 182 / 356 in 491.661s
# 	Calibrated mode 183 / 356 in 494.394s
# 	Calibrated mode 184 / 356 in 497.128s
# 	Calibrated mode 185 / 356 in 499.862s
# 	Calibrated mode 186 / 356 in 502.598s
# 	Calibrated mode 187 / 356 in 505.329s
# 	Calibrated mode 188 / 356 in 508.050s
# 	Calibrated mode 189 / 356 in 510.783s
# 	Calibrated mode 190 / 356 in 513.518s
# 	Calibrated mode 191 / 356 in 516.254s
# 	Calibrated mode 192 / 356 in 518.988s
# 	Calibrated mode 193 / 356 in 521.716s
# 	Calibrated mode 194 / 356 in 524.445s
# 	Calibrated mode 195 / 356 in 527.173s
# 	Calibrated mode 196 / 356 in 529.893s
# 	Calibrated mode 197 / 356 in 532.614s
# 	Calibrated mode 198 / 356 in 535.335s
# 	Calibrated mode 199 / 356 in 538.056s
# 	Calibrated mode 200 / 356 in 540.781s
# 	Calibrated mode 201 / 356 in 543.509s
# 	Calibrated mode 202 / 356 in 546.235s
# 	Calibrated mode 203 / 356 in 548.968s
# 	Calibrated mode 204 / 356 in 551.702s
# 	Calibrated mode 205 / 356 in 554.430s
# 	Calibrated mode 206 / 356 in 557.160s
# 	Calibrated mode 207 / 356 in 559.889s
# 	Calibrated mode 208 / 356 in 562.620s
# 	Calibrated mode 209 / 356 in 565.342s
# 	Calibrated mode 210 / 356 in 568.076s
# 	Calibrated mode 211 / 356 in 570.809s
# 	Calibrated mode 212 / 356 in 573.528s
# 	Calibrated mode 213 / 356 in 576.231s
# 	Calibrated mode 214 / 356 in 578.957s
# 	Calibrated mode 215 / 356 in 581.688s
# 	Calibrated mode 216 / 356 in 584.416s
# 	Calibrated mode 217 / 356 in 587.141s
# 	Calibrated mode 218 / 356 in 589.880s
# 	Calibrated mode 219 / 356 in 592.618s
# 	Calibrated mode 220 / 356 in 595.355s
# 	Calibrated mode 221 / 356 in 598.093s
# 	Calibrated mode 222 / 356 in 600.835s
# 	Calibrated mode 223 / 356 in 603.574s
# 	Calibrated mode 224 / 356 in 606.315s
# 	Calibrated mode 225 / 356 in 609.054s
# 	Calibrated mode 226 / 356 in 611.793s
# 	Calibrated mode 227 / 356 in 614.538s
# 	Calibrated mode 228 / 356 in 617.289s
# 	Calibrated mode 229 / 356 in 620.030s
# 	Calibrated mode 230 / 356 in 622.773s
# 	Calibrated mode 231 / 356 in 625.513s
# 	Calibrated mode 232 / 356 in 628.256s
# 	Calibrated mode 233 / 356 in 631.001s
# 	Calibrated mode 234 / 356 in 633.750s
# 	Calibrated mode 235 / 356 in 636.493s
# 	Calibrated mode 236 / 356 in 639.241s
# 	Calibrated mode 237 / 356 in 641.983s
# 	Calibrated mode 238 / 356 in 644.728s
# 	Calibrated mode 239 / 356 in 647.469s
# 	Calibrated mode 240 / 356 in 650.219s
# 	Calibrated mode 241 / 356 in 652.953s
# 	Calibrated mode 242 / 356 in 655.696s
# 	Calibrated mode 243 / 356 in 658.438s
# 	Calibrated mode 244 / 356 in 661.184s
# 	Calibrated mode 245 / 356 in 663.928s
# 	Calibrated mode 246 / 356 in 666.671s
# 	Calibrated mode 247 / 356 in 669.414s
# 	Calibrated mode 248 / 356 in 672.160s
# 	Calibrated mode 249 / 356 in 674.905s
# 	Calibrated mode 250 / 356 in 677.653s
# 	Calibrated mode 251 / 356 in 680.392s
# 	Calibrated mode 252 / 356 in 683.137s
# 	Calibrated mode 253 / 356 in 685.869s
# 	Calibrated mode 254 / 356 in 688.617s
# 	Calibrated mode 255 / 356 in 691.360s
# 	Calibrated mode 256 / 356 in 694.108s
# 	Calibrated mode 257 / 356 in 696.853s
# 	Calibrated mode 258 / 356 in 699.588s
# 	Calibrated mode 259 / 356 in 702.318s
# 	Calibrated mode 260 / 356 in 705.029s
# 	Calibrated mode 261 / 356 in 707.735s
# 	Calibrated mode 262 / 356 in 710.445s
# 	Calibrated mode 263 / 356 in 713.148s
# 	Calibrated mode 264 / 356 in 715.854s
# 	Calibrated mode 265 / 356 in 718.544s
# 	Calibrated mode 266 / 356 in 721.242s
# 	Calibrated mode 267 / 356 in 723.939s
# 	Calibrated mode 268 / 356 in 726.635s
# 	Calibrated mode 269 / 356 in 729.329s
# 	Calibrated mode 270 / 356 in 732.026s
# 	Calibrated mode 271 / 356 in 734.717s
# 	Calibrated mode 272 / 356 in 737.420s
# 	Calibrated mode 273 / 356 in 740.119s
# 	Calibrated mode 274 / 356 in 742.824s
# 	Calibrated mode 275 / 356 in 745.521s
# 	Calibrated mode 276 / 356 in 748.227s
# 	Calibrated mode 277 / 356 in 750.926s
# 	Calibrated mode 278 / 356 in 753.633s
# 	Calibrated mode 279 / 356 in 756.333s
# 	Calibrated mode 280 / 356 in 759.040s
# 	Calibrated mode 281 / 356 in 761.745s
# 	Calibrated mode 282 / 356 in 764.459s
# 	Calibrated mode 283 / 356 in 767.153s
# 	Calibrated mode 284 / 356 in 769.861s
# 	Calibrated mode 285 / 356 in 772.570s
# 	Calibrated mode 286 / 356 in 775.273s
# 	Calibrated mode 287 / 356 in 777.978s
# 	Calibrated mode 288 / 356 in 780.685s
# 	Calibrated mode 289 / 356 in 783.389s
# 	Calibrated mode 290 / 356 in 786.101s
# 	Calibrated mode 291 / 356 in 788.809s
# 	Calibrated mode 292 / 356 in 791.521s
# 	Calibrated mode 293 / 356 in 794.225s
# 	Calibrated mode 294 / 356 in 796.931s
# 	Calibrated mode 295 / 356 in 799.634s
# 	Calibrated mode 296 / 356 in 802.342s
# 	Calibrated mode 297 / 356 in 805.048s
# 	Calibrated mode 298 / 356 in 807.751s
# 	Calibrated mode 299 / 356 in 810.454s
# 	Calibrated mode 300 / 356 in 813.163s
# 	Calibrated mode 301 / 356 in 815.871s
# 	Calibrated mode 302 / 356 in 818.580s
# 	Calibrated mode 303 / 356 in 821.282s
# 	Calibrated mode 304 / 356 in 823.987s
# 	Calibrated mode 305 / 356 in 826.688s
# 	Calibrated mode 306 / 356 in 829.392s
# 	Calibrated mode 307 / 356 in 832.096s
# 	Calibrated mode 308 / 356 in 834.806s
# 	Calibrated mode 309 / 356 in 837.514s
# 	Calibrated mode 310 / 356 in 840.231s
# 	Calibrated mode 311 / 356 in 842.936s
# 	Calibrated mode 312 / 356 in 845.648s
# 	Calibrated mode 313 / 356 in 848.352s
# 	Calibrated mode 314 / 356 in 851.062s
# 	Calibrated mode 315 / 356 in 853.771s
# 	Calibrated mode 316 / 356 in 856.485s
# 	Calibrated mode 317 / 356 in 859.196s
# 	Calibrated mode 318 / 356 in 861.909s
# 	Calibrated mode 319 / 356 in 864.609s
# 	Calibrated mode 320 / 356 in 867.322s
# 	Calibrated mode 321 / 356 in 870.029s
# 	Calibrated mode 322 / 356 in 872.740s
# 	Calibrated mode 323 / 356 in 875.444s
# 	Calibrated mode 324 / 356 in 878.160s
# 	Calibrated mode 325 / 356 in 880.871s
# 	Calibrated mode 326 / 356 in 883.588s
# 	Calibrated mode 327 / 356 in 886.299s
# 	Calibrated mode 328 / 356 in 889.010s
# 	Calibrated mode 329 / 356 in 891.720s
# 	Calibrated mode 330 / 356 in 894.437s
# 	Calibrated mode 331 / 356 in 897.144s
# 	Calibrated mode 332 / 356 in 899.861s
# 	Calibrated mode 333 / 356 in 902.586s
# 	Calibrated mode 334 / 356 in 905.318s
# 	Calibrated mode 335 / 356 in 908.055s
# 	Calibrated mode 336 / 356 in 910.801s
# 	Calibrated mode 337 / 356 in 913.562s
# 	Calibrated mode 338 / 356 in 916.337s
# 	Calibrated mode 339 / 356 in 919.119s
# 	Calibrated mode 340 / 356 in 921.913s
# 	Calibrated mode 341 / 356 in 924.694s
# 	Calibrated mode 342 / 356 in 927.489s
# 	Calibrated mode 343 / 356 in 930.286s
# 	Calibrated mode 344 / 356 in 933.094s
# 	Calibrated mode 345 / 356 in 935.893s
# 	Calibrated mode 346 / 356 in 938.700s
# 	Calibrated mode 347 / 356 in 941.510s
# 	Calibrated mode 348 / 356 in 944.320s
# 	Calibrated mode 349 / 356 in 947.129s
# 	Calibrated mode 350 / 356 in 949.946s
# 	Calibrated mode 351 / 356 in 952.758s
# 	Calibrated mode 352 / 356 in 955.564s
# 	Calibrated mode 353 / 356 in 958.364s
# 	Calibrated mode 354 / 356 in 961.164s
# 	Calibrated mode 355 / 356 in 963.937s
# 	Calibrated mode 356 / 356 in 966.705s
# Calibration complete.

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.imshow1(response_sum.reshape(c.npsf,c.npsf))

# %%
misc.save_fits('response_cube.fits', response_cube)
# Out:
# Saved data to:  response_cube.fits

# %%
response_cube.shape
# Out:
# (712, 2, 4096)

# %%
reload(iefc)
control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weight_map.flatten(), 
                                               nprobes=2, 
                                               rcond1=1e-2,
                                               rcond2=1e-2, 
                                               WLS=True,)
display(control_matrix.shape, calib_modes.shape)
# Out:
# Using Weighted Least Squares
# (712, 2144)
# (356, 1156)

# %%
reload(iefc)
c.reset_dms()
images, dm1_commands, dm2_commands = iefc.run(c, 
                                              control_matrix,
#                                               reg_fun,reg_conds,response_cube, 
                                              probe_modes, 
                                              probe_amp, 
                                              calib_modes,
#                                               fourier_modes,
#                                               fourier_modes,
                                              weight_map, 
                                              num_iterations=5, 
                                              loop_gain=0.5, leakage=0.0,
                                              display_all=True,
                                             )
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 5
# (712,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#       1 reload(iefc)
#       2 c.reset_dms()
# ----> 3 images, dm1_commands, dm2_commands = iefc.run(c,
#       4                                               control_matrix,
#       5 #                                               reg_fun,reg_conds,response_cube,
#       6                                               probe_modes,
#       7                                               probe_amp,
#       8                                               calib_modes,
#       9 #                                               fourier_modes,
#      10 #                                               fourier_modes,
#      11                                               weight_map,
#      12                                               num_iterations=5,
#      13                                               loop_gain=0.5, leakage=0.0,
#      14                                               display_all=True,
#      15                                              )
#
# File ~/Documents/roman-cgi-iefc/wfsc/iefc_2dm.py:350, in run(sysi, control_matrix, probe_modes, probe_amplitude, calibration_modes, weight_map, num_iterations, loop_gain, leakage, display_current, display_all)
#     347         print(commands.shape)
#     349         # Reconstruct the full phase from the Fourier modes
# --> 350         dm1_command = calibration_modes[:nc].T.dot(commands)[:sysi.Nact**2].reshape(sysi.Nact,sysi.Nact)
#     351         dm2_command = calibration_modes[nc:].T.dot(commands)[sysi.Nact**2:].reshape(sysi.Nact,sysi.Nact)
#     352 #         dm1_command = calibration_modes[:,:sysi.Nact**2].T.dot(commands).reshape(sysi.Nact,sysi.Nact)
#     353 #         dm2_command = calibration_modes[:,sysi.Nact**2:].T.dot(commands).reshape(sysi.Nact,sysi.Nact)
#     354 #         dm1_command = ( calibration_modes_1.T.dot(commands[nc1:]) ).reshape(sysi.Nact,sysi.Nact)
#     355 #         dm2_command = ( calibration_modes_2.T.dot(commands[nc1:]) ).reshape(sysi.Nact,sysi.Nact)
#
# ValueError: shapes (1156,356) and (712,) not aligned: 356 (dim 1) != 712 (dim 0)
