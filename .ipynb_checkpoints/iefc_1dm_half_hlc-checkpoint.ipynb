# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
reload(cgi)

import misc_funs as misc
reload(misc)

from wfsc import iefc_1dm as iefc
from wfsc import utils

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
reload(cgi)
reload(misc)
coro = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
#               use_noise=True,
#               texp=300*u.s,
             )
# coro.show_dms()

npsf = coro.npsf
Nact = coro.Nact

ref_psf = coro.snap()

misc.imshow1(ref_psf, pxscl=coro.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
xfp = (np.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*coro.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 2
iwa = 2
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-1,
    'outer_radius' : owa+1,
    'edge_position' : edge-0.2,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95

weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask 
misc.imshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=coro.psf_pixelscale_lamD, pxscl2=coro.psf_pixelscale_lamD, pxscl3=coro.psf_pixelscale_lamD)

reload(utils)
probe_amp = 5e-8
# probe_modes = utils.create_probe_poke_modes(Nact, xinds=[Nact//3, Nact//2, 2*Nact//3], yinds=[2*Nact//3, Nact//3, 2*Nact//3],display=True)
probe_modes = utils.create_probe_poke_modes(Nact, xinds=[Nact//4, Nact//4-1], yinds=[Nact//4, Nact//4], display=True)

# %%
reload(utils)
calib_amp = 5e-9
fourier_modes, fs = utils.select_fourier_modes(coro, control_mask, fourier_sampling=0.85) 
nmodes = fourier_modes.shape[0]
print(fourier_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
misc.imshow1(ref_psf, lognorm=True, pxscl=coro.psf_pixelscale_lamD, patches=patches)
# Out:
# (352, 2304) (176, 2)

# %%
for i in range(fourier_modes.shape[0]//2):
    try:
        misc.imshow2(fourier_modes[i].reshape(Nact,Nact), ref_psf, 
                       'Frequency Sampled: ({:.3f}, {:.3f})'.format(fs[i][0], fs[i][1]),
                       lognorm2=True,
                       pxscl2=coro.psf_pixelscale_lamD, 
                       patches2=[Circle(fs[i], 0.25, fill=True, color='g'),
                                 Circle(-fs[i], 0.25, fill=True, color='g')])
        clear_output(wait=True)
        time.sleep(0.25)
    except KeyboardInterrupt:
        break

# %% [markdown]
# # Use randomized probes

# %%
reload(utils)

nprobes = 2
probe_rms = 5e-9
probe_amplitude = 5e-9

alpha = 0
fmin = 2
fmax = 16
probe_modes = utils.get_random_probes(probe_rms, alpha, sys.dm_mask.astype(int), fmin=fmin, fmax=fmax, nprobe=nprobes)
# misc.myimshow2(probe_modes[0], probe_modes[1])

# %% [markdown]
# # Use Hadamard Calibration Modes

# %%
calib_amp = 5e-9
had_modes = utils.get_hadamard_modes(coro.dm_mask)[:1024]
print(had_modes.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 calib_amp = 5e-9
# ----> 2 had_modes = utils.get_hadamard_modes(coro.dm_mask)[:1024]
#       3 print(had_modes.shape)
#
# AttributeError: module 'wfsc.utils' has no attribute 'get_hadamard_modes'

# %%
for mode in had_modes:
    try:
        misc.myimshow(calibration_amplitude*mode.reshape(Nact,Nact))
        clear_output(wait=True)
        time.sleep(0.1)
    except KeyboardInterrupt:
        break

# %%
reload(iefc)
coro.reset_dms()
differential_images, single_images = iefc.take_measurement(coro, 
                                                           probe_modes, probe_amp, 
                                                           return_all=True, display=True)
# Out:
# -0.004594696347627604 0.004585739824532814 -0.000416 0.000403
# -0.004594696347627604 0.004585739824532814 -0.000416 0.000403
# -0.004594696347627604 0.004585739824532814 -0.000416 0.000403
# -0.004594696347627604 0.004585739824532814 -0.000416 0.000403

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(coro, 
                                                 probe_amp, probe_modes, 
                                                 calib_amp, fourier_modes, 
                                                 start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 352 in 3.120s
# 	Calibrated mode 2 / 352 in 6.038s
# 	Calibrated mode 3 / 352 in 8.955s
# 	Calibrated mode 4 / 352 in 11.901s
# 	Calibrated mode 5 / 352 in 14.856s
# 	Calibrated mode 6 / 352 in 17.758s
# 	Calibrated mode 7 / 352 in 20.678s
# 	Calibrated mode 8 / 352 in 23.620s
# 	Calibrated mode 9 / 352 in 26.614s
# 	Calibrated mode 10 / 352 in 29.623s
# 	Calibrated mode 11 / 352 in 32.613s
# 	Calibrated mode 12 / 352 in 35.558s
# 	Calibrated mode 13 / 352 in 38.575s
# 	Calibrated mode 14 / 352 in 41.557s
# 	Calibrated mode 15 / 352 in 44.648s
# 	Calibrated mode 16 / 352 in 47.694s
# 	Calibrated mode 17 / 352 in 50.818s
# 	Calibrated mode 18 / 352 in 53.927s
# 	Calibrated mode 19 / 352 in 56.983s
# 	Calibrated mode 20 / 352 in 59.946s
# 	Calibrated mode 21 / 352 in 62.877s
# 	Calibrated mode 22 / 352 in 65.821s
# 	Calibrated mode 23 / 352 in 68.978s
# 	Calibrated mode 24 / 352 in 71.953s
# 	Calibrated mode 25 / 352 in 74.858s
# 	Calibrated mode 26 / 352 in 77.778s
# 	Calibrated mode 27 / 352 in 80.728s
# 	Calibrated mode 28 / 352 in 83.638s
# 	Calibrated mode 29 / 352 in 86.568s
# 	Calibrated mode 30 / 352 in 89.504s
# 	Calibrated mode 31 / 352 in 92.409s
# 	Calibrated mode 32 / 352 in 95.318s
# 	Calibrated mode 33 / 352 in 98.248s
# 	Calibrated mode 34 / 352 in 101.158s
# 	Calibrated mode 35 / 352 in 104.068s
# 	Calibrated mode 36 / 352 in 107.022s
# 	Calibrated mode 37 / 352 in 109.968s
# 	Calibrated mode 38 / 352 in 112.951s
# 	Calibrated mode 39 / 352 in 115.894s
# 	Calibrated mode 40 / 352 in 118.823s
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
# fname = 'hlc_opds_flatmaps_39_half_fourier_probes'
# fname = 'hlc_opds_flatmaps_39_half_dense'

fname = 'hlc_flatmaps_had_2-9.pkl'

misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_flatmaps_had_2-9.pkl
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_flatmaps_had_2-9.pkl

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
fname = 'hlc_opds_flatmaps_39_half_fourier_probes'

response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.imshow1(response_sum.reshape(npsf, npsf))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), 
                                               rcond=1e-2, 
                                               nprobes=probe_modes.shape[0], pca_modes=None)
response_cube.shape, control_matrix.shape

reg_fun = iefc.construct_control_matrix
reg_conds = np.array([[0, 10, 15, 20],
                      [1e-1, 1e-3, 1e-1, 1e-2]])
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC
#
# So the differential images are the difference between each pair of probed images.
#
# The measurement vector is the concatenated area of the focal plane from each differential image.
#
# The coefficeints are the dot product of the cintrol_matrix with the measurement vector.
#
# The DM command is the dot product of the calibration modes with the the coefficients.

# %%
calib_modes[:].shape
# Out:
# (480, 48, 48)

# %%
reload(iefc)
coro.reset_dms()
# probe_amplitude = 0.1 * sys.wavelength_c.to(u.m).value

images, dm_commands = iefc.run(coro, 
                               reg_fun,
                               reg_conds,
                               response_cube,
                               probe_modes, 
                               probe_amp, 
                               fourier_modes, 
                               weights, 
                               num_iterations=30,
                               loop_gain=0.5, 
                               leakage=0.0,
                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-01
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 2 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 3 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 4 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 5 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 6 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 7 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 8 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 9 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 10 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 11 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-03
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 12 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 13 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 14 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 15 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 16 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-01
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 17 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 18 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 19 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 20 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 21 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-02
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 22 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 23 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 24 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 25 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 26 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 27 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 28 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 29 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# 	Closed-loop iteration 30 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (352,)
# I-EFC loop completed in 65.368s.

# %%
import matplotlib.pyplot as plt
bins, contrast = utils.get_radial_contrast(images[-1], dh_mask.reshape(npsf,npsf))
r = bins*coro.psf_pixelscale_lamD
plt.semilogy(r,contrast)

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
