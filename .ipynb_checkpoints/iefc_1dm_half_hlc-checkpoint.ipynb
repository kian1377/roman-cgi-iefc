# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_1dm as iefc
from wfsc import utils

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')
# Out:
# INFO:numexpr.utils:Note: detected 96 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 96 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.

# %%
reload(cgi)
sys = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
#               use_noise=True,
              texp=300*u.s,
             )
# sys.show_dms()

npsf = sys.npsf
Nact = sys.Nact

ref_psf = sys.snap()

misc.myimshow(ref_psf, lognorm=True)
# Out:
# 0.00023164260456764313 m

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
xfp = (np.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*sys.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 2
iwa = 2
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-1,
    'outer_radius' : owa+1,
    'edge_position' : edge-0.2,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95

weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask 
misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=sys.psf_pixelscale_lamD, pxscl2=sys.psf_pixelscale_lamD, pxscl3=sys.psf_pixelscale_lamD)

# %%
probe_amp = 3e-8
calib_amp = 5e-9

print(probe_amp, calib_amp)
# Out:
# 3e-08 5e-09

# %%
reload(utils)
fourier_modes, fs = utils.select_fourier_modes(sys, control_mask, fourier_sampling=0.75) 
nmodes = calib_modes.shape[0]
print(calib_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
misc.myimshow(ref_psf, lognorm=True, pxscl=sys.psf_pixelscale_lamD, patches=patches)
# Out:
# (480, 2304) (240, 2)

# %%
for i in range(fourier_modes.shape[0]//2):
    try:
        misc.myimshow2(fourier_modes[i].reshape(Nact,Nact), ref_psf, 
                       'Frequency Sampled: ({:.3f}, {:.3f})'.format(fs[i][0], fs[i][1]),
                       lognorm2=True,
                       pxscl2=sys.psf_pixelscale_lamD, 
                       patches2=[Circle(fs[i], 0.25, fill=True, color='g'),
                                 Circle(-fs[i], 0.25, fill=True, color='g')])
        clear_output(wait=True)
        time.sleep(0.25)
    except KeyboardInterrupt:
        break

# %%
reload(utils)
# probe_modes = utils.create_probe_poke_modes(Nact, xinds=[Nact//3, Nact//2, 2*Nact//3], yinds=[2*Nact//3, Nact//3, 2*Nact//3],display=True)
probe_modes = utils.create_probe_poke_modes(Nact, xinds=[Nact//4, Nact//4-1], yinds=[Nact//4, Nact//4], display=True)

# %% [markdown]
# # Use randomized probes

# %%
reload(utils)

nprobes = 2
probe_rms = 5e-9
probe_amplitude = 5e-9

alpha = 0
fmin = 2
fmax = 16
probe_modes = utils.get_random_probes(probe_rms, alpha, sys.dm_mask.astype(int), fmin=fmin, fmax=fmax, nprobe=nprobes)
# misc.myimshow2(probe_modes[0], probe_modes[1])

# %% [markdown]
# # Use Hadamard Calibration Modes

# %%
calib_amp = 5e-9
had_modes = utils.get_hadamard_modes(sys.dm_mask)[:1024]
print(had_modes.shape)
# Out:
# (1024, 2304)

# %%
for mode in had_modes:
    try:
        misc.myimshow(calibration_amplitude*mode.reshape(Nact,Nact))
        clear_output(wait=True)
        time.sleep(0.1)
    except KeyboardInterrupt:
        break

# %%
reload(iefc)
sys.reset_dms()
differential_images, single_images = iefc.take_measurement(sys, 
                                                           probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(sys, 
                                                 probe_amp, probe_modes, 
                                                 calib_amp, had_modes, 
                                                 start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 1024 in 3.530s
# 	Calibrated mode 2 / 1024 in 6.038s
# 	Calibrated mode 3 / 1024 in 8.541s
# 	Calibrated mode 4 / 1024 in 11.040s
# 	Calibrated mode 5 / 1024 in 13.543s
# 	Calibrated mode 6 / 1024 in 16.045s
# 	Calibrated mode 7 / 1024 in 18.570s
# 	Calibrated mode 8 / 1024 in 21.102s
# 	Calibrated mode 9 / 1024 in 23.632s
# 	Calibrated mode 10 / 1024 in 26.169s
# 	Calibrated mode 11 / 1024 in 28.701s
# 	Calibrated mode 12 / 1024 in 31.232s
# 	Calibrated mode 13 / 1024 in 33.761s
# 	Calibrated mode 14 / 1024 in 36.287s
# 	Calibrated mode 15 / 1024 in 38.811s
# 	Calibrated mode 16 / 1024 in 41.332s
# 	Calibrated mode 17 / 1024 in 43.847s
# 	Calibrated mode 18 / 1024 in 46.350s
# 	Calibrated mode 19 / 1024 in 48.850s
# 	Calibrated mode 20 / 1024 in 51.349s
# 	Calibrated mode 21 / 1024 in 53.851s
# 	Calibrated mode 22 / 1024 in 56.358s
# 	Calibrated mode 23 / 1024 in 58.859s
# 	Calibrated mode 24 / 1024 in 61.376s
# 	Calibrated mode 25 / 1024 in 63.884s
# 	Calibrated mode 26 / 1024 in 66.392s
# 	Calibrated mode 27 / 1024 in 68.917s
# 	Calibrated mode 28 / 1024 in 71.451s
# 	Calibrated mode 29 / 1024 in 73.992s
# 	Calibrated mode 30 / 1024 in 76.544s
# 	Calibrated mode 31 / 1024 in 79.092s
# 	Calibrated mode 32 / 1024 in 81.629s
# 	Calibrated mode 33 / 1024 in 84.188s
# 	Calibrated mode 34 / 1024 in 86.732s
# 	Calibrated mode 35 / 1024 in 89.268s
# 	Calibrated mode 36 / 1024 in 91.801s
# 	Calibrated mode 37 / 1024 in 94.322s
# 	Calibrated mode 38 / 1024 in 96.840s
# 	Calibrated mode 39 / 1024 in 99.610s
# 	Calibrated mode 40 / 1024 in 102.121s
# 	Calibrated mode 41 / 1024 in 104.626s
# 	Calibrated mode 42 / 1024 in 107.127s
# 	Calibrated mode 43 / 1024 in 109.629s
# 	Calibrated mode 44 / 1024 in 112.154s
# 	Calibrated mode 45 / 1024 in 114.656s
# 	Calibrated mode 46 / 1024 in 117.187s
# 	Calibrated mode 47 / 1024 in 119.809s
# 	Calibrated mode 48 / 1024 in 122.318s
# 	Calibrated mode 49 / 1024 in 124.829s
# 	Calibrated mode 50 / 1024 in 127.343s
# 	Calibrated mode 51 / 1024 in 129.869s
# 	Calibrated mode 52 / 1024 in 132.408s
# 	Calibrated mode 53 / 1024 in 134.948s
# 	Calibrated mode 54 / 1024 in 137.512s
# 	Calibrated mode 55 / 1024 in 140.084s
# 	Calibrated mode 56 / 1024 in 142.649s
# 	Calibrated mode 57 / 1024 in 145.210s
# 	Calibrated mode 58 / 1024 in 147.770s
# 	Calibrated mode 59 / 1024 in 150.337s
# 	Calibrated mode 60 / 1024 in 152.896s
# 	Calibrated mode 61 / 1024 in 155.452s
# 	Calibrated mode 62 / 1024 in 158.002s
# 	Calibrated mode 63 / 1024 in 160.529s
# 	Calibrated mode 64 / 1024 in 163.086s
# 	Calibrated mode 65 / 1024 in 165.648s
# 	Calibrated mode 66 / 1024 in 168.213s
# 	Calibrated mode 67 / 1024 in 170.784s
# 	Calibrated mode 68 / 1024 in 173.565s
# 	Calibrated mode 69 / 1024 in 176.125s
# 	Calibrated mode 70 / 1024 in 178.677s
# 	Calibrated mode 71 / 1024 in 181.236s
# 	Calibrated mode 72 / 1024 in 183.780s
# 	Calibrated mode 73 / 1024 in 186.327s
# 	Calibrated mode 74 / 1024 in 188.900s
# 	Calibrated mode 75 / 1024 in 191.444s
# 	Calibrated mode 76 / 1024 in 193.983s
# 	Calibrated mode 77 / 1024 in 196.525s
# 	Calibrated mode 78 / 1024 in 199.049s
# 	Calibrated mode 79 / 1024 in 201.583s
# 	Calibrated mode 80 / 1024 in 204.105s
# 	Calibrated mode 81 / 1024 in 206.625s
# 	Calibrated mode 82 / 1024 in 209.341s
# 	Calibrated mode 83 / 1024 in 211.849s
# 	Calibrated mode 84 / 1024 in 214.354s
# 	Calibrated mode 85 / 1024 in 216.858s
# 	Calibrated mode 86 / 1024 in 219.360s
# 	Calibrated mode 87 / 1024 in 222.090s
# 	Calibrated mode 88 / 1024 in 224.594s
# 	Calibrated mode 89 / 1024 in 227.091s
# 	Calibrated mode 90 / 1024 in 229.599s
# 	Calibrated mode 91 / 1024 in 232.093s
# 	Calibrated mode 92 / 1024 in 234.584s
# 	Calibrated mode 93 / 1024 in 237.085s
# 	Calibrated mode 94 / 1024 in 239.590s
# 	Calibrated mode 95 / 1024 in 242.091s
# 	Calibrated mode 96 / 1024 in 244.644s
# 	Calibrated mode 97 / 1024 in 247.141s
# 	Calibrated mode 98 / 1024 in 249.633s
# 	Calibrated mode 99 / 1024 in 252.288s
# 	Calibrated mode 100 / 1024 in 254.780s
# 	Calibrated mode 101 / 1024 in 257.278s
# 	Calibrated mode 102 / 1024 in 259.770s
# 	Calibrated mode 103 / 1024 in 262.276s
# 	Calibrated mode 104 / 1024 in 264.782s
# 	Calibrated mode 105 / 1024 in 267.286s
# 	Calibrated mode 106 / 1024 in 269.780s
# 	Calibrated mode 107 / 1024 in 272.273s
# 	Calibrated mode 108 / 1024 in 274.780s
# 	Calibrated mode 774 / 1024 in 1951.616s
# 	Calibrated mode 775 / 1024 in 1954.114s
# 	Calibrated mode 776 / 1024 in 1956.593s
# 	Calibrated mode 777 / 1024 in 1959.066s
# 	Calibrated mode 778 / 1024 in 1961.547s
# 	Calibrated mode 779 / 1024 in 1964.024s
# 	Calibrated mode 780 / 1024 in 1966.506s
# 	Calibrated mode 781 / 1024 in 1968.994s
# 	Calibrated mode 782 / 1024 in 1971.468s
# 	Calibrated mode 783 / 1024 in 1973.950s
# 	Calibrated mode 784 / 1024 in 1976.426s
# 	Calibrated mode 785 / 1024 in 1978.905s
# 	Calibrated mode 786 / 1024 in 1981.374s
# 	Calibrated mode 787 / 1024 in 1983.861s
# 	Calibrated mode 788 / 1024 in 1986.341s
# 	Calibrated mode 789 / 1024 in 1989.025s
# 	Calibrated mode 790 / 1024 in 1991.504s
# 	Calibrated mode 791 / 1024 in 1993.987s
# 	Calibrated mode 792 / 1024 in 1996.466s
# 	Calibrated mode 793 / 1024 in 1998.936s
# 	Calibrated mode 794 / 1024 in 2001.403s
# 	Calibrated mode 795 / 1024 in 2003.872s
# 	Calibrated mode 796 / 1024 in 2006.332s
# 	Calibrated mode 797 / 1024 in 2008.793s
# 	Calibrated mode 798 / 1024 in 2011.257s
# 	Calibrated mode 799 / 1024 in 2013.728s
# 	Calibrated mode 800 / 1024 in 2016.189s
# 	Calibrated mode 801 / 1024 in 2018.650s
# 	Calibrated mode 802 / 1024 in 2021.109s
# 	Calibrated mode 803 / 1024 in 2023.579s
# 	Calibrated mode 804 / 1024 in 2026.059s
# 	Calibrated mode 805 / 1024 in 2028.566s
# 	Calibrated mode 806 / 1024 in 2031.068s
# 	Calibrated mode 807 / 1024 in 2033.579s
# 	Calibrated mode 808 / 1024 in 2036.092s
# 	Calibrated mode 809 / 1024 in 2038.596s
# 	Calibrated mode 810 / 1024 in 2041.101s
# 	Calibrated mode 811 / 1024 in 2043.615s
# 	Calibrated mode 812 / 1024 in 2046.122s
# 	Calibrated mode 813 / 1024 in 2048.631s
# 	Calibrated mode 814 / 1024 in 2051.143s
# 	Calibrated mode 815 / 1024 in 2053.850s
# 	Calibrated mode 816 / 1024 in 2056.358s
# 	Calibrated mode 817 / 1024 in 2058.858s
# 	Calibrated mode 818 / 1024 in 2061.367s
# 	Calibrated mode 819 / 1024 in 2063.875s
# 	Calibrated mode 820 / 1024 in 2066.387s
# 	Calibrated mode 821 / 1024 in 2068.906s
# 	Calibrated mode 822 / 1024 in 2071.414s
# 	Calibrated mode 823 / 1024 in 2073.922s
# 	Calibrated mode 824 / 1024 in 2076.412s
# 	Calibrated mode 825 / 1024 in 2078.921s
# 	Calibrated mode 826 / 1024 in 2081.426s
# 	Calibrated mode 827 / 1024 in 2083.943s
# 	Calibrated mode 828 / 1024 in 2086.454s
# 	Calibrated mode 829 / 1024 in 2088.963s
# 	Calibrated mode 830 / 1024 in 2091.470s
# 	Calibrated mode 831 / 1024 in 2093.979s
# 	Calibrated mode 832 / 1024 in 2096.481s
# 	Calibrated mode 833 / 1024 in 2098.988s
# 	Calibrated mode 834 / 1024 in 2101.500s
# 	Calibrated mode 835 / 1024 in 2104.019s
# 	Calibrated mode 836 / 1024 in 2106.670s
# 	Calibrated mode 837 / 1024 in 2109.194s
# 	Calibrated mode 838 / 1024 in 2111.702s
# 	Calibrated mode 839 / 1024 in 2114.210s
# 	Calibrated mode 840 / 1024 in 2116.696s
# 	Calibrated mode 841 / 1024 in 2119.197s
# 	Calibrated mode 842 / 1024 in 2121.701s
# 	Calibrated mode 843 / 1024 in 2124.207s
# 	Calibrated mode 844 / 1024 in 2126.716s
# 	Calibrated mode 845 / 1024 in 2129.227s
# 	Calibrated mode 846 / 1024 in 2131.735s
# 	Calibrated mode 847 / 1024 in 2134.240s
# 	Calibrated mode 848 / 1024 in 2136.743s
# 	Calibrated mode 849 / 1024 in 2139.448s
# 	Calibrated mode 850 / 1024 in 2141.946s
# 	Calibrated mode 851 / 1024 in 2144.452s
# 	Calibrated mode 852 / 1024 in 2146.969s
# 	Calibrated mode 853 / 1024 in 2149.460s
# 	Calibrated mode 854 / 1024 in 2151.952s
# 	Calibrated mode 855 / 1024 in 2154.443s
# 	Calibrated mode 856 / 1024 in 2156.931s
# 	Calibrated mode 857 / 1024 in 2159.411s
# 	Calibrated mode 858 / 1024 in 2161.900s
# 	Calibrated mode 859 / 1024 in 2164.377s
# 	Calibrated mode 860 / 1024 in 2166.850s
# 	Calibrated mode 861 / 1024 in 2169.325s
# 	Calibrated mode 862 / 1024 in 2171.939s
# 	Calibrated mode 863 / 1024 in 2174.412s
# 	Calibrated mode 864 / 1024 in 2177.098s
# 	Calibrated mode 865 / 1024 in 2179.593s
# 	Calibrated mode 866 / 1024 in 2182.091s
# 	Calibrated mode 867 / 1024 in 2184.589s
# 	Calibrated mode 868 / 1024 in 2187.084s
# 	Calibrated mode 869 / 1024 in 2189.572s
# 	Calibrated mode 870 / 1024 in 2192.067s
# 	Calibrated mode 871 / 1024 in 2194.557s
# 	Calibrated mode 872 / 1024 in 2197.050s
# 	Calibrated mode 873 / 1024 in 2199.540s
# 	Calibrated mode 874 / 1024 in 2202.038s
# 	Calibrated mode 875 / 1024 in 2204.557s
# 	Calibrated mode 876 / 1024 in 2207.072s
# 	Calibrated mode 877 / 1024 in 2209.580s
# 	Calibrated mode 878 / 1024 in 2212.303s
# 	Calibrated mode 879 / 1024 in 2214.805s
# 	Calibrated mode 880 / 1024 in 2217.288s
# 	Calibrated mode 881 / 1024 in 2219.752s
# 	Calibrated mode 882 / 1024 in 2222.198s
# 	Calibrated mode 883 / 1024 in 2224.643s
# 	Calibrated mode 884 / 1024 in 2227.076s
# 	Calibrated mode 885 / 1024 in 2229.543s
# 	Calibrated mode 886 / 1024 in 2231.973s
# 	Calibrated mode 887 / 1024 in 2234.396s
# 	Calibrated mode 888 / 1024 in 2236.814s
# 	Calibrated mode 889 / 1024 in 2239.230s
# 	Calibrated mode 890 / 1024 in 2241.667s
# 	Calibrated mode 891 / 1024 in 2244.095s
# 	Calibrated mode 892 / 1024 in 2246.514s
# 	Calibrated mode 893 / 1024 in 2248.924s
# 	Calibrated mode 894 / 1024 in 2251.331s
# 	Calibrated mode 895 / 1024 in 2253.759s
# 	Calibrated mode 896 / 1024 in 2256.172s
# 	Calibrated mode 897 / 1024 in 2258.780s
# 	Calibrated mode 898 / 1024 in 2261.187s
# 	Calibrated mode 899 / 1024 in 2263.598s
# 	Calibrated mode 900 / 1024 in 2265.996s
# 	Calibrated mode 901 / 1024 in 2268.398s
# 	Calibrated mode 902 / 1024 in 2270.991s
# 	Calibrated mode 903 / 1024 in 2273.397s
# 	Calibrated mode 904 / 1024 in 2275.805s
# 	Calibrated mode 905 / 1024 in 2278.203s
# 	Calibrated mode 906 / 1024 in 2280.605s
# 	Calibrated mode 907 / 1024 in 2283.014s
# 	Calibrated mode 908 / 1024 in 2285.420s
# 	Calibrated mode 909 / 1024 in 2287.825s
# 	Calibrated mode 910 / 1024 in 2290.244s
# 	Calibrated mode 911 / 1024 in 2292.649s
# 	Calibrated mode 912 / 1024 in 2295.061s
# 	Calibrated mode 913 / 1024 in 2297.467s
# 	Calibrated mode 914 / 1024 in 2300.010s
# 	Calibrated mode 915 / 1024 in 2302.428s
# 	Calibrated mode 916 / 1024 in 2304.844s
# 	Calibrated mode 917 / 1024 in 2307.260s
# 	Calibrated mode 918 / 1024 in 2309.684s
# 	Calibrated mode 919 / 1024 in 2312.106s
# 	Calibrated mode 920 / 1024 in 2314.543s
# 	Calibrated mode 921 / 1024 in 2316.979s
# 	Calibrated mode 922 / 1024 in 2319.411s
# 	Calibrated mode 923 / 1024 in 2321.849s
# 	Calibrated mode 924 / 1024 in 2324.469s
# 	Calibrated mode 925 / 1024 in 2326.910s
# 	Calibrated mode 926 / 1024 in 2329.354s
# 	Calibrated mode 927 / 1024 in 2331.799s
# 	Calibrated mode 928 / 1024 in 2334.238s
# 	Calibrated mode 929 / 1024 in 2336.687s
# 	Calibrated mode 930 / 1024 in 2339.134s
# 	Calibrated mode 931 / 1024 in 2341.581s
# 	Calibrated mode 932 / 1024 in 2344.021s
# 	Calibrated mode 933 / 1024 in 2346.465s
# 	Calibrated mode 934 / 1024 in 2348.912s
# 	Calibrated mode 935 / 1024 in 2351.355s
# 	Calibrated mode 936 / 1024 in 2353.794s
# 	Calibrated mode 937 / 1024 in 2356.236s
# 	Calibrated mode 938 / 1024 in 2358.674s
# 	Calibrated mode 939 / 1024 in 2361.107s
# 	Calibrated mode 940 / 1024 in 2363.542s
# 	Calibrated mode 941 / 1024 in 2365.985s
# 	Calibrated mode 942 / 1024 in 2368.425s
# 	Calibrated mode 943 / 1024 in 2370.857s
# 	Calibrated mode 944 / 1024 in 2373.300s
# 	Calibrated mode 945 / 1024 in 2375.746s
# 	Calibrated mode 946 / 1024 in 2378.179s
# 	Calibrated mode 947 / 1024 in 2380.615s
# 	Calibrated mode 948 / 1024 in 2383.062s
# 	Calibrated mode 949 / 1024 in 2385.503s
# 	Calibrated mode 950 / 1024 in 2388.127s
# 	Calibrated mode 951 / 1024 in 2390.735s
# 	Calibrated mode 952 / 1024 in 2393.172s
# 	Calibrated mode 953 / 1024 in 2395.608s
# 	Calibrated mode 954 / 1024 in 2398.067s
# 	Calibrated mode 955 / 1024 in 2400.514s
# 	Calibrated mode 956 / 1024 in 2402.967s
# 	Calibrated mode 957 / 1024 in 2405.465s
# 	Calibrated mode 958 / 1024 in 2407.915s
# 	Calibrated mode 959 / 1024 in 2410.363s
# 	Calibrated mode 960 / 1024 in 2412.813s
# 	Calibrated mode 961 / 1024 in 2415.276s
# 	Calibrated mode 962 / 1024 in 2417.743s
# 	Calibrated mode 963 / 1024 in 2420.214s
# 	Calibrated mode 964 / 1024 in 2422.681s
# 	Calibrated mode 965 / 1024 in 2425.153s
# 	Calibrated mode 966 / 1024 in 2427.631s
# 	Calibrated mode 967 / 1024 in 2430.098s
# 	Calibrated mode 968 / 1024 in 2432.573s
# 	Calibrated mode 969 / 1024 in 2435.045s
# 	Calibrated mode 970 / 1024 in 2437.519s
# 	Calibrated mode 971 / 1024 in 2439.994s
# 	Calibrated mode 972 / 1024 in 2442.468s
# 	Calibrated mode 973 / 1024 in 2444.938s
# 	Calibrated mode 974 / 1024 in 2447.413s
# 	Calibrated mode 975 / 1024 in 2449.878s
# 	Calibrated mode 976 / 1024 in 2452.340s
# 	Calibrated mode 977 / 1024 in 2454.815s
# 	Calibrated mode 978 / 1024 in 2457.389s
# 	Calibrated mode 979 / 1024 in 2459.871s
# 	Calibrated mode 980 / 1024 in 2462.347s
# 	Calibrated mode 981 / 1024 in 2464.827s
# 	Calibrated mode 982 / 1024 in 2467.304s
# 	Calibrated mode 983 / 1024 in 2469.766s
# 	Calibrated mode 984 / 1024 in 2472.414s
# 	Calibrated mode 985 / 1024 in 2474.892s
# 	Calibrated mode 986 / 1024 in 2477.363s
# 	Calibrated mode 987 / 1024 in 2479.833s
# 	Calibrated mode 988 / 1024 in 2482.312s
# 	Calibrated mode 989 / 1024 in 2484.793s
# 	Calibrated mode 990 / 1024 in 2487.319s
# 	Calibrated mode 991 / 1024 in 2489.782s
# 	Calibrated mode 992 / 1024 in 2492.265s
# 	Calibrated mode 993 / 1024 in 2494.747s
# 	Calibrated mode 994 / 1024 in 2497.222s
# 	Calibrated mode 995 / 1024 in 2499.698s
# 	Calibrated mode 996 / 1024 in 2502.172s
# 	Calibrated mode 997 / 1024 in 2504.646s
# 	Calibrated mode 998 / 1024 in 2507.228s
# 	Calibrated mode 999 / 1024 in 2509.710s
# 	Calibrated mode 1000 / 1024 in 2512.188s
# 	Calibrated mode 1001 / 1024 in 2514.666s
# 	Calibrated mode 1002 / 1024 in 2517.143s
# 	Calibrated mode 1003 / 1024 in 2519.625s
# 	Calibrated mode 1004 / 1024 in 2522.108s
# 	Calibrated mode 1005 / 1024 in 2524.588s
# 	Calibrated mode 1006 / 1024 in 2527.069s
# 	Calibrated mode 1007 / 1024 in 2529.549s
# 	Calibrated mode 1008 / 1024 in 2532.038s
# 	Calibrated mode 1009 / 1024 in 2534.527s
# 	Calibrated mode 1010 / 1024 in 2537.006s
# 	Calibrated mode 1011 / 1024 in 2539.489s
# 	Calibrated mode 1012 / 1024 in 2541.970s
# 	Calibrated mode 1013 / 1024 in 2544.623s
# 	Calibrated mode 1014 / 1024 in 2547.075s
# 	Calibrated mode 1015 / 1024 in 2549.558s
# 	Calibrated mode 1016 / 1024 in 2552.037s
# 	Calibrated mode 1017 / 1024 in 2554.514s
# 	Calibrated mode 1018 / 1024 in 2556.991s
# 	Calibrated mode 1019 / 1024 in 2559.470s
# 	Calibrated mode 1020 / 1024 in 2561.956s
# 	Calibrated mode 1021 / 1024 in 2564.439s
# 	Calibrated mode 1022 / 1024 in 2566.912s
# 	Calibrated mode 1023 / 1024 in 2569.398s
# 	Calibrated mode 1024 / 1024 in 2571.879s
# Calibration complete.

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
# fname = 'hlc_opds_flatmaps_39_half_fourier_probes'
# fname = 'hlc_opds_flatmaps_39_half_dense'

fname = 'hlc_flatmaps_had_2-9.pkl'

misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_flatmaps_had_2-9.pkl
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_flatmaps_had_2-9.pkl

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
fname = 'hlc_opds_flatmaps_39_half_fourier_probes'

response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), 
                                               rcond=1e-2, 
                                               nprobes=probe_modes.shape[0], pca_modes=None)
response_cube.shape, control_matrix.shape

reg_fun = iefc.construct_control_matrix
reg_conds = np.array([[0, 10, 15, 20],
                      [1e-1, 1e-3, 1e-1, 1e-2]])
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC
#
# So the differential images are the difference between each pair of probed images.
#
# The measurement vector is the concatenated area of the focal plane from each differential image.
#
# The coefficeints are the dot product of the cintrol_matrix with the measurement vector.
#
# The DM command is the dot product of the calibration modes with the the coefficients.

# %%
calib_modes[:].shape
# Out:
# (480, 48, 48)

# %%
reload(iefc)
sys.reset_dms()
# probe_amplitude = 0.1 * sys.wavelength_c.to(u.m).value

images, dm_commands = iefc.run(sys, 
                               reg_fun,
                               reg_conds,
                               response_cube,
                               probe_modes, 
                               probe_amp, 
                               had_modes, 
                               weights, 
                               num_iterations=30,
                               loop_gain=0.5, 
                               leakage=0.0,
                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-01
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 2 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 3 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 4 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 5 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 6 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 7 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 8 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 9 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 10 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 11 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-03
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 12 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 13 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 14 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 15 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 16 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-01
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 17 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 18 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 19 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 20 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 21 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-02
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 22 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 23 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 24 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 25 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 26 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 27 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 28 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 29 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# 	Closed-loop iteration 30 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1296,)
# reconstructed_coefficients shape:  (1024,)
# I-EFC loop completed in 67.828s.

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
