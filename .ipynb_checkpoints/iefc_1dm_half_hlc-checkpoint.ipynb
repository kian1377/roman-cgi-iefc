# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_1dm as iefc
from wfsc import utils

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')

# %%
reload(cgi)
sys = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
sys.show_dms()

npsf = sys.npsf
Nact = sys.Nact

ref_psf = sys.snap()

misc.myimshow(ref_psf, lognorm=True)
# Out:
# 0.00023164260456764313 m

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * sys.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 2
iwa = 3
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-1,
    'outer_radius' : owa+1,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95

weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask 
misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=sys.psf_pixelscale_lamD, pxscl2=sys.psf_pixelscale_lamD, pxscl3=sys.psf_pixelscale_lamD)

# %%
control_mask.sum()
# Out:
# 532

# %% [markdown]
# # Use poke probes

# %%
probe_modes = iefc.create_probe_poke_modes(Nact, xinds=[Nact//3, Nact//2, 2*Nact//3], yinds=[2*Nact//3, Nact//3, 2*Nact//3],display=True)
# probe_modes = iefc.create_probe_poke_modes(Nact, xinds=[Nact//4, Nact//4-1], yinds=[Nact//4, Nact//4], display=True)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(iefc)
calibration_modes, fx, fy = iefc.create_fourier_modes(xfp, 
                                                      control_mask.reshape((npsf,npsf)), 
                                                      Nact, 
                                                      circular_mask=False)
calibration_modes[:] *= sys.dm_mask.flatten()


calibration_amplitude = 0.006 * sys.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * sys.wavelength_c.to(u.m).value
nmodes = calibration_modes.shape[0]

print('Calibration modes required: {:d}'.format(nmodes))
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 244

# %%
for i in range(nmodes//2):
    try:
        misc.myimshow(calibration_modes[i].reshape(Nact,Nact), 'Mode {:d}: ({:.2f},{:.2f})'.format(i, fx[i], fy[i]))
        clear_output(wait=True)
        time.sleep(0.1)
    except KeyboardInterrupt:
        break

# %% [markdown]
# # Use uniform probes

# %%
probe1 = calibration_modes[:nmodes//2].sum(axis=0).reshape(Nact,Nact)
probe2 = calibration_modes[nmodes//2:].sum(axis=0).reshape(Nact,Nact)

probe1 /= probe1.max()
probe2 /= probe2.max()

probe_modes = np.array([probe1,probe2])
probe_modes.shape

misc.myimshow2(probe1, probe2)

oversample = 4
probe1_fft = np.fft.fftshift(np.fft.fft2(misc.pad_or_crop(probe1, Nact*oversample)))
probe2_fft = np.fft.fftshift(np.fft.fft2(misc.pad_or_crop(probe2, Nact*oversample)))

misc.myimshow2(np.abs(probe1_fft), np.abs(probe2_fft), 
               pxscl1=1/oversample, pxscl2=1/oversample, 
               patches1=[Circle((0,0), 3, fill=False, color='c'), Circle((0,0), 9, fill=False, color='c')],
               patches2=[Circle((0,0), 3, fill=False, color='c'), Circle((0,0), 9, fill=False, color='c')])

# %% [markdown]
# # Use randomized probes

# %%
reload(utils)

nprobes = 2
probe_rms = 5e-9
probe_amplitude = 5e-9

alpha = 0
fmin = 2
fmax = 16
probe_modes = utils.get_random_probes(probe_rms, alpha, sys.dm_mask.astype(int), fmin=fmin, fmax=fmax, nprobe=nprobes)
# misc.myimshow2(probe_modes[0], probe_modes[1])

# %% [markdown]
# # Use Hadamard Calibration Modes

# %%
calibration_amplitude = 5e-9
calibration_modes = utils.get_hadamard_modes(sys.dm_mask)[:1024]
print(calibration_modes.shape)
# Out:
# (1024, 2304)

# %%
for mode in calibration_modes:
    try:
        misc.myimshow(calibration_amplitude*mode.reshape(Nact,Nact))
        clear_output(wait=True)
        time.sleep(0.1)
    except KeyboardInterrupt:
        break

# %%
reload(iefc)
sys.reset_dms()
differential_images, single_images = iefc.take_measurement(sys, 
                                                           probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(sys, 
                                                 probe_amplitude, probe_modes, 
                                                 calibration_amplitude, calibration_modes, 
                                                 start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 1024 in 2.560s
# 	Calibrated mode 2 / 1024 in 5.085s
# 	Calibrated mode 3 / 1024 in 7.603s
# 	Calibrated mode 4 / 1024 in 10.147s
# 	Calibrated mode 5 / 1024 in 12.717s
# 	Calibrated mode 6 / 1024 in 15.453s
# 	Calibrated mode 7 / 1024 in 18.045s
# 	Calibrated mode 8 / 1024 in 20.640s
# 	Calibrated mode 9 / 1024 in 23.236s
# 	Calibrated mode 10 / 1024 in 25.831s
# 	Calibrated mode 11 / 1024 in 28.432s
# 	Calibrated mode 12 / 1024 in 31.029s
# 	Calibrated mode 13 / 1024 in 33.625s
# 	Calibrated mode 14 / 1024 in 36.223s
# 	Calibrated mode 15 / 1024 in 38.825s
# 	Calibrated mode 16 / 1024 in 41.428s
# 	Calibrated mode 17 / 1024 in 44.024s
# 	Calibrated mode 18 / 1024 in 46.623s
# 	Calibrated mode 19 / 1024 in 49.233s
# 	Calibrated mode 20 / 1024 in 51.831s
# 	Calibrated mode 21 / 1024 in 54.445s
# 	Calibrated mode 22 / 1024 in 57.048s
# 	Calibrated mode 23 / 1024 in 59.773s
# 	Calibrated mode 24 / 1024 in 62.369s
# 	Calibrated mode 25 / 1024 in 64.963s
# 	Calibrated mode 26 / 1024 in 67.559s
# 	Calibrated mode 27 / 1024 in 70.155s
# 	Calibrated mode 28 / 1024 in 72.934s
# 	Calibrated mode 29 / 1024 in 75.484s
# 	Calibrated mode 30 / 1024 in 78.031s
# 	Calibrated mode 31 / 1024 in 80.748s
# 	Calibrated mode 32 / 1024 in 83.365s
# 	Calibrated mode 33 / 1024 in 85.924s
# 	Calibrated mode 34 / 1024 in 88.474s
# 	Calibrated mode 35 / 1024 in 91.028s
# 	Calibrated mode 36 / 1024 in 93.619s
# 	Calibrated mode 37 / 1024 in 96.341s
# 	Calibrated mode 38 / 1024 in 98.937s
# 	Calibrated mode 39 / 1024 in 101.539s
# 	Calibrated mode 40 / 1024 in 104.133s
# 	Calibrated mode 41 / 1024 in 106.729s
# 	Calibrated mode 42 / 1024 in 109.329s
# 	Calibrated mode 43 / 1024 in 111.925s
# 	Calibrated mode 44 / 1024 in 114.521s
# 	Calibrated mode 45 / 1024 in 117.120s
# 	Calibrated mode 46 / 1024 in 119.715s
# 	Calibrated mode 47 / 1024 in 122.437s
# 	Calibrated mode 48 / 1024 in 125.029s
# 	Calibrated mode 49 / 1024 in 127.625s
# 	Calibrated mode 50 / 1024 in 130.213s
# 	Calibrated mode 51 / 1024 in 132.804s
# 	Calibrated mode 52 / 1024 in 135.394s
# 	Calibrated mode 53 / 1024 in 137.988s
# 	Calibrated mode 54 / 1024 in 140.587s
# 	Calibrated mode 55 / 1024 in 143.181s
# 	Calibrated mode 56 / 1024 in 145.775s
# 	Calibrated mode 57 / 1024 in 148.378s
# 	Calibrated mode 58 / 1024 in 150.978s
# 	Calibrated mode 59 / 1024 in 153.578s
# 	Calibrated mode 60 / 1024 in 156.279s
# 	Calibrated mode 61 / 1024 in 158.825s
# 	Calibrated mode 62 / 1024 in 161.375s
# 	Calibrated mode 63 / 1024 in 163.951s
# 	Calibrated mode 64 / 1024 in 166.546s
# 	Calibrated mode 65 / 1024 in 169.097s
# 	Calibrated mode 66 / 1024 in 171.648s
# 	Calibrated mode 67 / 1024 in 174.209s
# 	Calibrated mode 68 / 1024 in 176.814s
# 	Calibrated mode 69 / 1024 in 179.421s
# 	Calibrated mode 70 / 1024 in 182.023s
# 	Calibrated mode 71 / 1024 in 184.889s
# 	Calibrated mode 72 / 1024 in 187.842s
# 	Calibrated mode 73 / 1024 in 190.424s
# 	Calibrated mode 74 / 1024 in 194.171s
# 	Calibrated mode 75 / 1024 in 198.634s
# 	Calibrated mode 76 / 1024 in 203.225s
# 	Calibrated mode 77 / 1024 in 207.824s
# 	Calibrated mode 78 / 1024 in 212.390s
# 	Calibrated mode 79 / 1024 in 216.931s
# 	Calibrated mode 80 / 1024 in 221.450s
# 	Calibrated mode 81 / 1024 in 226.031s
# 	Calibrated mode 82 / 1024 in 230.614s
# 	Calibrated mode 83 / 1024 in 235.150s
# 	Calibrated mode 84 / 1024 in 239.633s
# 	Calibrated mode 85 / 1024 in 244.199s
# 	Calibrated mode 86 / 1024 in 248.840s
# 	Calibrated mode 87 / 1024 in 253.307s
# 	Calibrated mode 88 / 1024 in 257.796s
# 	Calibrated mode 89 / 1024 in 262.388s
# 	Calibrated mode 90 / 1024 in 266.933s
# 	Calibrated mode 91 / 1024 in 271.451s
# 	Calibrated mode 92 / 1024 in 276.031s
# 	Calibrated mode 93 / 1024 in 280.605s
# 	Calibrated mode 94 / 1024 in 285.140s
# 	Calibrated mode 95 / 1024 in 289.660s
# 	Calibrated mode 96 / 1024 in 294.249s
# 	Calibrated mode 97 / 1024 in 298.836s
# 	Calibrated mode 98 / 1024 in 303.407s
# 	Calibrated mode 99 / 1024 in 308.049s
# 	Calibrated mode 648 / 1024 in 2066.290s
# 	Calibrated mode 649 / 1024 in 2069.814s
# 	Calibrated mode 650 / 1024 in 2073.315s
# 	Calibrated mode 651 / 1024 in 2076.935s
# 	Calibrated mode 652 / 1024 in 2080.652s
# 	Calibrated mode 653 / 1024 in 2084.130s
# 	Calibrated mode 654 / 1024 in 2088.019s
# 	Calibrated mode 655 / 1024 in 2091.282s
# 	Calibrated mode 656 / 1024 in 2095.270s
# 	Calibrated mode 657 / 1024 in 2098.977s
# 	Calibrated mode 658 / 1024 in 2102.657s
# 	Calibrated mode 659 / 1024 in 2106.384s
# 	Calibrated mode 660 / 1024 in 2109.836s
# 	Calibrated mode 661 / 1024 in 2113.487s
# 	Calibrated mode 662 / 1024 in 2117.083s
# 	Calibrated mode 663 / 1024 in 2120.953s
# 	Calibrated mode 664 / 1024 in 2124.521s
# 	Calibrated mode 665 / 1024 in 2128.382s
# 	Calibrated mode 666 / 1024 in 2132.093s
# 	Calibrated mode 667 / 1024 in 2135.695s
# 	Calibrated mode 668 / 1024 in 2138.987s
# 	Calibrated mode 669 / 1024 in 2141.678s
# 	Calibrated mode 670 / 1024 in 2144.224s
# 	Calibrated mode 671 / 1024 in 2146.733s
# 	Calibrated mode 672 / 1024 in 2149.251s
# 	Calibrated mode 673 / 1024 in 2151.776s
# 	Calibrated mode 674 / 1024 in 2154.349s
# 	Calibrated mode 675 / 1024 in 2156.873s
# 	Calibrated mode 676 / 1024 in 2159.388s
# 	Calibrated mode 677 / 1024 in 2161.911s
# 	Calibrated mode 678 / 1024 in 2164.466s
# 	Calibrated mode 679 / 1024 in 2167.151s
# 	Calibrated mode 680 / 1024 in 2169.708s
# 	Calibrated mode 681 / 1024 in 2172.268s
# 	Calibrated mode 682 / 1024 in 2175.955s
# 	Calibrated mode 683 / 1024 in 2179.548s
# 	Calibrated mode 684 / 1024 in 2183.422s
# 	Calibrated mode 685 / 1024 in 2187.011s
# 	Calibrated mode 686 / 1024 in 2190.879s
# 	Calibrated mode 687 / 1024 in 2194.588s
# 	Calibrated mode 688 / 1024 in 2198.164s
# 	Calibrated mode 689 / 1024 in 2201.885s
# 	Calibrated mode 690 / 1024 in 2205.078s
# 	Calibrated mode 691 / 1024 in 2208.775s
# 	Calibrated mode 692 / 1024 in 2212.682s
# 	Calibrated mode 693 / 1024 in 2216.208s
# 	Calibrated mode 694 / 1024 in 2219.889s
# 	Calibrated mode 695 / 1024 in 2223.331s
# 	Calibrated mode 696 / 1024 in 2227.186s
# 	Calibrated mode 697 / 1024 in 2230.839s
# 	Calibrated mode 698 / 1024 in 2234.392s
# 	Calibrated mode 699 / 1024 in 2237.796s
# 	Calibrated mode 700 / 1024 in 2241.585s
# 	Calibrated mode 701 / 1024 in 2245.086s
# 	Calibrated mode 702 / 1024 in 2248.913s
# 	Calibrated mode 703 / 1024 in 2252.782s
# 	Calibrated mode 704 / 1024 in 2256.206s
# 	Calibrated mode 705 / 1024 in 2259.937s
# 	Calibrated mode 706 / 1024 in 2263.424s
# 	Calibrated mode 707 / 1024 in 2267.313s
# 	Calibrated mode 708 / 1024 in 2270.831s
# 	Calibrated mode 709 / 1024 in 2274.504s
# 	Calibrated mode 710 / 1024 in 2278.223s
# 	Calibrated mode 711 / 1024 in 2281.686s
# 	Calibrated mode 712 / 1024 in 2285.397s
# 	Calibrated mode 713 / 1024 in 2288.996s
# 	Calibrated mode 714 / 1024 in 2292.409s
# 	Calibrated mode 715 / 1024 in 2294.973s
# 	Calibrated mode 716 / 1024 in 2297.542s
# 	Calibrated mode 717 / 1024 in 2300.103s
# 	Calibrated mode 718 / 1024 in 2302.664s
# 	Calibrated mode 719 / 1024 in 2305.227s
# 	Calibrated mode 720 / 1024 in 2307.793s
# 	Calibrated mode 721 / 1024 in 2310.331s
# 	Calibrated mode 722 / 1024 in 2312.848s
# 	Calibrated mode 723 / 1024 in 2315.365s
# 	Calibrated mode 724 / 1024 in 2317.914s
# 	Calibrated mode 725 / 1024 in 2320.478s
# 	Calibrated mode 726 / 1024 in 2322.999s
# 	Calibrated mode 727 / 1024 in 2325.642s
# 	Calibrated mode 728 / 1024 in 2328.173s
# 	Calibrated mode 729 / 1024 in 2330.734s
# 	Calibrated mode 730 / 1024 in 2333.300s
# 	Calibrated mode 731 / 1024 in 2335.865s
# 	Calibrated mode 732 / 1024 in 2338.427s
# 	Calibrated mode 733 / 1024 in 2340.994s
# 	Calibrated mode 734 / 1024 in 2343.558s
# 	Calibrated mode 735 / 1024 in 2346.123s
# 	Calibrated mode 736 / 1024 in 2348.689s
# 	Calibrated mode 737 / 1024 in 2351.255s
# 	Calibrated mode 738 / 1024 in 2353.823s
# 	Calibrated mode 739 / 1024 in 2356.388s
# 	Calibrated mode 740 / 1024 in 2358.955s
# 	Calibrated mode 741 / 1024 in 2361.641s
# 	Calibrated mode 742 / 1024 in 2364.202s
# 	Calibrated mode 743 / 1024 in 2367.455s
# 	Calibrated mode 744 / 1024 in 2370.962s
# 	Calibrated mode 745 / 1024 in 2374.629s
# 	Calibrated mode 746 / 1024 in 2378.347s
# 	Calibrated mode 747 / 1024 in 2381.134s
# 	Calibrated mode 748 / 1024 in 2383.710s
# 	Calibrated mode 749 / 1024 in 2386.272s
# 	Calibrated mode 750 / 1024 in 2388.836s
# 	Calibrated mode 751 / 1024 in 2391.394s
# 	Calibrated mode 752 / 1024 in 2393.917s
# 	Calibrated mode 753 / 1024 in 2396.430s
# 	Calibrated mode 754 / 1024 in 2399.077s
# 	Calibrated mode 755 / 1024 in 2401.649s
# 	Calibrated mode 756 / 1024 in 2404.172s
# 	Calibrated mode 757 / 1024 in 2406.688s
# 	Calibrated mode 758 / 1024 in 2409.205s
# 	Calibrated mode 759 / 1024 in 2411.770s
# 	Calibrated mode 760 / 1024 in 2414.308s
# 	Calibrated mode 761 / 1024 in 2416.825s
# 	Calibrated mode 762 / 1024 in 2419.348s
# 	Calibrated mode 763 / 1024 in 2422.824s
# 	Calibrated mode 764 / 1024 in 2426.471s
# 	Calibrated mode 765 / 1024 in 2429.814s
# 	Calibrated mode 766 / 1024 in 2433.626s
# 	Calibrated mode 767 / 1024 in 2437.405s
# 	Calibrated mode 768 / 1024 in 2440.853s
# 	Calibrated mode 769 / 1024 in 2444.641s
# 	Calibrated mode 770 / 1024 in 2447.997s
# 	Calibrated mode 771 / 1024 in 2451.712s
# 	Calibrated mode 772 / 1024 in 2455.124s
# 	Calibrated mode 773 / 1024 in 2459.004s
# 	Calibrated mode 774 / 1024 in 2462.492s
# 	Calibrated mode 775 / 1024 in 2466.127s
# 	Calibrated mode 776 / 1024 in 2469.397s
# 	Calibrated mode 777 / 1024 in 2473.316s
# 	Calibrated mode 778 / 1024 in 2477.074s
# 	Calibrated mode 779 / 1024 in 2480.653s
# 	Calibrated mode 780 / 1024 in 2484.495s
# 	Calibrated mode 781 / 1024 in 2488.044s
# 	Calibrated mode 782 / 1024 in 2491.884s
# 	Calibrated mode 783 / 1024 in 2494.449s
# 	Calibrated mode 784 / 1024 in 2496.975s
# 	Calibrated mode 785 / 1024 in 2499.489s
# 	Calibrated mode 786 / 1024 in 2502.004s
# 	Calibrated mode 787 / 1024 in 2504.565s
# 	Calibrated mode 788 / 1024 in 2507.110s
# 	Calibrated mode 789 / 1024 in 2509.628s
# 	Calibrated mode 790 / 1024 in 2512.142s
# 	Calibrated mode 791 / 1024 in 2514.684s
# 	Calibrated mode 792 / 1024 in 2518.037s
# 	Calibrated mode 793 / 1024 in 2521.545s
# 	Calibrated mode 794 / 1024 in 2525.197s
# 	Calibrated mode 795 / 1024 in 2528.891s
# 	Calibrated mode 796 / 1024 in 2532.339s
# 	Calibrated mode 797 / 1024 in 2536.194s
# 	Calibrated mode 798 / 1024 in 2539.571s
# 	Calibrated mode 799 / 1024 in 2543.375s
# 	Calibrated mode 800 / 1024 in 2546.660s
# 	Calibrated mode 801 / 1024 in 2549.222s
# 	Calibrated mode 802 / 1024 in 2551.909s
# 	Calibrated mode 803 / 1024 in 2554.468s
# 	Calibrated mode 804 / 1024 in 2557.026s
# 	Calibrated mode 805 / 1024 in 2559.584s
# 	Calibrated mode 806 / 1024 in 2562.290s
# 	Calibrated mode 807 / 1024 in 2566.136s
# 	Calibrated mode 808 / 1024 in 2569.818s
# 	Calibrated mode 809 / 1024 in 2573.400s
# 	Calibrated mode 810 / 1024 in 2576.812s
# 	Calibrated mode 811 / 1024 in 2580.601s
# 	Calibrated mode 812 / 1024 in 2584.233s
# 	Calibrated mode 813 / 1024 in 2587.786s
# 	Calibrated mode 814 / 1024 in 2591.473s
# 	Calibrated mode 815 / 1024 in 2595.057s
# 	Calibrated mode 816 / 1024 in 2598.748s
# 	Calibrated mode 817 / 1024 in 2602.184s
# 	Calibrated mode 818 / 1024 in 2606.071s
# 	Calibrated mode 819 / 1024 in 2609.442s
# 	Calibrated mode 820 / 1024 in 2613.281s
# 	Calibrated mode 821 / 1024 in 2616.953s
# 	Calibrated mode 822 / 1024 in 2620.524s
# 	Calibrated mode 823 / 1024 in 2623.833s
# 	Calibrated mode 824 / 1024 in 2627.681s
# 	Calibrated mode 825 / 1024 in 2631.162s
# 	Calibrated mode 826 / 1024 in 2634.798s
# 	Calibrated mode 827 / 1024 in 2638.490s
# 	Calibrated mode 828 / 1024 in 2641.752s
# 	Calibrated mode 829 / 1024 in 2644.436s
# 	Calibrated mode 830 / 1024 in 2646.999s
# 	Calibrated mode 831 / 1024 in 2649.561s
# 	Calibrated mode 832 / 1024 in 2652.121s
# 	Calibrated mode 833 / 1024 in 2654.678s
# 	Calibrated mode 834 / 1024 in 2657.237s
# 	Calibrated mode 835 / 1024 in 2659.789s
# 	Calibrated mode 836 / 1024 in 2662.309s
# 	Calibrated mode 837 / 1024 in 2664.828s
# 	Calibrated mode 838 / 1024 in 2667.353s
# 	Calibrated mode 839 / 1024 in 2669.927s
# 	Calibrated mode 840 / 1024 in 2672.454s
# 	Calibrated mode 841 / 1024 in 2674.973s
# 	Calibrated mode 842 / 1024 in 2677.493s
# 	Calibrated mode 843 / 1024 in 2680.062s
# 	Calibrated mode 844 / 1024 in 2682.609s
# 	Calibrated mode 845 / 1024 in 2685.123s
# 	Calibrated mode 846 / 1024 in 2687.757s
# 	Calibrated mode 847 / 1024 in 2690.302s
# 	Calibrated mode 848 / 1024 in 2692.868s
# 	Calibrated mode 849 / 1024 in 2695.432s
# 	Calibrated mode 850 / 1024 in 2697.992s
# 	Calibrated mode 851 / 1024 in 2700.557s
# 	Calibrated mode 852 / 1024 in 2703.122s
# 	Calibrated mode 853 / 1024 in 2705.685s
# 	Calibrated mode 854 / 1024 in 2708.248s
# 	Calibrated mode 855 / 1024 in 2710.809s
# 	Calibrated mode 856 / 1024 in 2713.372s
# 	Calibrated mode 857 / 1024 in 2715.925s
# 	Calibrated mode 858 / 1024 in 2718.480s
# 	Calibrated mode 859 / 1024 in 2721.040s
# 	Calibrated mode 860 / 1024 in 2723.725s
# 	Calibrated mode 861 / 1024 in 2726.280s
# 	Calibrated mode 862 / 1024 in 2728.844s
# 	Calibrated mode 863 / 1024 in 2731.409s
# 	Calibrated mode 864 / 1024 in 2733.972s
# 	Calibrated mode 865 / 1024 in 2736.536s
# 	Calibrated mode 866 / 1024 in 2739.101s
# 	Calibrated mode 867 / 1024 in 2741.665s
# 	Calibrated mode 868 / 1024 in 2744.232s
# 	Calibrated mode 869 / 1024 in 2746.800s
# 	Calibrated mode 870 / 1024 in 2749.489s
# 	Calibrated mode 871 / 1024 in 2752.055s
# 	Calibrated mode 872 / 1024 in 2754.586s
# 	Calibrated mode 873 / 1024 in 2757.107s
# 	Calibrated mode 874 / 1024 in 2759.627s
# 	Calibrated mode 875 / 1024 in 2762.193s
# 	Calibrated mode 876 / 1024 in 2764.741s
# 	Calibrated mode 877 / 1024 in 2767.265s
# 	Calibrated mode 878 / 1024 in 2769.785s
# 	Calibrated mode 879 / 1024 in 2772.329s
# 	Calibrated mode 880 / 1024 in 2774.898s
# 	Calibrated mode 881 / 1024 in 2777.469s
# 	Calibrated mode 882 / 1024 in 2780.038s
# 	Calibrated mode 883 / 1024 in 2782.730s
# 	Calibrated mode 884 / 1024 in 2785.296s
# 	Calibrated mode 885 / 1024 in 2787.860s
# 	Calibrated mode 886 / 1024 in 2790.429s
# 	Calibrated mode 887 / 1024 in 2792.997s
# 	Calibrated mode 888 / 1024 in 2795.561s
# 	Calibrated mode 889 / 1024 in 2798.124s
# 	Calibrated mode 890 / 1024 in 2800.692s
# 	Calibrated mode 891 / 1024 in 2803.261s
# 	Calibrated mode 892 / 1024 in 2805.832s
# 	Calibrated mode 893 / 1024 in 2808.401s
# 	Calibrated mode 894 / 1024 in 2810.968s
# 	Calibrated mode 895 / 1024 in 2813.540s
# 	Calibrated mode 896 / 1024 in 2816.233s
# 	Calibrated mode 897 / 1024 in 2818.799s
# 	Calibrated mode 898 / 1024 in 2821.363s
# 	Calibrated mode 899 / 1024 in 2823.928s
# 	Calibrated mode 900 / 1024 in 2826.496s
# 	Calibrated mode 901 / 1024 in 2829.061s
# 	Calibrated mode 902 / 1024 in 2831.628s
# 	Calibrated mode 903 / 1024 in 2834.195s
# 	Calibrated mode 904 / 1024 in 2836.723s
# 	Calibrated mode 905 / 1024 in 2839.246s
# 	Calibrated mode 906 / 1024 in 2841.769s
# 	Calibrated mode 907 / 1024 in 2844.332s
# 	Calibrated mode 908 / 1024 in 2846.883s
# 	Calibrated mode 909 / 1024 in 2849.409s
# 	Calibrated mode 910 / 1024 in 2851.933s
# 	Calibrated mode 911 / 1024 in 2854.476s
# 	Calibrated mode 912 / 1024 in 2857.044s
# 	Calibrated mode 913 / 1024 in 2859.733s
# 	Calibrated mode 914 / 1024 in 2862.296s
# 	Calibrated mode 915 / 1024 in 2864.861s
# 	Calibrated mode 916 / 1024 in 2867.425s
# 	Calibrated mode 917 / 1024 in 2869.996s
# 	Calibrated mode 918 / 1024 in 2872.560s
# 	Calibrated mode 919 / 1024 in 2875.130s
# 	Calibrated mode 920 / 1024 in 2877.695s
# 	Calibrated mode 921 / 1024 in 2880.264s
# 	Calibrated mode 922 / 1024 in 2882.836s
# 	Calibrated mode 923 / 1024 in 2885.412s
# 	Calibrated mode 924 / 1024 in 2887.985s
# 	Calibrated mode 925 / 1024 in 2890.558s
# 	Calibrated mode 926 / 1024 in 2893.129s
# 	Calibrated mode 927 / 1024 in 2895.824s
# 	Calibrated mode 928 / 1024 in 2898.388s
# 	Calibrated mode 929 / 1024 in 2900.948s
# 	Calibrated mode 930 / 1024 in 2903.513s
# 	Calibrated mode 931 / 1024 in 2906.075s
# 	Calibrated mode 932 / 1024 in 2908.640s
# 	Calibrated mode 933 / 1024 in 2911.202s
# 	Calibrated mode 934 / 1024 in 2913.767s
# 	Calibrated mode 935 / 1024 in 2916.332s
# 	Calibrated mode 936 / 1024 in 2918.867s
# 	Calibrated mode 937 / 1024 in 2921.513s
# 	Calibrated mode 938 / 1024 in 2924.027s
# 	Calibrated mode 939 / 1024 in 2926.595s
# 	Calibrated mode 940 / 1024 in 2929.145s
# 	Calibrated mode 941 / 1024 in 2931.670s
# 	Calibrated mode 942 / 1024 in 2934.192s
# 	Calibrated mode 943 / 1024 in 2936.730s
# 	Calibrated mode 944 / 1024 in 2939.299s
# 	Calibrated mode 945 / 1024 in 2941.865s
# 	Calibrated mode 946 / 1024 in 2944.433s
# 	Calibrated mode 947 / 1024 in 2947.001s
# 	Calibrated mode 948 / 1024 in 2949.568s
# 	Calibrated mode 1009 / 1024 in 3106.268s
# 	Calibrated mode 1010 / 1024 in 3108.794s
# 	Calibrated mode 1011 / 1024 in 3111.321s
# 	Calibrated mode 1012 / 1024 in 3113.902s
# 	Calibrated mode 1013 / 1024 in 3116.435s
# 	Calibrated mode 1014 / 1024 in 3118.964s
# 	Calibrated mode 1015 / 1024 in 3121.488s
# 	Calibrated mode 1016 / 1024 in 3124.046s
# 	Calibrated mode 1017 / 1024 in 3126.615s
# 	Calibrated mode 1018 / 1024 in 3129.307s
# 	Calibrated mode 1019 / 1024 in 3131.876s
# 	Calibrated mode 1020 / 1024 in 3134.442s
# 	Calibrated mode 1021 / 1024 in 3137.007s
# 	Calibrated mode 1022 / 1024 in 3139.572s
# 	Calibrated mode 1023 / 1024 in 3142.139s
# 	Calibrated mode 1024 / 1024 in 3144.704s
# Calibration complete.

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
# fname = 'hlc_opds_flatmaps_39_half_fourier_probes'
fname = 'hlc_opds_flatmaps_39_half_hadamard'

misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_opds_flatmaps_39_half_hadamard
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_opds_flatmaps_39_half_hadamard

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
fname = 'hlc_opds_flatmaps_39_half_fourier_probes'

response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), 
                                               rcond=1e-2, 
                                               nprobes=probe_modes.shape[0], pca_modes=None)
response_cube.shape, control_matrix.shape

reg_fun = iefc.construct_control_matrix
reg_conds = np.array([[0, 10, 15, 20],
                      [1e-1, 1e-3, 1e-1, 1e-2]])
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC
#
# So the differential images are the difference between each pair of probed images.
#
# The measurement vector is the concatenated area of the focal plane from each differential image.
#
# The coefficeints are the dot product of the cintrol_matrix with the measurement vector.
#
# The DM command is the dot product of the calibration modes with the the coefficients.

# %%
reload(iefc)
sys.reset_dms()
# probe_amplitude = 0.1 * sys.wavelength_c.to(u.m).value

images, dm_commands = iefc.run(sys, 
                               reg_fun,
                               reg_conds,
                               response_cube,
                               probe_modes, 
                               probe_amplitude, 
                               calibration_modes, 
                               weights, 
                               num_iterations=30,
                               loop_gain=0.5, 
                               leakage=0.0,
                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-01
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 2 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 3 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 4 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 5 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 6 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 7 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 8 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 9 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 10 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 11 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-03
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 12 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 13 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 14 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 15 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 16 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-01
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 17 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 18 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 19 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 20 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 21 / 30
# 	Computing EFC matrix via construct_control_matrix with condition value 1.00e-02
# Using Weighted Least Squares
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 22 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 23 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 24 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 25 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 26 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 27 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 28 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 29 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 30 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# I-EFC loop completed in 63.698s.

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
