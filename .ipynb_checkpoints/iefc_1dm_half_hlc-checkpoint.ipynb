# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_1dm as iefc
from wfsc import utils

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')

# %%
reload(cgi)
sys = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
sys.show_dms()

npsf = sys.npsf
Nact = sys.Nact

ref_psf = sys.snap()

misc.myimshow(ref_psf, lognorm=True)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * sys.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 2
iwa = 3
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':False
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95

weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask 
misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=sys.psf_pixelscale_lamD, pxscl2=sys.psf_pixelscale_lamD, pxscl3=sys.psf_pixelscale_lamD)

# %%
control_mask.sum()
# Out:
# 532

# %% [markdown]
# # Create probe and fourier modes

# %%
# probe_modes = iefc.create_probe_poke_modes(Nact, 
#                                            xinds=[Nact//3, Nact//2, 2*Nact//3],
#                                            yinds=[2*Nact//3, Nact//3, 2*Nact//3],
#                                            display=True)
probe_modes = iefc.create_probe_poke_modes(Nact, 
                                           xinds=[Nact//4, Nact//4-1],
                                           yinds=[Nact//4, Nact//4],
                                           display=True)

calibration_modes, fx, fy = iefc.create_fourier_modes(xfp, 
                                                      control_mask.reshape((npsf,npsf)), 
                                                      Nact, 
                                                      circular_mask=False)
calibration_modes[:] *= sys.dm_mask.flatten()


calibration_amplitude = 0.006 * sys.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * sys.wavelength_c.to(u.m).value
nmodes = calibration_modes.shape[0]

print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow(calibration_modes[0].reshape(Nact,Nact))
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 228

# %%
probe1=0
probe2=0
for i in range(nmodes):
    if i%2==0:
        probe1+=calibration_modes[i]
    else:
        probe2+=calibration_modes[i]
probe1 = probe1.reshape(Nact,Nact)
probe2 = probe2.reshape(Nact,Nact)
misc.myimshow3(probe1, probe2, calibration_modes.sum(axis=0).reshape(Nact,Nact))

probe1_fft = np.fft.fftshift(np.fft.fft2(probe1))
probe2_fft = np.fft.fftshift(np.fft.fft2(probe2))

misc.myimshow2(np.abs(probe1_fft), np.angle(probe1_fft))
misc.myimshow2(np.abs(probe2_fft), np.angle(probe2_fft))

# %%
probe1 = calibration_modes[:nmodes//2].sum(axis=0).reshape(Nact,Nact)
probe2 = calibration_modes[nmodes//2:].sum(axis=0).reshape(Nact,Nact)
probe_modes = np.array([probe1,probe2])
probe_modes.shape

misc.myimshow2(probe1, probe2)

probe1_fft = np.fft.fftshift(np.fft.fft2(probe1))
probe2_fft = np.fft.fftshift(np.fft.fft2(probe2))

misc.myimshow2(np.abs(probe1_fft), np.angle(probe1_fft))
misc.myimshow2(np.abs(probe2_fft), np.angle(probe2_fft))

# %%
calibration_modes.shape
# Out:
# (228, 2304)

# %%
reload(iefc)
sys.reset_dms()
differential_images, single_images = iefc.take_measurement(sys, 
                                                           probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(sys, 
                                                 probe_amplitude, probe_modes, 
                                                 calibration_amplitude, calibration_modes, 
                                                 start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 228 in 2.455s
# 	Calibrated mode 2 / 228 in 4.912s
# 	Calibrated mode 3 / 228 in 7.370s
# 	Calibrated mode 4 / 228 in 9.827s
# 	Calibrated mode 5 / 228 in 12.281s
# 	Calibrated mode 6 / 228 in 14.718s
# 	Calibrated mode 7 / 228 in 17.384s
# 	Calibrated mode 8 / 228 in 19.843s
# 	Calibrated mode 9 / 228 in 22.493s
# 	Calibrated mode 10 / 228 in 24.931s
# 	Calibrated mode 11 / 228 in 27.380s
# 	Calibrated mode 12 / 228 in 29.821s
# 	Calibrated mode 13 / 228 in 32.277s
# 	Calibrated mode 14 / 228 in 34.716s
# 	Calibrated mode 15 / 228 in 37.163s
# 	Calibrated mode 16 / 228 in 39.625s
# 	Calibrated mode 17 / 228 in 42.104s
# 	Calibrated mode 18 / 228 in 44.553s
# 	Calibrated mode 19 / 228 in 47.028s
# 	Calibrated mode 20 / 228 in 49.476s
# 	Calibrated mode 21 / 228 in 51.937s
# 	Calibrated mode 22 / 228 in 54.375s
# 	Calibrated mode 23 / 228 in 56.835s
# 	Calibrated mode 24 / 228 in 59.292s
# 	Calibrated mode 25 / 228 in 61.755s
# 	Calibrated mode 26 / 228 in 64.213s
# 	Calibrated mode 27 / 228 in 66.651s
# 	Calibrated mode 28 / 228 in 69.106s
# 	Calibrated mode 29 / 228 in 71.569s
# 	Calibrated mode 30 / 228 in 74.013s
# 	Calibrated mode 31 / 228 in 76.472s
# 	Calibrated mode 32 / 228 in 78.912s
# 	Calibrated mode 33 / 228 in 81.521s
# 	Calibrated mode 34 / 228 in 83.958s
# 	Calibrated mode 35 / 228 in 86.413s
# 	Calibrated mode 36 / 228 in 88.866s
# 	Calibrated mode 37 / 228 in 91.328s
# 	Calibrated mode 38 / 228 in 93.789s
# 	Calibrated mode 39 / 228 in 96.246s
# 	Calibrated mode 40 / 228 in 98.685s
# 	Calibrated mode 41 / 228 in 101.135s
# 	Calibrated mode 42 / 228 in 103.596s
# 	Calibrated mode 43 / 228 in 106.047s
# 	Calibrated mode 44 / 228 in 108.485s
# 	Calibrated mode 45 / 228 in 110.940s
# 	Calibrated mode 46 / 228 in 113.401s
# 	Calibrated mode 47 / 228 in 115.862s
# 	Calibrated mode 48 / 228 in 118.290s
# 	Calibrated mode 49 / 228 in 120.760s
# 	Calibrated mode 50 / 228 in 123.221s
# 	Calibrated mode 51 / 228 in 125.690s
# 	Calibrated mode 52 / 228 in 128.151s
# 	Calibrated mode 53 / 228 in 130.625s
# 	Calibrated mode 54 / 228 in 133.080s
# 	Calibrated mode 55 / 228 in 135.686s
# 	Calibrated mode 56 / 228 in 138.143s
# 	Calibrated mode 57 / 228 in 140.605s
# 	Calibrated mode 58 / 228 in 143.063s
# 	Calibrated mode 59 / 228 in 145.509s
# 	Calibrated mode 60 / 228 in 147.970s
# 	Calibrated mode 61 / 228 in 150.427s
# 	Calibrated mode 62 / 228 in 152.890s
# 	Calibrated mode 63 / 228 in 155.352s
# 	Calibrated mode 64 / 228 in 157.798s
# 	Calibrated mode 199 / 228 in 491.374s
# 	Calibrated mode 200 / 228 in 493.829s
# 	Calibrated mode 201 / 228 in 496.275s
# 	Calibrated mode 202 / 228 in 498.719s
# 	Calibrated mode 203 / 228 in 501.183s
# 	Calibrated mode 204 / 228 in 503.650s
# 	Calibrated mode 205 / 228 in 506.111s
# 	Calibrated mode 206 / 228 in 508.555s
# 	Calibrated mode 207 / 228 in 511.013s
# 	Calibrated mode 208 / 228 in 513.477s
# 	Calibrated mode 209 / 228 in 515.937s
# 	Calibrated mode 210 / 228 in 518.409s
# 	Calibrated mode 211 / 228 in 520.855s
# 	Calibrated mode 212 / 228 in 523.319s
# 	Calibrated mode 213 / 228 in 525.781s
# 	Calibrated mode 214 / 228 in 528.219s
# 	Calibrated mode 215 / 228 in 530.679s
# 	Calibrated mode 216 / 228 in 533.298s
# 	Calibrated mode 217 / 228 in 535.746s
# 	Calibrated mode 218 / 228 in 538.201s
# 	Calibrated mode 219 / 228 in 540.659s
# 	Calibrated mode 220 / 228 in 543.111s
# 	Calibrated mode 221 / 228 in 545.559s
# 	Calibrated mode 222 / 228 in 548.007s
# 	Calibrated mode 223 / 228 in 550.464s
# 	Calibrated mode 224 / 228 in 552.918s
# 	Calibrated mode 225 / 228 in 555.371s
# 	Calibrated mode 226 / 228 in 557.828s
# 	Calibrated mode 227 / 228 in 560.284s
# 	Calibrated mode 228 / 228 in 562.745s
# Calibration complete.

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
fname = 'hlc_opds_flatmaps_39_half_fourier_probes'

misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_opds_flatmaps_39_half_fourier_probes
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_opds_flatmaps_39_half_fourier_probes

# %%
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# fname = 'hlc_opds_flatmaps_39_half'
fname = 'hlc_opds_flatmaps_39_half_fourier_probes'

response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64), lognorm=True)

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), 
                                               rcond=1e-2, 
                                               nprobes=probe_modes.shape[0], pca_modes=None)
response_cube.shape, control_matrix.shape
# Out:
# Using Weighted Least Squares
# ((228, 2, 4096), (228, 1064))

# %% [markdown]
# # Run IEFC
#
# So the differential images are the difference between each pair of probed images.
#
# The measurement vector is the concatenated area of the focal plane from each differential image.
#
# The coefficeints are the dot product of the cintrol_matrix with the measurement vector.
#
# The DM command is the dot product of the calibration modes with the the coefficients.

# %%
reload(iefc)
sys.reset_dms()
probe_amplitude = 0.1 * sys.wavelength_c.to(u.m).value

images, dm_commands = iefc.run(sys, 
                               control_matrix, 
                               probe_modes, 
                               probe_amplitude, 
                               calibration_modes, 
                               weights, 
                               num_iterations=30,
                               gain=-0.5, leakage=0.0,
                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 2 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 3 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 4 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 5 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 6 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 7 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 8 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# 	Closed-loop iteration 9 / 30
# differential_images shape:  (2, 4096)
# measurement_vector shape:  (1064,)
# reconstructed_coefficients shape:  (228,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [52], in <cell line: 5>()
#       2 sys.reset_dms()
#       3 probe_amplitude = 0.1 * sys.wavelength_c.to(u.m).value
# ----> 5 images, dm_commands = iefc.run(sys,
#       6                                control_matrix,
#       7                                probe_modes,
#       8                                probe_amplitude,
#       9                                calibration_modes,
#      10                                weights,
#      11                                num_iterations=30,
#      12                                gain=-0.5, leakage=0.0,
#      13                                display=True)
#
# File ~/Documents/roman-cgi-iefc/wfsc/iefc_1dm.py:240, in run(sysi, control_matrix, probe_modes, probe_amplitude, calibration_modes, weights, num_iterations, gain, leakage, display)
#     237     metric_images.append(copy.copy(image))
#     238     dm_commands.append(sysi.get_dm1())
# --> 240     if display: misc.myimshow2(dm_commands[i], image,
#     241                                'DM', 'Image: Iteration {:d}'.format(i+1),
#     242                                lognorm2=True, vmin2=image.max()/1e6)
#     244 print('I-EFC loop completed in {:.3f}s.'.format(time.time()-start))
#     245 return metric_images, dm_commands
#
# File ~/src/cgi-phasec-poppy/cgi_phasec_poppy/misc.py:178, in myimshow2(arr1, arr2, title1, title2, npix, npix1, npix2, pxscl, pxscl1, pxscl2, cmap1, cmap2, lognorm1, lognorm2, vmin1, vmax1, vmin2, vmax2, patches1, patches2, display_fig, return_fig, figsize, dpi, wspace)
#     175 plt.subplots_adjust(wspace=wspace)
#     176 plt.close()
# --> 178 if display_fig: display(fig)
#     179 if return_fig: return fig,ax
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axis.py:1158, in Axis.draw(self, renderer, *args, **kwargs)
#    1155     return
#    1156 renderer.open_group(__name__, gid=self.get_gid())
# -> 1158 ticks_to_draw = self._update_ticks()
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axis.py:1055, in Axis._update_ticks(self)
#    1053 minor_locs = self.get_minorticklocs()
#    1054 minor_labels = self.minor.formatter.format_ticks(minor_locs)
# -> 1055 minor_ticks = self.get_minor_ticks(len(minor_locs))
#    1056 self.minor.formatter.set_locs(minor_locs)
#    1057 for tick, loc, label in zip(minor_ticks, minor_locs, minor_labels):
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axis.py:1388, in Axis.get_minor_ticks(self, numticks)
#    1384     numticks = len(self.get_minorticklocs())
#    1386 while len(self.minorTicks) < numticks:
#    1387     # Update the new tick label properties from the old.
# -> 1388     tick = self._get_tick(major=False)
#    1389     self.minorTicks.append(tick)
#    1390     self._copy_tick_props(self.minorTicks[0], tick)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axis.py:2322, in YAxis._get_tick(self, major)
#    2320 else:
#    2321     tick_kw = self._minor_tick_kw
# -> 2322 return YTick(self.axes, 0, major=major, **tick_kw)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axis.py:476, in YTick.__init__(self, *args, **kwargs)
#     475 def __init__(self, *args, **kwargs):
# --> 476     super().__init__(*args, **kwargs)
#     477     # x in axes coords, y in data coords
#     478     ax = self.axes
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/axis.py:166, in Tick.__init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     155 self.tick2line = mlines.Line2D(
#     156     [], [],
#     157     color=color, linestyle="none", zorder=zorder, visible=tick2On,
#     158     markeredgecolor=color, markersize=size, markeredgewidth=width,
#     159 )
#     160 self.gridline = mlines.Line2D(
#     161     [], [],
#     162     color=grid_color, alpha=grid_alpha, visible=gridOn,
#     163     linestyle=grid_linestyle, linewidth=grid_linewidth, marker="",
#     164     **grid_kw,
#     165 )
# --> 166 self.gridline.get_path()._interpolation_steps = \
#     167     GRIDLINE_INTERPOLATION_STEPS
#     168 self.label1 = mtext.Text(
#     169     np.nan, np.nan,
#     170     fontsize=labelsize, color=labelcolor, visible=label1On,
#     171     rotation=self._labelrotation[1])
#     172 self.label2 = mtext.Text(
#     173     np.nan, np.nan,
#     174     fontsize=labelsize, color=labelcolor, visible=label2On,
#     175     rotation=self._labelrotation[1])
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/lines.py:999, in Line2D.get_path(self)
#     997 """Return the `~matplotlib.path.Path` associated with this line."""
#     998 if self._invalidy or self._invalidx:
# --> 999     self.recache()
#    1000 return self._path
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/lines.py:686, in Line2D.recache(self, always)
#     684     interpolation_steps = 1
#     685 xy = STEP_LOOKUP_MAP[self._drawstyle](*self._xy.T)
# --> 686 self._path = Path(np.asarray(xy).T,
#     687                   _interpolation_steps=interpolation_steps)
#     688 self._transformed_path = None
#     689 self._invalidx = False
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#     133     codes = np.asarray(codes, self.code_type)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/matplotlib/_api/__init__.py:154, in check_shape(_shape, **kwargs)
#     149 for k, v in kwargs.items():
#     150     data_shape = v.shape
#     152     if len(target_shape) != len(data_shape) or any(
#     153             t not in [s, None]
# --> 154             for t, s in zip(target_shape, data_shape)
#     155     ):
#     156         dim_labels = iter(itertools.chain(
#     157             'MNLIJKLH',
#     158             (f"D{i}" for i in itertools.count())))
#     159         text_shape = ", ".join((str(n)
#     160                                 if n is not None
#     161                                 else next(dim_labels)
#     162                                 for n in target_shape))
#
# KeyboardInterrupt:

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
