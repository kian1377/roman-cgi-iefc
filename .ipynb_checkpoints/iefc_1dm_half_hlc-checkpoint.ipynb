# %%
import numpy as np
import scipy

import cupy as cp
import cupyx.scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import wfsc_tests as wfsc
wfsc.math_module.update_np(cp)
wfsc.math_module.update_scipy(cupyx.scipy)

from wfsc_tests.math_module import xp, _scipy

import cgi_phasec_poppy as cgi
reload(cgi)

from matplotlib.colors import ListedColormap
#Blue to Red Color scale for S1 and S2
colmap = np.zeros((255,3));
# Red
colmap[126:183,0]= np.linspace(0,1,57);
colmap[183:255,0]= 1;
# Green
colmap[0:96,1] = np.linspace(1,0,96);
colmap[158:255,1]= np.linspace(0,1,97);
# Blue
colmap[0:71,2] = 1;
colmap[71:128,2]= np.linspace(1,0,57);
colmap2 = colmap[128:,:]
colmap = ListedColormap(colmap)

iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')
# Out:
# INFO:numexpr.utils:Note: detected 96 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 96 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.

# %%
from emccd_detect.emccd_detect import EMCCDDetect, emccd_detect

meta_path = Path('/home/u21/kianmilani/src/emccd_detect/emccd_detect', 'emccd_detect', 'util', 'metadata.yaml')

dark_current = 0.05*u.electron/u.pix/u.hour

uoEMCCD = EMCCDDetect(
    em_gain=10.,
    full_well_image=50000.,  # e-
    full_well_serial=90000.,  # e-
    dark_current=dark_current.to_value(u.electron/u.pixel/u.second),  # e-/pix/s
    cic=0.016,  # e-/pix/frame
    read_noise=120.,  # e-/pix/frame
    bias=10000.,  # e-
    qe=0.9,
    cr_rate=5.,  # hits/cm^2/s
    pixel_pitch=13e-6,  # m
    eperdn=7.,
    nbits=14,
    numel_gain_register=604,
    meta_path=meta_path,
)

oEMCCD = EMCCDDetect(
    em_gain=10.,
    full_well_image=50000.,  # e-
    full_well_serial=90000.,  # e-
    dark_current=dark_current.to_value(u.electron/u.pixel/u.second),  # e-/pix/s
    cic=0.016,  # e-/pix/frame
    read_noise=120.,  # e-/pix/frame
    bias=10000.,  # e-
    qe=0.9,
    cr_rate=5.,  # hits/cm^2/s
    pixel_pitch=13e-6,  # m
    eperdn=7.,
    nbits=14,
    numel_gain_register=604,
    meta_path=meta_path,
)

# %%
reload(cgi)

source_flux = 2.0208517e8 * u.ph/u.s/u.m**2 # flux of 47 UMa at 575nm with 10% bandpass
uo_exp_time = 0.001*u.s # unocculted exposure time

c = cgi.CGI(cgi_mode='hlc', 
            use_pupil_defocus=True, 
            use_opds=True,
            source_flux=source_flux,
            exp_time=0.0005*u.s,
            EMCCD=uoEMCCD)

c.set_dm1(dm1_flat)
c.set_dm2(dm2_flat)

npsf = c.npsf
Nact = c.Nact

c.use_fpm = False
ref_unocc_im = c.snap()
wfsc.imshow1(ref_unocc_im, pxscl=c.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)

max_ref = cgi.ensure_np_array(ref_unocc_im).max()
display(max_ref)

o_exp_time = 2*u.s
c.exp_time = o_exp_time # occulted exposure time
c.EMCCD = oEMCCD

# Now use FPM and adjust the exposure time
c.use_fpm = True
ref_im = c.snap()
wfsc.imshow1(ref_im, pxscl=c.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)

contrast_map = ref_im/max_ref * uo_exp_time/o_exp_time
wfsc.imshow1(contrast_map, pxscl=c.psf_pixelscale_lamD, xlabel='$\lambda/D$', lognorm=True)
# Out:
# 10948

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(wfsc)
reload(wfsc.utils)
reload(wfsc.imshows)
xfp = (xp.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*c.psf_pixelscale_lamD
fpx,fpy = xp.meshgrid(xfp,xfp)
  
iwa = 3
owa = 9
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 2,
        'rotation':0,
        'full':True,
    }
roi1 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

iwa = 3
owa = 9
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 1.5,
        'rotation':0,
        'full':True,
    }
roi2 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

# wfsc.imshow2(roi1, roi2)
weight_map = roi1 + 0.1*(roi2 * ~roi1)
control_mask = weight_map>0
wfsc.imshow1(weight_map)

probe_amp = 3e-8
calib_amp = 5e-9

# %%
reload(wfsc.utils)
calib_amp = 5e-9
fourier_modes, fs = wfsc.utils.select_fourier_modes(c, control_mask, fourier_sampling=0.75) 
nmodes = fourier_modes.shape[0]
print(fourier_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
wfsc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD, patches=patches)
# Out:
# (400, 2304) (200, 2)

# %%
for i in range(fourier_modes.shape[0]//2):
    try:
        wfsc.imshow2(fourier_modes[i].reshape(Nact,Nact), ref_im, 
                       'Frequency Sampled: ({:.3f}, {:.3f})'.format(fs[i][0], fs[i][1]),
                       lognorm2=True,
                       pxscl2=c.psf_pixelscale_lamD, 
                       patches2=[Circle(fs[i], 0.25, fill=True, color='g'),
                                 Circle(-fs[i], 0.25, fill=True, color='g')])
        clear_output(wait=True)
        time.sleep(0.25)
    except KeyboardInterrupt:
        break

# %%
reload(wfsc.utils)
probe_modes_1 = wfsc.utils.create_fourier_probes(fourier_modes, Nact=48, plot=True)

probe_modes_2 = wfsc.utils.create_probe_poke_modes(Nact, 
                                                   poke_indices=[(Nact//5, Nact//2), (Nact//5+1, Nact//2)], 
                                                   plot=True)

# probe_modes = probe_modes_1
probe_modes = probe_modes_2
# probe_modes = probe_modes_1 + probe_modes_2
wfsc.imshow2(probe_modes[0], probe_modes[1])

# %%
reload(wfsc.iefc_1dm)

probe_amp = 5e-8
calib_amp = 5e-9

c.set_dm1(dm1_flat)
c.set_dm2(dm2_flat)

differential_images, single_images = wfsc.iefc_1dm.take_measurement(c, 
                                                                   probe_modes_2, probe_amp, 
                                                                   return_all=True)
ims = differential_images.reshape(2, c.npsf, c.npsf)
wfsc.imshow3(ims[0], ims[1], ims[0]-ims[1], wspace=0.35)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(wfsc.iefc_1dm)
response_matrix, response_cube = wfsc.iefc_1dm.calibrate(c, 
                                                         control_mask.ravel(),
                                                         probe_amp, probe_modes, 
                                                         calib_amp, fourier_modes, 
                                                         return_all=True)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 400 in 2.475s
# 	Calibrated mode 2 / 400 in 4.947s
# 	Calibrated mode 3 / 400 in 7.419s
# 	Calibrated mode 4 / 400 in 10.035s
# 	Calibrated mode 5 / 400 in 12.497s
# 	Calibrated mode 6 / 400 in 14.959s
# 	Calibrated mode 7 / 400 in 17.417s
# 	Calibrated mode 8 / 400 in 19.885s
# 	Calibrated mode 9 / 400 in 22.347s
# 	Calibrated mode 10 / 400 in 24.808s
# 	Calibrated mode 11 / 400 in 27.271s
# 	Calibrated mode 12 / 400 in 29.732s
# 	Calibrated mode 13 / 400 in 32.193s
# 	Calibrated mode 14 / 400 in 34.654s
# 	Calibrated mode 15 / 400 in 37.118s
# 	Calibrated mode 16 / 400 in 39.578s
# 	Calibrated mode 339 / 400 in 838.630s
# 	Calibrated mode 340 / 400 in 841.103s
# 	Calibrated mode 341 / 400 in 843.578s
# 	Calibrated mode 342 / 400 in 846.045s
# 	Calibrated mode 343 / 400 in 848.516s
# 	Calibrated mode 344 / 400 in 850.989s
# 	Calibrated mode 345 / 400 in 853.568s
# 	Calibrated mode 346 / 400 in 856.035s
# 	Calibrated mode 347 / 400 in 858.501s
# 	Calibrated mode 348 / 400 in 860.971s
# 	Calibrated mode 349 / 400 in 863.441s
# 	Calibrated mode 350 / 400 in 865.910s
# 	Calibrated mode 351 / 400 in 868.378s
# 	Calibrated mode 352 / 400 in 870.852s
# 	Calibrated mode 353 / 400 in 873.322s
# 	Calibrated mode 354 / 400 in 875.795s
# 	Calibrated mode 355 / 400 in 878.274s
# 	Calibrated mode 356 / 400 in 880.745s
# 	Calibrated mode 357 / 400 in 883.216s
# 	Calibrated mode 358 / 400 in 885.686s
# 	Calibrated mode 359 / 400 in 888.160s
# 	Calibrated mode 360 / 400 in 890.632s
# 	Calibrated mode 361 / 400 in 893.102s
# 	Calibrated mode 362 / 400 in 895.577s
# 	Calibrated mode 363 / 400 in 898.045s
# 	Calibrated mode 364 / 400 in 900.516s
# 	Calibrated mode 365 / 400 in 902.988s
# 	Calibrated mode 366 / 400 in 905.566s
# 	Calibrated mode 367 / 400 in 908.030s
# 	Calibrated mode 368 / 400 in 910.494s
# 	Calibrated mode 369 / 400 in 912.958s
# 	Calibrated mode 370 / 400 in 915.427s
# 	Calibrated mode 371 / 400 in 917.904s
# 	Calibrated mode 372 / 400 in 920.372s
# 	Calibrated mode 373 / 400 in 922.840s
# 	Calibrated mode 374 / 400 in 925.309s
# 	Calibrated mode 375 / 400 in 927.780s
# 	Calibrated mode 376 / 400 in 930.246s
# 	Calibrated mode 377 / 400 in 932.716s
# 	Calibrated mode 378 / 400 in 935.188s
# 	Calibrated mode 379 / 400 in 937.660s
# 	Calibrated mode 380 / 400 in 940.138s
# 	Calibrated mode 381 / 400 in 942.610s
# 	Calibrated mode 382 / 400 in 945.081s
# 	Calibrated mode 383 / 400 in 947.553s
# 	Calibrated mode 384 / 400 in 950.027s
# 	Calibrated mode 385 / 400 in 952.498s
# 	Calibrated mode 386 / 400 in 954.971s
# 	Calibrated mode 387 / 400 in 957.441s
# 	Calibrated mode 388 / 400 in 960.017s
# 	Calibrated mode 389 / 400 in 962.486s
# 	Calibrated mode 390 / 400 in 964.954s
# 	Calibrated mode 391 / 400 in 967.426s
# 	Calibrated mode 392 / 400 in 969.893s
# 	Calibrated mode 393 / 400 in 972.365s
# 	Calibrated mode 394 / 400 in 974.838s
# 	Calibrated mode 395 / 400 in 977.311s
# 	Calibrated mode 396 / 400 in 979.781s
# 	Calibrated mode 397 / 400 in 982.254s
# 	Calibrated mode 398 / 400 in 984.731s
# 	Calibrated mode 399 / 400 in 987.214s
# 	Calibrated mode 400 / 400 in 989.695s
# Calibration complete.

# %%
response_sum = xp.sum(abs(response_cube), axis=(0,1))
wfsc.imshow1(response_sum.reshape(npsf, npsf), lognorm=True)

# %%
import misc_funs as misc

misc.save_fits(iefc_dir/'response-data'/'hlc_iefc_response_matrix_20230518.fits', 
               wfsc.utils.ensure_np_array(response_matrix))
misc.save_fits(iefc_dir/'response-data'/'hlc_iefc_response_cube_20230518.fits', 
               wfsc.utils.ensure_np_array(response_cube))
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_iefc_response_matrix_20230518.fits
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_iefc_response_cube_20230518.fits

# %%
response_matrix = xp.array(fits.getdata(iefc_dir/'response-data'/'hlc_iefc_response_matrix_20230518.fits'))
response_cube_2 = xp.array(fits.getdata(iefc_dir/'response-data'/'hlc_iefc_response_cube_20230518.fits'))

# %%
response_sum_2 = xp.sum(abs(response_cube_2), axis=(0,1))
wfsc.imshow1(response_sum.reshape(npsf, npsf), lognorm=True)

# %%
wfsc.imshow1(response_sum.reshape(npsf, npsf)-response_sum_2.reshape(npsf, npsf))

# %% [markdown]
# # Create control matrix

# %%
im = c.snap()
wfsc.imshow1(im, lognorm=True)
if mean_readout<thresh
# Out:
# 2095.5505836575876

# %%
response_matrix.shape, Wmatrix.shape
# Out:
# ((1244, 476), (1244, 1244))

# %%
reload(wfsc.iefc_1dm)
reload(wfsc.utils)

c.set_dm1(dm1_flat)
c.set_dm2(dm2_flat)
c.exp_time = o_exp_time

reg_cond = 1e-2
reg_conds = [(1e-1,10), (1e-2, 20), (1e-3, 20)]

cm_tik = wfsc.utils.TikhonovInverse(response_matrix, rcond=reg_cond)
Wmatrix = np.diag(np.concatenate((weight_map[control_mask], weight_map[control_mask])))
cm_wls = wfsc.utils.WeightedLeastSquares(response_matrix, Wmatrix, rcond=reg_cond)

contrast_parameters = {
    'max_ref':max_ref,
    'unocculted_exp_time':uo_exp_time,
}
for i in range(len(reg_conds)):

    cm_wls = wfsc.utils.WeightedLeastSquares(response_matrix, Wmatrix, rcond=reg_conds[i][0])
    
    images, dm_commands_1 = wfsc.iefc_1dm.run(c, 
                                              cm_wls,
                                              probe_modes, 
                                              probe_amp, 
                                              fourier_modes,
                                              control_mask, 
                                              num_iterations=reg_conds[i][1], 
                                              loop_gain=0.5, 
                                              leakage=0.0,
                                              thresh=3000, 
                                              exp_time_gain=1.1,
                                              plot_all=True,
                                              contrast_parameters=contrast_parameters,
                                             )
# Out:
# Running I-EFC...
# 	Closed-loop iteration 0 / 10
# 	Closed-loop iteration 1 / 10
# 	Closed-loop iteration 2 / 10
# 	Closed-loop iteration 3 / 10
# 	Closed-loop iteration 4 / 10
# 	Closed-loop iteration 5 / 10
# 	Closed-loop iteration 6 / 10
# 	Closed-loop iteration 7 / 10
# 	Closed-loop iteration 8 / 10
# 	Closed-loop iteration 9 / 10
# 	Closed-loop iteration 10 / 10
# I-EFC loop completed in 23.467s.
# Running I-EFC...
# 	Closed-loop iteration 0 / 20
# 	Closed-loop iteration 1 / 20
# 	Closed-loop iteration 2 / 20
# 	Closed-loop iteration 3 / 20
# 	Closed-loop iteration 4 / 20
# 	Closed-loop iteration 5 / 20
# 	Closed-loop iteration 6 / 20
# 	Closed-loop iteration 7 / 20
# 	Closed-loop iteration 8 / 20
