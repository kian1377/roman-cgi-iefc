# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

from poppy_roman_cgi_phasec import cgi
from wfsc import iefc_2dm as iefc
from wfsc import utils

import misc

dm1_flat = 2*fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')
# Out:
# INFO:numexpr.utils:Note: detected 96 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 96 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.

# %%
# !nvidia-smi
# Out:
# Fri Jul 22 14:51:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 515.48.07    Driver Version: 515.48.07    CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100S-PCI...  On   | 00000000:25:00.0 Off |                    0 |
# | N/A   32C    P0    38W / 250W |  32504MiB / 32768MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     32446      C   ...oppy39-exp-env/bin/python    31407MiB |
# |    0   N/A  N/A     82880      C   ...oppy39-exp-env/bin/python     1093MiB |
# +-----------------------------------------------------------------------------+

# %%
reload(cgi)
hlc = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
hlc.show_dms()

npsf = hlc.npsf
Nact = hlc.Nact

ref_psf = hlc.snap()

misc.myimshow(ref_psf, lognorm=True)
# Out:
# (268, 268)
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Input In [2], in <cell line: 14>()
#      11 npsf = hlc.npsf
#      12 Nact = hlc.Nact
# ---> 14 ref_psf = hlc.snap()
#      16 misc.myimshow(ref_psf, lognorm=True)
#
# File ~/Documents/roman-cgi-iefc/poppy_roman_cgi_phasec/cgi.py:455, in CGI.snap(self)
#     453 self.init_inwave()
#     454 if self.cgi_mode=='hlc':
# --> 455     wfs = hlc.run(self, return_intermediates=False)
#     456 else:
#     457     wfs = spc.run(self, return_intermediates=False)
#
# File ~/Documents/roman-cgi-iefc/poppy_roman_cgi_phasec/hlc.py:229, in run(HLC, return_intermediates)
#     224     fosys2.add_optic(HLC.detector, distance=d_fold4_image)
#     226 #     fosys2.add_optic(HLC.detector, distance=d_lens_2_pp2_fold4 + d_fold4_image)
#     227
#     228     # Calculate a psf from the first optical system to retrieve the final wavefront at the FPM plane
# --> 229     fpm_hdu, wfs_to_fpm = fosys1.calc_psf(wavelength=HLC.wavelength, inwave=HLC.inwave,
#     230                                           return_final=True, return_intermediates=return_intermediates)
#     231     inwave2 = copy.deepcopy(wfs_to_fpm[-1]) # copy Wavefront object for use in the post FPM system
#     233     if HLC.use_fpm:
#
# File ~/src/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/src/poppy/poppy/poppy_core.py:1743, in BaseOpticalSystem.calc_psf(self, wavelength, weight, save_intermediates, save_intermediates_what, display, return_intermediates, return_final, source, normalize, display_intermediates, inwave)
#    1741     plt.clf()
#    1742 for wlen, wave_weight in zip(wavelength, normwts):
# -> 1743     mono_psf, mono_intermediate_wfs = self.propagate_mono(
#    1744         wlen,
#    1745         retain_intermediates=retain_intermediates,
#    1746         retain_final=return_final,
#    1747         display_intermediates=display_intermediates,
#    1748         normalize=normalize,
#    1749         inwave=inwave
#    1750     )
#    1752     if outfits is None:
#    1753         # for the first wavelength processed, set up the arrays where we accumulate the output
#    1754         outfits = mono_psf
#
# File ~/src/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/src/poppy/poppy/poppy_core.py:1881, in BaseOpticalSystem.propagate_mono(self, wavelength, normalize, retain_intermediates, retain_final, display_intermediates, inwave)
#    1879     wavefront, intermediate_wfs = self.propagate(wavefront, **kwargs)
#    1880 else:
# -> 1881     wavefront = self.propagate(wavefront, **kwargs)
#    1882     intermediate_wfs = []
#    1884 if (not retain_intermediates) & retain_final:  # return the full complex wavefront of the last plane.
#
# File ~/src/poppy/poppy/fresnel.py:1430, in FresnelOpticalSystem.propagate(self, wavefront, normalize, return_intermediates, display_intermediates)
#    1427     s0 = time.time()
#    1429 # The actual propagation:
# -> 1430 wavefront.propagate_to(optic, distance)
#    1431 wavefront *= optic
#    1433 # Normalize if appropriate:
#
# File ~/src/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/src/poppy/poppy/fresnel.py:672, in FresnelWavefront.propagate_to(self, optic, distance)
#     669 # Apply Fresnel propagation for the specified distance, regardless of
#     670 # what type of plane is next
#     671 if distance != 0 * u.m:
# --> 672     self.propagate_fresnel(distance)
#     674 self.current_plane_index += 1
#     676 # Now we may do some further manipulations depending on the next plane
#
# File ~/src/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/src/poppy/poppy/fresnel.py:866, in FresnelWavefront.propagate_fresnel(self, delta_z, display_intermed)
#     863     plt.figure()
#     864     self.display('both', colorbar=True, title="Starting Surface")
# --> 866 self.wavefront = accel_math._fftshift(self.wavefront)
#     867 _log.debug("Beginning Fresnel Prop. Waist at z = " + str(self.z_w0))
#     869 if not self.spherical:
#
# File ~/src/poppy/poppy/accel_math.py:157, in _fftshift(x)
#     155     return x
#     156 elif _USE_CUPY:
# --> 157     return cp.fft.fftshift(x)
#     158 else:
#     159     return np.fft.fftshift(x)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/cupy/fft/_fft.py:1083, in fftshift(x, axes)
#    1081     axes = (axes,)
#    1082 for axis in axes:
# -> 1083     x = cupy.roll(x, x.shape[axis] // 2, axis)
#    1084 return x
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/cupy/_manipulation/rearrange.py:140, in roll(a, shift, axis)
#     135     if offset:
#     136         # (original, result), (original, result)
#     137         rolls[ax] = ((slice(None, -offset), slice(offset, None)),
#     138                      (slice(-offset, None), slice(None, offset)))
# --> 140 result = cupy.empty_like(a)
#     141 for indices in itertools.product(*rolls):
#     142     arr_index, res_index = zip(*indices)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/cupy/_creation/basic.py:88, in empty_like(a, dtype, order, subok, shape)
#      85 order, strides, memptr = _new_like_order_and_strides(a, dtype, order,
#      86                                                      shape)
#      87 shape = shape if shape else a.shape
# ---> 88 return cupy.ndarray(shape, dtype, memptr, strides, order)
#
# File cupy/_core/core.pyx:171, in cupy._core.core.ndarray.__init__()
#
# File cupy/cuda/memory.pyx:698, in cupy.cuda.memory.alloc()
#
# File cupy/cuda/memory.pyx:1375, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1396, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1076, in cupy.cuda.memory.SingleDeviceMemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1097, in cupy.cuda.memory.SingleDeviceMemoryPool._malloc()
#
# File cupy/cuda/memory.pyx:1335, in cupy.cuda.memory.SingleDeviceMemoryPool._try_malloc()
#
# OutOfMemoryError: Out of memory allocating 16,777,216 bytes (allocated so far: 770,566,656 bytes).

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlc.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1
iwa = 3
owa = 7
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95

weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask
misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=hlc.psf_pixelscale_lamD, pxscl2=hlc.psf_pixelscale_lamD, pxscl3=hlc.psf_pixelscale_lamD)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(iefc)
probe_modes = iefc.create_probe_poke_modes(Nact, 
                                           xinds=[Nact//4, Nact//4+1],
                                           yinds=[Nact//4, Nact//4], 
                                           display=True)

calibration_modes, fx, fy = iefc.create_fourier_modes(xfp, 
                                                      control_mask.reshape((npsf,npsf)), 
                                                      Nact, 
                                                      circular_mask=False)
calibration_modes[:] *= hlc.dm_mask.flatten()

nmodes = calibration_modes.shape[0]
print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow(calibration_modes[0].reshape(Nact,Nact))

calibration_amplitude = 0.006 * hlc.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * hlc.wavelength_c.to(u.m).value
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 162

# %%
reload(iefc)
hlc.reset_dms()
differential_images, single_images = iefc.take_measurement(hlc, probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(hlc, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, calibration_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 162 in 4.347s
# 	Calibrated mode 2 / 162 in 8.684s
# 	Calibrated mode 3 / 162 in 13.019s
# 	Calibrated mode 4 / 162 in 17.348s
# 	Calibrated mode 5 / 162 in 21.680s
# 	Calibrated mode 6 / 162 in 26.008s
# 	Calibrated mode 7 / 162 in 30.360s
# 	Calibrated mode 8 / 162 in 34.859s
# 	Calibrated mode 9 / 162 in 39.272s
# 	Calibrated mode 10 / 162 in 43.594s
# 	Calibrated mode 11 / 162 in 47.926s
# 	Calibrated mode 12 / 162 in 52.267s
# 	Calibrated mode 13 / 162 in 56.613s
# 	Calibrated mode 14 / 162 in 60.955s
# 	Calibrated mode 15 / 162 in 65.292s
# 	Calibrated mode 16 / 162 in 69.640s
# 	Calibrated mode 17 / 162 in 73.985s
# 	Calibrated mode 18 / 162 in 78.447s
# 	Calibrated mode 19 / 162 in 82.765s
# 	Calibrated mode 20 / 162 in 87.092s
# 	Calibrated mode 21 / 162 in 91.417s
# 	Calibrated mode 22 / 162 in 95.735s
# 	Calibrated mode 23 / 162 in 100.044s
# 	Calibrated mode 24 / 162 in 104.358s
# 	Calibrated mode 25 / 162 in 108.685s
# 	Calibrated mode 26 / 162 in 113.009s
# 	Calibrated mode 27 / 162 in 117.442s
# 	Calibrated mode 28 / 162 in 121.773s
# 	Calibrated mode 29 / 162 in 126.094s
# 	Calibrated mode 30 / 162 in 130.413s
# 	Calibrated mode 31 / 162 in 134.731s
# 	Calibrated mode 32 / 162 in 139.057s
# 	Calibrated mode 33 / 162 in 143.378s
# 	Calibrated mode 34 / 162 in 147.702s
# 	Calibrated mode 35 / 162 in 152.022s
# 	Calibrated mode 36 / 162 in 156.345s
# 	Calibrated mode 37 / 162 in 160.769s
# 	Calibrated mode 38 / 162 in 165.089s
# 	Calibrated mode 39 / 162 in 169.405s
# 	Calibrated mode 40 / 162 in 173.722s
# 	Calibrated mode 41 / 162 in 178.050s
# 	Calibrated mode 42 / 162 in 182.378s
# 	Calibrated mode 43 / 162 in 186.693s
# 	Calibrated mode 44 / 162 in 191.023s
# 	Calibrated mode 45 / 162 in 195.349s
# 	Calibrated mode 46 / 162 in 199.770s
# 	Calibrated mode 47 / 162 in 204.081s
# 	Calibrated mode 48 / 162 in 208.423s
# 	Calibrated mode 49 / 162 in 212.732s
# 	Calibrated mode 50 / 162 in 217.055s
# 	Calibrated mode 51 / 162 in 221.371s
# 	Calibrated mode 52 / 162 in 225.785s
# 	Calibrated mode 53 / 162 in 230.097s
# 	Calibrated mode 54 / 162 in 234.416s
# 	Calibrated mode 55 / 162 in 238.838s
# 	Calibrated mode 56 / 162 in 243.166s
# 	Calibrated mode 57 / 162 in 247.472s
# 	Calibrated mode 58 / 162 in 251.779s
# 	Calibrated mode 59 / 162 in 256.091s
# 	Calibrated mode 60 / 162 in 260.411s
# 	Calibrated mode 61 / 162 in 264.728s
# 	Calibrated mode 62 / 162 in 269.052s
# 	Calibrated mode 63 / 162 in 273.366s
# 	Calibrated mode 64 / 162 in 277.775s
# 	Calibrated mode 65 / 162 in 282.083s
# 	Calibrated mode 66 / 162 in 286.397s
# 	Calibrated mode 67 / 162 in 290.718s
# 	Calibrated mode 68 / 162 in 295.039s
# 	Calibrated mode 69 / 162 in 299.358s
# 	Calibrated mode 70 / 162 in 303.667s
# 	Calibrated mode 71 / 162 in 307.977s
# 	Calibrated mode 72 / 162 in 312.285s
# 	Calibrated mode 73 / 162 in 316.598s
# 	Calibrated mode 74 / 162 in 321.005s
# 	Calibrated mode 75 / 162 in 325.321s
# 	Calibrated mode 76 / 162 in 329.625s
# 	Calibrated mode 77 / 162 in 333.946s
# 	Calibrated mode 78 / 162 in 338.262s
# 	Calibrated mode 79 / 162 in 342.568s
# 	Calibrated mode 80 / 162 in 346.874s
# 	Calibrated mode 81 / 162 in 351.189s
# 	Calibrated mode 82 / 162 in 355.497s
# 	Calibrated mode 83 / 162 in 359.900s
# 	Calibrated mode 84 / 162 in 364.217s
# 	Calibrated mode 85 / 162 in 368.529s
# 	Calibrated mode 86 / 162 in 372.850s
# 	Calibrated mode 87 / 162 in 377.152s
# 	Calibrated mode 88 / 162 in 381.464s
# 	Calibrated mode 89 / 162 in 385.775s
# 	Calibrated mode 90 / 162 in 390.100s
# 	Calibrated mode 91 / 162 in 394.421s
# 	Calibrated mode 92 / 162 in 398.831s
# 	Calibrated mode 93 / 162 in 403.143s
# 	Calibrated mode 94 / 162 in 407.456s
# 	Calibrated mode 95 / 162 in 411.780s
# 	Calibrated mode 96 / 162 in 416.100s
# 	Calibrated mode 97 / 162 in 420.421s
# 	Calibrated mode 98 / 162 in 424.738s
# 	Calibrated mode 99 / 162 in 429.048s
# 	Calibrated mode 100 / 162 in 433.372s
# 	Calibrated mode 101 / 162 in 437.789s
# 	Calibrated mode 102 / 162 in 442.101s
# 	Calibrated mode 103 / 162 in 446.418s
# 	Calibrated mode 104 / 162 in 450.723s
# 	Calibrated mode 105 / 162 in 455.034s
# 	Calibrated mode 106 / 162 in 459.341s
# 	Calibrated mode 107 / 162 in 463.655s
# 	Calibrated mode 108 / 162 in 467.977s
# 	Calibrated mode 109 / 162 in 472.298s
# 	Calibrated mode 110 / 162 in 476.713s
# 	Calibrated mode 111 / 162 in 481.034s
# 	Calibrated mode 112 / 162 in 485.340s
# 	Calibrated mode 113 / 162 in 489.655s
# 	Calibrated mode 114 / 162 in 493.973s
# 	Calibrated mode 115 / 162 in 498.282s
# 	Calibrated mode 116 / 162 in 502.592s
# 	Calibrated mode 117 / 162 in 506.911s
# 	Calibrated mode 118 / 162 in 511.227s
# 	Calibrated mode 119 / 162 in 515.545s
# 	Calibrated mode 120 / 162 in 519.950s
# 	Calibrated mode 121 / 162 in 524.259s
# 	Calibrated mode 122 / 162 in 528.573s
# 	Calibrated mode 123 / 162 in 532.882s
# 	Calibrated mode 124 / 162 in 537.201s
# 	Calibrated mode 125 / 162 in 541.518s
# 	Calibrated mode 126 / 162 in 545.830s
# 	Calibrated mode 127 / 162 in 550.149s
# 	Calibrated mode 128 / 162 in 554.455s
# 	Calibrated mode 129 / 162 in 558.869s
# 	Calibrated mode 130 / 162 in 563.182s
# 	Calibrated mode 131 / 162 in 567.498s
# 	Calibrated mode 132 / 162 in 571.814s
# 	Calibrated mode 133 / 162 in 576.130s
# 	Calibrated mode 134 / 162 in 580.443s
# 	Calibrated mode 135 / 162 in 584.764s
# 	Calibrated mode 136 / 162 in 589.257s
# 	Calibrated mode 137 / 162 in 593.571s
# 	Calibrated mode 138 / 162 in 597.987s
# 	Calibrated mode 139 / 162 in 602.513s
# 	Calibrated mode 140 / 162 in 606.826s
# 	Calibrated mode 141 / 162 in 611.147s
# 	Calibrated mode 142 / 162 in 615.468s
# 	Calibrated mode 143 / 162 in 619.799s
# 	Calibrated mode 144 / 162 in 624.124s
# 	Calibrated mode 145 / 162 in 628.441s
# 	Calibrated mode 146 / 162 in 632.770s
# 	Calibrated mode 147 / 162 in 637.181s
# 	Calibrated mode 148 / 162 in 641.490s
# 	Calibrated mode 149 / 162 in 645.801s
# 	Calibrated mode 150 / 162 in 650.116s
# 	Calibrated mode 151 / 162 in 654.426s
# 	Calibrated mode 152 / 162 in 658.742s
# 	Calibrated mode 153 / 162 in 663.049s
# 	Calibrated mode 154 / 162 in 667.363s
# 	Calibrated mode 155 / 162 in 671.682s
# 	Calibrated mode 156 / 162 in 675.997s
# 	Calibrated mode 157 / 162 in 680.407s
# 	Calibrated mode 158 / 162 in 684.710s
# 	Calibrated mode 159 / 162 in 689.014s
# 	Calibrated mode 160 / 162 in 693.323s
# 	Calibrated mode 161 / 162 in 697.632s
# 	Calibrated mode 162 / 162 in 701.939s
# Calibration complete.

# %%
fname = 'hlc_2dm_37'
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

# %%
misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_2dm_37
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_2dm_37

# %%
response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, weights.flatten(), 
                                               rcond1=1e-2,
                                               rcond2=1e-2,
                                               nprobes=probe_modes.shape[0], pca_modes=None)
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC

# %%
reload(iefc)

hlc.reset_dms()

images, dm1_commands, dm2_commands = iefc.run(hlc, 
                                              control_matrix, 
                                              probe_modes, 
                                              probe_amplitude, 
                                              calibration_modes, 
                                              weights, 
                                              num_iterations=10, 
                                              gain=-0.5, leakage=0.0,
                                              display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 10
# 	Closed-loop iteration 2 / 10
# 	Closed-loop iteration 3 / 10
# 	Closed-loop iteration 4 / 10
# 	Closed-loop iteration 5 / 10
# 	Closed-loop iteration 6 / 10
# 	Closed-loop iteration 7 / 10
# 	Closed-loop iteration 8 / 10
# 	Closed-loop iteration 9 / 10
# 	Closed-loop iteration 10 / 10
# I-EFC loop completed in 17.221s.

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
