# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_1dm as iefc
from wfsc import utils

import misc

dm1_flat = 2*fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')

# %%
reload(cgi)
hlc = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
hlc.show_dms()

npsf = hlc.npsf
Nact = hlc.Nact

ref_psf = hlc.snap()

misc.myimshow(ref_psf, lognorm=True)
# Out:
# (268, 268)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlc.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1
iwa = 3
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95

weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask 
misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=hlc.psf_pixelscale_lamD, pxscl2=hlc.psf_pixelscale_lamD, pxscl3=hlc.psf_pixelscale_lamD)

# %% [markdown]
# # Create probe and fourier modes

# %%
probe_modes = iefc.create_probe_poke_modes(Nact, 
                                           xinds=[Nact//3, Nact//2, 2*Nact//3],
                                           yinds=[2*Nact//3, Nact//3, 2*Nact//3],
                                           display=True)

calibration_modes, fx, fy = iefc.create_fourier_modes(xfp, 
                                                      control_mask.reshape((npsf,npsf)), 
                                                      Nact, 
                                                      circular_mask=False)
calibration_modes[:] *= hlc.dm_mask.flatten()


calibration_amplitude = 0.006 * hlc.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * hlc.wavelength_c.to(u.m).value
nmodes = calibration_modes.shape[0]

print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow(calibration_modes[0].reshape(Nact,Nact))
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 296

# %%
reload(iefc)
hlc.reset_dms()
differential_images, single_images = iefc.take_measurement(hlc, probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %%
hlc.show_dms()

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(hlc, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, calibration_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 296 in 3.894s
# 	Calibrated mode 2 / 296 in 7.591s
# 	Calibrated mode 3 / 296 in 11.304s
# 	Calibrated mode 4 / 296 in 15.019s
# 	Calibrated mode 5 / 296 in 18.726s
# 	Calibrated mode 6 / 296 in 22.433s
# 	Calibrated mode 7 / 296 in 26.139s
# 	Calibrated mode 8 / 296 in 29.857s
# 	Calibrated mode 9 / 296 in 33.568s
# 	Calibrated mode 10 / 296 in 37.278s
# 	Calibrated mode 11 / 296 in 41.126s
# 	Calibrated mode 12 / 296 in 44.837s
# 	Calibrated mode 13 / 296 in 48.537s
# 	Calibrated mode 14 / 296 in 52.238s
# 	Calibrated mode 15 / 296 in 55.937s
# 	Calibrated mode 270 / 296 in 1005.441s
# 	Calibrated mode 271 / 296 in 1009.309s
# 	Calibrated mode 272 / 296 in 1013.039s
# 	Calibrated mode 273 / 296 in 1016.764s
# 	Calibrated mode 274 / 296 in 1020.504s
# 	Calibrated mode 275 / 296 in 1024.245s
# 	Calibrated mode 276 / 296 in 1027.973s
# 	Calibrated mode 277 / 296 in 1031.811s
# 	Calibrated mode 278 / 296 in 1035.532s
# 	Calibrated mode 279 / 296 in 1039.255s
# 	Calibrated mode 280 / 296 in 1042.979s
# 	Calibrated mode 281 / 296 in 1046.691s
# 	Calibrated mode 282 / 296 in 1050.423s
# 	Calibrated mode 283 / 296 in 1054.146s
# 	Calibrated mode 284 / 296 in 1057.867s
# 	Calibrated mode 285 / 296 in 1061.586s
# 	Calibrated mode 286 / 296 in 1065.301s
# 	Calibrated mode 287 / 296 in 1069.153s
# 	Calibrated mode 288 / 296 in 1072.862s
# 	Calibrated mode 289 / 296 in 1076.573s
# 	Calibrated mode 290 / 296 in 1080.288s
# 	Calibrated mode 291 / 296 in 1084.008s
# 	Calibrated mode 292 / 296 in 1087.728s
# 	Calibrated mode 293 / 296 in 1091.451s
# 	Calibrated mode 294 / 296 in 1095.212s
# 	Calibrated mode 295 / 296 in 1098.939s
# 	Calibrated mode 296 / 296 in 1102.659s
# Calibration complete.

# %%
fname = 'hlc_opds_flatmaps_39'

iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

# %%
misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_opds_flatmaps_39
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_opds_flatmaps_39

# %%
response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, weights.flatten(), 
                                               rcond=1e-2, 
                                               nprobes=probe_modes.shape[0], pca_modes=None)
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC

# %%
hlc.reset_dms()

# %%
reload(iefc)
images, dm_commands = iefc.run(hlc, 
                               control_matrix, 
                               probe_modes, 
                               probe_amplitude, 
                               calibration_modes, 
                               weights, 
                               num_iterations=15, gain=-0.5, leakage=0.0,
                               display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 15
# 	Closed-loop iteration 2 / 15
# 	Closed-loop iteration 3 / 15
# 	Closed-loop iteration 4 / 15
# 	Closed-loop iteration 5 / 15
# 	Closed-loop iteration 6 / 15
# 	Closed-loop iteration 7 / 15
# 	Closed-loop iteration 8 / 15
# 	Closed-loop iteration 9 / 15
# 	Closed-loop iteration 10 / 15
# 	Closed-loop iteration 11 / 15
# 	Closed-loop iteration 12 / 15
# 	Closed-loop iteration 13 / 15
# 	Closed-loop iteration 14 / 15
# 	Closed-loop iteration 15 / 15
# I-EFC loop completed in 41.221s.

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
