# %%
import numpy as np
import astropy.units as u
from astropy.io import fits
from pathlib import Path
from importlib import reload
from IPython.display import clear_output

import poppy
print(poppy.accel_math._NUMEXPR_AVAILABLE)
print(poppy.accel_math._MKLFFT_AVAILABLE)
print(poppy.accel_math._FFTW_AVAILABLE)
print(poppy.accel_math._CUDA_AVAILABLE)
print(poppy.accel_math._OPENCL_AVAILABLE)

# poppy.conf.use_numexpr = True
# poppy.conf.use_fftw = False
# poppy.conf.use_mkl = True
# poppy.conf.use_cuda = False
# poppy.conf.use_opencl = False

import misc
import poppy_roman_cgi_phasec as cgi
from poppy_roman_cgi_phasec import hlc
reload(hlc)

# set debugging mode for more information from POPPY as propagation is performed
# import logging, sys
# _log = logging.getLogger('poppy')
# _log.setLevel("DEBUG")
# logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# cgi_dir = Path('C:/Users/Kian/Desktop/roman-cgi-phasec-data')
# cgi_dir = Path('/Users/kianmilani/Desktop/roman-cgi-phasec-data')
cgi_dir = Path('/groups/douglase/kians-data-files/roman-cgi-phasec-data')

wavelength_c = 575e-9*u.m

wavelength_ref = 0.5e-6*u.m
pixelscale_lamD_ref = 1/2
pixelscale_ref = 13e-6*u.m/u.pix
pixelscale_lamD = pixelscale_lamD_ref * (wavelength_ref/wavelength_c)
print(pixelscale_lamD)

wavelength = 575e-9*u.m
npsf = 64
psf_pixelscale = 13e-6*u.m/u.pix
# npsf = 256
# psf_pixelscale = 2.9587987694e-6*u.m/u.pix
psf_pixelscale_lamD = pixelscale_lamD * (psf_pixelscale/pixelscale_ref)
print(psf_pixelscale_lamD)

Nact = 48
dm_diam = 46.3*u.mm
act_spacing = 0.9906*u.mm

dm_dir = Path('/groups/douglase/kians-data-files/roman-cgi-phasec-data/dms')
DM1 = poppy.ContinuousDeformableMirror(name='DM1', dm_shape=(Nact,Nact), actuator_spacing=act_spacing, 
                                       radius=dm_diam/2, influence_func=str(dm_dir/'proper_inf_func.fits'))
DM2 = poppy.ContinuousDeformableMirror(name='DM2', dm_shape=(Nact,Nact), actuator_spacing=act_spacing, 
                                       radius=dm_diam/2, influence_func=str(dm_dir/'proper_inf_func.fits'))
# Out:
# True
# True
# False
# False
# False
# 0.43478260869565216
# 0.43478260869565216

# %%
reload(hlc)

use_opds = False

psf, wfs = hlc.run_single(wavelength=wavelength,
                          npix=310, oversample=1024/310, 
                          npsf=npsf, psf_pixelscale=psf_pixelscale,
#                           offsets=(5,0),
#                           dm1='hlc_dm1.fits', dm2='hlc_dm2.fits',
#                           dm1='hlc_best_contrast_dm1.fits', dm2='hlc_best_contrast_dm2.fits',
                          use_opds=use_opds, use_pupil_defocus=True, use_fieldstop=True,
#                           polaxis=10,
                          cgi_dir=cgi_dir,
                          display_mode=False, display_intermediates=False, return_intermediates=True,
#                           show_fpm_steps=True,
                          )

misc.myimshow2(wfs[-1].intensity, wfs[-1].phase, lognorm1=True,
               pxscl1=psf_pixelscale, pxscl2=psf_pixelscale,)
# Out:
# Propagating wavelength 575.000 nm.
# Not employing polarization aberrations.
# PSF calculated in 7.49s

# %%
# set dark hole ROI (only annular dark-holes supported for now)
iwa = 2.8*psf_pixelscale/psf_pixelscale_lamD
owa = 9.7*psf_pixelscale/psf_pixelscale_lamD
roi_side = 'right'
roi_offset = 1*psf_pixelscale/psf_pixelscale_lamD

roi_mask = misc.create_annular_roi_mask(npsf, psf_pixelscale, iwa, owa, side=roi_side, offset=roi_offset)

misc.myimshow2(roi_mask, ~roi_mask.mask, 'Dark Zone: Maksed Array of Ones', 'Dark Zone Boolean Mask')
misc.myimshow2(wfs[-1].intensity*roi_mask, wfs[-1].phase*roi_mask, lognorm1=True,
               pxscl1=psf_pixelscale, pxscl2=psf_pixelscale,)

# %%
roi_mask.count()
# Out:
# 654

# %%
import IEFC_modules.iefc_functions as iefc

fp = np.linspace(-0.5, 0.5, npsf) * npsf * psf_pixelscale_lamD
xf,yf = np.meshgrid(fp,fp)

fourier_modes, fx, fy = iefc.create_fourier_modes(fp, ~roi_mask.mask, Nact)
probe_modes = iefc.create_probe_poke_modes(Nact, Nact//2, Nact//4, Nact//2, Nact//4-1)

probe_amplitude = 0.05 * wavelength
calibration_amplitude = 0.006 * wavelength

# %% [markdown]
# # Calibrate IEFC

# %%
# Calibrate the IEFC method
response_cube, calibration_cube = iefc.calibrate(tbi, probe_amplitude, probe_modes, calibration_amplitude, fourier_modes, start_mode=0)
