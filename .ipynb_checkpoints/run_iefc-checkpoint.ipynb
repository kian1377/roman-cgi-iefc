# %%
import numpy as np
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle
from pathlib import Path
from importlib import reload
from IPython.display import clear_output

import IEFC_modules.iefc_simulation as iefc
from IEFC_modules import iefc_functions
reload(iefc)

import roman
import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

wavelength_c = 575e-9*u.m

wavelength_ref = 0.5e-6*u.m
pixelscale_lamD_ref = 1/2
pixelscale_ref = 13e-6*u.m/u.pix
pixelscale_lamD = pixelscale_lamD_ref * (wavelength_ref/wavelength_c)
print(pixelscale_lamD)

wavelength = 575e-9*u.m
npsf = 64
psf_pixelscale = 13e-6*u.m/u.pix
# npsf = 256
# psf_pixelscale = 2.9587987694e-6*u.m/u.pix
psf_pixelscale_lamD = pixelscale_lamD * (psf_pixelscale/pixelscale_ref)
print(psf_pixelscale_lamD)

Nact = 48
dm_diam = 46.3*u.mm
act_spacing = 0.9906*u.mm
# Out:
# 0.43478260869565216
# 0.43478260869565216

# %%
reload(roman)

hlci = roman.CGI(quiet=False)
psf = hlci.calc_psf()

misc.myimshow(psf, lognorm=True, pxscl=hlci.psf_pixelscale)
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.88s

# %%
reload(roman)

hlci = roman.CGI(quiet=False)
# hlci.DM1.set_surface(np.ones((48,48)))

dm1s = [np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), 
        np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48))]
dm2s = [np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), 
        np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48))]

# %timeit hlci.calc_psfs(dm1s, dm2s)
# Out:
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.84s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.87s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.94s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.97s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.00s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.00s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.13s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.14s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.77s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.81s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.77s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.92s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.81s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.97s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.87s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.81s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.82s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.93s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.97s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.98s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.00s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.11s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.12s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.75s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.82s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.77s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.77s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.89s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.92s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.74s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.84s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.93s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.92s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.91s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.03s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.06s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.07s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.76s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.82s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.91s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.92s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.00s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.05s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.04s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.74s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.85s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.87s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.94s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.01s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.01s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.94s
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.85s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.86s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.87s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.88s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.91s
# 9.09 s ± 261 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
# set dark hole ROI (only annular dark-holes supported for now)
iwa = 2.8*psf_pixelscale/psf_pixelscale_lamD
owa = 9.7*psf_pixelscale/psf_pixelscale_lamD
roi_side = 'right'
roi_offset = 1*psf_pixelscale/psf_pixelscale_lamD

roi_mask = misc.create_annular_roi_mask(npsf, psf_pixelscale, iwa, owa, side=roi_side, offset=roi_offset)

misc.myimshow2(roi_mask, ~roi_mask.mask, 'Dark Hole: Masked Array of Ones', 'Dark Hole: Boolean Mask')
misc.myimshow(psf*roi_mask, lognorm=True, pxscl=hlci.psf_pixelscale)

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

# Create the mask that is used to select which region to make dark.
dh_params = {
    'x0' : 0,
    'y0' : -6,
    'w' : 10,
    'h' : 8
}
dh_mask = iefc_functions.create_box_focal_plane_mask(xf, yf, dh_params['x0'], dh_params['y0'], 
                                                     dh_params['w'], dh_params['h']).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'x0' : 0,
    'y0' : -8,
    'w' : 10,
    'h' : 10
}
control_mask = iefc_functions.create_box_focal_plane_mask(xf, yf, control_params['x0'], control_params['y0'], 
                                                          control_params['w'], control_params['h']).ravel()
full_mask = control_mask * (abs(yf).ravel()>0.5)

print(dh_mask.shape, control_mask.shape, full_mask.shape)
misc.myimshow2(dh_mask.reshape(npsf,npsf), full_mask.reshape(npsf,npsf))

# Create the control matrix
relative_weight = 0.99
weights = dh_mask * relative_weight + (1 - relative_weight) * full_mask
# weights = roi_mask * relative_weight + (1 - relative_weight) * roi_mask

print(weights.shape)
misc.myimshow2(psf*weights.reshape(npsf,npsf), weights.reshape(npsf,npsf), lognorm1=True, lognorm2=True)
# Out:
# (4096,) (4096,) (4096,)
# (4096,)

# %% [markdown]
# # Create probe and fourier modes

# %%
# fourier_modes, fx, fy = iefc.create_fourier_modes(xfp, ~roi_mask.mask, Nact=Nact)
# probe_modes = iefc.create_probe_poke_modes(Nact, Nact//2, Nact//4, Nact//2, Nact//4-1)
fourier_modes, fx, fy = iefc.create_fourier_modes(xfp, control_mask.reshape((npsf,npsf)), Nact)
probe_modes = iefc.create_probe_poke_modes(Nact, Nact//2, Nact//4, Nact//2, Nact//4-1)

probe_amplitude = 0.05 * wavelength.to(u.m).value
calibration_amplitude = 0.006 * wavelength.to(u.m).value

print(fourier_modes.shape, probe_modes.shape)
misc.myimshow((probe_modes[0] - probe_modes[1]).reshape((Nact,Nact)))
misc.myimshow2(fourier_modes[0].reshape((Nact,Nact)), fourier_modes[140].reshape((Nact,Nact)))
# Out:
# Createing Fourier modes:  (64, 64)
# (242, 2304) (2, 2304)

# %%
reload(roman)

hlci = roman.CGI(quiet=False)
hlci.add_dm1(calibration_amplitude * fourier_modes[0])

misc.display_dm(hlci.DM1, vmax=1e-8)

differential_images, single_images = iefc.take_measurement(hlci, probe_modes, probe_amplitude, return_all=True)

print(differential_images.shape, single_images.shape)
misc.myimshow2(differential_images[1].reshape((64,64)), single_images[3].reshape((64,64)))
# Out:
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.91s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.95s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.16s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.16s
# (2, 4096) (4, 4096)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)

hlci = roman.CGI(cgi_mode='hlc')
response_cube, calibration_cube = iefc.calibrate(hlci, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, fourier_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 242 in 19.969s
# 	Calibrated mode 2 / 242 in 39.063s
# 	Calibrated mode 3 / 242 in 59.173s
# 	Calibrated mode 4 / 242 in 78.787s
# 	Calibrated mode 5 / 242 in 98.227s
# 	Calibrated mode 6 / 242 in 117.987s
# 	Calibrated mode 7 / 242 in 138.146s
# 	Calibrated mode 8 / 242 in 159.237s
# 	Calibrated mode 9 / 242 in 178.942s
# 	Calibrated mode 10 / 242 in 199.152s
# 	Calibrated mode 11 / 242 in 218.661s
# 	Calibrated mode 12 / 242 in 238.132s
# 	Calibrated mode 13 / 242 in 257.954s
# 	Calibrated mode 14 / 242 in 277.689s
# 	Calibrated mode 15 / 242 in 297.697s
# 	Calibrated mode 16 / 242 in 317.572s
# 	Calibrated mode 17 / 242 in 337.150s
# 	Calibrated mode 18 / 242 in 356.979s
# 	Calibrated mode 19 / 242 in 376.788s
# 	Calibrated mode 20 / 242 in 396.370s
# 	Calibrated mode 21 / 242 in 415.990s
# 	Calibrated mode 22 / 242 in 435.814s
# 	Calibrated mode 23 / 242 in 455.527s
# 	Calibrated mode 24 / 242 in 475.397s
# 	Calibrated mode 25 / 242 in 495.118s
# 	Calibrated mode 26 / 242 in 514.679s
# 	Calibrated mode 27 / 242 in 534.944s
# 	Calibrated mode 28 / 242 in 555.192s
# 	Calibrated mode 29 / 242 in 574.554s
# 	Calibrated mode 30 / 242 in 594.497s
# 	Calibrated mode 31 / 242 in 614.506s
# 	Calibrated mode 32 / 242 in 634.056s
# 	Calibrated mode 33 / 242 in 653.816s
# 	Calibrated mode 34 / 242 in 673.902s
# 	Calibrated mode 35 / 242 in 693.655s
# 	Calibrated mode 36 / 242 in 713.493s
# 	Calibrated mode 37 / 242 in 733.381s
# 	Calibrated mode 38 / 242 in 755.110s
# 	Calibrated mode 39 / 242 in 774.728s
# 	Calibrated mode 40 / 242 in 794.722s
# 	Calibrated mode 41 / 242 in 814.209s
# 	Calibrated mode 42 / 242 in 834.454s
# 	Calibrated mode 43 / 242 in 854.305s
# 	Calibrated mode 44 / 242 in 873.869s
# 	Calibrated mode 45 / 242 in 893.898s
# 	Calibrated mode 46 / 242 in 913.807s
# 	Calibrated mode 47 / 242 in 933.357s
# 	Calibrated mode 48 / 242 in 953.221s
# 	Calibrated mode 49 / 242 in 973.150s
# 	Calibrated mode 50 / 242 in 992.524s
# 	Calibrated mode 51 / 242 in 1012.168s
# 	Calibrated mode 52 / 242 in 1032.103s
# 	Calibrated mode 53 / 242 in 1051.675s
# 	Calibrated mode 54 / 242 in 1071.350s
# 	Calibrated mode 55 / 242 in 1090.977s
# 	Calibrated mode 56 / 242 in 1110.452s
# 	Calibrated mode 57 / 242 in 1130.236s
# 	Calibrated mode 58 / 242 in 1150.029s
# 	Calibrated mode 59 / 242 in 1169.744s
# 	Calibrated mode 60 / 242 in 1189.618s
# 	Calibrated mode 61 / 242 in 1209.241s
# 	Calibrated mode 62 / 242 in 1228.387s
# 	Calibrated mode 63 / 242 in 1248.601s
# 	Calibrated mode 64 / 242 in 1268.298s
# 	Calibrated mode 65 / 242 in 1287.715s
# 	Calibrated mode 66 / 242 in 1307.589s
# 	Calibrated mode 67 / 242 in 1327.559s
# 	Calibrated mode 68 / 242 in 1347.782s
# 	Calibrated mode 69 / 242 in 1367.997s
# 	Calibrated mode 70 / 242 in 1388.114s
# 	Calibrated mode 71 / 242 in 1407.460s
# 	Calibrated mode 72 / 242 in 1427.037s
# 	Calibrated mode 73 / 242 in 1447.293s
# 	Calibrated mode 74 / 242 in 1467.033s
# 	Calibrated mode 75 / 242 in 1486.649s
# 	Calibrated mode 76 / 242 in 1506.315s
# 	Calibrated mode 77 / 242 in 1526.211s
# 	Calibrated mode 78 / 242 in 1546.100s
# 	Calibrated mode 79 / 242 in 1566.169s
# 	Calibrated mode 80 / 242 in 1586.378s
# 	Calibrated mode 81 / 242 in 1606.342s
# 	Calibrated mode 82 / 242 in 1626.049s
# 	Calibrated mode 83 / 242 in 1645.830s
# 	Calibrated mode 84 / 242 in 1665.975s
# 	Calibrated mode 85 / 242 in 1685.857s
# 	Calibrated mode 86 / 242 in 1705.111s
# 	Calibrated mode 87 / 242 in 1725.411s
# 	Calibrated mode 88 / 242 in 1745.081s
# 	Calibrated mode 89 / 242 in 1764.415s
# 	Calibrated mode 90 / 242 in 1784.375s
# 	Calibrated mode 91 / 242 in 1804.244s
# 	Calibrated mode 92 / 242 in 1823.805s
# 	Calibrated mode 93 / 242 in 1843.404s
# 	Calibrated mode 94 / 242 in 1863.402s
# 	Calibrated mode 95 / 242 in 1882.706s
# 	Calibrated mode 96 / 242 in 1902.674s
# 	Calibrated mode 97 / 242 in 1922.448s
# 	Calibrated mode 98 / 242 in 1942.022s
# 	Calibrated mode 99 / 242 in 1961.652s
# 	Calibrated mode 100 / 242 in 1981.659s
# 	Calibrated mode 101 / 242 in 2001.323s
# 	Calibrated mode 102 / 242 in 2020.761s
# 	Calibrated mode 103 / 242 in 2040.993s
# 	Calibrated mode 104 / 242 in 2060.763s
# 	Calibrated mode 105 / 242 in 2080.453s
# 	Calibrated mode 106 / 242 in 2099.936s
# 	Calibrated mode 107 / 242 in 2119.454s
# 	Calibrated mode 108 / 242 in 2139.850s
# 	Calibrated mode 109 / 242 in 2159.593s
# 	Calibrated mode 110 / 242 in 2178.945s
# 	Calibrated mode 111 / 242 in 2198.945s
# 	Calibrated mode 112 / 242 in 2218.844s
# 	Calibrated mode 113 / 242 in 2238.030s
# 	Calibrated mode 114 / 242 in 2257.998s
# 	Calibrated mode 115 / 242 in 2278.069s
# 	Calibrated mode 116 / 242 in 2297.636s
# 	Calibrated mode 117 / 242 in 2317.815s
# 	Calibrated mode 118 / 242 in 2337.885s
# 	Calibrated mode 119 / 242 in 2357.476s
# 	Calibrated mode 120 / 242 in 2377.314s
# 	Calibrated mode 121 / 242 in 2397.127s
# 	Calibrated mode 122 / 242 in 2416.717s
# 	Calibrated mode 123 / 242 in 2436.752s
# 	Calibrated mode 124 / 242 in 2456.709s
# 	Calibrated mode 125 / 242 in 2476.027s
# 	Calibrated mode 126 / 242 in 2496.032s
# 	Calibrated mode 127 / 242 in 2515.808s
# 	Calibrated mode 128 / 242 in 2535.241s
# 	Calibrated mode 129 / 242 in 2554.887s
# 	Calibrated mode 130 / 242 in 2574.422s
# 	Calibrated mode 131 / 242 in 2593.843s
# 	Calibrated mode 132 / 242 in 2613.776s
# 	Calibrated mode 133 / 242 in 2633.557s
# 	Calibrated mode 134 / 242 in 2653.159s
# 	Calibrated mode 135 / 242 in 2673.234s
# 	Calibrated mode 136 / 242 in 2693.262s
# 	Calibrated mode 137 / 242 in 2713.043s
# 	Calibrated mode 138 / 242 in 2732.717s
# 	Calibrated mode 139 / 242 in 2752.480s
# 	Calibrated mode 140 / 242 in 2771.785s
# 	Calibrated mode 141 / 242 in 2791.880s
# 	Calibrated mode 142 / 242 in 2811.967s
# 	Calibrated mode 143 / 242 in 2831.612s
# 	Calibrated mode 144 / 242 in 2851.069s
# 	Calibrated mode 145 / 242 in 2870.670s
# 	Calibrated mode 146 / 242 in 2890.310s
# 	Calibrated mode 147 / 242 in 2910.111s
# 	Calibrated mode 148 / 242 in 2930.052s
# 	Calibrated mode 149 / 242 in 2950.018s
# 	Calibrated mode 150 / 242 in 2969.801s
# 	Calibrated mode 151 / 242 in 2989.546s
# 	Calibrated mode 152 / 242 in 3008.936s
# 	Calibrated mode 153 / 242 in 3028.983s
# 	Calibrated mode 154 / 242 in 3048.812s
# 	Calibrated mode 155 / 242 in 3068.241s
# 	Calibrated mode 156 / 242 in 3088.153s
# 	Calibrated mode 157 / 242 in 3108.074s
# 	Calibrated mode 158 / 242 in 3127.679s
# 	Calibrated mode 159 / 242 in 3149.903s
# 	Calibrated mode 160 / 242 in 3170.044s
# 	Calibrated mode 161 / 242 in 3189.451s
# 	Calibrated mode 162 / 242 in 3209.377s
# 	Calibrated mode 163 / 242 in 3229.336s
# 	Calibrated mode 164 / 242 in 3248.827s
# 	Calibrated mode 165 / 242 in 3268.787s
# 	Calibrated mode 166 / 242 in 3288.538s
# 	Calibrated mode 167 / 242 in 3308.425s
# 	Calibrated mode 168 / 242 in 3328.292s
# 	Calibrated mode 169 / 242 in 3348.345s
# 	Calibrated mode 170 / 242 in 3367.991s
# 	Calibrated mode 171 / 242 in 3388.160s
# 	Calibrated mode 172 / 242 in 3408.094s
# 	Calibrated mode 173 / 242 in 3427.882s
# 	Calibrated mode 174 / 242 in 3448.893s
# 	Calibrated mode 175 / 242 in 3468.770s
# 	Calibrated mode 176 / 242 in 3488.470s
# 	Calibrated mode 177 / 242 in 3508.455s
# 	Calibrated mode 178 / 242 in 3527.853s
# 	Calibrated mode 179 / 242 in 3547.468s
# 	Calibrated mode 180 / 242 in 3567.453s
# 	Calibrated mode 181 / 242 in 3587.252s
# 	Calibrated mode 182 / 242 in 3606.987s
# 	Calibrated mode 183 / 242 in 3626.864s
# 	Calibrated mode 184 / 242 in 3646.669s
# 	Calibrated mode 185 / 242 in 3665.808s
# 	Calibrated mode 186 / 242 in 3685.916s
# 	Calibrated mode 187 / 242 in 3705.546s
# 	Calibrated mode 188 / 242 in 3724.661s
# 	Calibrated mode 189 / 242 in 3744.540s
# 	Calibrated mode 190 / 242 in 3764.147s
# 	Calibrated mode 191 / 242 in 3783.524s
# 	Calibrated mode 192 / 242 in 3803.380s
# 	Calibrated mode 193 / 242 in 3823.123s
# 	Calibrated mode 194 / 242 in 3842.668s
# 	Calibrated mode 195 / 242 in 3862.354s
# 	Calibrated mode 196 / 242 in 3881.953s
# 	Calibrated mode 197 / 242 in 3901.479s
# 	Calibrated mode 198 / 242 in 3921.381s
# 	Calibrated mode 199 / 242 in 3941.246s
# 	Calibrated mode 200 / 242 in 3961.092s
# 	Calibrated mode 201 / 242 in 3981.539s
# 	Calibrated mode 202 / 242 in 4001.262s
# 	Calibrated mode 203 / 242 in 4020.871s
# 	Calibrated mode 204 / 242 in 4040.687s
# 	Calibrated mode 205 / 242 in 4060.582s
# 	Calibrated mode 206 / 242 in 4080.325s
# 	Calibrated mode 207 / 242 in 4100.277s
# 	Calibrated mode 208 / 242 in 4120.304s
# 	Calibrated mode 209 / 242 in 4139.759s
# 	Calibrated mode 210 / 242 in 4159.854s
# 	Calibrated mode 211 / 242 in 4179.588s
# 	Calibrated mode 212 / 242 in 4199.058s
# 	Calibrated mode 213 / 242 in 4218.970s
# 	Calibrated mode 214 / 242 in 4238.884s
# 	Calibrated mode 215 / 242 in 4258.628s
# 	Calibrated mode 216 / 242 in 4278.646s
# 	Calibrated mode 217 / 242 in 4298.446s
# 	Calibrated mode 218 / 242 in 4317.764s
# 	Calibrated mode 219 / 242 in 4337.926s
# 	Calibrated mode 220 / 242 in 4361.402s
# 	Calibrated mode 221 / 242 in 4380.714s
# 	Calibrated mode 222 / 242 in 4400.563s
# 	Calibrated mode 223 / 242 in 4420.411s
# 	Calibrated mode 224 / 242 in 4440.030s
# 	Calibrated mode 225 / 242 in 4459.697s
# 	Calibrated mode 226 / 242 in 4479.543s
# 	Calibrated mode 227 / 242 in 4499.189s
# 	Calibrated mode 228 / 242 in 4519.048s
# 	Calibrated mode 229 / 242 in 4538.777s
# 	Calibrated mode 230 / 242 in 4558.508s
# 	Calibrated mode 231 / 242 in 4579.204s
# 	Calibrated mode 232 / 242 in 4598.919s
# 	Calibrated mode 233 / 242 in 4618.144s
# 	Calibrated mode 234 / 242 in 4638.427s
# 	Calibrated mode 235 / 242 in 4658.108s
# 	Calibrated mode 236 / 242 in 4677.746s
# 	Calibrated mode 237 / 242 in 4697.582s
# 	Calibrated mode 238 / 242 in 4717.409s
# 	Calibrated mode 239 / 242 in 4737.070s
# 	Calibrated mode 240 / 242 in 4757.019s
# 	Calibrated mode 241 / 242 in 4777.377s
# 	Calibrated mode 242 / 242 in 4797.442s
# Calibration complete.

# %%
print(response_cube.shape, calibration_cube.shape)

response_hdu = fits.PrimaryHDU(data=response_cube)
response_hdu.writeto(data_dir/'response-data'/'response_cube_box_mask.fits', overwrite=True)

calib_hdu = fits.PrimaryHDU(data=calibration_cube)
calib_hdu.writeto(data_dir/'calibration-data'/'calibration_cube_box_mask.fits', overwrite=True)
# Out:
# (242, 2, 4096) (484, 4, 4096)

# %%
response_cube = fits.getdata(data_dir/'response-data'/'response_cube_box_mask.fits')
calibration_cube = fits.getdata(data_dir/'calibration-data'/'calibration_cube_box_mask.fits')

# %% [markdown]
# # Filter calibration data

# %%
# Filter the calibration files by subtracting PCA modes
npca = 3
filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

# %% [markdown]
# # Create control matrix

# %%
control_matrix = iefc.construct_control_matrix(filtered_response_cube, 
                                               weights.flatten(), rcond=3e-4, pca_modes=pca_modes)

# %% [markdown]
# # Run IEFC

# %%
# The metric
metric_images = []
dm_commands = []
command = 0.0

## Run IEFC for num_iterations
num_iterations = 10
gain = -0.4
leakage = 0.0

for i in range(num_iterations):
    print("Closed-loop iteration {:d} / {:d}".format(i+1, num_iterations))
#     delta_coefficients = iefc_functions.IEFC_single_iteration(tbi, probe_modes, probe_amplitude, 
#                                                               control_matrix, weights>0)
    delta_coefficients = iefc.single_iteration(hlci, probe_modes, probe_amplitude, 
                                               control_matrix, weights.flatten()>0)
    command = (1.0-leakage) * command + gain * delta_coefficients
    
    # Reconstruct the full phase from the Fourier modes
    dm_command = np.einsum('ij, i->j', fourier_modes, command)
    print(dm_command.shape, delta_coefficients.shape)
    
    # Set the current DM state
#     tbi.set_dm(dm_command)
#     ret = tbi.send_dm()
    hlci.set_dm1(dm_command)
    
    # Take an image to estimate the metrics
#     metric_images.append(tbi.snap())
    image = hlci.calc_psf()
    metric_images.append(image)
    dm_commands.append(dm_command)
    
    misc.myimshow2(dm_command.reshape(Nact,Nact), image, lognorm2=True)
    pass
# Out:
# Closed-loop iteration 1 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.95s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.00s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.04s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.02s
# Closed-loop iteration 2 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.02s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.01s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.12s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.77s
# Closed-loop iteration 3 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.09s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.39s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.37s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.38s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.76s
# Closed-loop iteration 4 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.03s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.23s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.33s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.32s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.11s
# Closed-loop iteration 5 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.08s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.12s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.30s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.34s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.00s
# Closed-loop iteration 6 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.90s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.02s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.98s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.03s
# Closed-loop iteration 7 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.04s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.34s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.53s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.51s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.03s
# Closed-loop iteration 8 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.92s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.25s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.28s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.32s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.76s
# Closed-loop iteration 9 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.10s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.19s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.28s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# Closed-loop iteration 10 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.06s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.17s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.13s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.29s
# (2304,) (242,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.04s

# %%
hdr = fits.Header()
hdr['GAIN'] = gain
hdr['LEAKAGE'] = leakage

images_hdu = fits.PrimaryHDU(data=metric_images, header=hdr)
images_hdu.writeto(data_dir/'image-results'/'rect_dh.fits', overwrite=True)
dms_hdu = fits.PrimaryHDU(data=dm_commands, header=hdr)
dms_hdu.writeto(data_dir/'dm-results'/'rect_dh.fits', overwrite=True)

# %%
reload(iefc)
ind = 2
patches = [iefc.create_rect_patch(dh_params)]
misc.myimshow2(dm_commands[ind].reshape(Nact,Nact), metric_images[ind], 
               lognorm2=True, patches2=patches, pxscl2=psf_pixelscale_lamD.value)

# %%
metric_images = fits.getdata(data_dir/'image-results'/'rect_dh.fits')
dm_commands = fits.getdata(data_dir/'dm-results'/'rect_dh.fits')
hdr = fits.getheader(data_dir/'dm-results'/'rect_dh.fits')
print(hdr['GAIN'], hdr['LEAKAGE'])
# Out:
# -0.4 0.0

# %% [markdown]
# # Testing

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import LogNorm
from matplotlib.animation import FFMpegWriter
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.rcParams['animation.ffmpeg_path'] ='/.../bin/ffmpeg.exe'
plt.rcParams['animation.convert_path'] = '/.../magick.exe'
plt.rcParams['animation.html'] = 'html5'

wfs_min, wfs_max = (1, 0)
for i in range(len(images)):
    m, M = ( np.min(images), np.max(images) )
    if m < wfs_min: wfs_min = m
    if M > wfs_max: wfs_max = M

fig,ax = plt.subplots(1,2, figsize=(10,4), dpi=100)

dm_ext = np.array([-Nact/2, Nact/2, -Nact/2, Nact/2])*hlci.act_spacing.value
psf_ext = np.array([-npsf/2, npsf/2, -npsf/2, npsf/2])*psf_pixelscale_lamD
    
ax0 = ax[0].imshow(actuators[0], cmap='magma', extent=dm_ext)
divider = make_axes_locatable(ax[0])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax0, cax=cax)
ax0_title = ax[0].set_title('Iteration {:d}'.format(range(15)[0]), fontsize = 18)

ax1 = ax[1].imshow(images[0], norm=LogNorm(), cmap='gist_heat', extent=psf_ext)
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax1, cax=cax)
ax1_title = ax[1].set_title('PSF', fontsize = 18)
ax1.add_patch(iefc.create_rect_patch(dh_params))

plt.close()

def animate(i):
    ax0.set_data(actuators[i])
    ax0.set_clim(np.min(actuators[i]), np.max(actuators[i]))
    ax0_title.set_text('Iteration {:d}'.format(range(15)[i]))
    
    ax1.set_data(wavefronts[i][-1].intensity)
    ax1.set_clim(wfs_min, wfs_max)
    ax1.add_patch(iefc.create_rect_patch(dh_params))

anim = animation.FuncAnimation(fig, animate, frames=len(actuators))
anim

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import LogNorm
from matplotlib.animation import FFMpegWriter
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.rcParams['animation.ffmpeg_path'] ='/.../bin/ffmpeg.exe'
plt.rcParams['animation.convert_path'] = '/.../magick.exe'
plt.rcParams['animation.html'] = 'html5'

wfs_min, wfs_max = (1, 0)
for i in range(len(wavefronts)):
    m, M = ( np.min(wavefronts[i][-1].intensity), np.max(wavefronts[i][-1].intensity) )
    if m < wfs_min: wfs_min = m
    if M > wfs_max: wfs_max = M

fig,ax = plt.subplots(1,2, figsize=(10,4), dpi=100)

dm_ext = np.array([-Nacts/2, Nacts/2, -Nacts/2, Nacts/2])*act_spacing.value
psf_ext = np.array([-npsf/2, npsf/2, -npsf/2, npsf/2])*wavefronts[0][-1].pixelscale.to(u.mm/u.pix).value
    
ax0 = ax[0].imshow(actuators[0], cmap='magma', extent=dm_ext)
divider = make_axes_locatable(ax[0])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax0, cax=cax)
ax0_title = ax[0].set_title('Iteration {:d}'.format(range(15)[0]), fontsize = 18)

ax1 = ax[1].imshow(wavefronts[0][-1].intensity, norm=LogNorm(), cmap='gist_heat', extent=psf_ext)
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax1, cax=cax)
ax1_title = ax[1].set_title('PSF', fontsize = 18)
plt.close()

def animate(i):
    ax0.set_data(actuators[i])
    ax0.set_clim(np.min(actuators[i]), np.max(actuators[i]))
    ax0_title.set_text('Iteration {:d}'.format(range(15)[i]))
    
    ax1.set_data(wavefronts[i][-1].intensity)
    ax1.set_clim(wfs_min, wfs_max)
    ax1

anim = animation.FuncAnimation(fig, animate, frames=len(actuators))
anim
