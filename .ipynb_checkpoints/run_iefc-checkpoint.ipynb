# %%
import numpy as np
import astropy.units as u
from astropy.io import fits
from pathlib import Path
from importlib import reload
from IPython.display import clear_output

import IEFC_modules.iefc_simulation as iefc
from IEFC_modules import iefc_functions
reload(iefc)

import roman
import misc

wavelength_c = 575e-9*u.m

wavelength_ref = 0.5e-6*u.m
pixelscale_lamD_ref = 1/2
pixelscale_ref = 13e-6*u.m/u.pix
pixelscale_lamD = pixelscale_lamD_ref * (wavelength_ref/wavelength_c)
print(pixelscale_lamD)

wavelength = 575e-9*u.m
npsf = 64
psf_pixelscale = 13e-6*u.m/u.pix
# npsf = 256
# psf_pixelscale = 2.9587987694e-6*u.m/u.pix
psf_pixelscale_lamD = pixelscale_lamD * (psf_pixelscale/pixelscale_ref)
print(psf_pixelscale_lamD)

Nact = 48
dm_diam = 46.3*u.mm
act_spacing = 0.9906*u.mm
# Out:
# 0.43478260869565216
# 0.43478260869565216

# %%
reload(roman)

hlci = roman.CGI(quiet=False)
psf = hlci.calc_psf()

misc.myimshow(psf, lognorm=True, pxscl=hlci.psf_pixelscale)
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.63s

# %%
reload(roman)

hlci = roman.CGI(quiet=False)
# hlci.DM1.set_surface(np.ones((48,48)))

dm1s = [np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), 
        np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48))]
dm2s = [np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), 
        np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48)), np.zeros((48,48))]
psfs = hlci.calc_psfs(dm1s, dm2s)

misc.myimshow(psfs[0].intensity, lognorm=True)
# Out:
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 10.87s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.27s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.30s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.45s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.59s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.72s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.74s

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
# set dark hole ROI (only annular dark-holes supported for now)
iwa = 2.8*psf_pixelscale/psf_pixelscale_lamD
owa = 9.7*psf_pixelscale/psf_pixelscale_lamD
roi_side = 'right'
roi_offset = 1*psf_pixelscale/psf_pixelscale_lamD

roi_mask = misc.create_annular_roi_mask(npsf, psf_pixelscale, iwa, owa, side=roi_side, offset=roi_offset)

misc.myimshow2(roi_mask, ~roi_mask.mask, 'Dark Hole: Masked Array of Ones', 'Dark Hole: Boolean Mask')
misc.myimshow(psf*roi_mask, lognorm=True, pxscl=hlci.psf_pixelscale)

# %% [markdown]
# # Create probe and fourier modes

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

fourier_modes, fx, fy = iefc.create_fourier_modes(xfp, ~roi_mask.mask, Nact=Nact)
probe_modes = iefc.create_probe_poke_modes(Nact, Nact//2, Nact//4, Nact//2, Nact//4-1)

probe_amplitude = 0.05 * wavelength.to(u.m).value
calibration_amplitude = 0.006 * wavelength.to(u.m).value

print(fourier_modes.shape, probe_modes.shape)
misc.myimshow((probe_modes[0] - probe_modes[1]).reshape((Nact,Nact)))
misc.myimshow2(fourier_modes[0].reshape((Nact,Nact)), fourier_modes[140].reshape((Nact,Nact)))
# Out:
# Createing Fourier modes:  (64, 64)
# (300, 2304) (2, 2304)

# %%
reload(roman)

hlci = roman.CGI(quiet=False)
hlci.add_dm1(calibration_amplitude * fourier_modes[0])

misc.display_dm(hlci.DM1, vmax=1e-8)

differential_images, single_images = iefc.take_measurement(hlci, probe_modes, probe_amplitude, return_all=True)

print(differential_images.shape, single_images.shape)
misc.myimshow2(differential_images[1].reshape((64,64)), single_images[3].reshape((64,64)))
# Out:
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.20s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.33s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.35s
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.49s
# (2, 4096) (4, 4096)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)

hlci = roman.CGI(cgi_mode='hlc')
response_cube, calibration_cube = iefc.calibrate(hlci, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, fourier_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 300 in 25.436s
# 	Calibrated mode 2 / 300 in 53.290s
# 	Calibrated mode 3 / 300 in 77.237s
# 	Calibrated mode 4 / 300 in 99.989s
# 	Calibrated mode 5 / 300 in 127.867s
# 	Calibrated mode 6 / 300 in 152.408s
# 	Calibrated mode 7 / 300 in 177.487s
# 	Calibrated mode 8 / 300 in 195.944s
# 	Calibrated mode 9 / 300 in 215.094s
# 	Calibrated mode 10 / 300 in 233.621s
# 	Calibrated mode 11 / 300 in 252.111s
# 	Calibrated mode 12 / 300 in 271.187s
# 	Calibrated mode 13 / 300 in 290.158s
# 	Calibrated mode 14 / 300 in 308.637s
# 	Calibrated mode 15 / 300 in 327.037s
# 	Calibrated mode 16 / 300 in 346.499s
# 	Calibrated mode 17 / 300 in 365.246s
# 	Calibrated mode 18 / 300 in 383.794s
# 	Calibrated mode 19 / 300 in 402.853s
# 	Calibrated mode 20 / 300 in 421.198s
# 	Calibrated mode 21 / 300 in 439.864s
# 	Calibrated mode 22 / 300 in 458.434s
# 	Calibrated mode 23 / 300 in 477.287s
# 	Calibrated mode 24 / 300 in 496.222s
# 	Calibrated mode 25 / 300 in 514.619s
# 	Calibrated mode 26 / 300 in 533.656s
# 	Calibrated mode 27 / 300 in 552.051s
# 	Calibrated mode 28 / 300 in 570.678s
# 	Calibrated mode 29 / 300 in 589.193s
# 	Calibrated mode 30 / 300 in 608.169s
# 	Calibrated mode 31 / 300 in 626.625s
# 	Calibrated mode 32 / 300 in 645.107s
# 	Calibrated mode 33 / 300 in 663.906s
# 	Calibrated mode 34 / 300 in 682.660s
# 	Calibrated mode 35 / 300 in 701.351s
# 	Calibrated mode 36 / 300 in 719.734s
# 	Calibrated mode 37 / 300 in 738.639s
# 	Calibrated mode 38 / 300 in 757.162s
# 	Calibrated mode 39 / 300 in 775.804s
# 	Calibrated mode 40 / 300 in 795.068s
# 	Calibrated mode 41 / 300 in 813.538s
# 	Calibrated mode 42 / 300 in 832.032s
# 	Calibrated mode 43 / 300 in 850.917s
# 	Calibrated mode 44 / 300 in 870.056s
# 	Calibrated mode 45 / 300 in 888.883s
# 	Calibrated mode 46 / 300 in 907.565s
# 	Calibrated mode 47 / 300 in 926.956s
# 	Calibrated mode 48 / 300 in 945.435s
# 	Calibrated mode 49 / 300 in 963.906s
# 	Calibrated mode 50 / 300 in 982.268s
# 	Calibrated mode 51 / 300 in 1001.464s
# 	Calibrated mode 52 / 300 in 1019.838s
# 	Calibrated mode 53 / 300 in 1038.340s
# 	Calibrated mode 54 / 300 in 1057.580s
# 	Calibrated mode 289 / 300 in 5447.817s
# 	Calibrated mode 290 / 300 in 5466.467s
# 	Calibrated mode 291 / 300 in 5485.070s
# 	Calibrated mode 292 / 300 in 5503.971s
# 	Calibrated mode 293 / 300 in 5522.401s
# 	Calibrated mode 294 / 300 in 5541.000s
# 	Calibrated mode 295 / 300 in 5559.341s
# 	Calibrated mode 296 / 300 in 5578.665s
# 	Calibrated mode 297 / 300 in 5597.611s
# 	Calibrated mode 298 / 300 in 5616.274s
# 	Calibrated mode 299 / 300 in 5635.486s
# 	Calibrated mode 300 / 300 in 5653.888s
# Calibration complete.

# %%
print(response_cube.shape, calibration_cube.shape)

response_hdu = fits.PrimaryHDU(data=response_cube)
response_hdu.writeto(Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/response_cube.fits'), overwrite=True)

calib_hdu = fits.PrimaryHDU(data=calibration_cube)
calib_hdu.writeto(Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration_cube.fits'), overwrite=True)
# Out:
# (300, 2, 4096) (600, 4, 4096)

# %%
response_cube = fits.getdata(Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/response_cube.fits'))
calibration_cube = fits.getdata(Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration_cube.fits'))

# %% [markdown]
# # Filter calibration data

# %%
# Filter the calibration files by subtracting PCA modes
npca = 3
filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

# %% [markdown]
# # Create control matrix

# %%
# Create the mask that is used to select which region to make dark.
dark_hole_options = {
    'x0' : 0,
    'y0' : -6,
    'w' : 10,
    'h' : 8
}
dark_hole_mask = iefc_functions.create_box_focal_plane_mask(xf, yf, 
                                                            dark_hole_options['x0'],
                                                            dark_hole_options['y0'], 
                                                            dark_hole_options['w'],
                                                            dark_hole_options['h']).ravel()

#Create the mask that is used to select which region to make dark.
control_region_options = {
    'x0' : 0,
    'y0' : -8,
    'w' : 10,
    'h' : 10
}
control_region_mask = iefc_functions.create_box_focal_plane_mask(xf, yf, 
                                                                 control_region_options['x0'], 
                                                                 control_region_options['y0'], 
                                                                 control_region_options['w'], 
                                                                 control_region_options['h']).ravel()
full_mask = control_region_mask * (abs(yf).ravel()>0.5)

print(dark_hole_mask.shape, control_region_mask.shape, full_mask.shape)
misc.myimshow2(dark_hole_mask.reshape(npsf,npsf), full_mask.reshape(npsf,npsf))
# Out:
# (4096,) (4096,) (4096,)

# %%
# Create the control matrix
relative_weight = 0.99
weights = dark_hole_mask * relative_weight + (1 - relative_weight) * full_mask
# weights = roi_mask * relative_weight + (1 - relative_weight) * roi_mask

print(weights.shape)
misc.myimshow(weights.reshape(npsf,npsf))
# Out:
# (4096,)

# %%
control_matrix = iefc.construct_control_matrix(filtered_response_cube, 
                                               weights.flatten(), rcond=3e-4, pca_modes=pca_modes)

# %% [markdown]
# # Run IEFC

# %%
# The metric
metric_images = []
command = 0.0

## Run IEFC for num_iterations
num_iterations = 10
gain = -0.8
leakage = 0.0

# %%
for i in range(num_iterations):
    print("Closed-loop iteration {:d} / {:d}".format(i+1, num_iterations))
#     delta_coefficients = iefc_functions.IEFC_single_iteration(tbi, probe_modes, probe_amplitude, 
#                                                               control_matrix, weights>0)
    delta_coefficients = iefc.single_iteration(hlci, probe_modes, probe_amplitude, 
                                               control_matrix, weights.flatten()>0)
    print(delta_coefficients.shape)
    command = (1.0-leakage) * command + gain * delta_coefficients
    
    # Reconstruct the full phase from the Fourier modes
    voltage_command = np.einsum('ij, i->j', fourier_modes, command)
    print(voltage_command.shape)
    
    # Set the current DM state
#     tbi.set_dm(voltage_command)
#     ret = tbi.send_dm()
    hlci.set_dm1(voltage_command)
    
    # Take an image to estimate the metrics
#     metric_images.append(tbi.snap())
    image = hlci.calc_psf()
    metric_images.append(image)
    
    misc.myimshow2(voltage_command.reshape(Nact,Nact), image)
    pass
# Out:
# Closed-loop iteration 1 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.76s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.87s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.52s
# Closed-loop iteration 2 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.73s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.74s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.77s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.57s
# Closed-loop iteration 3 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.72s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.73s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.75s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.83s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.54s
# Closed-loop iteration 4 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.74s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.81s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.56s
# Closed-loop iteration 5 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.73s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.75s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.81s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.84s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.57s
# Closed-loop iteration 6 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.72s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.74s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.57s
# Closed-loop iteration 7 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.72s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.75s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.59s
# Closed-loop iteration 8 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.74s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.79s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.76s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.94s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 7.09s
# Closed-loop iteration 9 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.75s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.83s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.84s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.59s
# Closed-loop iteration 10 / 10
# Running mode HLC575 for multiple DM settings.
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.78s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.88s
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.80s
# (300,)
# (2304,)
# Propagating wavelength 575.000 nm.
# PSF calculated in 6.59s

# %%
misc.myimshow(metric_images[9], lognorm=True)

# %% [markdown]
# # Testing

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import LogNorm
from matplotlib.animation import FFMpegWriter
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.rcParams['animation.ffmpeg_path'] ='/.../bin/ffmpeg.exe'
plt.rcParams['animation.convert_path'] = '/.../magick.exe'
plt.rcParams['animation.html'] = 'html5'

wfs_min, wfs_max = (1, 0)
for i in range(len(wavefronts)):
    m, M = ( np.min(wavefronts[i][-1].intensity), np.max(wavefronts[i][-1].intensity) )
    if m < wfs_min: wfs_min = m
    if M > wfs_max: wfs_max = M

fig,ax = plt.subplots(1,2, figsize=(10,4), dpi=100)

dm_ext = np.array([-Nacts/2, Nacts/2, -Nacts/2, Nacts/2])*act_spacing.value
psf_ext = np.array([-npsf/2, npsf/2, -npsf/2, npsf/2])*wavefronts[0][-1].pixelscale.to(u.mm/u.pix).value
    
ax0 = ax[0].imshow(actuators[0], cmap='magma', extent=dm_ext)
divider = make_axes_locatable(ax[0])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax0, cax=cax)
ax0_title = ax[0].set_title('Iteration {:d}'.format(range(15)[0]), fontsize = 18)

ax1 = ax[1].imshow(wavefronts[0][-1].intensity, norm=LogNorm(), cmap='gist_heat', extent=psf_ext)
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax1, cax=cax)
ax1_title = ax[1].set_title('PSF', fontsize = 18)
plt.close()

def animate(i):
    ax0.set_data(actuators[i])
    ax0.set_clim(np.min(actuators[i]), np.max(actuators[i]))
    ax0_title.set_text('Iteration {:d}'.format(range(15)[i]))
    
    ax1.set_data(wavefronts[i][-1].intensity)
    ax1.set_clim(wfs_min, wfs_max)

anim = animation.FuncAnimation(fig, animate, frames=len(actuators))
anim
