# %%
import numpy as np
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle
from pathlib import Path
from importlib import reload
from IPython.display import clear_output

from IEFC_modules import iefc_functions

import cgi
import iefc_simulation as iefc
import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

wavelength_c = 575e-9*u.m

wavelength_ref = 0.5e-6*u.m
pixelscale_lamD_ref = 1/2
pixelscale_ref = 13e-6*u.m/u.pix
pixelscale_lamD = pixelscale_lamD_ref * (wavelength_ref/wavelength_c)

wavelength = 575e-9*u.m
npsf = 64
psf_pixelscale = 13e-6*u.m/u.pix
psf_pixelscale_lamD = pixelscale_lamD * (psf_pixelscale/pixelscale_ref)
print(psf_pixelscale_lamD)

flatmaps_dir = Path.home()/'src/pyfalco/roman/flatmaps'

dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')
# Out:
# 0.43478260869565216

# %%
reload(cgi)

hlci = cgi.CGI_PROPER(use_opds=False, use_fieldstop=True, quiet=True)
# hlci.set_dm1(dm1_flatmap)
# hlci.set_dm2(dm2_flatmap)

psf = hlci.calc_psf()

misc.myimshow(psf, lognorm=True, pxscl=hlci.psf_pixelscale)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(iefc)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1.5
iwa = 2.8
owa = 9.7

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : '+x'
}
dh_mask = iefc.create_dshaped_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.5,
    'outer_radius' : owa+1,
    'edge_position' : edge,
    'direction' : '+x'
}
control_mask = iefc.create_dshaped_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.99
weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask

print(dh_mask.shape, control_mask.shape, control_mask.shape, weights.shape)
misc.myimshow2(dh_mask.reshape(npsf,npsf), control_mask.reshape(npsf,npsf), 
               pxscl1=psf_pixelscale_lamD, pxscl2=psf_pixelscale_lamD)
misc.myimshow2(psf*weights.reshape(npsf,npsf), weights.reshape(npsf,npsf), lognorm1=True, lognorm2=True,
               pxscl1=psf_pixelscale_lamD, pxscl2=psf_pixelscale_lamD)
# Out:
# (4096,) (4096,) (4096,) (4096,)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(iefc)

Nact = hlci.Nact

fourier_modes, fx, fy = iefc.create_fourier_modes(xfp, control_mask.reshape((npsf,npsf)), Nact, circular_mask=False)
probe_modes = iefc.create_probe_poke_modes(hlci.Nact, 3*Nact//4, Nact//2, 3*Nact//4-1, Nact//2)

probe_amplitude = 0.05 * wavelength.to(u.m).value
calibration_amplitude = 0.006 * wavelength.to(u.m).value

print(fourier_modes.shape, probe_modes.shape)
misc.myimshow((probe_modes[0] - probe_modes[1]).reshape((Nact,Nact)))
misc.myimshow2(fourier_modes[0].reshape((Nact,Nact)), fourier_modes[300].reshape((Nact,Nact)))
# Out:
# Creating Fourier modes:  (64, 64)
# (326, 2304) (2, 2304)

# %% [markdown]
# # Testing

# %%
reload(cgi)
reload(iefc)

hlci.add_dm1(calibration_amplitude * fourier_modes[200])
misc.myimshow(hlci.DM1, vmax=1e-8)
differential_images, single_images = iefc.take_measurement(hlci, probe_modes, probe_amplitude, return_all=True)

hlci.add_dm1(-calibration_amplitude * fourier_modes[200]) # remove the previous DM setting

hlci.add_dm1(-calibration_amplitude * fourier_modes[200])
misc.myimshow(hlci.DM1, vmax=1e-8)
differential_images_2, single_images_2 = iefc.take_measurement(hlci, probe_modes, probe_amplitude, return_all=True)

print(differential_images.shape, single_images.shape)
misc.myimshow2(differential_images[1].reshape((64,64)), single_images[3].reshape((64,64)))
misc.myimshow2(differential_images_2[1].reshape((64,64)), single_images_2[3].reshape((64,64)))
misc.myimshow((differential_images[1]-differential_images_2[1]).reshape(npsf,npsf))
# Out:
# (2, 4096) (4, 4096)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)

response_cube, calibration_cube = iefc.calibrate(hlci, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, fourier_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 300 in 18.444s
# 	Calibrated mode 2 / 300 in 35.850s
# 	Calibrated mode 3 / 300 in 53.480s
# 	Calibrated mode 4 / 300 in 71.778s
# 	Calibrated mode 5 / 300 in 89.185s
# 	Calibrated mode 6 / 300 in 106.850s
# 	Calibrated mode 7 / 300 in 124.216s
# 	Calibrated mode 8 / 300 in 142.890s
# 	Calibrated mode 9 / 300 in 160.400s
# 	Calibrated mode 10 / 300 in 177.808s
# 	Calibrated mode 11 / 300 in 195.867s
# 	Calibrated mode 12 / 300 in 213.277s
# 	Calibrated mode 13 / 300 in 230.668s
# 	Calibrated mode 14 / 300 in 248.060s
# 	Calibrated mode 15 / 300 in 266.200s
# 	Calibrated mode 16 / 300 in 283.660s
# 	Calibrated mode 17 / 300 in 301.266s
# 	Calibrated mode 18 / 300 in 319.563s
# 	Calibrated mode 19 / 300 in 337.052s
# 	Calibrated mode 20 / 300 in 354.533s
# 	Calibrated mode 21 / 300 in 372.084s
# 	Calibrated mode 22 / 300 in 390.358s
# 	Calibrated mode 23 / 300 in 407.724s
# 	Calibrated mode 24 / 300 in 425.262s
# 	Calibrated mode 25 / 300 in 443.533s
# 	Calibrated mode 26 / 300 in 461.238s
# 	Calibrated mode 27 / 300 in 478.721s
# 	Calibrated mode 28 / 300 in 496.162s
# 	Calibrated mode 29 / 300 in 514.399s
# 	Calibrated mode 30 / 300 in 531.820s
# 	Calibrated mode 31 / 300 in 549.366s
# 	Calibrated mode 32 / 300 in 567.509s
# 	Calibrated mode 33 / 300 in 585.060s
# 	Calibrated mode 34 / 300 in 602.441s
# 	Calibrated mode 35 / 300 in 619.842s
# 	Calibrated mode 36 / 300 in 638.253s
# 	Calibrated mode 37 / 300 in 655.682s
# 	Calibrated mode 38 / 300 in 673.434s
# 	Calibrated mode 39 / 300 in 691.577s
# 	Calibrated mode 40 / 300 in 709.270s
# 	Calibrated mode 41 / 300 in 726.911s
# 	Calibrated mode 42 / 300 in 744.424s
# 	Calibrated mode 43 / 300 in 762.846s
# 	Calibrated mode 44 / 300 in 780.333s
# 	Calibrated mode 45 / 300 in 797.865s
# 	Calibrated mode 46 / 300 in 815.994s
# 	Calibrated mode 113 / 300 in 2004.252s
# 	Calibrated mode 114 / 300 in 2022.015s
# 	Calibrated mode 115 / 300 in 2039.483s
# 	Calibrated mode 116 / 300 in 2057.615s
# 	Calibrated mode 117 / 300 in 2075.069s
# 	Calibrated mode 118 / 300 in 2092.715s
# 	Calibrated mode 119 / 300 in 2110.115s
# 	Calibrated mode 120 / 300 in 2128.887s
# 	Calibrated mode 121 / 300 in 2146.313s
# 	Calibrated mode 122 / 300 in 2164.042s
# 	Calibrated mode 123 / 300 in 2182.253s
# 	Calibrated mode 124 / 300 in 2199.923s
# 	Calibrated mode 125 / 300 in 2217.279s
# 	Calibrated mode 126 / 300 in 2234.878s
# 	Calibrated mode 127 / 300 in 2253.094s
# 	Calibrated mode 128 / 300 in 2270.567s
# 	Calibrated mode 129 / 300 in 2288.001s
# 	Calibrated mode 130 / 300 in 2306.257s
# 	Calibrated mode 131 / 300 in 2323.881s
# 	Calibrated mode 132 / 300 in 2341.517s
# 	Calibrated mode 133 / 300 in 2358.932s
# 	Calibrated mode 134 / 300 in 2377.195s
# 	Calibrated mode 135 / 300 in 2399.636s
# 	Calibrated mode 136 / 300 in 2417.015s
# 	Calibrated mode 137 / 300 in 2435.145s
# 	Calibrated mode 138 / 300 in 2452.646s
# 	Calibrated mode 139 / 300 in 2469.998s
# 	Calibrated mode 140 / 300 in 2487.414s
# 	Calibrated mode 141 / 300 in 2505.598s
# 	Calibrated mode 142 / 300 in 2522.978s
# 	Calibrated mode 143 / 300 in 2540.525s
# 	Calibrated mode 144 / 300 in 2558.701s
# 	Calibrated mode 145 / 300 in 2576.271s
# 	Calibrated mode 146 / 300 in 2593.698s
# 	Calibrated mode 147 / 300 in 2611.138s
# 	Calibrated mode 148 / 300 in 2629.327s
# 	Calibrated mode 149 / 300 in 2646.658s
# 	Calibrated mode 150 / 300 in 2663.996s
# 	Calibrated mode 151 / 300 in 2682.070s
# 	Calibrated mode 152 / 300 in 2699.429s
# 	Calibrated mode 153 / 300 in 2716.785s
# 	Calibrated mode 154 / 300 in 2734.225s
# 	Calibrated mode 155 / 300 in 2752.275s
# 	Calibrated mode 156 / 300 in 2769.750s
# 	Calibrated mode 157 / 300 in 2787.191s
# 	Calibrated mode 158 / 300 in 2805.437s
# 	Calibrated mode 159 / 300 in 2823.070s
# 	Calibrated mode 160 / 300 in 2840.485s
# 	Calibrated mode 161 / 300 in 2858.016s
# 	Calibrated mode 162 / 300 in 2876.063s
# 	Calibrated mode 163 / 300 in 2893.670s
# 	Calibrated mode 164 / 300 in 2911.042s
# 	Calibrated mode 165 / 300 in 2929.209s
# 	Calibrated mode 166 / 300 in 2946.722s
# 	Calibrated mode 167 / 300 in 2964.096s
# 	Calibrated mode 168 / 300 in 2981.476s
# 	Calibrated mode 169 / 300 in 3000.528s
# 	Calibrated mode 170 / 300 in 3017.975s
# 	Calibrated mode 171 / 300 in 3035.304s
# 	Calibrated mode 172 / 300 in 3053.357s
# 	Calibrated mode 173 / 300 in 3070.959s
# 	Calibrated mode 174 / 300 in 3088.513s
# 	Calibrated mode 175 / 300 in 3105.943s
# 	Calibrated mode 176 / 300 in 3124.199s
# 	Calibrated mode 177 / 300 in 3141.722s
# 	Calibrated mode 178 / 300 in 3159.143s
# 	Calibrated mode 245 / 300 in 4364.357s
# 	Calibrated mode 246 / 300 in 4381.962s
# 	Calibrated mode 247 / 300 in 4399.354s
# 	Calibrated mode 248 / 300 in 4416.762s
# 	Calibrated mode 249 / 300 in 4434.667s
# 	Calibrated mode 250 / 300 in 4452.220s
# 	Calibrated mode 251 / 300 in 4469.625s
# 	Calibrated mode 252 / 300 in 4487.756s
# 	Calibrated mode 253 / 300 in 4505.451s
# 	Calibrated mode 254 / 300 in 4522.943s
# 	Calibrated mode 255 / 300 in 4540.434s
# 	Calibrated mode 256 / 300 in 4558.753s
# 	Calibrated mode 257 / 300 in 4576.694s
# 	Calibrated mode 258 / 300 in 4594.177s
# 	Calibrated mode 259 / 300 in 4612.223s
# 	Calibrated mode 260 / 300 in 4629.674s
# 	Calibrated mode 261 / 300 in 4647.109s
# 	Calibrated mode 262 / 300 in 4664.449s
# 	Calibrated mode 263 / 300 in 4682.629s
# 	Calibrated mode 264 / 300 in 4700.143s
# 	Calibrated mode 265 / 300 in 4717.555s
# 	Calibrated mode 266 / 300 in 4735.526s
# 	Calibrated mode 267 / 300 in 4753.066s
# 	Calibrated mode 268 / 300 in 4770.521s
# 	Calibrated mode 269 / 300 in 4787.892s
# 	Calibrated mode 270 / 300 in 4805.831s
# 	Calibrated mode 271 / 300 in 4823.322s
# 	Calibrated mode 272 / 300 in 4840.751s
# 	Calibrated mode 273 / 300 in 4858.895s
# 	Calibrated mode 274 / 300 in 4876.502s
# 	Calibrated mode 275 / 300 in 4893.978s
# 	Calibrated mode 276 / 300 in 4911.547s
# 	Calibrated mode 277 / 300 in 4929.863s
# 	Calibrated mode 278 / 300 in 4947.388s
# 	Calibrated mode 279 / 300 in 4964.868s
# 	Calibrated mode 280 / 300 in 4982.908s
# 	Calibrated mode 281 / 300 in 5000.446s
# 	Calibrated mode 282 / 300 in 5017.825s
# 	Calibrated mode 283 / 300 in 5035.237s
# 	Calibrated mode 284 / 300 in 5053.381s
# 	Calibrated mode 285 / 300 in 5070.879s
# 	Calibrated mode 286 / 300 in 5088.256s
# 	Calibrated mode 287 / 300 in 5106.269s
# 	Calibrated mode 288 / 300 in 5123.839s
# 	Calibrated mode 289 / 300 in 5141.192s
# 	Calibrated mode 290 / 300 in 5158.582s
# 	Calibrated mode 291 / 300 in 5176.657s
# 	Calibrated mode 292 / 300 in 5194.107s
# 	Calibrated mode 293 / 300 in 5211.651s
# 	Calibrated mode 294 / 300 in 5229.726s
# 	Calibrated mode 295 / 300 in 5247.239s
# 	Calibrated mode 296 / 300 in 5264.606s
# 	Calibrated mode 297 / 300 in 5281.945s
# 	Calibrated mode 298 / 300 in 5299.902s
# 	Calibrated mode 299 / 300 in 5317.447s
# 	Calibrated mode 300 / 300 in 5334.800s
# Calibration complete.

# %%
print(response_cube.shape, calibration_cube.shape)

response_hdu = fits.PrimaryHDU(data=response_cube)
response_hdu.writeto(data_dir/'response-data'/'hlc_response_cube_ann_mask.fits', overwrite=True)

calib_hdu = fits.PrimaryHDU(data=calibration_cube)
calib_hdu.writeto(data_dir/'calibration-data'/'hlc_calibration_cube_ann_mask.fits', overwrite=True)
# Out:
# (300, 2, 4096) (600, 4, 4096)

# %%
im = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(im.reshape(64,64))
