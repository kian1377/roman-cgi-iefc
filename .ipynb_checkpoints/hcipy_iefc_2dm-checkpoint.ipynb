# %%
import numpy as np
import scipy

import cupy as cp
import cupyx.scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import warnings
warnings.filterwarnings("ignore")

import poppy
import hcipy as hci

import wfsc_tests as wfsc
wfsc.math_module.update_np(np)
wfsc.math_module.update_scipy(scipy)

import misc_funs as misc

from matplotlib.colors import ListedColormap
#Blue to Red Color scale for S1 and S2
colmap = np.zeros((255,3));
# Red
colmap[126:183,0]= np.linspace(0,1,57);
colmap[183:255,0]= 1;
# Green
colmap[0:96,1] = np.linspace(1,0,96);
colmap[158:255,1]= np.linspace(0,1,97);
# Blue
colmap[0:71,2] = 1;
colmap[71:128,2]= np.linspace(1,0,57);
colmap2 = colmap[128:,:]
colmap = ListedColormap(colmap)

# %%
class CORO():

    def __init__(self, 
                 wavelength=None, 
                ):
        
        self.wavelength_c = 575e-9*u.m
        self.wavelength = self.wavelength_c if wavelength is None else wavelength
        self.f = 500*u.mm
        
        self.dm_diam = 10.2*u.mm
        self.dm1_dm2 = 200e-3*u.m
        
        self.FN = (self.dm_diam**2/self.dm1_dm2/self.wavelength).decompose()
        
        # define the grids
        self.npix = 256
        self.oversample = 2
        self.spatial_resolution = self.f.to_value(u.m) * self.wavelength.to_value(u.m) / self.dm_diam.to_value(u.m)
        self.npsf = 64
        self.psf_pixelscale_lamD = self.spatial_resolution/self.f.to_value(u.m)*(self.dm_diam/self.wavelength_c).decompose().value/2
        
        self.pupil_grid = hci.make_pupil_grid(self.npix*self.oversample, self.dm_diam.to_value(u.m) * self.oversample)
        self.focal_grid = hci.make_focal_grid(2, 16, spatial_resolution=self.spatial_resolution)
        self.prop = hci.FraunhoferPropagator(self.pupil_grid, self.focal_grid, self.f.to_value(u.m))

        self.aperture = hci.Field(np.exp(-(self.pupil_grid.as_('polar').r / (0.5 * self.dm_diam.to_value(u.m)))**30), self.pupil_grid)
        
        # define the DMs
        self.Nact = 34
        actuator_spacing = 1.00 / self.Nact * self.dm_diam.to_value(u.m)
        
#         influence_functions = hci.make_xinetics_influence_functions(self.pupil_grid, self.Nact, actuator_spacing)
        influence_functions = hci.make_gaussian_influence_functions(self.pupil_grid, self.Nact, actuator_spacing)
        
        self.DM1 = hci.DeformableMirror(influence_functions)
        self.DM2 = hci.DeformableMirror(influence_functions)

        self.prop_between_dms = hci.FresnelPropagator(self.pupil_grid, self.dm1_dm2.to_value(u.m))
        
        self.dm_mask = np.ones((self.Nact,self.Nact), dtype=bool)
        xx = (np.linspace(0, self.Nact-1, self.Nact) - self.Nact/2 + 1/2) * actuator_spacing*2
        x,y = np.meshgrid(xx,xx)
        r = np.sqrt(x**2 + y**2)
        self.dm_mask[r>0.0105] = 0 # had to set the threshold to 10.5 instead of 10.2 to include edge actuators
        
#         self.dm_zernikes = poppy.zernike.arbitrary_basis(self.dm_mask, nterms=15, outside=0)
        self.dm_zernikes = poppy.zernike.arbitrary_basis(cp.array(self.dm_mask), nterms=15, outside=0).get()
        
        # make the aberrations of the system (make sure to remove tip-tilt)
        aberration_ptv = 0.02 * self.wavelength.to_value(u.m)
        tip_tilt = hci.make_zernike_basis(3, self.dm_diam.to_value(u.m), self.pupil_grid, starting_mode=2)
        wfe = hci.SurfaceAberration(self.pupil_grid, aberration_ptv, self.dm_diam.to_value(u.m), remove_modes=tip_tilt, exponent=-3)
        aberration_distance_m = 100e-3
        self.wfe_at_distance = hci.SurfaceAberrationAtDistance(wfe, aberration_distance_m)
        
        # make the coronagraph model
        self.coronagraph = hci.PerfectCoronagraph(self.aperture, order=6)
        
        
    def set_dm1(self, command):
        self.DM1.actuators = command.ravel()
        
    def set_dm2(self, command):
        self.DM2.actuators = command.ravel()
        
    def add_dm1(self, command):
        self.DM1.actuators += command.ravel()
        
    def add_dm2(self, command):
        self.DM2.actuators += command.ravel()
        
    def get_dm1(self):
        return self.DM1.actuators.reshape(self.Nact, self.Nact)
        
    def get_dm2(self):
        return self.DM2.actuators.reshape(self.Nact, self.Nact)
    
    def reset_dms(self):
        self.DM1.actuators = np.zeros((self.Nact, self.Nact)).ravel()
        self.DM2.actuators = np.zeros((self.Nact, self.Nact)).ravel()
    
    def show_dms(self):
        misc.imshow2(self.DM1.actuators.reshape(c.Nact, c.Nact),
                     self.DM2.actuators.reshape(c.Nact, c.Nact))
        
    def calc_psf(self):
        wf = hci.Wavefront(self.aperture, self.wavelength.to_value(u.m))
        wf = self.wfe_at_distance(wf) # apply aberrations to wavefront
        wf = self.prop_between_dms.backward(self.DM2(self.prop_between_dms.forward(self.DM1(wf)))) # apply DMs
        wf = self.prop(self.coronagraph(wf))
        psf_wf = wf.real.shaped + 1j*wf.imag.shaped

        return np.array(psf_wf)

    def snap(self):
        wf = hci.Wavefront(self.aperture, self.wavelength.to_value(u.m))
        wf = self.wfe_at_distance(wf) # apply aberrations to wavefront
        wf = self.prop_between_dms.backward(self.DM2(self.prop_between_dms.forward(self.DM1(wf)))) # apply DMs
        im = self.prop(self.coronagraph(wf))

        return np.array(im.intensity.shaped)
    
c = CORO()

# %%
Nact = c.Nact
npsf = c.npsf

c.reset_dms()
ref_im = c.snap()

misc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD)

# %% [markdown]
# # define the dark hole region

# %%
reload(wfsc)
reload(wfsc.utils)
reload(wfsc.imshows)
xfp = (np.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*c.psf_pixelscale_lamD
fpx,fpy = np.meshgrid(xfp,xfp)
fpr = np.sqrt(fpx**2 + fpy**2)
    
iwa = 3
owa = 9
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
#         'edge' : 0,
        'rotation':0,
        'full':True,
    }
roi1 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

iwa = (3-1)
owa = (9+0.5)
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
#         'edge' : 0,
        'rotation':0,
        'full':True,
    }
roi2 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

# wfsc.imshow2(roi1, roi2)
weight_map = roi1 + 0.2*(roi2 * ~roi1)
control_mask = weight_map>0
wfsc.imshow1(weight_map)

probe_amp = 3e-8
calib_amp = 5e-9

# %%
reload(wfsc.imshows)
calib_modes, fs = wfsc.utils.select_fourier_modes(c, control_mask*(fpx>0), fourier_sampling=0.9) 
nmodes = calib_modes.shape[0]
display(calib_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
wfsc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD, patches=patches)
# Out:
# (356, 1156)
# (178, 2)

# %%
reload(wfsc.utils)
probe_modes = wfsc.utils.create_probe_poke_modes(Nact, 
                                                 poke_indices=[(Nact//3, Nact//3), 
                                                               (Nact//3, Nact//3+1),
                                                               (Nact//3+1, Nact//3+1)], 
                                                 plot=True)

# %%
reload(wfsc.iefc)

probe_amp = 3e-8
calib_amp = 5e-9

c.reset_dms()
c.texp = 1
differential_images, single_images = wfsc.iefc_1dm.take_measurement(c, 
                                                           probe_modes, probe_amp, 
                                                           return_all=True)
ims = differential_images.reshape(3, c.npsf, c.npsf)
misc.imshow3( ims[0]-ims[1],  ims[0]-ims[2], ims[1]-ims[2], wspace=0.35)

# %%
reload(wfsc.iefc_1dm)
c.reset_dms()
response_matrix, response_cube = wfsc.iefc_1dm.calibrate(c, 
                                                         control_mask.ravel(),
                                                         probe_amp, probe_modes, 
                                                         calib_amp, calib_modes,
                                                         return_all=True)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 356 in 1.373s
# 	Calibrated mode 2 / 356 in 2.751s
# 	Calibrated mode 3 / 356 in 4.135s
# 	Calibrated mode 4 / 356 in 5.515s
# 	Calibrated mode 5 / 356 in 6.898s
# 	Calibrated mode 6 / 356 in 8.282s
# 	Calibrated mode 7 / 356 in 9.676s
# 	Calibrated mode 8 / 356 in 11.060s
# 	Calibrated mode 9 / 356 in 12.442s
# 	Calibrated mode 10 / 356 in 13.828s
# 	Calibrated mode 11 / 356 in 15.204s
# 	Calibrated mode 12 / 356 in 16.589s
# 	Calibrated mode 13 / 356 in 17.971s
# 	Calibrated mode 14 / 356 in 19.359s
# 	Calibrated mode 15 / 356 in 20.741s
# 	Calibrated mode 16 / 356 in 22.127s
# 	Calibrated mode 17 / 356 in 23.507s
# 	Calibrated mode 18 / 356 in 24.896s
# 	Calibrated mode 19 / 356 in 26.274s
# 	Calibrated mode 20 / 356 in 27.651s
# 	Calibrated mode 21 / 356 in 29.035s
# 	Calibrated mode 22 / 356 in 30.419s
# 	Calibrated mode 23 / 356 in 31.802s
# 	Calibrated mode 24 / 356 in 33.186s
# 	Calibrated mode 25 / 356 in 34.574s
# 	Calibrated mode 26 / 356 in 35.964s
# 	Calibrated mode 27 / 356 in 37.353s
# 	Calibrated mode 28 / 356 in 38.742s
# 	Calibrated mode 29 / 356 in 40.115s
# 	Calibrated mode 30 / 356 in 41.498s
# 	Calibrated mode 31 / 356 in 42.883s
# 	Calibrated mode 32 / 356 in 44.269s
# 	Calibrated mode 33 / 356 in 45.644s
# 	Calibrated mode 34 / 356 in 47.026s
# 	Calibrated mode 35 / 356 in 48.410s
# 	Calibrated mode 36 / 356 in 49.793s
# 	Calibrated mode 37 / 356 in 51.184s
# 	Calibrated mode 38 / 356 in 52.561s
# 	Calibrated mode 39 / 356 in 53.936s
# 	Calibrated mode 40 / 356 in 55.321s
# 	Calibrated mode 41 / 356 in 56.699s
# 	Calibrated mode 42 / 356 in 58.085s
# 	Calibrated mode 43 / 356 in 59.472s
# 	Calibrated mode 44 / 356 in 60.859s
# 	Calibrated mode 45 / 356 in 62.243s
# 	Calibrated mode 46 / 356 in 63.641s
# 	Calibrated mode 47 / 356 in 65.034s
# 	Calibrated mode 48 / 356 in 66.423s
# 	Calibrated mode 49 / 356 in 67.807s
# 	Calibrated mode 50 / 356 in 69.180s
# 	Calibrated mode 51 / 356 in 70.560s
# 	Calibrated mode 52 / 356 in 71.950s
# 	Calibrated mode 53 / 356 in 73.332s
# 	Calibrated mode 54 / 356 in 74.714s
# 	Calibrated mode 55 / 356 in 76.103s
# 	Calibrated mode 56 / 356 in 77.496s
# 	Calibrated mode 57 / 356 in 78.876s
# 	Calibrated mode 58 / 356 in 80.266s
# 	Calibrated mode 59 / 356 in 81.649s
# 	Calibrated mode 60 / 356 in 83.024s
# 	Calibrated mode 61 / 356 in 84.410s
# 	Calibrated mode 62 / 356 in 85.789s
# 	Calibrated mode 63 / 356 in 87.169s
# 	Calibrated mode 64 / 356 in 88.550s
# 	Calibrated mode 65 / 356 in 89.929s
# 	Calibrated mode 66 / 356 in 91.313s
# 	Calibrated mode 67 / 356 in 92.691s
# 	Calibrated mode 68 / 356 in 94.079s
# 	Calibrated mode 69 / 356 in 95.468s
# 	Calibrated mode 70 / 356 in 96.849s
# 	Calibrated mode 71 / 356 in 98.225s
# 	Calibrated mode 72 / 356 in 99.610s
# 	Calibrated mode 73 / 356 in 100.995s
# 	Calibrated mode 74 / 356 in 102.379s
# 	Calibrated mode 75 / 356 in 103.765s
# 	Calibrated mode 76 / 356 in 105.146s
# 	Calibrated mode 77 / 356 in 106.532s
# 	Calibrated mode 78 / 356 in 107.924s
# 	Calibrated mode 79 / 356 in 109.304s
# 	Calibrated mode 80 / 356 in 110.681s
# 	Calibrated mode 81 / 356 in 112.058s
# 	Calibrated mode 82 / 356 in 113.443s
# 	Calibrated mode 83 / 356 in 114.836s
# 	Calibrated mode 84 / 356 in 116.216s
# 	Calibrated mode 85 / 356 in 117.603s
# 	Calibrated mode 86 / 356 in 118.995s
# 	Calibrated mode 87 / 356 in 120.383s
# 	Calibrated mode 88 / 356 in 121.765s
# 	Calibrated mode 89 / 356 in 123.143s
# 	Calibrated mode 90 / 356 in 124.527s
# 	Calibrated mode 91 / 356 in 125.904s
# 	Calibrated mode 92 / 356 in 127.296s
# 	Calibrated mode 93 / 356 in 128.690s
# 	Calibrated mode 94 / 356 in 130.075s
# 	Calibrated mode 95 / 356 in 131.454s
# 	Calibrated mode 96 / 356 in 132.843s
# 	Calibrated mode 97 / 356 in 134.228s
# 	Calibrated mode 98 / 356 in 135.613s
# 	Calibrated mode 99 / 356 in 137.001s
# 	Calibrated mode 100 / 356 in 138.384s
# 	Calibrated mode 101 / 356 in 139.760s
# 	Calibrated mode 102 / 356 in 141.143s
# 	Calibrated mode 103 / 356 in 142.533s
# 	Calibrated mode 104 / 356 in 143.925s
# 	Calibrated mode 105 / 356 in 145.316s
# 	Calibrated mode 106 / 356 in 146.697s
# 	Calibrated mode 107 / 356 in 148.080s
# 	Calibrated mode 108 / 356 in 149.466s
# 	Calibrated mode 109 / 356 in 150.846s
# 	Calibrated mode 110 / 356 in 152.232s
# 	Calibrated mode 111 / 356 in 153.628s
# 	Calibrated mode 112 / 356 in 155.008s
# 	Calibrated mode 113 / 356 in 156.398s
# 	Calibrated mode 114 / 356 in 157.781s
# 	Calibrated mode 115 / 356 in 159.163s
# 	Calibrated mode 116 / 356 in 160.543s
# 	Calibrated mode 117 / 356 in 161.931s
# 	Calibrated mode 118 / 356 in 163.313s
# 	Calibrated mode 119 / 356 in 164.698s
# 	Calibrated mode 120 / 356 in 166.080s
# 	Calibrated mode 121 / 356 in 167.463s
# 	Calibrated mode 122 / 356 in 168.850s
# 	Calibrated mode 123 / 356 in 170.230s
# 	Calibrated mode 124 / 356 in 171.612s
# 	Calibrated mode 125 / 356 in 172.989s
# 	Calibrated mode 126 / 356 in 174.373s
# 	Calibrated mode 127 / 356 in 175.752s
# 	Calibrated mode 128 / 356 in 177.137s
# 	Calibrated mode 129 / 356 in 178.519s
# 	Calibrated mode 130 / 356 in 179.903s
# 	Calibrated mode 131 / 356 in 181.284s
# 	Calibrated mode 132 / 356 in 182.666s
# 	Calibrated mode 133 / 356 in 184.059s
# 	Calibrated mode 134 / 356 in 185.438s
# 	Calibrated mode 135 / 356 in 186.825s
# 	Calibrated mode 136 / 356 in 188.208s
# 	Calibrated mode 137 / 356 in 189.594s
# 	Calibrated mode 138 / 356 in 190.982s
# 	Calibrated mode 139 / 356 in 192.365s
# 	Calibrated mode 140 / 356 in 193.767s
# 	Calibrated mode 141 / 356 in 195.156s
# 	Calibrated mode 142 / 356 in 196.539s
# 	Calibrated mode 143 / 356 in 197.915s
# 	Calibrated mode 144 / 356 in 199.300s
# 	Calibrated mode 145 / 356 in 200.687s
# 	Calibrated mode 146 / 356 in 202.067s
# 	Calibrated mode 147 / 356 in 203.437s
# 	Calibrated mode 148 / 356 in 204.822s
# 	Calibrated mode 149 / 356 in 206.206s
# 	Calibrated mode 150 / 356 in 207.603s
# 	Calibrated mode 151 / 356 in 208.999s
# 	Calibrated mode 152 / 356 in 210.385s
# 	Calibrated mode 153 / 356 in 211.764s
# 	Calibrated mode 154 / 356 in 213.150s
# 	Calibrated mode 155 / 356 in 214.532s
# 	Calibrated mode 156 / 356 in 215.918s
# 	Calibrated mode 157 / 356 in 217.295s
# 	Calibrated mode 158 / 356 in 218.676s
# 	Calibrated mode 159 / 356 in 220.049s
# 	Calibrated mode 160 / 356 in 221.430s
# 	Calibrated mode 161 / 356 in 222.817s
# 	Calibrated mode 162 / 356 in 224.194s
# 	Calibrated mode 163 / 356 in 225.570s
# 	Calibrated mode 164 / 356 in 226.940s
# 	Calibrated mode 165 / 356 in 228.321s
# 	Calibrated mode 166 / 356 in 229.699s
# 	Calibrated mode 167 / 356 in 231.077s
# 	Calibrated mode 168 / 356 in 232.462s
# 	Calibrated mode 169 / 356 in 233.842s
# 	Calibrated mode 170 / 356 in 235.223s
# 	Calibrated mode 171 / 356 in 236.599s
# 	Calibrated mode 172 / 356 in 237.978s
# 	Calibrated mode 173 / 356 in 239.350s
# 	Calibrated mode 174 / 356 in 240.726s
# 	Calibrated mode 175 / 356 in 242.100s
# 	Calibrated mode 176 / 356 in 243.479s
# 	Calibrated mode 177 / 356 in 244.857s
# 	Calibrated mode 178 / 356 in 246.236s
# 	Calibrated mode 179 / 356 in 247.618s
# 	Calibrated mode 180 / 356 in 249.005s
# 	Calibrated mode 181 / 356 in 250.381s
# 	Calibrated mode 182 / 356 in 251.756s
# 	Calibrated mode 183 / 356 in 253.135s
# 	Calibrated mode 184 / 356 in 254.515s
# 	Calibrated mode 185 / 356 in 255.883s
# 	Calibrated mode 186 / 356 in 257.252s
# 	Calibrated mode 187 / 356 in 258.624s
# 	Calibrated mode 188 / 356 in 259.997s
# 	Calibrated mode 189 / 356 in 261.375s
# 	Calibrated mode 190 / 356 in 262.749s
# 	Calibrated mode 191 / 356 in 264.134s
# 	Calibrated mode 192 / 356 in 265.523s
# 	Calibrated mode 193 / 356 in 266.903s
# 	Calibrated mode 194 / 356 in 268.295s
# 	Calibrated mode 195 / 356 in 269.682s
# 	Calibrated mode 196 / 356 in 271.063s
# 	Calibrated mode 197 / 356 in 272.437s
# 	Calibrated mode 198 / 356 in 273.826s
# 	Calibrated mode 199 / 356 in 275.205s
# 	Calibrated mode 200 / 356 in 276.594s
# 	Calibrated mode 201 / 356 in 277.975s
# 	Calibrated mode 202 / 356 in 279.357s
# 	Calibrated mode 203 / 356 in 280.733s
# 	Calibrated mode 204 / 356 in 282.110s
# 	Calibrated mode 205 / 356 in 283.488s
# 	Calibrated mode 206 / 356 in 284.859s
# 	Calibrated mode 207 / 356 in 286.230s
# 	Calibrated mode 208 / 356 in 287.609s
# 	Calibrated mode 209 / 356 in 288.995s
# 	Calibrated mode 210 / 356 in 290.367s
# 	Calibrated mode 211 / 356 in 291.749s
# 	Calibrated mode 212 / 356 in 293.132s
# 	Calibrated mode 213 / 356 in 294.516s
# 	Calibrated mode 214 / 356 in 295.888s
# 	Calibrated mode 215 / 356 in 297.260s
# 	Calibrated mode 216 / 356 in 298.628s
# 	Calibrated mode 217 / 356 in 300.009s
# 	Calibrated mode 218 / 356 in 301.389s
# 	Calibrated mode 219 / 356 in 302.762s
# 	Calibrated mode 220 / 356 in 304.145s
# 	Calibrated mode 221 / 356 in 305.524s
# 	Calibrated mode 222 / 356 in 306.903s
# 	Calibrated mode 223 / 356 in 308.276s
# 	Calibrated mode 224 / 356 in 309.658s
# 	Calibrated mode 225 / 356 in 311.034s
# 	Calibrated mode 226 / 356 in 312.412s
# 	Calibrated mode 227 / 356 in 313.798s
# 	Calibrated mode 228 / 356 in 315.179s
# 	Calibrated mode 229 / 356 in 316.556s
# 	Calibrated mode 230 / 356 in 317.933s
# 	Calibrated mode 231 / 356 in 319.307s
# 	Calibrated mode 232 / 356 in 320.685s
# 	Calibrated mode 233 / 356 in 322.067s
# 	Calibrated mode 234 / 356 in 323.453s
# 	Calibrated mode 235 / 356 in 324.826s
# 	Calibrated mode 236 / 356 in 326.205s
# 	Calibrated mode 237 / 356 in 327.582s
# 	Calibrated mode 238 / 356 in 328.959s
# 	Calibrated mode 239 / 356 in 330.342s
# 	Calibrated mode 240 / 356 in 331.717s
# 	Calibrated mode 241 / 356 in 333.097s
# 	Calibrated mode 242 / 356 in 334.479s
# 	Calibrated mode 243 / 356 in 335.855s
# 	Calibrated mode 244 / 356 in 337.232s
# 	Calibrated mode 245 / 356 in 338.608s
# 	Calibrated mode 246 / 356 in 339.983s
# 	Calibrated mode 247 / 356 in 341.360s
# 	Calibrated mode 248 / 356 in 342.732s
# 	Calibrated mode 249 / 356 in 344.115s
# 	Calibrated mode 250 / 356 in 345.505s
# 	Calibrated mode 251 / 356 in 346.882s
# 	Calibrated mode 252 / 356 in 348.259s
# 	Calibrated mode 253 / 356 in 349.639s
# 	Calibrated mode 254 / 356 in 351.016s
# 	Calibrated mode 255 / 356 in 352.392s
# 	Calibrated mode 256 / 356 in 353.771s
# 	Calibrated mode 257 / 356 in 355.140s
# 	Calibrated mode 258 / 356 in 356.511s
# 	Calibrated mode 259 / 356 in 357.895s
# 	Calibrated mode 260 / 356 in 359.277s
# 	Calibrated mode 261 / 356 in 360.658s
# 	Calibrated mode 262 / 356 in 362.035s
# 	Calibrated mode 263 / 356 in 363.411s
# 	Calibrated mode 264 / 356 in 364.787s
# 	Calibrated mode 265 / 356 in 366.164s
# 	Calibrated mode 266 / 356 in 367.537s
# 	Calibrated mode 267 / 356 in 368.912s
# 	Calibrated mode 268 / 356 in 370.295s
# 	Calibrated mode 269 / 356 in 371.675s
# 	Calibrated mode 270 / 356 in 373.062s
# 	Calibrated mode 271 / 356 in 374.447s
# 	Calibrated mode 272 / 356 in 375.822s
# 	Calibrated mode 273 / 356 in 377.201s
# 	Calibrated mode 274 / 356 in 378.580s
# 	Calibrated mode 275 / 356 in 379.955s
# 	Calibrated mode 276 / 356 in 381.334s
# 	Calibrated mode 277 / 356 in 382.714s
# 	Calibrated mode 278 / 356 in 384.096s
# 	Calibrated mode 279 / 356 in 385.471s
# 	Calibrated mode 280 / 356 in 386.855s
# 	Calibrated mode 281 / 356 in 388.236s
# 	Calibrated mode 282 / 356 in 389.615s
# 	Calibrated mode 283 / 356 in 390.994s
# 	Calibrated mode 284 / 356 in 392.371s
# 	Calibrated mode 285 / 356 in 393.747s
# 	Calibrated mode 286 / 356 in 395.130s
# 	Calibrated mode 287 / 356 in 396.511s
# 	Calibrated mode 288 / 356 in 397.886s
# 	Calibrated mode 289 / 356 in 399.260s
# 	Calibrated mode 290 / 356 in 400.641s
# 	Calibrated mode 291 / 356 in 402.018s
# 	Calibrated mode 292 / 356 in 403.394s
# 	Calibrated mode 293 / 356 in 404.775s
# 	Calibrated mode 294 / 356 in 406.155s
# 	Calibrated mode 295 / 356 in 407.529s
# 	Calibrated mode 296 / 356 in 408.903s
# 	Calibrated mode 297 / 356 in 410.282s
# 	Calibrated mode 298 / 356 in 411.658s
# 	Calibrated mode 299 / 356 in 413.040s
# 	Calibrated mode 300 / 356 in 414.420s
# 	Calibrated mode 301 / 356 in 415.796s
# 	Calibrated mode 302 / 356 in 417.175s
# 	Calibrated mode 303 / 356 in 418.553s
# 	Calibrated mode 304 / 356 in 419.932s
# 	Calibrated mode 305 / 356 in 421.312s
# 	Calibrated mode 306 / 356 in 422.690s
# 	Calibrated mode 307 / 356 in 424.080s
# 	Calibrated mode 308 / 356 in 425.461s
# 	Calibrated mode 309 / 356 in 426.840s
# 	Calibrated mode 310 / 356 in 428.217s
# 	Calibrated mode 311 / 356 in 429.603s
# 	Calibrated mode 312 / 356 in 430.983s
# 	Calibrated mode 313 / 356 in 432.367s
# 	Calibrated mode 314 / 356 in 433.749s
# 	Calibrated mode 315 / 356 in 435.123s
# 	Calibrated mode 316 / 356 in 436.503s
# 	Calibrated mode 317 / 356 in 437.886s
# 	Calibrated mode 318 / 356 in 439.274s
# 	Calibrated mode 319 / 356 in 440.661s
# 	Calibrated mode 320 / 356 in 442.037s
# 	Calibrated mode 321 / 356 in 443.426s
# 	Calibrated mode 322 / 356 in 444.810s
# 	Calibrated mode 323 / 356 in 446.196s
# 	Calibrated mode 324 / 356 in 447.580s
# 	Calibrated mode 325 / 356 in 448.950s
# 	Calibrated mode 326 / 356 in 450.332s
# 	Calibrated mode 327 / 356 in 451.720s
# 	Calibrated mode 328 / 356 in 453.105s
# 	Calibrated mode 329 / 356 in 454.493s
# 	Calibrated mode 330 / 356 in 455.873s
# 	Calibrated mode 331 / 356 in 457.261s
# 	Calibrated mode 332 / 356 in 458.655s
# 	Calibrated mode 333 / 356 in 460.036s
# 	Calibrated mode 334 / 356 in 461.406s
# 	Calibrated mode 335 / 356 in 462.779s
# 	Calibrated mode 336 / 356 in 464.164s
# 	Calibrated mode 337 / 356 in 465.543s
# 	Calibrated mode 338 / 356 in 466.925s
# 	Calibrated mode 339 / 356 in 468.305s
# 	Calibrated mode 340 / 356 in 469.683s
# 	Calibrated mode 341 / 356 in 471.059s
# 	Calibrated mode 342 / 356 in 472.441s
# 	Calibrated mode 343 / 356 in 473.820s
# 	Calibrated mode 344 / 356 in 475.192s
# 	Calibrated mode 345 / 356 in 476.573s
# 	Calibrated mode 346 / 356 in 477.949s
# 	Calibrated mode 347 / 356 in 479.326s
# 	Calibrated mode 348 / 356 in 480.706s
# 	Calibrated mode 349 / 356 in 482.096s
# 	Calibrated mode 350 / 356 in 483.482s
# 	Calibrated mode 351 / 356 in 484.860s
# 	Calibrated mode 352 / 356 in 486.244s
# 	Calibrated mode 353 / 356 in 487.621s
# 	Calibrated mode 354 / 356 in 488.989s
# 	Calibrated mode 355 / 356 in 490.367s
# 	Calibrated mode 356 / 356 in 491.739s
# Calibration complete.

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
wfsc.imshow1(response_sum.reshape(npsf,npsf))

# %%
misc.save_fits('response_matrix_1dm.fits', response_matrix)
misc.save_fits('response_cube_1dm.fits', response_cube)
# Out:
# Saved data to:  response_matrix_1dm.fits
# Saved data to:  response_cube_1dm.fits

# %%
response_cube.shape
# Out:
# (356, 2, 4096)

# %%
cm_tik = wfsc.utils.TikhonovInverse(response_matrix, rcond=1e-1)

Wmatrix = np.diag(np.concatenate((weight_map[control_mask], weight_map[control_mask])))
cm_wls = wfsc.utils.WeightedLeastSquares(response_matrix, Wmatrix, rcond=1e-1)

# %%
reload(wfsc.iefc_1dm)

c.reset_dms()

images, dm_commands_1 = wfsc.iefc_1dm.run(c, 
                                          cm_wls,
                                          probe_modes, 
                                          probe_amp, 
                                          calib_modes,
                                          weight_map, 
                                          num_iterations=20, 
                                          loop_gain=0.5, leakage=0.0,
                                          display_all=True,
                                         )
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 20
# 	Closed-loop iteration 2 / 20
# 	Closed-loop iteration 3 / 20
# 	Closed-loop iteration 4 / 20
# 	Closed-loop iteration 5 / 20
# 	Closed-loop iteration 6 / 20
# 	Closed-loop iteration 7 / 20
# 	Closed-loop iteration 8 / 20
# 	Closed-loop iteration 9 / 20
# 	Closed-loop iteration 10 / 20
# 	Closed-loop iteration 11 / 20
# 	Closed-loop iteration 12 / 20
# 	Closed-loop iteration 13 / 20
# 	Closed-loop iteration 14 / 20
# 	Closed-loop iteration 15 / 20
# 	Closed-loop iteration 16 / 20
# 	Closed-loop iteration 17 / 20
# 	Closed-loop iteration 18 / 20
# 	Closed-loop iteration 19 / 20
# 	Closed-loop iteration 20 / 20
# 	Closed-loop iteration 21 / 20
# I-EFC loop completed in 31.935s.
