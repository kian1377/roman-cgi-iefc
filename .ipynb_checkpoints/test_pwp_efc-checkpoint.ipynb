# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

from roman_cgi_iefc_2.poppy_roman_cgi_phasec import cgi
from roman_cgi_iefc_2 import iefc_utils as iefcu
from roman_cgi_iefc_2 import efc

import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
flatmaps_dir = Path.home()/'src/pyfalco/roman/flatmaps'

dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')

def init(ngpus=1):
    hlci = cgi.CGI_POPPY(polaxis=0, use_opds=True, use_fieldstop=True, 
                         use_shot_noise=False, use_read_noise=False,
                         return_intermediates=False, quiet=True, 
                         ngpus=ngpus)
    hlci.set_dm1(2*dm1_flatmap)
    hlci.set_dm2(2*dm2_flatmap)
    return hlci

hlci = init()

ref_psf = hlci.calc_psf()[-1]
misc.myimshow(ref_psf.intensity, lognorm=True)

npsf = hlci.npsf
Nact = hlci.Nact

# %%
hlci = init()

ref_psf = hlci.calc_psfs()[0][-1]
misc.myimshow(ref_psf.intensity*1e10, lognorm=True)

# %%
noise_mask = np.random.poisson(ref_psf.intensity.get()*1e10)
noise_mask -= np.mean(noise_mask) 
misc.myimshow2(noise_mask, 1e10*ref_psf.intensity.get()+noise_mask, lognorm2=True)
misc.myimshow((1e10*ref_psf.intensity.get()+noise_mask)/1e10, lognorm=True)

# %% [markdown]
# # Create the dark-hole mask

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlci.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1
iwa = 3
owa = 9

# Create the mask that is used to select which region to make dark.
dh_params = {'inner_radius' : iwa, 'outer_radius' : owa, 'edge_position' : edge, 'direction' : '+x'}
dh_mask = iefcu.create_annular_focal_plane_mask(xf, yf, dh_params)
nmask = dh_mask.sum()

misc.myimshow(dh_mask, pxscl=hlci.psf_pixelscale_lamD)

# %%
reload(efc)

hlci = cgi.CGI_POPPY(polaxis=0, use_opds=True, use_fieldstop=True, quiet=True, ngpus=1/2)
hlci.set_dm1(2*dm1_flatmap)
hlci.set_dm2(2*dm2_flatmap)

jac = efc.build_jacobian(hlci, 1e-9, dh_mask)
# Out:
# Building Jacobian.
# 	Calculating response for mode 0. Elapsed time=0.000 sec.
# 	Calculating response for mode 1. Elapsed time=1.863 sec.
# 	Calculating response for mode 2. Elapsed time=2.556 sec.
# 	Calculating response for mode 3. Elapsed time=3.226 sec.
# 	Calculating response for mode 4. Elapsed time=3.890 sec.
# 	Calculating response for mode 5. Elapsed time=4.550 sec.
# 	Calculating response for mode 6. Elapsed time=5.207 sec.
# 	Calculating response for mode 7. Elapsed time=5.878 sec.
# 	Calculating response for mode 8. Elapsed time=6.536 sec.
# 	Calculating response for mode 9. Elapsed time=7.197 sec.
# 	Calculating response for mode 10. Elapsed time=7.852 sec.
# 	Calculating response for mode 11. Elapsed time=8.495 sec.
# 	Calculating response for mode 12. Elapsed time=9.136 sec.
# 	Calculating response for mode 13. Elapsed time=9.766 sec.
# 	Calculating response for mode 14. Elapsed time=10.405 sec.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <module>
#       4 hlci.set_dm1(2*dm1_flatmap)
#       5 hlci.set_dm2(2*dm2_flatmap)
# ----> 7 jac = efc.build_jacobian(hlci, 1e-9, dh_mask)
#
# File ~/Documents/roman-cgi-iefc/roman_cgi_iefc_2/efc.py:33, in build_jacobian(sysi, epsilon, dark_mask)
#      29 dm1_commands = [amps[0]*mode, amps[1]*mode]
#      30 dm_commands = [np.vstack( (dm1_commands[0], np.zeros((sysi.Nact**2))) ),
#      31                np.vstack( (dm1_commands[1], np.zeros((sysi.Nact**2))) )]
# ---> 33 wfs = sysi.calc_psfs(dm_commands=dm_commands)
#      35 response = (amps[0]*wfs[0][-1].wavefront + amps[1]*wfs[1][-1].wavefront)
#      36 response /= np.var(amps)
#
# File ~/Documents/roman-cgi-iefc/roman_cgi_iefc_2/poppy_roman_cgi_phasec/cgi.py:279, in CGI_POPPY.calc_psfs(self, wavelengths, dm_commands, offsets)
#     277         self.add_dm1(-dm_commands[j][0])
#     278         self.add_dm2(-dm_commands[j][1])
# --> 279 wfs = ray.get(pending_results)
#     280 if not self.quiet: print('All PSFs calculated in {:.3f}s'.format(time.time()-start))
#     282 return wfs
#
# File ~/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/worker.py:1756, in get(object_refs, timeout)
#    1752     raise ValueError("'object_refs' must either be an object ref "
#    1753                      "or a list of object refs.")
#    1755 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1756 values, debugger_breakpoint = worker.get_objects(
#    1757     object_refs, timeout=timeout)
#    1758 for i, value in enumerate(values):
#    1759     if isinstance(value, RayError):
#
# File ~/anaconda3/envs/poppy-env/lib/python3.9/site-packages/ray/worker.py:352, in Worker.get_objects(self, object_refs, timeout)
#     347         raise TypeError(
#     348             f"Attempting to call `get` on the value {object_ref}, "
#     349             "which is not an ray.ObjectRef.")
#     351 timeout_ms = int(timeout * 1000) if timeout else -1
# --> 352 data_metadata_pairs = self.core_worker.get_objects(
#     353     object_refs, self.current_task_id, timeout_ms)
#     354 debugger_breakpoint = b""
#     355 for (data, metadata) in data_metadata_pairs:
#
# KeyboardInterrupt:

# %%
iefcu.save_pickle(data_dir/'jacobians'/'jac_opds_right39', jac, quiet=False)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/jacobians/jac_opds_right39

# %%
jac = iefcu.load_pickle(data_dir/'jacobians'/'jac_opds_right39')
jac.shape
# Out:
# (1044, 2304)

# %% [markdown]
# # Generate probes and test PWP

# %%
reload(efc)

Npairs = 3
probe_amp = 0.01*hlci.wavelength_c.value
probe_radius = 10
probe_offset = (10,10)

probes = efc.create_sinc_probes(Npairs, Nact, probe_amp, probe_radius, probe_offset, display=True)
# Out:
# Generating probe with amplitude=5.750e-09, radius=10.0, phase=0.000, offset=(10.0,10.0), with discontinuity along x axis.
# Generating probe with amplitude=5.750e-09, radius=10.0, phase=1.047, offset=(10.0,10.0), with discontinuity along y axis.
# Generating probe with amplitude=5.750e-09, radius=10.0, phase=2.094, offset=(10.0,10.0), with discontinuity along x axis.

# %%
reload(efc)

hlci = init()

E_est = efc.run_pwp(hlci, probes, jac, dh_mask)

misc.myimshow2(cp.abs(E_est)**2, cp.angle(E_est), 
               'Estimated Intensity', 'Estimated Phase', lognorm1=True)
misc.myimshow2(ref_psf.intensity.get()*dh_mask, ref_psf.phase.get()*dh_mask, 
               'Exact Model Intensity', 'Exact Model Phase', lognorm1=True)
misc.myimshow2(abs(ref_psf.intensity - cp.abs(E_est)**2).get()*dh_mask, 
               (ref_psf.phase - cp.angle(E_est)).get()*dh_mask,
               'Intensity Difference', 'Phase Difference',
               lognorm1=True)

# %% [markdown]
# # Invert the Jacobian to get the control matrix

# %%
control_matrix = iefcu.TikhonovInverse(jac, 5e-2)
control_matrix.shape
# Out:
# (2304, 1044)

# %% [markdown]
# # Run EFC with perfect model

# %%
reload(efc)

hlci = init()

commands, efields = efc.run_efc_perfect(hlci, control_matrix, dh_mask, iterations=10, display=True)
# Out:
# Beginning closed-loop EFC simulation.
# 	Running iteration 1/10.
# 	Running iteration 2/10.
# 	Running iteration 3/10.
# 	Running iteration 4/10.
# 	Running iteration 5/10.
# 	Running iteration 6/10.
# 	Running iteration 7/10.
# 	Running iteration 8/10.
# 	Running iteration 9/10.
# 	Running iteration 10/10.
# EFC completed in 10.704 sec.

# %% [markdown]
# # Run EFC with PWP

# %%
reload(efc)

hlci = init()

commands, efields, images = efc.run_efc_pwp(hlci, control_matrix, jac, probes, dh_mask, iterations=5, display=True)
# Out:
# Beginning closed-loop EFC simulation.
# 	Running iteration 1/5.
# 	Running iteration 2/5.
# 	Running iteration 3/5.
# 	Running iteration 4/5.
# 	Running iteration 5/5.
# EFC completed in 19.840 sec.

# %%
# !nvidia-smi
# Out:
# Tue May  3 10:45:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100S-PCI...  On   | 00000000:25:00.0 Off |                    0 |
# | N/A   34C    P0    35W / 250W |   3430MiB / 32768MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     77364      C   ...envs/poppy-env/bin/python     1829MiB |
# |    0   N/A  N/A     77586      C   ray::IDLE                        1597MiB |
# +-----------------------------------------------------------------------------+
