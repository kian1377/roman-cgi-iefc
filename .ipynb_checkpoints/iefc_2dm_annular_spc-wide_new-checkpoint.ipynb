# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_2dm as iefc
from wfsc import utils

dm_dir = cgi.data_dir/'dm-acts'

# %%
reload(cgi)
sysi = cgi.CGI(cgi_mode='spc-wide', npsf=150,
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
             )
sysi.show_dms()

npsf = sysi.npsf
Nact = sysi.Nact

ref_psf = sysi.snap()

misc.myimshow(ref_psf, lognorm=True)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(utils)
xfp = (np.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*sysi.psf_pixelscale_lamD
fpx,fpy = np.meshgrid(xfp,xfp)
fpr = np.sqrt(fpx**2 + fpy**2)
    
iwa = 5.5
owa = 20.5
regions = [iwa, 6, 10, 20, owa]
weights = [0.1, 0.8, 1, 0.1]
weight_map = np.zeros((sysi.npsf,sysi.npsf), dtype=np.float64)
for i in range(len(weights)):
    roi_params = {
        'inner_radius' : regions[i],
        'outer_radius' : regions[i+1],
        'edge_position' : 0,
        'rotation':0,
        'full':True,
    }
    roi = utils.create_annular_focal_plane_mask(fpx, fpy, roi_params)
    weight_map += roi*weights[i]

control_mask = weight_map>0
misc.myimshow2(weight_map, control_mask)

probe_amp = 3e-8
calib_amp = 5e-9

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(utils)
fourier_modes, fs = utils.select_fourier_modes(sysi, control_mask*(fpx>0), fourier_sampling=0.85) 
nf = fourier_modes.shape[0]
print(fourier_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
misc.myimshow(ref_psf, lognorm=True, pxscl=sysi.psf_pixelscale_lamD, patches=patches)
# Out:
# (1732, 2304) (866, 2)

# %%
cos_modes = fourier_modes[:nf//2]
sin_modes = fourier_modes[nf//2:]

for i in range(cos_modes.shape[0]):
    try:
        misc.myimshow3(cos_modes[i].reshape(Nact,Nact), sin_modes[i].reshape(Nact,Nact),
                       cos_modes[i].reshape(Nact,Nact)-sin_modes[i].reshape(Nact,Nact))
        clear_output(wait=True)
        time.sleep(0.1)
    except KeyboardInterrupt:
        break

# %%
import time
for i in range(nf//2):
    try:
        misc.myimshow2(fourier_modes[i].reshape(Nact,Nact), ref_psf, 
                       'Frequency Sampled: ({:.3f}, {:.3f})'.format(fs[i][0], fs[i][1]),
                       lognorm2=True,
                       pxscl2=sysi.psf_pixelscale_lamD, 
                       patches2=[Circle(fs[i], 0.25, fill=True, color='g'),
                                 Circle(-fs[i], 0.25, fill=True, color='g')])
        clear_output(wait=True)
        time.sleep(0.25)
    except KeyboardInterrupt:
        break

# %%
Nacts = int(sysi.dm_mask.sum())
Nacts
# Out:
# 1780

# %%
reload(utils)
# had_modes = utils.get_hadamard_modes_1(sysi.dm_mask)
# had_modes_1 = had_modes[:1024]
# had_modes_2 = had_modes[1024:]
had_modes_1, had_modes_2 = utils.get_hadamard_modes_2(2*Nacts, sysi.dm_mask)
nh = had_modes.shape[0]
print(had_modes.shape, had_modes_1.shape)
# Out:
# (4096, 4096)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 5>()
#       1 reload(utils)
#       2 # had_modes = utils.get_hadamard_modes_1(sysi.dm_mask)
#       3 # had_modes_1 = had_modes[:1024]
#       4 # had_modes_2 = had_modes[1024:]
# ----> 5 had_modes_1, had_modes_2 = utils.get_hadamard_modes_2(2*Nacts, sysi.dm_mask)
#       6 nh = had_modes.shape[0]
#       7 print(had_modes.shape, had_modes_1.shape)
#
# File ~/Documents/roman-cgi-iefc/wfsc/utils.py:201, in get_hadamard_modes_2(Nacts, dm_mask)
#     199     mode[inds] = hmode_1
#     200     had_modes_1.append(mode_1)
# --> 201     had_modes_2.append(mode_2)
#     202 had_modes_1 = np.array(had_modes_1)
#     203 had_modes_2 = np.array(had_modes_2)
#
# ValueError: shape mismatch: value array of shape (0,) could not be broadcast to indexing result of shape (1780,)

# %%
# for mode in had_modes:
#     try:
#         misc.myimshow(calib_amp*mode.reshape(Nact,Nact))
#         clear_output(wait=True)
#         time.sleep(0.1)
#     except KeyboardInterrupt:
#         break
        
for i in range(had_modes_1.shape[0]):
    try:
        misc.myimshow3(had_modes_1[i].reshape(Nact,Nact), had_modes_2[i].reshape(Nact,Nact),
                       had_modes_1[i].reshape(Nact,Nact)-had_modes_2[i].reshape(Nact,Nact))
        clear_output(wait=True)
        time.sleep(0.1)
    except KeyboardInterrupt:
        break

# %%
reload(iefc)
probe_modes = utils.create_probe_poke_modes(Nact, xinds=[Nact//4, Nact//4+1], yinds=[Nact//4, Nact//4], display=True)
# probe_modes = utils.create_fourier_probes(calib_modes, display_probes=True)

# %%
reload(iefc)
sysi.reset_dms()
differential_images, single_images = iefc.take_measurement(sysi, 
                                                           probe_modes, probe_amp, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
sysi.reset_dms()
response_cube, calibration_cube = iefc.calibrate(sysi, 
                                                 probe_amp, probe_modes, 
                                                 calib_amp, fourier_modes, had_modes)
# Out:
# Calibrating I-EFC...
# 	Calibrated DM1 mode 1 / 516 in 2.643s
# 	Calibrated DM1 mode 2 / 516 in 5.170s
# 	Calibrated DM1 mode 3 / 516 in 7.699s
# 	Calibrated DM1 mode 4 / 516 in 10.233s
# 	Calibrated DM1 mode 5 / 516 in 12.850s
# 	Calibrated DM1 mode 6 / 516 in 15.429s
# 	Calibrated DM1 mode 7 / 516 in 17.956s
# 	Calibrated DM1 mode 8 / 516 in 20.496s
# 	Calibrated DM1 mode 9 / 516 in 23.029s
# 	Calibrated DM1 mode 10 / 516 in 25.584s
# 	Calibrated DM1 mode 11 / 516 in 28.233s
# 	Calibrated DM1 mode 12 / 516 in 30.772s
# 	Calibrated DM1 mode 13 / 516 in 33.317s
# 	Calibrated DM1 mode 14 / 516 in 35.866s
# 	Calibrated DM1 mode 15 / 516 in 38.411s
# 	Calibrated DM1 mode 16 / 516 in 40.953s
# 	Calibrated DM1 mode 17 / 516 in 43.498s
# 	Calibrated DM1 mode 18 / 516 in 46.044s
# 	Calibrated DM1 mode 19 / 516 in 48.586s
# 	Calibrated DM1 mode 20 / 516 in 51.133s
# 	Calibrated DM1 mode 21 / 516 in 53.674s
# 	Calibrated DM1 mode 22 / 516 in 56.297s
# 	Calibrated DM1 mode 23 / 516 in 58.841s
# 	Calibrated DM1 mode 24 / 516 in 61.386s
# 	Calibrated DM1 mode 25 / 516 in 63.932s
# 	Calibrated DM1 mode 26 / 516 in 66.481s
# 	Calibrated DM1 mode 27 / 516 in 69.027s
# 	Calibrated DM1 mode 28 / 516 in 71.580s
# 	Calibrated DM1 mode 29 / 516 in 74.125s
# 	Calibrated DM1 mode 30 / 516 in 76.690s
# 	Calibrated DM1 mode 31 / 516 in 79.240s
# 	Calibrated DM1 mode 32 / 516 in 81.789s
# 	Calibrated DM1 mode 33 / 516 in 84.339s
# 	Calibrated DM1 mode 34 / 516 in 86.890s
# 	Calibrated DM1 mode 35 / 516 in 89.445s
# 	Calibrated DM1 mode 36 / 516 in 92.099s
# 	Calibrated DM1 mode 37 / 516 in 94.642s
# 	Calibrated DM1 mode 38 / 516 in 97.192s
# 	Calibrated DM1 mode 39 / 516 in 99.746s
# 	Calibrated DM1 mode 40 / 516 in 102.296s
# 	Calibrated DM1 mode 41 / 516 in 104.843s
# 	Calibrated DM1 mode 42 / 516 in 107.395s
# 	Calibrated DM1 mode 43 / 516 in 109.946s
# 	Calibrated DM1 mode 44 / 516 in 112.488s
# 	Calibrated DM1 mode 45 / 516 in 115.040s
# 	Calibrated DM1 mode 46 / 516 in 117.596s
# 	Calibrated DM1 mode 47 / 516 in 120.146s
# 	Calibrated DM1 mode 48 / 516 in 122.698s
# 	Calibrated DM1 mode 49 / 516 in 125.249s
# 	Calibrated DM1 mode 50 / 516 in 127.798s
# 	Calibrated DM1 mode 51 / 516 in 130.459s
# 	Calibrated DM1 mode 52 / 516 in 132.983s
# 	Calibrated DM1 mode 53 / 516 in 135.533s
# 	Calibrated DM1 mode 54 / 516 in 138.079s
# 	Calibrated DM1 mode 55 / 516 in 140.629s
# 	Calibrated DM1 mode 56 / 516 in 143.226s
# 	Calibrated DM1 mode 57 / 516 in 145.777s
# 	Calibrated DM1 mode 58 / 516 in 148.385s
# 	Calibrated DM1 mode 59 / 516 in 150.929s
# 	Calibrated DM1 mode 60 / 516 in 153.480s
# 	Calibrated DM1 mode 61 / 516 in 156.029s
# 	Calibrated DM1 mode 62 / 516 in 158.580s
# 	Calibrated DM1 mode 63 / 516 in 161.258s
# 	Calibrated DM1 mode 64 / 516 in 163.807s
# 	Calibrated DM1 mode 65 / 516 in 166.357s
# 	Calibrated DM1 mode 66 / 516 in 168.909s
# 	Calibrated DM1 mode 67 / 516 in 171.431s
# 	Calibrated DM1 mode 68 / 516 in 173.981s
# 	Calibrated DM1 mode 69 / 516 in 176.526s
# 	Calibrated DM1 mode 70 / 516 in 179.325s
# 	Calibrated DM1 mode 71 / 516 in 181.874s
# 	Calibrated DM1 mode 72 / 516 in 184.437s
# 	Calibrated DM1 mode 73 / 516 in 186.988s
# 	Calibrated DM1 mode 74 / 516 in 189.531s
# 	Calibrated DM1 mode 75 / 516 in 192.080s
# 	Calibrated DM1 mode 76 / 516 in 194.630s
# 	Calibrated DM1 mode 77 / 516 in 197.297s
# 	Calibrated DM1 mode 78 / 516 in 199.846s
# 	Calibrated DM2 mode 1 / 1024 in 1317.682s
# 	Calibrated DM2 mode 2 / 1024 in 1320.295s
# 	Calibrated DM2 mode 3 / 1024 in 1322.800s
# 	Calibrated DM2 mode 4 / 1024 in 1325.309s
# 	Calibrated DM2 mode 5 / 1024 in 1327.818s
# 	Calibrated DM2 mode 6 / 1024 in 1330.328s
# 	Calibrated DM2 mode 7 / 1024 in 1332.835s
# 	Calibrated DM2 mode 8 / 1024 in 1335.345s
# 	Calibrated DM2 mode 9 / 1024 in 1337.858s
# 	Calibrated DM2 mode 10 / 1024 in 1340.370s
# 	Calibrated DM2 mode 11 / 1024 in 1342.879s
# 	Calibrated DM2 mode 12 / 1024 in 1345.398s
# 	Calibrated DM2 mode 13 / 1024 in 1347.912s
# 	Calibrated DM2 mode 14 / 1024 in 1350.428s
# 	Calibrated DM2 mode 15 / 1024 in 1352.936s
# 	Calibrated DM2 mode 16 / 1024 in 1355.451s
# 	Calibrated DM2 mode 17 / 1024 in 1358.029s
# 	Calibrated DM2 mode 18 / 1024 in 1360.644s
# 	Calibrated DM2 mode 19 / 1024 in 1363.149s
# 	Calibrated DM2 mode 20 / 1024 in 1365.664s
# 	Calibrated DM2 mode 21 / 1024 in 1368.177s
# 	Calibrated DM2 mode 22 / 1024 in 1370.692s
# 	Calibrated DM2 mode 23 / 1024 in 1373.194s
# 	Calibrated DM2 mode 24 / 1024 in 1375.703s
# 	Calibrated DM2 mode 25 / 1024 in 1378.217s
# 	Calibrated DM2 mode 26 / 1024 in 1380.735s
# 	Calibrated DM2 mode 27 / 1024 in 1383.252s
# 	Calibrated DM2 mode 28 / 1024 in 1385.770s
# 	Calibrated DM2 mode 29 / 1024 in 1388.388s
# 	Calibrated DM2 mode 30 / 1024 in 1390.893s
# 	Calibrated DM2 mode 31 / 1024 in 1393.469s
# 	Calibrated DM2 mode 32 / 1024 in 1396.119s
# 	Calibrated DM2 mode 33 / 1024 in 1398.677s
# 	Calibrated DM2 mode 34 / 1024 in 1401.192s
# 	Calibrated DM2 mode 35 / 1024 in 1403.707s
# 	Calibrated DM2 mode 36 / 1024 in 1406.190s
# 	Calibrated DM2 mode 37 / 1024 in 1408.839s
# 	Calibrated DM2 mode 38 / 1024 in 1411.308s
# 	Calibrated DM2 mode 39 / 1024 in 1413.785s
# 	Calibrated DM2 mode 40 / 1024 in 1416.373s
# 	Calibrated DM2 mode 41 / 1024 in 1418.884s
# 	Calibrated DM2 mode 42 / 1024 in 1421.388s
# 	Calibrated DM2 mode 43 / 1024 in 1424.037s
# 	Calibrated DM2 mode 44 / 1024 in 1426.825s
# 	Calibrated DM2 mode 45 / 1024 in 1429.338s
# 	Calibrated DM2 mode 46 / 1024 in 1431.854s
# 	Calibrated DM2 mode 47 / 1024 in 1434.376s
# 	Calibrated DM2 mode 48 / 1024 in 1436.893s
# 	Calibrated DM2 mode 49 / 1024 in 1439.411s
# 	Calibrated DM2 mode 50 / 1024 in 1441.933s
# 	Calibrated DM2 mode 51 / 1024 in 1444.454s
# 	Calibrated DM2 mode 52 / 1024 in 1446.973s
# 	Calibrated DM2 mode 53 / 1024 in 1449.484s
# 	Calibrated DM2 mode 54 / 1024 in 1452.013s
# 	Calibrated DM2 mode 55 / 1024 in 1454.542s
# 	Calibrated DM2 mode 56 / 1024 in 1457.063s
# 	Calibrated DM2 mode 57 / 1024 in 1459.584s
# 	Calibrated DM2 mode 58 / 1024 in 1462.206s
# 	Calibrated DM2 mode 59 / 1024 in 1464.725s
# 	Calibrated DM2 mode 60 / 1024 in 1467.242s
# 	Calibrated DM2 mode 61 / 1024 in 1469.756s
# 	Calibrated DM2 mode 62 / 1024 in 1472.271s
# 	Calibrated DM2 mode 63 / 1024 in 1474.791s
# 	Calibrated DM2 mode 64 / 1024 in 1477.308s
# 	Calibrated DM2 mode 65 / 1024 in 1479.841s
# 	Calibrated DM2 mode 66 / 1024 in 1482.361s
# 	Calibrated DM2 mode 67 / 1024 in 1484.878s
# 	Calibrated DM2 mode 68 / 1024 in 1487.394s
# 	Calibrated DM2 mode 69 / 1024 in 1489.914s
# 	Calibrated DM2 mode 70 / 1024 in 1492.431s
# 	Calibrated DM2 mode 71 / 1024 in 1494.953s
# 	Calibrated DM2 mode 72 / 1024 in 1497.472s
# 	Calibrated DM2 mode 73 / 1024 in 1499.993s
# 	Calibrated DM2 mode 74 / 1024 in 1502.513s
# 	Calibrated DM2 mode 75 / 1024 in 1505.032s
# 	Calibrated DM2 mode 76 / 1024 in 1507.543s
# 	Calibrated DM2 mode 77 / 1024 in 1510.168s
# 	Calibrated DM2 mode 78 / 1024 in 1512.690s
# 	Calibrated DM2 mode 79 / 1024 in 1515.212s
# 	Calibrated DM2 mode 80 / 1024 in 1517.731s
# 	Calibrated DM2 mode 81 / 1024 in 1520.256s
# 	Calibrated DM2 mode 82 / 1024 in 1522.788s
# 	Calibrated DM2 mode 83 / 1024 in 1525.305s
# 	Calibrated DM2 mode 84 / 1024 in 1527.835s
# 	Calibrated DM2 mode 85 / 1024 in 1530.361s
# 	Calibrated DM2 mode 86 / 1024 in 1532.882s
# 	Calibrated DM2 mode 87 / 1024 in 1535.402s
# 	Calibrated DM2 mode 88 / 1024 in 1537.926s
# 	Calibrated DM2 mode 89 / 1024 in 1540.445s
# 	Calibrated DM2 mode 90 / 1024 in 1542.966s
# 	Calibrated DM2 mode 91 / 1024 in 1545.483s
# 	Calibrated DM2 mode 92 / 1024 in 1548.006s
# 	Calibrated DM2 mode 93 / 1024 in 1550.626s
# 	Calibrated DM2 mode 94 / 1024 in 1553.146s
# 	Calibrated DM2 mode 95 / 1024 in 1555.666s
# 	Calibrated DM2 mode 96 / 1024 in 1558.184s
# 	Calibrated DM2 mode 97 / 1024 in 1560.703s
# 	Calibrated DM2 mode 98 / 1024 in 1563.220s
# 	Calibrated DM2 mode 99 / 1024 in 1565.741s
# 	Calibrated DM2 mode 100 / 1024 in 1568.257s
# 	Calibrated DM2 mode 101 / 1024 in 1570.773s
# 	Calibrated DM2 mode 102 / 1024 in 1573.290s
# 	Calibrated DM2 mode 103 / 1024 in 1575.814s
# 	Calibrated DM2 mode 104 / 1024 in 1578.434s
# 	Calibrated DM2 mode 105 / 1024 in 1580.948s
# 	Calibrated DM2 mode 106 / 1024 in 1583.453s
# 	Calibrated DM2 mode 107 / 1024 in 1585.966s
# 	Calibrated DM2 mode 108 / 1024 in 1588.481s
# 	Calibrated DM2 mode 109 / 1024 in 1590.997s
# 	Calibrated DM2 mode 110 / 1024 in 1593.514s
# 	Calibrated DM2 mode 111 / 1024 in 1596.030s
# 	Calibrated DM2 mode 112 / 1024 in 1598.594s
# 	Calibrated DM2 mode 113 / 1024 in 1601.107s
# 	Calibrated DM2 mode 114 / 1024 in 1603.612s
# 	Calibrated DM2 mode 115 / 1024 in 1606.200s
# 	Calibrated DM2 mode 116 / 1024 in 1608.716s
# 	Calibrated DM2 mode 117 / 1024 in 1611.229s
# 	Calibrated DM2 mode 118 / 1024 in 1613.745s
# 	Calibrated DM2 mode 119 / 1024 in 1616.364s
# 	Calibrated DM2 mode 120 / 1024 in 1618.873s
# 	Calibrated DM2 mode 121 / 1024 in 1621.370s
# 	Calibrated DM2 mode 122 / 1024 in 1624.021s
# 	Calibrated DM2 mode 123 / 1024 in 1626.525s
# 	Calibrated DM2 mode 124 / 1024 in 1629.035s
# 	Calibrated DM2 mode 125 / 1024 in 1631.552s
# 	Calibrated DM2 mode 126 / 1024 in 1634.060s
# 	Calibrated DM2 mode 127 / 1024 in 1636.557s
# 	Calibrated DM2 mode 128 / 1024 in 1639.055s
# 	Calibrated DM2 mode 129 / 1024 in 1641.541s
# 	Calibrated DM2 mode 130 / 1024 in 1644.039s
# 	Calibrated DM2 mode 131 / 1024 in 1646.536s
# 	Calibrated DM2 mode 132 / 1024 in 1649.027s
# 	Calibrated DM2 mode 133 / 1024 in 1651.627s
# 	Calibrated DM2 mode 134 / 1024 in 1654.123s
# 	Calibrated DM2 mode 135 / 1024 in 1656.619s
# 	Calibrated DM2 mode 136 / 1024 in 1659.110s
# 	Calibrated DM2 mode 137 / 1024 in 1661.605s
# 	Calibrated DM2 mode 138 / 1024 in 1664.100s
# 	Calibrated DM2 mode 139 / 1024 in 1666.600s
# 	Calibrated DM2 mode 140 / 1024 in 1669.098s
# 	Calibrated DM2 mode 141 / 1024 in 1671.593s
# 	Calibrated DM2 mode 142 / 1024 in 1674.093s
# 	Calibrated DM2 mode 143 / 1024 in 1676.597s
# 	Calibrated DM2 mode 144 / 1024 in 1679.087s
# 	Calibrated DM2 mode 145 / 1024 in 1681.584s
# 	Calibrated DM2 mode 146 / 1024 in 1684.084s
# 	Calibrated DM2 mode 147 / 1024 in 1686.585s
# 	Calibrated DM2 mode 148 / 1024 in 1689.084s
# 	Calibrated DM2 mode 149 / 1024 in 1691.587s
# 	Calibrated DM2 mode 150 / 1024 in 1694.090s
# 	Calibrated DM2 mode 151 / 1024 in 1696.594s
# 	Calibrated DM2 mode 152 / 1024 in 1699.183s
# 	Calibrated DM2 mode 153 / 1024 in 1701.676s
# 	Calibrated DM2 mode 154 / 1024 in 1704.180s
# 	Calibrated DM2 mode 155 / 1024 in 1706.683s
# 	Calibrated DM2 mode 156 / 1024 in 1709.183s
# 	Calibrated DM2 mode 157 / 1024 in 1711.683s
# 	Calibrated DM2 mode 158 / 1024 in 1714.189s
# 	Calibrated DM2 mode 159 / 1024 in 1716.796s
# 	Calibrated DM2 mode 160 / 1024 in 1719.298s
# 	Calibrated DM2 mode 161 / 1024 in 1721.800s
# 	Calibrated DM2 mode 162 / 1024 in 1724.303s
# 	Calibrated DM2 mode 163 / 1024 in 1726.811s
# 	Calibrated DM2 mode 164 / 1024 in 1729.323s
# 	Calibrated DM2 mode 165 / 1024 in 1731.825s
# 	Calibrated DM2 mode 166 / 1024 in 1734.330s
# 	Calibrated DM2 mode 167 / 1024 in 1736.814s
# 	Calibrated DM2 mode 168 / 1024 in 1739.411s
# 	Calibrated DM2 mode 169 / 1024 in 1741.907s
# 	Calibrated DM2 mode 170 / 1024 in 1744.410s
# 	Calibrated DM2 mode 171 / 1024 in 1746.906s
# 	Calibrated DM2 mode 172 / 1024 in 1749.426s
# 	Calibrated DM2 mode 173 / 1024 in 1751.929s
# 	Calibrated DM2 mode 174 / 1024 in 1754.433s
# 	Calibrated DM2 mode 175 / 1024 in 1756.928s
# 	Calibrated DM2 mode 176 / 1024 in 1759.430s
# 	Calibrated DM2 mode 177 / 1024 in 1761.929s
# 	Calibrated DM2 mode 178 / 1024 in 1764.531s
# 	Calibrated DM2 mode 179 / 1024 in 1767.033s
# 	Calibrated DM2 mode 180 / 1024 in 1769.530s
# 	Calibrated DM2 mode 181 / 1024 in 1772.030s
# 	Calibrated DM2 mode 182 / 1024 in 1774.535s
# 	Calibrated DM2 mode 183 / 1024 in 1777.008s
# 	Calibrated DM2 mode 184 / 1024 in 1779.514s
# 	Calibrated DM2 mode 185 / 1024 in 1782.016s
# 	Calibrated DM2 mode 186 / 1024 in 1784.521s
# 	Calibrated DM2 mode 187 / 1024 in 1787.024s
# 	Calibrated DM2 mode 188 / 1024 in 1789.528s
# 	Calibrated DM2 mode 189 / 1024 in 1792.030s
# 	Calibrated DM2 mode 190 / 1024 in 1794.531s
# 	Calibrated DM2 mode 191 / 1024 in 1797.025s
# 	Calibrated DM2 mode 192 / 1024 in 1799.529s
# 	Calibrated DM2 mode 193 / 1024 in 1802.130s
# 	Calibrated DM2 mode 194 / 1024 in 1804.634s
# 	Calibrated DM2 mode 195 / 1024 in 1807.132s
# 	Calibrated DM2 mode 196 / 1024 in 1809.637s
# 	Calibrated DM2 mode 197 / 1024 in 1812.143s
# 	Calibrated DM2 mode 198 / 1024 in 1814.647s
# 	Calibrated DM2 mode 199 / 1024 in 1817.225s
# 	Calibrated DM2 mode 200 / 1024 in 1819.727s
# 	Calibrated DM2 mode 201 / 1024 in 1822.236s
# 	Calibrated DM2 mode 202 / 1024 in 1824.739s
# 	Calibrated DM2 mode 203 / 1024 in 1827.248s
# 	Calibrated DM2 mode 204 / 1024 in 1829.751s
# 	Calibrated DM2 mode 205 / 1024 in 1832.256s
# 	Calibrated DM2 mode 206 / 1024 in 1834.763s
# 	Calibrated DM2 mode 207 / 1024 in 1837.265s
# 	Calibrated DM2 mode 208 / 1024 in 1839.875s
# 	Calibrated DM2 mode 209 / 1024 in 1842.371s
# 	Calibrated DM2 mode 210 / 1024 in 1844.872s
# 	Calibrated DM2 mode 211 / 1024 in 1847.372s
# 	Calibrated DM2 mode 212 / 1024 in 1849.874s
# 	Calibrated DM2 mode 213 / 1024 in 1852.373s
# 	Calibrated DM2 mode 214 / 1024 in 1854.851s
# 	Calibrated DM2 mode 215 / 1024 in 1857.347s
# 	Calibrated DM2 mode 216 / 1024 in 1859.847s
# 	Calibrated DM2 mode 217 / 1024 in 1862.348s
# 	Calibrated DM2 mode 218 / 1024 in 1864.844s
# 	Calibrated DM2 mode 219 / 1024 in 1867.345s
# 	Calibrated DM2 mode 220 / 1024 in 1869.849s
# 	Calibrated DM2 mode 221 / 1024 in 1872.349s
# 	Calibrated DM2 mode 222 / 1024 in 1874.846s
# 	Calibrated DM2 mode 223 / 1024 in 1877.347s
# 	Calibrated DM2 mode 224 / 1024 in 1879.852s
# 	Calibrated DM2 mode 225 / 1024 in 1882.353s
# 	Calibrated DM2 mode 226 / 1024 in 1884.855s
# 	Calibrated DM2 mode 227 / 1024 in 1887.459s
# 	Calibrated DM2 mode 228 / 1024 in 1889.964s
# 	Calibrated DM2 mode 229 / 1024 in 1892.457s
# 	Calibrated DM2 mode 230 / 1024 in 1894.932s
# 	Calibrated DM2 mode 231 / 1024 in 1897.435s
# 	Calibrated DM2 mode 232 / 1024 in 1899.935s
# 	Calibrated DM2 mode 233 / 1024 in 1902.437s
# 	Calibrated DM2 mode 234 / 1024 in 1904.944s
# 	Calibrated DM2 mode 235 / 1024 in 1907.446s
# 	Calibrated DM2 mode 236 / 1024 in 1909.948s
# 	Calibrated DM2 mode 237 / 1024 in 1912.448s
# 	Calibrated DM2 mode 238 / 1024 in 1914.948s
# 	Calibrated DM2 mode 239 / 1024 in 1917.452s
# 	Calibrated DM2 mode 240 / 1024 in 1919.954s
# 	Calibrated DM2 mode 241 / 1024 in 1922.457s
# 	Calibrated DM2 mode 242 / 1024 in 1925.061s
# 	Calibrated DM2 mode 243 / 1024 in 1927.563s
# 	Calibrated DM2 mode 244 / 1024 in 1930.064s
# 	Calibrated DM2 mode 245 / 1024 in 1932.554s
# 	Calibrated DM2 mode 246 / 1024 in 1935.055s
# 	Calibrated DM2 mode 247 / 1024 in 1937.553s
# 	Calibrated DM2 mode 248 / 1024 in 1940.057s
# 	Calibrated DM2 mode 249 / 1024 in 1942.586s
# 	Calibrated DM2 mode 250 / 1024 in 1945.090s
# 	Calibrated DM2 mode 251 / 1024 in 1947.590s
# 	Calibrated DM2 mode 252 / 1024 in 1950.095s
# 	Calibrated DM2 mode 253 / 1024 in 1952.683s
# 	Calibrated DM2 mode 254 / 1024 in 1955.180s
# 	Calibrated DM2 mode 255 / 1024 in 1957.683s
# 	Calibrated DM2 mode 256 / 1024 in 1960.185s
# 	Calibrated DM2 mode 257 / 1024 in 1962.686s
# 	Calibrated DM2 mode 258 / 1024 in 1965.193s
# 	Calibrated DM2 mode 259 / 1024 in 1967.698s
# 	Calibrated DM2 mode 260 / 1024 in 1970.199s
# 	Calibrated DM2 mode 261 / 1024 in 1972.699s
# 	Calibrated DM2 mode 262 / 1024 in 1975.203s
# 	Calibrated DM2 mode 263 / 1024 in 1977.707s
# 	Calibrated DM2 mode 264 / 1024 in 1980.213s
# 	Calibrated DM2 mode 265 / 1024 in 1982.716s
# 	Calibrated DM2 mode 266 / 1024 in 1985.222s
# 	Calibrated DM2 mode 267 / 1024 in 1987.730s
# 	Calibrated DM2 mode 268 / 1024 in 1990.338s
# 	Calibrated DM2 mode 269 / 1024 in 1992.821s
# 	Calibrated DM2 mode 270 / 1024 in 1995.326s
# 	Calibrated DM2 mode 271 / 1024 in 1997.829s
# 	Calibrated DM2 mode 272 / 1024 in 2000.331s
# 	Calibrated DM2 mode 273 / 1024 in 2002.836s
# 	Calibrated DM2 mode 274 / 1024 in 2005.343s
# 	Calibrated DM2 mode 275 / 1024 in 2007.848s
# 	Calibrated DM2 mode 276 / 1024 in 2010.346s
# 	Calibrated DM2 mode 277 / 1024 in 2012.848s
# 	Calibrated DM2 mode 278 / 1024 in 2015.352s
# 	Calibrated DM2 mode 279 / 1024 in 2017.858s
# 	Calibrated DM2 mode 280 / 1024 in 2020.364s
# 	Calibrated DM2 mode 281 / 1024 in 2022.865s
# 	Calibrated DM2 mode 282 / 1024 in 2025.368s
# 	Calibrated DM2 mode 283 / 1024 in 2027.989s
# 	Calibrated DM2 mode 284 / 1024 in 2030.463s
# 	Calibrated DM2 mode 285 / 1024 in 2032.954s
# 	Calibrated DM2 mode 286 / 1024 in 2035.454s
# 	Calibrated DM2 mode 287 / 1024 in 2037.949s
# 	Calibrated DM2 mode 288 / 1024 in 2040.452s
# 	Calibrated DM2 mode 289 / 1024 in 2042.955s
# 	Calibrated DM2 mode 290 / 1024 in 2045.454s
# 	Calibrated DM2 mode 291 / 1024 in 2047.959s
# 	Calibrated DM2 mode 292 / 1024 in 2050.450s
# 	Calibrated DM2 mode 293 / 1024 in 2052.949s
# 	Calibrated DM2 mode 294 / 1024 in 2055.455s
# 	Calibrated DM2 mode 295 / 1024 in 2057.957s
# 	Calibrated DM2 mode 296 / 1024 in 2060.458s
# 	Calibrated DM2 mode 297 / 1024 in 2062.958s
# 	Calibrated DM2 mode 298 / 1024 in 2065.456s
# 	Calibrated DM2 mode 299 / 1024 in 2067.957s
# 	Calibrated DM2 mode 300 / 1024 in 2070.427s
# 	Calibrated DM2 mode 301 / 1024 in 2073.024s
# 	Calibrated DM2 mode 302 / 1024 in 2075.519s
# 	Calibrated DM2 mode 303 / 1024 in 2078.017s
# 	Calibrated DM2 mode 304 / 1024 in 2080.518s
# 	Calibrated DM2 mode 305 / 1024 in 2083.016s
# 	Calibrated DM2 mode 306 / 1024 in 2085.513s
# 	Calibrated DM2 mode 307 / 1024 in 2088.013s
# 	Calibrated DM2 mode 308 / 1024 in 2090.504s
# 	Calibrated DM2 mode 309 / 1024 in 2093.000s
# 	Calibrated DM2 mode 310 / 1024 in 2095.497s
# 	Calibrated DM2 mode 311 / 1024 in 2097.999s
# 	Calibrated DM2 mode 312 / 1024 in 2100.500s
# 	Calibrated DM2 mode 313 / 1024 in 2103.002s
# 	Calibrated DM2 mode 314 / 1024 in 2105.503s
# 	Calibrated DM2 mode 315 / 1024 in 2107.997s
# 	Calibrated DM2 mode 316 / 1024 in 2110.497s
# 	Calibrated DM2 mode 317 / 1024 in 2113.098s
# 	Calibrated DM2 mode 318 / 1024 in 2115.599s
# 	Calibrated DM2 mode 319 / 1024 in 2118.094s
# 	Calibrated DM2 mode 320 / 1024 in 2120.594s
# 	Calibrated DM2 mode 321 / 1024 in 2123.093s
# 	Calibrated DM2 mode 322 / 1024 in 2125.592s
# 	Calibrated DM2 mode 323 / 1024 in 2128.095s
# 	Calibrated DM2 mode 324 / 1024 in 2130.582s
# 	Calibrated DM2 mode 325 / 1024 in 2133.076s
# 	Calibrated DM2 mode 326 / 1024 in 2135.571s
# 	Calibrated DM2 mode 327 / 1024 in 2138.067s
# 	Calibrated DM2 mode 328 / 1024 in 2140.671s
# 	Calibrated DM2 mode 329 / 1024 in 2143.169s
# 	Calibrated DM2 mode 330 / 1024 in 2145.669s
# 	Calibrated DM2 mode 331 / 1024 in 2148.161s
# 	Calibrated DM2 mode 332 / 1024 in 2150.660s
# 	Calibrated DM2 mode 333 / 1024 in 2153.155s
# 	Calibrated DM2 mode 334 / 1024 in 2155.654s
# 	Calibrated DM2 mode 335 / 1024 in 2158.154s
# 	Calibrated DM2 mode 336 / 1024 in 2160.655s
# 	Calibrated DM2 mode 337 / 1024 in 2163.156s
# 	Calibrated DM2 mode 338 / 1024 in 2165.657s
# 	Calibrated DM2 mode 339 / 1024 in 2168.148s
# 	Calibrated DM2 mode 340 / 1024 in 2170.647s
# 	Calibrated DM2 mode 341 / 1024 in 2173.147s
# 	Calibrated DM2 mode 342 / 1024 in 2175.653s
# 	Calibrated DM2 mode 343 / 1024 in 2178.261s
# 	Calibrated DM2 mode 344 / 1024 in 2180.759s
# 	Calibrated DM2 mode 345 / 1024 in 2183.256s
# 	Calibrated DM2 mode 346 / 1024 in 2185.758s
# 	Calibrated DM2 mode 347 / 1024 in 2188.229s
# 	Calibrated DM2 mode 348 / 1024 in 2190.729s
# 	Calibrated DM2 mode 349 / 1024 in 2193.233s
# 	Calibrated DM2 mode 350 / 1024 in 2195.738s
# 	Calibrated DM2 mode 351 / 1024 in 2198.281s
# 	Calibrated DM2 mode 352 / 1024 in 2200.784s
# 	Calibrated DM2 mode 353 / 1024 in 2203.295s
# 	Calibrated DM2 mode 354 / 1024 in 2205.789s
# 	Calibrated DM2 mode 355 / 1024 in 2208.287s
# 	Calibrated DM2 mode 356 / 1024 in 2210.787s
# 	Calibrated DM2 mode 357 / 1024 in 2213.290s
# 	Calibrated DM2 mode 358 / 1024 in 2215.897s
# 	Calibrated DM2 mode 359 / 1024 in 2218.393s
# 	Calibrated DM2 mode 360 / 1024 in 2220.891s
# 	Calibrated DM2 mode 361 / 1024 in 2223.388s
# 	Calibrated DM2 mode 362 / 1024 in 2225.870s
# 	Calibrated DM2 mode 363 / 1024 in 2228.356s
# 	Calibrated DM2 mode 364 / 1024 in 2230.852s
# 	Calibrated DM2 mode 365 / 1024 in 2233.352s
# 	Calibrated DM2 mode 366 / 1024 in 2235.856s
# 	Calibrated DM2 mode 367 / 1024 in 2238.357s
# 	Calibrated DM2 mode 368 / 1024 in 2240.853s
# 	Calibrated DM2 mode 369 / 1024 in 2243.348s
# 	Calibrated DM2 mode 370 / 1024 in 2245.844s
# 	Calibrated DM2 mode 371 / 1024 in 2248.344s
# 	Calibrated DM2 mode 372 / 1024 in 2250.843s
# 	Calibrated DM2 mode 373 / 1024 in 2253.346s
# 	Calibrated DM2 mode 374 / 1024 in 2255.851s
# 	Calibrated DM2 mode 375 / 1024 in 2258.357s
# 	Calibrated DM2 mode 376 / 1024 in 2260.963s
# 	Calibrated DM2 mode 377 / 1024 in 2263.464s
# 	Calibrated DM2 mode 378 / 1024 in 2265.937s
# 	Calibrated DM2 mode 379 / 1024 in 2268.435s
# 	Calibrated DM2 mode 380 / 1024 in 2270.933s
# 	Calibrated DM2 mode 381 / 1024 in 2273.433s
# 	Calibrated DM2 mode 382 / 1024 in 2275.937s
# 	Calibrated DM2 mode 383 / 1024 in 2278.448s
# 	Calibrated DM2 mode 384 / 1024 in 2280.954s
# 	Calibrated DM2 mode 385 / 1024 in 2283.463s
# 	Calibrated DM2 mode 386 / 1024 in 2285.958s
# 	Calibrated DM2 mode 387 / 1024 in 2288.463s
# 	Calibrated DM2 mode 388 / 1024 in 2290.967s
# 	Calibrated DM2 mode 389 / 1024 in 2293.474s
# 	Calibrated DM2 mode 390 / 1024 in 2295.981s
# 	Calibrated DM2 mode 391 / 1024 in 2298.490s
# 	Calibrated DM2 mode 392 / 1024 in 2301.097s
# 	Calibrated DM2 mode 393 / 1024 in 2303.593s
# 	Calibrated DM2 mode 394 / 1024 in 2306.092s
# 	Calibrated DM2 mode 395 / 1024 in 2308.597s
# 	Calibrated DM2 mode 396 / 1024 in 2311.098s
# 	Calibrated DM2 mode 397 / 1024 in 2313.601s
# 	Calibrated DM2 mode 398 / 1024 in 2316.099s
# 	Calibrated DM2 mode 399 / 1024 in 2318.606s
# 	Calibrated DM2 mode 400 / 1024 in 2321.107s
# 	Calibrated DM2 mode 401 / 1024 in 2323.604s
# 	Calibrated DM2 mode 402 / 1024 in 2326.105s
# 	Calibrated DM2 mode 403 / 1024 in 2328.712s
# 	Calibrated DM2 mode 404 / 1024 in 2331.216s
# 	Calibrated DM2 mode 405 / 1024 in 2333.722s
# 	Calibrated DM2 mode 406 / 1024 in 2336.224s
# 	Calibrated DM2 mode 407 / 1024 in 2338.727s
# 	Calibrated DM2 mode 408 / 1024 in 2341.230s
# 	Calibrated DM2 mode 409 / 1024 in 2343.700s
# 	Calibrated DM2 mode 410 / 1024 in 2346.272s
# 	Calibrated DM2 mode 411 / 1024 in 2348.781s
# 	Calibrated DM2 mode 412 / 1024 in 2351.287s
# 	Calibrated DM2 mode 413 / 1024 in 2353.805s
# 	Calibrated DM2 mode 414 / 1024 in 2356.311s
# 	Calibrated DM2 mode 415 / 1024 in 2358.811s
# 	Calibrated DM2 mode 416 / 1024 in 2361.312s
# 	Calibrated DM2 mode 417 / 1024 in 2363.802s
# 	Calibrated DM2 mode 418 / 1024 in 2366.406s
# 	Calibrated DM2 mode 419 / 1024 in 2368.899s
# 	Calibrated DM2 mode 420 / 1024 in 2371.423s
# 	Calibrated DM2 mode 421 / 1024 in 2373.927s
# 	Calibrated DM2 mode 422 / 1024 in 2376.426s
# 	Calibrated DM2 mode 423 / 1024 in 2378.929s
# 	Calibrated DM2 mode 424 / 1024 in 2381.424s
# 	Calibrated DM2 mode 425 / 1024 in 2383.907s
# 	Calibrated DM2 mode 426 / 1024 in 2386.412s
# 	Calibrated DM2 mode 427 / 1024 in 2388.915s
# 	Calibrated DM2 mode 428 / 1024 in 2391.414s
# 	Calibrated DM2 mode 429 / 1024 in 2393.916s
# 	Calibrated DM2 mode 430 / 1024 in 2396.415s
# 	Calibrated DM2 mode 431 / 1024 in 2398.925s
# 	Calibrated DM2 mode 432 / 1024 in 2401.528s
# 	Calibrated DM2 mode 433 / 1024 in 2404.034s
# 	Calibrated DM2 mode 434 / 1024 in 2406.534s
# 	Calibrated DM2 mode 435 / 1024 in 2409.034s
# 	Calibrated DM2 mode 436 / 1024 in 2411.534s
# 	Calibrated DM2 mode 437 / 1024 in 2414.039s
# 	Calibrated DM2 mode 438 / 1024 in 2416.542s
# 	Calibrated DM2 mode 439 / 1024 in 2419.044s
# 	Calibrated DM2 mode 440 / 1024 in 2421.539s
# 	Calibrated DM2 mode 441 / 1024 in 2424.186s
# 	Calibrated DM2 mode 442 / 1024 in 2426.697s
# 	Calibrated DM2 mode 443 / 1024 in 2429.202s
# 	Calibrated DM2 mode 444 / 1024 in 2431.706s
# 	Calibrated DM2 mode 445 / 1024 in 2434.212s
# 	Calibrated DM2 mode 446 / 1024 in 2436.712s
# 	Calibrated DM2 mode 447 / 1024 in 2439.214s
# 	Calibrated DM2 mode 448 / 1024 in 2441.685s
# 	Calibrated DM2 mode 449 / 1024 in 2444.188s
# 	Calibrated DM2 mode 450 / 1024 in 2446.693s
# 	Calibrated DM2 mode 451 / 1024 in 2449.299s
# 	Calibrated DM2 mode 452 / 1024 in 2451.801s
# 	Calibrated DM2 mode 453 / 1024 in 2454.301s
# 	Calibrated DM2 mode 454 / 1024 in 2456.913s
# 	Calibrated DM2 mode 455 / 1024 in 2459.411s
# 	Calibrated DM2 mode 456 / 1024 in 2461.912s
# 	Calibrated DM2 mode 457 / 1024 in 2464.418s
# 	Calibrated DM2 mode 458 / 1024 in 2466.923s
# 	Calibrated DM2 mode 459 / 1024 in 2469.431s
# 	Calibrated DM2 mode 460 / 1024 in 2471.934s
# 	Calibrated DM2 mode 461 / 1024 in 2474.441s
# 	Calibrated DM2 mode 462 / 1024 in 2476.949s
# 	Calibrated DM2 mode 463 / 1024 in 2479.432s
# 	Calibrated DM2 mode 464 / 1024 in 2481.924s
# 	Calibrated DM2 mode 465 / 1024 in 2484.463s
# 	Calibrated DM2 mode 466 / 1024 in 2486.970s
# 	Calibrated DM2 mode 467 / 1024 in 2489.578s
# 	Calibrated DM2 mode 468 / 1024 in 2492.078s
# 	Calibrated DM2 mode 469 / 1024 in 2494.582s
# 	Calibrated DM2 mode 470 / 1024 in 2497.088s
# 	Calibrated DM2 mode 471 / 1024 in 2499.585s
# 	Calibrated DM2 mode 472 / 1024 in 2502.085s
# 	Calibrated DM2 mode 473 / 1024 in 2504.577s
# 	Calibrated DM2 mode 474 / 1024 in 2507.076s
# 	Calibrated DM2 mode 475 / 1024 in 2509.579s
# 	Calibrated DM2 mode 476 / 1024 in 2512.079s
# 	Calibrated DM2 mode 477 / 1024 in 2514.581s
# 	Calibrated DM2 mode 478 / 1024 in 2517.190s
# 	Calibrated DM2 mode 479 / 1024 in 2519.662s
# 	Calibrated DM2 mode 480 / 1024 in 2522.165s
# 	Calibrated DM2 mode 481 / 1024 in 2524.669s
# 	Calibrated DM2 mode 482 / 1024 in 2527.171s
# 	Calibrated DM2 mode 483 / 1024 in 2529.674s
# 	Calibrated DM2 mode 484 / 1024 in 2532.174s
# 	Calibrated DM2 mode 485 / 1024 in 2534.675s
# 	Calibrated DM2 mode 486 / 1024 in 2537.180s
# 	Calibrated DM2 mode 487 / 1024 in 2539.671s
# 	Calibrated DM2 mode 488 / 1024 in 2542.172s
# 	Calibrated DM2 mode 489 / 1024 in 2544.675s
# 	Calibrated DM2 mode 490 / 1024 in 2547.178s
# 	Calibrated DM2 mode 491 / 1024 in 2549.691s
# 	Calibrated DM2 mode 492 / 1024 in 2552.192s
# 	Calibrated DM2 mode 493 / 1024 in 2554.796s
# 	Calibrated DM2 mode 494 / 1024 in 2557.287s
# 	Calibrated DM2 mode 495 / 1024 in 2559.769s
# 	Calibrated DM2 mode 496 / 1024 in 2562.269s
# 	Calibrated DM2 mode 497 / 1024 in 2564.773s
# 	Calibrated DM2 mode 498 / 1024 in 2567.279s
# 	Calibrated DM2 mode 499 / 1024 in 2569.783s
# 	Calibrated DM2 mode 500 / 1024 in 2572.282s
# 	Calibrated DM2 mode 501 / 1024 in 2574.786s
# 	Calibrated DM2 mode 502 / 1024 in 2577.281s
# 	Calibrated DM2 mode 503 / 1024 in 2579.791s
# 	Calibrated DM2 mode 504 / 1024 in 2582.294s
# 	Calibrated DM2 mode 505 / 1024 in 2584.796s
# 	Calibrated DM2 mode 506 / 1024 in 2587.298s
# 	Calibrated DM2 mode 507 / 1024 in 2589.908s
# 	Calibrated DM2 mode 508 / 1024 in 2592.407s
# 	Calibrated DM2 mode 509 / 1024 in 2594.906s
# 	Calibrated DM2 mode 510 / 1024 in 2597.380s
# 	Calibrated DM2 mode 511 / 1024 in 2599.887s
# 	Calibrated DM2 mode 512 / 1024 in 2602.390s
# 	Calibrated DM2 mode 513 / 1024 in 2604.891s
# 	Calibrated DM2 mode 514 / 1024 in 2607.393s
# 	Calibrated DM2 mode 515 / 1024 in 2609.897s
# 	Calibrated DM2 mode 516 / 1024 in 2612.401s
# 	Calibrated DM2 mode 517 / 1024 in 2614.905s
# 	Calibrated DM2 mode 518 / 1024 in 2617.406s
# 	Calibrated DM2 mode 519 / 1024 in 2619.910s
# 	Calibrated DM2 mode 520 / 1024 in 2622.411s
# 	Calibrated DM2 mode 521 / 1024 in 2624.913s
# 	Calibrated DM2 mode 522 / 1024 in 2627.414s
# 	Calibrated DM2 mode 523 / 1024 in 2629.921s
# 	Calibrated DM2 mode 524 / 1024 in 2632.422s
# 	Calibrated DM2 mode 525 / 1024 in 2634.912s
# 	Calibrated DM2 mode 526 / 1024 in 2637.507s
# 	Calibrated DM2 mode 527 / 1024 in 2640.006s
# 	Calibrated DM2 mode 528 / 1024 in 2642.504s
# 	Calibrated DM2 mode 529 / 1024 in 2645.005s
# 	Calibrated DM2 mode 530 / 1024 in 2647.506s
# 	Calibrated DM2 mode 531 / 1024 in 2650.007s
# 	Calibrated DM2 mode 532 / 1024 in 2652.509s
# 	Calibrated DM2 mode 533 / 1024 in 2654.995s
# 	Calibrated DM2 mode 534 / 1024 in 2657.492s
# 	Calibrated DM2 mode 535 / 1024 in 2660.000s
# 	Calibrated DM2 mode 536 / 1024 in 2662.494s
# 	Calibrated DM2 mode 537 / 1024 in 2664.997s
# 	Calibrated DM2 mode 538 / 1024 in 2667.498s
# 	Calibrated DM2 mode 539 / 1024 in 2670.000s
# 	Calibrated DM2 mode 540 / 1024 in 2672.502s
# 	Calibrated DM2 mode 541 / 1024 in 2675.100s
# 	Calibrated DM2 mode 542 / 1024 in 2677.583s
# 	Calibrated DM2 mode 543 / 1024 in 2680.076s
# 	Calibrated DM2 mode 544 / 1024 in 2682.567s
# 	Calibrated DM2 mode 545 / 1024 in 2685.065s
# 	Calibrated DM2 mode 546 / 1024 in 2687.561s
# 	Calibrated DM2 mode 547 / 1024 in 2690.062s
# 	Calibrated DM2 mode 548 / 1024 in 2692.597s
# 	Calibrated DM2 mode 549 / 1024 in 2695.067s
# 	Calibrated DM2 mode 550 / 1024 in 2697.547s
# 	Calibrated DM2 mode 551 / 1024 in 2700.051s
# 	Calibrated DM2 mode 552 / 1024 in 2702.662s
# 	Calibrated DM2 mode 553 / 1024 in 2705.166s
# 	Calibrated DM2 mode 554 / 1024 in 2707.677s
# 	Calibrated DM2 mode 555 / 1024 in 2710.178s
# 	Calibrated DM2 mode 556 / 1024 in 2712.669s
# 	Calibrated DM2 mode 557 / 1024 in 2715.161s
# 	Calibrated DM2 mode 558 / 1024 in 2717.664s
# 	Calibrated DM2 mode 559 / 1024 in 2720.165s
# 	Calibrated DM2 mode 560 / 1024 in 2722.666s
# 	Calibrated DM2 mode 561 / 1024 in 2725.166s
# 	Calibrated DM2 mode 562 / 1024 in 2727.668s
# 	Calibrated DM2 mode 563 / 1024 in 2730.169s
# 	Calibrated DM2 mode 564 / 1024 in 2732.671s
# 	Calibrated DM2 mode 565 / 1024 in 2735.147s
# 	Calibrated DM2 mode 566 / 1024 in 2737.653s
# 	Calibrated DM2 mode 567 / 1024 in 2740.256s
# 	Calibrated DM2 mode 568 / 1024 in 2742.760s
# 	Calibrated DM2 mode 569 / 1024 in 2745.264s
# 	Calibrated DM2 mode 570 / 1024 in 2747.759s
# 	Calibrated DM2 mode 571 / 1024 in 2750.261s
# 	Calibrated DM2 mode 572 / 1024 in 2752.754s
# 	Calibrated DM2 mode 573 / 1024 in 2755.268s
# 	Calibrated DM2 mode 574 / 1024 in 2757.765s
# 	Calibrated DM2 mode 575 / 1024 in 2760.273s
# 	Calibrated DM2 mode 576 / 1024 in 2762.773s
# ...
# 	Calibrated DM2 mode 671 / 1024 in 2999.514s
# 	Calibrated DM2 mode 672 / 1024 in 3001.989s
# 	Calibrated DM2 mode 673 / 1024 in 3004.469s
# 	Calibrated DM2 mode 674 / 1024 in 3006.945s
# 	Calibrated DM2 mode 675 / 1024 in 3009.502s
# 	Calibrated DM2 mode 676 / 1024 in 3011.986s
# 	Calibrated DM2 mode 677 / 1024 in 3014.458s
# 	Calibrated DM2 mode 678 / 1024 in 3016.940s
# 	Calibrated DM2 mode 679 / 1024 in 3019.422s
# 	Calibrated DM2 mode 680 / 1024 in 3021.903s
# 	Calibrated DM2 mode 681 / 1024 in 3024.386s
# 	Calibrated DM2 mode 682 / 1024 in 3026.869s
# 	Calibrated DM2 mode 683 / 1024 in 3029.333s
# 	Calibrated DM2 mode 684 / 1024 in 3031.821s
# 	Calibrated DM2 mode 685 / 1024 in 3034.312s
# 	Calibrated DM2 mode 686 / 1024 in 3036.804s
# 	Calibrated DM2 mode 687 / 1024 in 3039.306s
# 	Calibrated DM2 mode 688 / 1024 in 3041.798s
# 	Calibrated DM2 mode 689 / 1024 in 3044.286s
# 	Calibrated DM2 mode 690 / 1024 in 3046.771s
# 	Calibrated DM2 mode 691 / 1024 in 3049.354s
# 	Calibrated DM2 mode 692 / 1024 in 3051.837s
# 	Calibrated DM2 mode 693 / 1024 in 3054.330s
# 	Calibrated DM2 mode 694 / 1024 in 3056.825s
# 	Calibrated DM2 mode 695 / 1024 in 3059.314s
# 	Calibrated DM2 mode 696 / 1024 in 3061.805s
# 	Calibrated DM2 mode 697 / 1024 in 3064.296s
# 	Calibrated DM2 mode 698 / 1024 in 3066.782s
# 	Calibrated DM2 mode 699 / 1024 in 3069.250s
# 	Calibrated DM2 mode 700 / 1024 in 3071.734s
# 	Calibrated DM2 mode 701 / 1024 in 3074.190s
# 	Calibrated DM2 mode 702 / 1024 in 3076.762s
# 	Calibrated DM2 mode 703 / 1024 in 3079.221s
# 	Calibrated DM2 mode 704 / 1024 in 3081.686s
# 	Calibrated DM2 mode 705 / 1024 in 3084.172s
# 	Calibrated DM2 mode 706 / 1024 in 3086.664s
# 	Calibrated DM2 mode 707 / 1024 in 3089.146s
# 	Calibrated DM2 mode 708 / 1024 in 3091.644s
# 	Calibrated DM2 mode 709 / 1024 in 3094.140s
# 	Calibrated DM2 mode 710 / 1024 in 3096.639s
# 	Calibrated DM2 mode 711 / 1024 in 3099.141s
# 	Calibrated DM2 mode 712 / 1024 in 3101.642s
# 	Calibrated DM2 mode 713 / 1024 in 3104.144s
# 	Calibrated DM2 mode 714 / 1024 in 3106.637s
# 	Calibrated DM2 mode 715 / 1024 in 3109.118s
# 	Calibrated DM2 mode 716 / 1024 in 3111.617s
# 	Calibrated DM2 mode 717 / 1024 in 3114.225s
# 	Calibrated DM2 mode 718 / 1024 in 3116.725s
# 	Calibrated DM2 mode 719 / 1024 in 3119.224s
# 	Calibrated DM2 mode 720 / 1024 in 3121.733s
# 	Calibrated DM2 mode 721 / 1024 in 3124.233s
# 	Calibrated DM2 mode 722 / 1024 in 3126.729s
# 	Calibrated DM2 mode 723 / 1024 in 3129.228s
# 	Calibrated DM2 mode 724 / 1024 in 3131.733s
# 	Calibrated DM2 mode 725 / 1024 in 3134.231s
# 	Calibrated DM2 mode 726 / 1024 in 3136.734s
# 	Calibrated DM2 mode 727 / 1024 in 3139.237s
# 	Calibrated DM2 mode 728 / 1024 in 3141.733s
# 	Calibrated DM2 mode 729 / 1024 in 3144.232s
# 	Calibrated DM2 mode 730 / 1024 in 3146.713s
# 	Calibrated DM2 mode 731 / 1024 in 3149.303s
# 	Calibrated DM2 mode 732 / 1024 in 3151.799s
# 	Calibrated DM2 mode 733 / 1024 in 3154.303s
# 	Calibrated DM2 mode 734 / 1024 in 3156.804s
# 	Calibrated DM2 mode 735 / 1024 in 3159.309s
# 	Calibrated DM2 mode 736 / 1024 in 3161.803s
# 	Calibrated DM2 mode 737 / 1024 in 3164.300s
# 	Calibrated DM2 mode 738 / 1024 in 3166.792s
# 	Calibrated DM2 mode 739 / 1024 in 3169.293s
# 	Calibrated DM2 mode 740 / 1024 in 3171.791s
# 	Calibrated DM2 mode 741 / 1024 in 3174.290s
# 	Calibrated DM2 mode 742 / 1024 in 3176.791s
# 	Calibrated DM2 mode 743 / 1024 in 3179.292s
# 	Calibrated DM2 mode 744 / 1024 in 3181.789s
# 	Calibrated DM2 mode 745 / 1024 in 3184.291s
# 	Calibrated DM2 mode 746 / 1024 in 3186.767s
# 	Calibrated DM2 mode 747 / 1024 in 3189.262s
# 	Calibrated DM2 mode 748 / 1024 in 3191.762s
# 	Calibrated DM2 mode 749 / 1024 in 3194.266s
# 	Calibrated DM2 mode 750 / 1024 in 3196.866s
# 	Calibrated DM2 mode 751 / 1024 in 3199.366s
# 	Calibrated DM2 mode 752 / 1024 in 3201.868s
# 	Calibrated DM2 mode 753 / 1024 in 3204.370s
# 	Calibrated DM2 mode 754 / 1024 in 3206.858s
# 	Calibrated DM2 mode 755 / 1024 in 3209.357s
# 	Calibrated DM2 mode 756 / 1024 in 3211.851s
# 	Calibrated DM2 mode 757 / 1024 in 3214.350s
# 	Calibrated DM2 mode 758 / 1024 in 3216.848s
# 	Calibrated DM2 mode 759 / 1024 in 3219.349s
# 	Calibrated DM2 mode 760 / 1024 in 3221.845s
# 	Calibrated DM2 mode 761 / 1024 in 3224.345s
# 	Calibrated DM2 mode 762 / 1024 in 3226.823s
# 	Calibrated DM2 mode 763 / 1024 in 3229.322s
# 	Calibrated DM2 mode 764 / 1024 in 3231.822s
# 	Calibrated DM2 mode 765 / 1024 in 3234.536s
# 	Calibrated DM2 mode 766 / 1024 in 3237.137s
# 	Calibrated DM2 mode 767 / 1024 in 3239.635s
# 	Calibrated DM2 mode 768 / 1024 in 3242.132s
# 	Calibrated DM2 mode 769 / 1024 in 3244.626s
# 	Calibrated DM2 mode 770 / 1024 in 3247.119s
# 	Calibrated DM2 mode 771 / 1024 in 3249.611s
# 	Calibrated DM2 mode 772 / 1024 in 3252.240s
# 	Calibrated DM2 mode 773 / 1024 in 3254.760s
# 	Calibrated DM2 mode 774 / 1024 in 3257.260s
# 	Calibrated DM2 mode 775 / 1024 in 3259.760s
# 	Calibrated DM2 mode 776 / 1024 in 3262.362s
# 	Calibrated DM2 mode 777 / 1024 in 3264.844s
# 	Calibrated DM2 mode 778 / 1024 in 3267.332s
# 	Calibrated DM2 mode 779 / 1024 in 3269.834s
# 	Calibrated DM2 mode 780 / 1024 in 3272.330s
# 	Calibrated DM2 mode 781 / 1024 in 3274.831s
# 	Calibrated DM2 mode 782 / 1024 in 3277.330s
# 	Calibrated DM2 mode 783 / 1024 in 3279.841s
# 	Calibrated DM2 mode 784 / 1024 in 3282.337s
# 	Calibrated DM2 mode 785 / 1024 in 3284.832s
# 	Calibrated DM2 mode 786 / 1024 in 3287.331s
# 	Calibrated DM2 mode 787 / 1024 in 3289.835s
# 	Calibrated DM2 mode 788 / 1024 in 3292.335s
# 	Calibrated DM2 mode 789 / 1024 in 3294.844s
# 	Calibrated DM2 mode 790 / 1024 in 3297.398s
# 	Calibrated DM2 mode 791 / 1024 in 3299.998s
# 	Calibrated DM2 mode 792 / 1024 in 3302.498s
# 	Calibrated DM2 mode 793 / 1024 in 3304.979s
# 	Calibrated DM2 mode 794 / 1024 in 3307.477s
# 	Calibrated DM2 mode 795 / 1024 in 3309.979s
# 	Calibrated DM2 mode 796 / 1024 in 3312.489s
# 	Calibrated DM2 mode 797 / 1024 in 3314.991s
# 	Calibrated DM2 mode 798 / 1024 in 3317.507s
# 	Calibrated DM2 mode 799 / 1024 in 3320.005s
# 	Calibrated DM2 mode 800 / 1024 in 3322.507s
# 	Calibrated DM2 mode 801 / 1024 in 3325.001s
# 	Calibrated DM2 mode 802 / 1024 in 3327.501s
# 	Calibrated DM2 mode 803 / 1024 in 3329.999s
# 	Calibrated DM2 mode 804 / 1024 in 3332.495s
# 	Calibrated DM2 mode 805 / 1024 in 3334.994s
# 	Calibrated DM2 mode 806 / 1024 in 3337.604s
# 	Calibrated DM2 mode 807 / 1024 in 3340.111s
# 	Calibrated DM2 mode 808 / 1024 in 3342.601s
# 	Calibrated DM2 mode 809 / 1024 in 3345.079s
# 	Calibrated DM2 mode 810 / 1024 in 3347.577s
# 	Calibrated DM2 mode 811 / 1024 in 3350.077s
# 	Calibrated DM2 mode 812 / 1024 in 3352.571s
# 	Calibrated DM2 mode 813 / 1024 in 3355.072s
# 	Calibrated DM2 mode 814 / 1024 in 3357.570s
# 	Calibrated DM2 mode 815 / 1024 in 3360.070s
# 	Calibrated DM2 mode 816 / 1024 in 3362.565s
# 	Calibrated DM2 mode 817 / 1024 in 3365.063s
# 	Calibrated DM2 mode 818 / 1024 in 3367.564s
# 	Calibrated DM2 mode 819 / 1024 in 3370.071s
# 	Calibrated DM2 mode 820 / 1024 in 3372.573s
# 	Calibrated DM2 mode 821 / 1024 in 3375.075s
# 	Calibrated DM2 mode 822 / 1024 in 3377.572s
# 	Calibrated DM2 mode 823 / 1024 in 3380.079s
# 	Calibrated DM2 mode 824 / 1024 in 3382.576s
# 	Calibrated DM2 mode 825 / 1024 in 3385.168s
# 	Calibrated DM2 mode 826 / 1024 in 3387.663s
# 	Calibrated DM2 mode 827 / 1024 in 3390.165s
# 	Calibrated DM2 mode 828 / 1024 in 3392.665s
# 	Calibrated DM2 mode 829 / 1024 in 3395.163s
# 	Calibrated DM2 mode 830 / 1024 in 3397.676s
# 	Calibrated DM2 mode 831 / 1024 in 3400.178s
# 	Calibrated DM2 mode 832 / 1024 in 3402.686s
# 	Calibrated DM2 mode 833 / 1024 in 3405.188s
# 	Calibrated DM2 mode 834 / 1024 in 3407.689s
# 	Calibrated DM2 mode 835 / 1024 in 3410.191s
# 	Calibrated DM2 mode 836 / 1024 in 3412.692s
# 	Calibrated DM2 mode 837 / 1024 in 3415.188s
# 	Calibrated DM2 mode 838 / 1024 in 3417.694s
# 	Calibrated DM2 mode 839 / 1024 in 3420.195s
# 	Calibrated DM2 mode 840 / 1024 in 3422.768s
# 	Calibrated DM2 mode 841 / 1024 in 3425.269s
# 	Calibrated DM2 mode 842 / 1024 in 3427.770s
# 	Calibrated DM2 mode 843 / 1024 in 3430.273s
# 	Calibrated DM2 mode 844 / 1024 in 3432.772s
# 	Calibrated DM2 mode 845 / 1024 in 3435.278s
# 	Calibrated DM2 mode 846 / 1024 in 3437.776s
# 	Calibrated DM2 mode 847 / 1024 in 3440.275s
# 	Calibrated DM2 mode 848 / 1024 in 3442.770s
# 	Calibrated DM2 mode 849 / 1024 in 3445.265s
# 	Calibrated DM2 mode 850 / 1024 in 3447.778s
# 	Calibrated DM2 mode 851 / 1024 in 3450.374s
# 	Calibrated DM2 mode 852 / 1024 in 3452.872s
# 	Calibrated DM2 mode 853 / 1024 in 3455.368s
# 	Calibrated DM2 mode 854 / 1024 in 3457.873s
# 	Calibrated DM2 mode 855 / 1024 in 3460.360s
# 	Calibrated DM2 mode 856 / 1024 in 3462.842s
# 	Calibrated DM2 mode 857 / 1024 in 3465.349s
# 	Calibrated DM2 mode 858 / 1024 in 3467.847s
# 	Calibrated DM2 mode 859 / 1024 in 3470.345s
# 	Calibrated DM2 mode 860 / 1024 in 3473.056s
# 	Calibrated DM2 mode 861 / 1024 in 3475.559s
# 	Calibrated DM2 mode 862 / 1024 in 3478.064s
# 	Calibrated DM2 mode 863 / 1024 in 3480.561s
# 	Calibrated DM2 mode 864 / 1024 in 3483.062s
# 	Calibrated DM2 mode 865 / 1024 in 3485.562s
# 	Calibrated DM2 mode 866 / 1024 in 3488.164s
# 	Calibrated DM2 mode 867 / 1024 in 3490.657s
# 	Calibrated DM2 mode 868 / 1024 in 3493.158s
# 	Calibrated DM2 mode 869 / 1024 in 3495.660s
# 	Calibrated DM2 mode 870 / 1024 in 3498.159s
# 	Calibrated DM2 mode 871 / 1024 in 3500.650s
# 	Calibrated DM2 mode 872 / 1024 in 3503.145s
# 	Calibrated DM2 mode 873 / 1024 in 3505.600s
# 	Calibrated DM2 mode 874 / 1024 in 3508.045s
# 	Calibrated DM2 mode 875 / 1024 in 3510.493s
# 	Calibrated DM2 mode 876 / 1024 in 3512.943s
# 	Calibrated DM2 mode 877 / 1024 in 3515.397s
# 	Calibrated DM2 mode 878 / 1024 in 3517.855s
# 	Calibrated DM2 mode 879 / 1024 in 3520.287s
# 	Calibrated DM2 mode 880 / 1024 in 3522.744s
# 	Calibrated DM2 mode 881 / 1024 in 3525.305s
# 	Calibrated DM2 mode 882 / 1024 in 3527.770s
# 	Calibrated DM2 mode 883 / 1024 in 3530.233s
# 	Calibrated DM2 mode 884 / 1024 in 3532.698s
# 	Calibrated DM2 mode 885 / 1024 in 3535.320s
# 	Calibrated DM2 mode 886 / 1024 in 3537.800s
# 	Calibrated DM2 mode 887 / 1024 in 3540.270s
# 	Calibrated DM2 mode 888 / 1024 in 3542.744s
# 	Calibrated DM2 mode 889 / 1024 in 3545.417s
# 	Calibrated DM2 mode 890 / 1024 in 3547.902s
# 	Calibrated DM2 mode 891 / 1024 in 3550.387s
# 	Calibrated DM2 mode 892 / 1024 in 3552.869s
# 	Calibrated DM2 mode 893 / 1024 in 3555.353s
# 	Calibrated DM2 mode 894 / 1024 in 3557.835s
# 	Calibrated DM2 mode 895 / 1024 in 3560.305s
# 	Calibrated DM2 mode 896 / 1024 in 3562.790s
# 	Calibrated DM2 mode 897 / 1024 in 3565.279s
# 	Calibrated DM2 mode 898 / 1024 in 3567.764s
# 	Calibrated DM2 mode 899 / 1024 in 3570.348s
# 	Calibrated DM2 mode 900 / 1024 in 3572.838s
# 	Calibrated DM2 mode 901 / 1024 in 3575.324s
# 	Calibrated DM2 mode 902 / 1024 in 3577.793s
# 	Calibrated DM2 mode 903 / 1024 in 3580.247s
# 	Calibrated DM2 mode 904 / 1024 in 3582.703s
# 	Calibrated DM2 mode 905 / 1024 in 3585.165s
# 	Calibrated DM2 mode 906 / 1024 in 3587.624s
# 	Calibrated DM2 mode 907 / 1024 in 3590.115s
# 	Calibrated DM2 mode 908 / 1024 in 3592.579s
# 	Calibrated DM2 mode 909 / 1024 in 3595.048s
# 	Calibrated DM2 mode 910 / 1024 in 3597.510s
# 	Calibrated DM2 mode 911 / 1024 in 3599.974s
# 	Calibrated DM2 mode 912 / 1024 in 3602.452s
# 	Calibrated DM2 mode 913 / 1024 in 3604.936s
# 	Calibrated DM2 mode 914 / 1024 in 3607.429s
# 	Calibrated DM2 mode 915 / 1024 in 3610.021s
# 	Calibrated DM2 mode 916 / 1024 in 3612.503s
# 	Calibrated DM2 mode 917 / 1024 in 3614.990s
# 	Calibrated DM2 mode 918 / 1024 in 3617.467s
# 	Calibrated DM2 mode 919 / 1024 in 3619.954s
# 	Calibrated DM2 mode 920 / 1024 in 3622.436s
# 	Calibrated DM2 mode 921 / 1024 in 3624.923s
# 	Calibrated DM2 mode 922 / 1024 in 3627.410s
# 	Calibrated DM2 mode 923 / 1024 in 3629.901s
# 	Calibrated DM2 mode 924 / 1024 in 3632.390s
# 	Calibrated DM2 mode 925 / 1024 in 3634.880s
# 	Calibrated DM2 mode 926 / 1024 in 3637.454s
# 	Calibrated DM2 mode 927 / 1024 in 3639.941s
# 	Calibrated DM2 mode 928 / 1024 in 3642.428s
# 	Calibrated DM2 mode 929 / 1024 in 3644.921s
# 	Calibrated DM2 mode 930 / 1024 in 3647.411s
# 	Calibrated DM2 mode 931 / 1024 in 3649.901s
# 	Calibrated DM2 mode 932 / 1024 in 3652.388s
# 	Calibrated DM2 mode 933 / 1024 in 3654.878s
# 	Calibrated DM2 mode 934 / 1024 in 3657.361s
# 	Calibrated DM2 mode 935 / 1024 in 3659.850s
# 	Calibrated DM2 mode 936 / 1024 in 3662.340s
# 	Calibrated DM2 mode 937 / 1024 in 3664.887s
# 	Calibrated DM2 mode 938 / 1024 in 3667.392s
# 	Calibrated DM2 mode 939 / 1024 in 3670.022s
# 	Calibrated DM2 mode 940 / 1024 in 3672.522s
# 	Calibrated DM2 mode 941 / 1024 in 3675.214s
# 	Calibrated DM2 mode 942 / 1024 in 3677.687s
# 	Calibrated DM2 mode 943 / 1024 in 3680.187s
# 	Calibrated DM2 mode 944 / 1024 in 3682.750s
# 	Calibrated DM2 mode 945 / 1024 in 3685.246s
# 	Calibrated DM2 mode 946 / 1024 in 3687.741s
# 	Calibrated DM2 mode 947 / 1024 in 3690.244s
# 	Calibrated DM2 mode 948 / 1024 in 3692.751s
# 	Calibrated DM2 mode 949 / 1024 in 3695.254s
# 	Calibrated DM2 mode 950 / 1024 in 3697.758s
# 	Calibrated DM2 mode 951 / 1024 in 3700.278s
# 	Calibrated DM2 mode 952 / 1024 in 3702.786s
# 	Calibrated DM2 mode 953 / 1024 in 3705.290s
# 	Calibrated DM2 mode 954 / 1024 in 3707.793s
# 	Calibrated DM2 mode 955 / 1024 in 3710.400s
# 	Calibrated DM2 mode 956 / 1024 in 3712.902s
# 	Calibrated DM2 mode 957 / 1024 in 3715.400s
# 	Calibrated DM2 mode 958 / 1024 in 3717.891s
# 	Calibrated DM2 mode 959 / 1024 in 3720.415s
# 	Calibrated DM2 mode 960 / 1024 in 3723.048s
# 	Calibrated DM2 mode 961 / 1024 in 3725.553s
# 	Calibrated DM2 mode 962 / 1024 in 3728.052s
# 	Calibrated DM2 mode 963 / 1024 in 3730.585s
# 	Calibrated DM2 mode 964 / 1024 in 3733.109s
# 	Calibrated DM2 mode 965 / 1024 in 3735.602s
# 	Calibrated DM2 mode 966 / 1024 in 3738.099s
# 	Calibrated DM2 mode 967 / 1024 in 3740.602s
# 	Calibrated DM2 mode 968 / 1024 in 3743.113s
# 	Calibrated DM2 mode 969 / 1024 in 3745.615s
# 	Calibrated DM2 mode 970 / 1024 in 3748.130s
# 	Calibrated DM2 mode 971 / 1024 in 3750.630s
# 	Calibrated DM2 mode 972 / 1024 in 3753.154s
# 	Calibrated DM2 mode 973 / 1024 in 3755.650s
# 	Calibrated DM2 mode 974 / 1024 in 3758.279s
# 	Calibrated DM2 mode 975 / 1024 in 3760.782s
# 	Calibrated DM2 mode 976 / 1024 in 3763.283s
# 	Calibrated DM2 mode 977 / 1024 in 3765.791s
# 	Calibrated DM2 mode 978 / 1024 in 3768.293s
# 	Calibrated DM2 mode 979 / 1024 in 3770.799s
# 	Calibrated DM2 mode 980 / 1024 in 3773.305s
# 	Calibrated DM2 mode 981 / 1024 in 3775.785s
# 	Calibrated DM2 mode 982 / 1024 in 3778.290s
# 	Calibrated DM2 mode 983 / 1024 in 3780.795s
# 	Calibrated DM2 mode 984 / 1024 in 3783.299s
# 	Calibrated DM2 mode 985 / 1024 in 3785.798s
# 	Calibrated DM2 mode 986 / 1024 in 3788.301s
# 	Calibrated DM2 mode 987 / 1024 in 3791.104s
# 	Calibrated DM2 mode 988 / 1024 in 3793.597s
# 	Calibrated DM2 mode 989 / 1024 in 3796.091s
# 	Calibrated DM2 mode 990 / 1024 in 3798.683s
# 	Calibrated DM2 mode 991 / 1024 in 3801.185s
# 	Calibrated DM2 mode 992 / 1024 in 3803.678s
# 	Calibrated DM2 mode 993 / 1024 in 3806.167s
# 	Calibrated DM2 mode 994 / 1024 in 3808.662s
# 	Calibrated DM2 mode 995 / 1024 in 3811.155s
# 	Calibrated DM2 mode 996 / 1024 in 3813.627s
# 	Calibrated DM2 mode 997 / 1024 in 3816.121s
# 	Calibrated DM2 mode 998 / 1024 in 3818.612s
# 	Calibrated DM2 mode 999 / 1024 in 3821.106s
# 	Calibrated DM2 mode 1000 / 1024 in 3823.600s
# 	Calibrated DM2 mode 1001 / 1024 in 3826.189s
# 	Calibrated DM2 mode 1002 / 1024 in 3828.680s
# 	Calibrated DM2 mode 1003 / 1024 in 3831.172s
# 	Calibrated DM2 mode 1004 / 1024 in 3833.665s
# 	Calibrated DM2 mode 1005 / 1024 in 3836.158s
# 	Calibrated DM2 mode 1006 / 1024 in 3838.654s
# 	Calibrated DM2 mode 1007 / 1024 in 3841.151s
# 	Calibrated DM2 mode 1008 / 1024 in 3843.660s
# 	Calibrated DM2 mode 1009 / 1024 in 3846.154s
# 	Calibrated DM2 mode 1010 / 1024 in 3848.648s
# 	Calibrated DM2 mode 1011 / 1024 in 3851.141s
# 	Calibrated DM2 mode 1012 / 1024 in 3853.633s
# 	Calibrated DM2 mode 1013 / 1024 in 3856.126s
# 	Calibrated DM2 mode 1014 / 1024 in 3858.780s
# 	Calibrated DM2 mode 1015 / 1024 in 3861.376s
# 	Calibrated DM2 mode 1016 / 1024 in 3863.868s
# 	Calibrated DM2 mode 1017 / 1024 in 3866.360s
# 	Calibrated DM2 mode 1018 / 1024 in 3868.842s
# 	Calibrated DM2 mode 1019 / 1024 in 3871.331s
# 	Calibrated DM2 mode 1020 / 1024 in 3873.801s
# 	Calibrated DM2 mode 1021 / 1024 in 3876.296s
# 	Calibrated DM2 mode 1022 / 1024 in 3878.791s
# 	Calibrated DM2 mode 1023 / 1024 in 3881.282s
# 	Calibrated DM2 mode 1024 / 1024 in 3883.811s
# Calibration complete.

# %%
fname = 'spc-wide_2dm_annular_f_h.pkl'
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
# iefc_dir = Path('C:/Users/Kian/Documents/data-files/roman-cgi-iefc-data')

# %%
misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_2dm_annular_ff_3-9.pkl
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_2dm_annular_ff_3-9.pkl

# %%
response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(npsf,npsf))

# %% [markdown]
# # Create control matrix

# %%
response_cube.shape, nf, nh
# Out:
# ((1540, 2, 4096), 516, 1024)

# %%
weight_mask = weight_map.flatten()>0
response_cube[:, :, weight_mask].shape
# Out:
# (1540, 2, 1436)

# %%
def construct_control_matrix(response_matrix, 
                             weight_map, 
                             nc1, nc2, 
                             nprobes=2, 
                             rcond1=1e-2, 
                             rcond2=1e-2, 
                             WLS=True, 
                             pca_modes=None):
    weight_mask = weight_map>0
    
    masked_matrix = response_matrix[:, :, weight_mask].reshape((response_matrix.shape[0], -1)).T
    print(masked_matrix.shape)
    
    nmodes = int(response_matrix.shape[0]/2)
    if WLS:
        print('Using Weighted Least Squares ')
        if nprobes==2:
            Wmatrix = np.diag(np.concatenate((weight_map[weight_mask], weight_map[weight_mask])))
        elif nprobes==3:
            Wmatrix = np.diag(np.concatenate((weight_map[weight_mask], weight_map[weight_mask], weight_map[weight_mask])))
        control_matrix_1 = utils.WeightedLeastSquares(masked_matrix[:,:nc1], Wmatrix, rcond=rcond1)
        control_matrix_2 = utils.WeightedLeastSquares(masked_matrix[:,nc1:], Wmatrix, rcond=rcond2)
    else: 
        print('Using Tikhonov Inverse')
        control_matrix_1 = utils.TikhonovInverse(masked_matrix[:,:nc1], rcond=rcond1)
        control_matrix_2 = utils.TikhonovInverse(masked_matrix[:,nc1:], rcond=rcond2)
        
    control_matrix = np.concatenate((control_matrix_1, control_matrix_2), axis=0)
    
    if pca_modes is not None:
        # Return the control matrix minus the pca_mode coefficients
        return control_matrix[0:-pca_modes.shape[0]]
    else:
        return control_matrix

# %%
reload(iefc)
control_matrix = construct_control_matrix(response_cube, 
                                                 weight_map.flatten(), 
                                               nc1=nf,
                                               nc2=nh,
                                                 rcond1=1e-1, 
                                                 rcond2=1e-1, 
                                                 nprobes=probe_modes.shape[0], pca_modes=None)
control_matrix.shape, nf, nh, control_mask.sum()*2
# Out:
# (26680, 2756)
# Using Weighted Least Squares
# ((2756, 26680), 1732, 1024, 26680)

# %%
reload(iefc)

reg_fun = iefc.construct_control_matrix
reg_conds = [[0, 10, 15, 20],
             [(1e-1, 1e-1), (1e-3, 1e-3), (1e-1, 1e-1), (1e-2, 1e-2)]]

# %% [markdown]
# # Run IEFC

# %%
reload(iefc)

sysi.reset_dms()

images, dm1_commands, dm2_commands = iefc.run(sysi, 
                                              control_matrix,
#                                               reg_fun,reg_conds,response_cube, 
                                              probe_modes, 
                                              probe_amp, 
                                              fourier_modes,
                                              had_modes,
                                              weight_map, 
                                              num_iterations=50, 
                                              loop_gain=0.2, leakage=0.0,
                                              display_all=True,
                                             )
