# %%
import numpy as np
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle
from pathlib import Path
from importlib import reload
from IPython.display import clear_output

from IEFC_modules import iefc_functions

import roman
import iefc_simulation as iefc
import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

wavelength_c = 575e-9*u.m

wavelength_ref = 0.5e-6*u.m
pixelscale_lamD_ref = 1/2
pixelscale_ref = 13e-6*u.m/u.pix
pixelscale_lamD = pixelscale_lamD_ref * (wavelength_ref/wavelength_c)
print(pixelscale_lamD)

wavelength = 575e-9*u.m
npsf = 64
psf_pixelscale = 13e-6*u.m/u.pix
# npsf = 256
# psf_pixelscale = 2.9587987694e-6*u.m/u.pix
psf_pixelscale_lamD = pixelscale_lamD * (psf_pixelscale/pixelscale_ref)
print(psf_pixelscale_lamD)

Nact = 48
dm_diam = 46.3*u.mm
act_spacing = 0.9906*u.mm
# Out:
# 0.43478260869565216
# 0.43478260869565216

# %%
reload(roman)

hlci = roman.CGI(use_opds=False, quiet=True)
psf = hlci.calc_psf()

misc.myimshow(psf, lognorm=True, pxscl=hlci.psf_pixelscale)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(iefc)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

# Create the mask that is used to select which region to make dark.
dh_params = {
    'x0' : 0,
    'y0' : -6,
    'w' : 10,
    'h' : 8
}
dh_mask = iefc.create_box_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'x0' : 0,
    'y0' : -8,
    'w' : 10,
    'h' : 10
}
control_mask = iefc.create_box_focal_plane_mask(xf, yf, control_params).ravel()
full_mask = control_mask * (abs(yf).ravel()>0.5)

relative_weight = 0.99
weights = dh_mask * relative_weight + (1 - relative_weight) * full_mask

print(dh_mask.shape, control_mask.shape, full_mask.shape, weights.shape)
misc.myimshow2(dh_mask.reshape(npsf,npsf), full_mask.reshape(npsf,npsf), 
               pxscl1=psf_pixelscale_lamD, pxscl2=psf_pixelscale_lamD)
misc.myimshow2(psf*weights.reshape(npsf,npsf), weights.reshape(npsf,npsf), lognorm1=True, lognorm2=True,
               pxscl1=psf_pixelscale_lamD, pxscl2=psf_pixelscale_lamD)
# Out:
# (4096,) (4096,) (4096,) (4096,)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(iefc)
fourier_modes, fx, fy = iefc.create_fourier_modes(xfp, control_mask.reshape((npsf,npsf)), Nact)
probe_modes = iefc.create_probe_poke_modes(Nact, Nact//2, Nact//4, Nact//2, Nact//4-1)

probe_amplitude = 0.05 * wavelength.to(u.m).value
calibration_amplitude = 0.006 * wavelength.to(u.m).value

print(fourier_modes.shape, probe_modes.shape)
misc.myimshow((probe_modes[0] - probe_modes[1]).reshape((Nact,Nact)))
misc.myimshow2(fourier_modes[0].reshape((Nact,Nact)), fourier_modes[200].reshape((Nact,Nact)))
# Out:
# Creating Fourier modes:  (64, 64)
# (242, 2304) (2, 2304)

# %%
reload(roman)

hlci.add_dm1(-calibration_amplitude * fourier_modes[200])

misc.display_dm(hlci.DM1, vmax=1e-8)

differential_images_2, single_images_2 = iefc.take_measurement(hlci, probe_modes, probe_amplitude, return_all=True)

print(differential_images.shape, single_images.shape)
misc.myimshow2(differential_images[1].reshape((64,64)), single_images[3].reshape((64,64)))
# Out:
# (2, 4096) (4, 4096)

# %%
misc.myimshow(differential_images_2[1].reshape((64,64))-differential_images[1].reshape((64,64)) )

# %%
reload(roman)

hlci.add_dm1(calibration_amplitude * fourier_modes[200])

misc.display_dm(hlci.DM1, vmax=1e-8)

differential_images, single_images = iefc.take_measurement(hlci, probe_modes, probe_amplitude, return_all=True)

print(differential_images.shape, single_images.shape)
misc.myimshow2(differential_images[1].reshape((64,64)), single_images[3].reshape((64,64)))
# Out:
# (2, 4096) (4, 4096)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)

# hlci = roman.CGI(cgi_mode='hlc')
response_cube, calibration_cube = iefc.calibrate(hlci, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, fourier_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 220 in 20.290s
# 	Calibrated mode 2 / 220 in 41.712s
# 	Calibrated mode 3 / 220 in 64.057s
# 	Calibrated mode 4 / 220 in 89.227s
# 	Calibrated mode 5 / 220 in 110.707s
# 	Calibrated mode 6 / 220 in 131.317s
# 	Calibrated mode 7 / 220 in 153.523s
# 	Calibrated mode 8 / 220 in 174.705s
# 	Calibrated mode 9 / 220 in 194.965s
# 	Calibrated mode 10 / 220 in 217.042s
# 	Calibrated mode 11 / 220 in 239.550s
# 	Calibrated mode 12 / 220 in 259.591s
# 	Calibrated mode 13 / 220 in 279.862s
# 	Calibrated mode 14 / 220 in 300.650s
# 	Calibrated mode 15 / 220 in 320.746s
# 	Calibrated mode 16 / 220 in 341.092s
# 	Calibrated mode 17 / 220 in 362.027s
# 	Calibrated mode 18 / 220 in 382.161s
# 	Calibrated mode 19 / 220 in 402.307s
# 	Calibrated mode 20 / 220 in 423.350s
# 	Calibrated mode 21 / 220 in 443.486s
# 	Calibrated mode 22 / 220 in 465.706s
# 	Calibrated mode 23 / 220 in 490.489s
# 	Calibrated mode 24 / 220 in 511.398s
# 	Calibrated mode 25 / 220 in 532.233s
# 	Calibrated mode 26 / 220 in 553.107s
# 	Calibrated mode 27 / 220 in 573.252s
# 	Calibrated mode 28 / 220 in 594.930s
# 	Calibrated mode 29 / 220 in 615.945s
# 	Calibrated mode 30 / 220 in 636.091s
# 	Calibrated mode 31 / 220 in 657.697s
# 	Calibrated mode 32 / 220 in 678.711s
# 	Calibrated mode 33 / 220 in 699.753s
# 	Calibrated mode 34 / 220 in 719.830s
# 	Calibrated mode 35 / 220 in 740.786s
# 	Calibrated mode 36 / 220 in 763.297s
# 	Calibrated mode 37 / 220 in 783.455s
# 	Calibrated mode 38 / 220 in 804.287s
# 	Calibrated mode 39 / 220 in 827.519s
# 	Calibrated mode 40 / 220 in 847.572s
# 	Calibrated mode 41 / 220 in 869.205s
# 	Calibrated mode 42 / 220 in 889.658s
# 	Calibrated mode 43 / 220 in 909.985s
# 	Calibrated mode 44 / 220 in 931.832s
# 	Calibrated mode 45 / 220 in 952.153s
# 	Calibrated mode 46 / 220 in 972.801s
# 	Calibrated mode 47 / 220 in 993.910s
# 	Calibrated mode 48 / 220 in 1014.090s
# 	Calibrated mode 49 / 220 in 1034.341s
# 	Calibrated mode 50 / 220 in 1056.075s
# 	Calibrated mode 51 / 220 in 1076.454s
# 	Calibrated mode 52 / 220 in 1100.481s
# 	Calibrated mode 53 / 220 in 1121.688s
# 	Calibrated mode 54 / 220 in 1142.039s
# 	Calibrated mode 55 / 220 in 1163.178s
# 	Calibrated mode 56 / 220 in 1184.704s
# 	Calibrated mode 57 / 220 in 1204.945s
# 	Calibrated mode 58 / 220 in 1229.713s
# 	Calibrated mode 59 / 220 in 1250.980s
# 	Calibrated mode 60 / 220 in 1271.148s
# 	Calibrated mode 61 / 220 in 1291.271s
# 	Calibrated mode 62 / 220 in 1312.199s
# 	Calibrated mode 63 / 220 in 1332.835s
# 	Calibrated mode 64 / 220 in 1353.227s
# 	Calibrated mode 65 / 220 in 1374.723s
# 	Calibrated mode 66 / 220 in 1394.933s
# 	Calibrated mode 67 / 220 in 1415.110s
# 	Calibrated mode 68 / 220 in 1443.501s
# 	Calibrated mode 69 / 220 in 1463.737s
# 	Calibrated mode 70 / 220 in 1483.860s
# 	Calibrated mode 71 / 220 in 1504.720s
# 	Calibrated mode 72 / 220 in 1525.031s
# 	Calibrated mode 73 / 220 in 1547.978s
# 	Calibrated mode 74 / 220 in 1570.167s
# 	Calibrated mode 75 / 220 in 1590.389s
# 	Calibrated mode 76 / 220 in 1610.590s
# 	Calibrated mode 77 / 220 in 1631.560s
# 	Calibrated mode 78 / 220 in 1651.798s
# 	Calibrated mode 79 / 220 in 1671.850s
# 	Calibrated mode 80 / 220 in 1692.606s
# 	Calibrated mode 81 / 220 in 1712.861s
# 	Calibrated mode 82 / 220 in 1733.283s
# 	Calibrated mode 83 / 220 in 1754.354s
# 	Calibrated mode 84 / 220 in 1774.608s
# 	Calibrated mode 85 / 220 in 1794.776s
# 	Calibrated mode 86 / 220 in 1816.116s
# 	Calibrated mode 87 / 220 in 1836.250s
# 	Calibrated mode 88 / 220 in 1856.378s
# 	Calibrated mode 89 / 220 in 1877.390s
# 	Calibrated mode 90 / 220 in 1897.685s
# 	Calibrated mode 91 / 220 in 1917.815s
# 	Calibrated mode 92 / 220 in 1938.754s
# 	Calibrated mode 93 / 220 in 1958.986s
# 	Calibrated mode 94 / 220 in 1979.008s
# 	Calibrated mode 95 / 220 in 1999.785s
# 	Calibrated mode 96 / 220 in 2020.003s
# 	Calibrated mode 97 / 220 in 2040.157s
# 	Calibrated mode 98 / 220 in 2061.016s
# 	Calibrated mode 99 / 220 in 2081.354s
# 	Calibrated mode 100 / 220 in 2101.580s
# 	Calibrated mode 101 / 220 in 2122.431s
# 	Calibrated mode 102 / 220 in 2143.026s
# 	Calibrated mode 103 / 220 in 2163.081s
# 	Calibrated mode 104 / 220 in 2184.086s
# 	Calibrated mode 105 / 220 in 2204.338s
# 	Calibrated mode 106 / 220 in 2224.449s
# 	Calibrated mode 107 / 220 in 2245.642s
# 	Calibrated mode 108 / 220 in 2265.754s
# 	Calibrated mode 109 / 220 in 2285.892s
# 	Calibrated mode 110 / 220 in 2306.815s
# 	Calibrated mode 111 / 220 in 2327.041s
# 	Calibrated mode 112 / 220 in 2347.134s
# 	Calibrated mode 113 / 220 in 2368.218s
# 	Calibrated mode 114 / 220 in 2388.430s
# 	Calibrated mode 115 / 220 in 2408.524s
# 	Calibrated mode 116 / 220 in 2429.645s
# 	Calibrated mode 117 / 220 in 2449.809s
# 	Calibrated mode 118 / 220 in 2470.173s
# 	Calibrated mode 119 / 220 in 2491.290s
# 	Calibrated mode 120 / 220 in 2511.575s
# 	Calibrated mode 121 / 220 in 2532.015s
# 	Calibrated mode 122 / 220 in 2552.800s
# 	Calibrated mode 123 / 220 in 2573.082s
# 	Calibrated mode 124 / 220 in 2593.281s
# 	Calibrated mode 125 / 220 in 2614.214s
# 	Calibrated mode 126 / 220 in 2641.191s
# 	Calibrated mode 127 / 220 in 2661.355s
# 	Calibrated mode 128 / 220 in 2682.370s
# 	Calibrated mode 129 / 220 in 2702.578s
# 	Calibrated mode 130 / 220 in 2722.832s
# 	Calibrated mode 131 / 220 in 2743.996s
# 	Calibrated mode 132 / 220 in 2764.367s
# 	Calibrated mode 133 / 220 in 2784.459s
# 	Calibrated mode 134 / 220 in 2805.269s
# 	Calibrated mode 135 / 220 in 2825.555s
# 	Calibrated mode 136 / 220 in 2845.911s
# 	Calibrated mode 137 / 220 in 2866.851s
# 	Calibrated mode 138 / 220 in 2887.133s
# 	Calibrated mode 139 / 220 in 2907.273s
# 	Calibrated mode 140 / 220 in 2928.131s
# 	Calibrated mode 141 / 220 in 2948.396s
# 	Calibrated mode 142 / 220 in 2968.452s
# 	Calibrated mode 143 / 220 in 2989.308s
# 	Calibrated mode 144 / 220 in 3009.541s
# 	Calibrated mode 145 / 220 in 3029.588s
# 	Calibrated mode 146 / 220 in 3050.448s
# 	Calibrated mode 147 / 220 in 3070.579s
# 	Calibrated mode 148 / 220 in 3090.577s
# 	Calibrated mode 149 / 220 in 3111.452s
# 	Calibrated mode 150 / 220 in 3131.450s
# 	Calibrated mode 151 / 220 in 3151.919s
# 	Calibrated mode 152 / 220 in 3172.766s
# 	Calibrated mode 153 / 220 in 3192.855s
# 	Calibrated mode 154 / 220 in 3212.910s
# 	Calibrated mode 155 / 220 in 3235.714s
# 	Calibrated mode 156 / 220 in 3255.934s
# 	Calibrated mode 157 / 220 in 3275.966s
# 	Calibrated mode 158 / 220 in 3296.799s
# 	Calibrated mode 159 / 220 in 3317.026s
# 	Calibrated mode 160 / 220 in 3337.196s
# 	Calibrated mode 161 / 220 in 3358.464s
# 	Calibrated mode 162 / 220 in 3378.702s
# 	Calibrated mode 163 / 220 in 3398.821s
# 	Calibrated mode 164 / 220 in 3419.722s
# 	Calibrated mode 165 / 220 in 3439.956s
# 	Calibrated mode 166 / 220 in 3460.055s
# 	Calibrated mode 167 / 220 in 3480.955s
# 	Calibrated mode 168 / 220 in 3501.228s
# 	Calibrated mode 169 / 220 in 3521.557s
# 	Calibrated mode 170 / 220 in 3542.380s
# 	Calibrated mode 171 / 220 in 3562.560s
# 	Calibrated mode 172 / 220 in 3582.921s
# 	Calibrated mode 173 / 220 in 3603.919s
# 	Calibrated mode 174 / 220 in 3624.177s
# 	Calibrated mode 175 / 220 in 3644.334s
# 	Calibrated mode 176 / 220 in 3664.951s
# 	Calibrated mode 177 / 220 in 3685.060s
# 	Calibrated mode 178 / 220 in 3705.115s
# 	Calibrated mode 179 / 220 in 3726.082s
# 	Calibrated mode 180 / 220 in 3746.625s
# 	Calibrated mode 181 / 220 in 3766.723s
# 	Calibrated mode 182 / 220 in 3787.391s
# 	Calibrated mode 183 / 220 in 3807.615s
# 	Calibrated mode 184 / 220 in 3829.730s
# 	Calibrated mode 185 / 220 in 3850.655s
# 	Calibrated mode 186 / 220 in 3870.946s
# 	Calibrated mode 187 / 220 in 3891.222s
# 	Calibrated mode 188 / 220 in 3912.137s
# 	Calibrated mode 189 / 220 in 3932.377s
# 	Calibrated mode 190 / 220 in 3952.594s
# 	Calibrated mode 191 / 220 in 3973.487s
# 	Calibrated mode 192 / 220 in 3993.691s
# 	Calibrated mode 193 / 220 in 4013.781s
# 	Calibrated mode 194 / 220 in 4034.664s
# 	Calibrated mode 195 / 220 in 4054.934s
# 	Calibrated mode 196 / 220 in 4075.191s
# 	Calibrated mode 197 / 220 in 4096.487s
# 	Calibrated mode 198 / 220 in 4116.785s
# 	Calibrated mode 199 / 220 in 4136.856s
# 	Calibrated mode 200 / 220 in 4157.716s
# 	Calibrated mode 201 / 220 in 4178.057s
# 	Calibrated mode 202 / 220 in 4198.336s
# 	Calibrated mode 203 / 220 in 4219.080s
# 	Calibrated mode 204 / 220 in 4239.367s
# 	Calibrated mode 205 / 220 in 4259.315s
# 	Calibrated mode 206 / 220 in 4279.983s
# 	Calibrated mode 207 / 220 in 4300.408s
# 	Calibrated mode 208 / 220 in 4320.768s
# 	Calibrated mode 209 / 220 in 4341.565s
# 	Calibrated mode 210 / 220 in 4361.808s
# 	Calibrated mode 211 / 220 in 4381.902s
# 	Calibrated mode 212 / 220 in 4402.613s
# 	Calibrated mode 213 / 220 in 4423.409s
# 	Calibrated mode 214 / 220 in 4443.912s
# 	Calibrated mode 215 / 220 in 4464.648s
# 	Calibrated mode 216 / 220 in 4484.848s
# 	Calibrated mode 217 / 220 in 4504.965s
# 	Calibrated mode 218 / 220 in 4525.847s
# 	Calibrated mode 219 / 220 in 4545.999s
# 	Calibrated mode 220 / 220 in 4566.067s
# Calibration complete.

# %%
print(response_cube.shape, calibration_cube.shape)

response_hdu = fits.PrimaryHDU(data=response_cube)
response_hdu.writeto(data_dir/'response-data'/'hlc_response_cube_box_mask.fits', overwrite=True)

calib_hdu = fits.PrimaryHDU(data=calibration_cube)
calib_hdu.writeto(data_dir/'calibration-data'/'hlc_calibration_cube_box_mask.fits', overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 print(response_cube.shape, calibration_cube.shape)
#       3 response_hdu = fits.PrimaryHDU(data=response_cube)
#       4 response_hdu.writeto(data_dir/'response-data'/'hlc_response_cube_box_mask.fits', overwrite=True)
#
# NameError: name 'response_cube' is not defined

# %%
response_cube = fits.getdata(data_dir/'response-data'/'hlc_response_cube_box_mask.fits')
calibration_cube = fits.getdata(data_dir/'calibration-data'/'hlc_calibration_cube_box_mask.fits')
print(response_cube.shape, calibration_cube.shape)
# Out:
# (242, 2, 4096) (484, 4, 4096)

# %%
im = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(im.reshape(64,64))

# %% [markdown]
# # Filter calibration data

# %%
# Filter the calibration files by subtracting PCA modes
npca = 3
filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

# %% [markdown]
# # Create control matrix

# %%
control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), rcond=5e-2, pca_modes=pca_modes)
# condition number penalizes large DM commands, the smaller the number
# the greater the penalization, really difficult to use small numbers when you need to correct
# large aberrations or in this case, the pure diffraction rings

# %% [markdown]
# # Run IEFC

# %%
# The metric
metric_images = []
dm_commands = []
command = 0.0

## Run IEFC for num_iterations
num_iterations = 10
gain = -0.4
leakage = 0.0

for i in range(num_iterations):
    print("Closed-loop iteration {:d} / {:d}".format(i+1, num_iterations))
#     delta_coefficients = iefc_functions.IEFC_single_iteration(tbi, probe_modes, probe_amplitude, 
#                                                               control_matrix, weights>0)
    delta_coefficients = iefc.single_iteration(hlci, probe_modes, probe_amplitude, 
                                               control_matrix, weights.flatten()>0)
    command = (1.0-leakage) * command + gain * delta_coefficients
    
    # Reconstruct the full phase from the Fourier modes
    dm_command = np.einsum('ij, i->j', fourier_modes, command)
    print(dm_command.shape, delta_coefficients.shape)
    
    # Set the current DM state
#     tbi.set_dm(dm_command)
#     ret = tbi.send_dm()
    hlci.set_dm1(dm_command)
    
    # Take an image to estimate the metrics
#     metric_images.append(tbi.snap())
    image = hlci.calc_psf()
    metric_images.append(image)
    dm_commands.append(dm_command)
    
    misc.myimshow2(dm_command.reshape(Nact,Nact), image, lognorm2=True)
    pass
# Out:
# Closed-loop iteration 1 / 10
# (2304,) (242,)
# Closed-loop iteration 2 / 10
# (2304,) (242,)
# Closed-loop iteration 3 / 10
# (2304,) (242,)
# Closed-loop iteration 4 / 10
# (2304,) (242,)
# Closed-loop iteration 5 / 10
# (2304,) (242,)
# Closed-loop iteration 6 / 10
# (2304,) (242,)
# Closed-loop iteration 7 / 10
# (2304,) (242,)
# Closed-loop iteration 8 / 10
# (2304,) (242,)
# Closed-loop iteration 9 / 10
# (2304,) (242,)
# Closed-loop iteration 10 / 10
# (2304,) (242,)

# %%
# The metric
metric_images = []
dm_commands = []
command = 0.0

## Run IEFC for num_iterations
num_iterations = 10
gain = -0.4
leakage = 0.0

for i in range(num_iterations):
    print("Closed-loop iteration {:d} / {:d}".format(i+1, num_iterations))
#     delta_coefficients = iefc_functions.IEFC_single_iteration(tbi, probe_modes, probe_amplitude, 
#                                                               control_matrix, weights>0)
    delta_coefficients = iefc.single_iteration(hlci, probe_modes, probe_amplitude, 
                                               control_matrix, weights.flatten()>0)
    command = (1.0-leakage) * command + gain * delta_coefficients
    
    # Reconstruct the full phase from the Fourier modes
    dm_command = np.einsum('ij, i->j', fourier_modes, command)
    print(dm_command.shape, delta_coefficients.shape)
    
    # Set the current DM state
#     tbi.set_dm(dm_command)
#     ret = tbi.send_dm()
    hlci.set_dm1(dm_command)
    
    # Take an image to estimate the metrics
#     metric_images.append(tbi.snap())
    image = hlci.calc_psf()
    metric_images.append(image)
    dm_commands.append(dm_command)
    
    misc.myimshow2(dm_command.reshape(Nact,Nact), image, lognorm2=True)
    pass
# Out:
# Closed-loop iteration 1 / 10
# (2304,) (242,)
# Closed-loop iteration 2 / 10
# (2304,) (242,)
# Closed-loop iteration 3 / 10
# (2304,) (242,)
# Closed-loop iteration 4 / 10
# (2304,) (242,)
# Closed-loop iteration 5 / 10
# (2304,) (242,)
# Closed-loop iteration 6 / 10
# (2304,) (242,)
# Closed-loop iteration 7 / 10
# (2304,) (242,)
# Closed-loop iteration 8 / 10
# (2304,) (242,)
# Closed-loop iteration 9 / 10
# (2304,) (242,)
# Closed-loop iteration 10 / 10
# (2304,) (242,)

# %%
hdr = fits.Header()
hdr['GAIN'] = gain
hdr['LEAKAGE'] = leakage

images_hdu = fits.PrimaryHDU(data=metric_images, header=hdr)
images_hdu.writeto(data_dir/'image-results'/'rect_dh.fits', overwrite=True)
dms_hdu = fits.PrimaryHDU(data=dm_commands, header=hdr)
dms_hdu.writeto(data_dir/'dm-results'/'rect_dh.fits', overwrite=True)

# %%
reload(iefc)
ind = 8
patches = [iefc.create_rect_patch(dh_params)]
misc.myimshow2(dm_commands[ind].reshape(Nact,Nact), metric_images[ind], 
               lognorm2=True, patches2=patches, pxscl2=psf_pixelscale_lamD.value)

# %%
metric_images = fits.getdata(data_dir/'image-results'/'rect_dh.fits')
dm_commands = fits.getdata(data_dir/'dm-results'/'rect_dh.fits')
hdr = fits.getheader(data_dir/'dm-results'/'rect_dh.fits')
print(hdr['GAIN'], hdr['LEAKAGE'])
# Out:
# -0.4 0.0

# %% [markdown]
# # Testing

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import LogNorm
from matplotlib.animation import FFMpegWriter
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.rcParams['animation.ffmpeg_path'] ='/.../bin/ffmpeg.exe'
plt.rcParams['animation.convert_path'] = '/.../magick.exe'
plt.rcParams['animation.html'] = 'html5'

wfs_min, wfs_max = (1, 0)
for i in range(len(images)):
    m, M = ( np.min(images), np.max(images) )
    if m < wfs_min: wfs_min = m
    if M > wfs_max: wfs_max = M

fig,ax = plt.subplots(1,2, figsize=(10,4), dpi=100)

dm_ext = np.array([-Nact/2, Nact/2, -Nact/2, Nact/2])*hlci.act_spacing.value
psf_ext = np.array([-npsf/2, npsf/2, -npsf/2, npsf/2])*psf_pixelscale_lamD
    
ax0 = ax[0].imshow(actuators[0], cmap='magma', extent=dm_ext)
divider = make_axes_locatable(ax[0])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax0, cax=cax)
ax0_title = ax[0].set_title('Iteration {:d}'.format(range(15)[0]), fontsize = 18)

ax1 = ax[1].imshow(images[0], norm=LogNorm(), cmap='gist_heat', extent=psf_ext)
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax1, cax=cax)
ax1_title = ax[1].set_title('PSF', fontsize = 18)
ax1.add_patch(iefc.create_rect_patch(dh_params))

plt.close()

def animate(i):
    ax0.set_data(actuators[i])
    ax0.set_clim(np.min(actuators[i]), np.max(actuators[i]))
    ax0_title.set_text('Iteration {:d}'.format(range(15)[i]))
    
    ax1.set_data(wavefronts[i][-1].intensity)
    ax1.set_clim(wfs_min, wfs_max)
    ax1.add_patch(iefc.create_rect_patch(dh_params))

anim = animation.FuncAnimation(fig, animate, frames=len(actuators))
anim

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import LogNorm
from matplotlib.animation import FFMpegWriter
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.rcParams['animation.ffmpeg_path'] ='/.../bin/ffmpeg.exe'
plt.rcParams['animation.convert_path'] = '/.../magick.exe'
plt.rcParams['animation.html'] = 'html5'

wfs_min, wfs_max = (1, 0)
for i in range(len(wavefronts)):
    m, M = ( np.min(wavefronts[i][-1].intensity), np.max(wavefronts[i][-1].intensity) )
    if m < wfs_min: wfs_min = m
    if M > wfs_max: wfs_max = M

fig,ax = plt.subplots(1,2, figsize=(10,4), dpi=100)

dm_ext = np.array([-Nacts/2, Nacts/2, -Nacts/2, Nacts/2])*act_spacing.value
psf_ext = np.array([-npsf/2, npsf/2, -npsf/2, npsf/2])*wavefronts[0][-1].pixelscale.to(u.mm/u.pix).value
    
ax0 = ax[0].imshow(actuators[0], cmap='magma', extent=dm_ext)
divider = make_axes_locatable(ax[0])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax0, cax=cax)
ax0_title = ax[0].set_title('Iteration {:d}'.format(range(15)[0]), fontsize = 18)

ax1 = ax[1].imshow(wavefronts[0][-1].intensity, norm=LogNorm(), cmap='gist_heat', extent=psf_ext)
divider = make_axes_locatable(ax[1])
cax = divider.append_axes("right", size="4%", pad=0.075)
cbar0 = fig.colorbar(ax1, cax=cax)
ax1_title = ax[1].set_title('PSF', fontsize = 18)
plt.close()

def animate(i):
    ax0.set_data(actuators[i])
    ax0.set_clim(np.min(actuators[i]), np.max(actuators[i]))
    ax0_title.set_text('Iteration {:d}'.format(range(15)[i]))
    
    ax1.set_data(wavefronts[i][-1].intensity)
    ax1.set_clim(wfs_min, wfs_max)
    ax1

anim = animation.FuncAnimation(fig, animate, frames=len(actuators))
anim
