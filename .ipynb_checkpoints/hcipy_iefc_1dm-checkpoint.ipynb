# %%
import numpy as np
import scipy

import cupy as cp
import cupyx.scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import warnings
warnings.filterwarnings("ignore")

import poppy
import hcipy as hci

import wfsc_tests as wfsc
wfsc.math_module.update_np(np)
wfsc.math_module.update_scipy(scipy)

import misc_funs as misc

from matplotlib.colors import ListedColormap
#Blue to Red Color scale for S1 and S2
colmap = np.zeros((255,3));
# Red
colmap[126:183,0]= np.linspace(0,1,57);
colmap[183:255,0]= 1;
# Green
colmap[0:96,1] = np.linspace(1,0,96);
colmap[158:255,1]= np.linspace(0,1,97);
# Blue
colmap[0:71,2] = 1;
colmap[71:128,2]= np.linspace(1,0,57);
colmap2 = colmap[128:,:]
colmap = ListedColormap(colmap)

# %%
class CORO():

    def __init__(self, 
                 wavelength=None, 
                ):
        
        self.wavelength_c = 575e-9*u.m
        self.wavelength = self.wavelength_c if wavelength is None else wavelength
        self.f = 500*u.mm
        
        self.dm_diam = 10.2*u.mm
        self.dm1_dm2 = 200e-3*u.m
        
        self.FN = (self.dm_diam**2/self.dm1_dm2/self.wavelength).decompose()
        
        # define the grids
        self.npix = 256
        self.oversample = 2
        self.spatial_resolution = self.f.to_value(u.m) * self.wavelength.to_value(u.m) / self.dm_diam.to_value(u.m)
        self.npsf = 64
        self.psf_pixelscale_lamD = self.spatial_resolution/self.f.to_value(u.m)*(self.dm_diam/self.wavelength_c).decompose().value/2
        
        self.pupil_grid = hci.make_pupil_grid(self.npix*self.oversample, self.dm_diam.to_value(u.m) * self.oversample)
        self.focal_grid = hci.make_focal_grid(2, 16, spatial_resolution=self.spatial_resolution)
        self.prop = hci.FraunhoferPropagator(self.pupil_grid, self.focal_grid, self.f.to_value(u.m))

        self.aperture = hci.Field(np.exp(-(self.pupil_grid.as_('polar').r / (0.5 * self.dm_diam.to_value(u.m)))**30), self.pupil_grid)
        
        # define the DMs
        self.Nact = 34
        actuator_spacing = 1.00 / self.Nact * self.dm_diam.to_value(u.m)
        
#         influence_functions = hci.make_xinetics_influence_functions(self.pupil_grid, self.Nact, actuator_spacing)
        influence_functions = hci.make_gaussian_influence_functions(self.pupil_grid, self.Nact, actuator_spacing)
        
        self.DM1 = hci.DeformableMirror(influence_functions)
        self.DM2 = hci.DeformableMirror(influence_functions)

        self.prop_between_dms = hci.FresnelPropagator(self.pupil_grid, self.dm1_dm2.to_value(u.m))
        
        self.dm_mask = np.ones((self.Nact,self.Nact), dtype=bool)
        xx = (np.linspace(0, self.Nact-1, self.Nact) - self.Nact/2 + 1/2) * actuator_spacing*2
        x,y = np.meshgrid(xx,xx)
        r = np.sqrt(x**2 + y**2)
        self.dm_mask[r>0.0105] = 0 # had to set the threshold to 10.5 instead of 10.2 to include edge actuators
        
#         self.dm_zernikes = poppy.zernike.arbitrary_basis(self.dm_mask, nterms=15, outside=0)
        self.dm_zernikes = poppy.zernike.arbitrary_basis(cp.array(self.dm_mask), nterms=15, outside=0).get()
        
        # make the aberrations of the system (make sure to remove tip-tilt)
        aberration_ptv = 0.02 * self.wavelength.to_value(u.m)
        tip_tilt = hci.make_zernike_basis(3, self.dm_diam.to_value(u.m), self.pupil_grid, starting_mode=2)
        wfe = hci.SurfaceAberration(self.pupil_grid, aberration_ptv, self.dm_diam.to_value(u.m), remove_modes=tip_tilt, exponent=-3)
        aberration_distance_m = 100e-3
        self.wfe_at_distance = hci.SurfaceAberrationAtDistance(wfe, aberration_distance_m)
        
        # make the coronagraph model
        self.coronagraph = hci.PerfectCoronagraph(self.aperture, order=6)
        
        
    def set_dm1(self, command):
        self.DM1.actuators = command.ravel()
        
    def set_dm2(self, command):
        self.DM2.actuators = command.ravel()
        
    def add_dm1(self, command):
        self.DM1.actuators += command.ravel()
        
    def add_dm2(self, command):
        self.DM2.actuators += command.ravel()
        
    def get_dm1(self):
        return self.DM1.actuators.reshape(self.Nact, self.Nact)
        
    def get_dm2(self):
        return self.DM2.actuators.reshape(self.Nact, self.Nact)
    
    def reset_dms(self):
        self.DM1.actuators = np.zeros((self.Nact, self.Nact)).ravel()
        self.DM2.actuators = np.zeros((self.Nact, self.Nact)).ravel()
    
    def show_dms(self):
        misc.imshow2(self.DM1.actuators.reshape(c.Nact, c.Nact),
                     self.DM2.actuators.reshape(c.Nact, c.Nact))
        
    def calc_psf(self):
        wf = hci.Wavefront(self.aperture, self.wavelength.to_value(u.m))
        wf = self.wfe_at_distance(wf) # apply aberrations to wavefront
        wf = self.prop_between_dms.backward(self.DM2(self.prop_between_dms.forward(self.DM1(wf)))) # apply DMs
        wf = self.prop(self.coronagraph(wf))
        psf_wf = wf.real.shaped + 1j*wf.imag.shaped

        return np.array(psf_wf)

    def snap(self):
        wf = hci.Wavefront(self.aperture, self.wavelength.to_value(u.m))
        wf = self.wfe_at_distance(wf) # apply aberrations to wavefront
        wf = self.prop_between_dms.backward(self.DM2(self.prop_between_dms.forward(self.DM1(wf)))) # apply DMs
        im = self.prop(self.coronagraph(wf))

        return np.array(im.intensity.shaped)
    
c = CORO()

# %%
Nact = c.Nact
npsf = c.npsf

c.reset_dms()
ref_im = c.snap()

misc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD)

# %% [markdown]
# # define the dark hole region

# %%
reload(wfsc)
reload(wfsc.utils)
reload(wfsc.imshows)
xfp = (np.linspace(-npsf/2, npsf/2-1, npsf) + 1/2)*c.psf_pixelscale_lamD
fpx,fpy = np.meshgrid(xfp,xfp)
fpr = np.sqrt(fpx**2 + fpy**2)
    
iwa = 3
owa = 9
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 2,
        'rotation':0,
        'full':True,
    }
roi1 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

iwa = (3-1)
owa = (9+0.5)
roi_params = {
        'inner_radius' : iwa,
        'outer_radius' : owa,
        'edge' : 2,
        'rotation':0,
        'full':True,
    }
roi2 = wfsc.utils.create_annular_focal_plane_mask(fpx, fpy, roi_params, plot=True)

# wfsc.imshow2(roi1, roi2)
weight_map = roi1 + 0.2*(roi2 * ~roi1)
control_mask = weight_map>0
wfsc.imshow1(weight_map)

probe_amp = 3e-8
calib_amp = 5e-9

# %%
reload(wfsc.imshows)
calib_modes, fs = wfsc.utils.select_fourier_modes(c, control_mask*(fpx>0), fourier_sampling=0.9) 
nmodes = calib_modes.shape[0]
display(calib_modes.shape, fs.shape)

patches = []
for f in fs:
    center = (f[0], f[1])
    radius = 0.25
    patches.append(Circle(center, radius, fill=True, color='g'))
    
wfsc.imshow1(ref_im, lognorm=True, pxscl=c.psf_pixelscale_lamD, patches=patches)
# Out:
# (280, 1156)
# (140, 2)

# %%
reload(wfsc.utils)
probe_modes = wfsc.utils.create_probe_poke_modes(Nact, 
                                                 poke_indices=[(Nact//3, Nact//3), (Nact//3+1, Nact//3)], 
                                                 plot=True)

# %%
reload(wfsc.iefc)

probe_amp = 3e-8
calib_amp = 5e-9

c.reset_dms()
c.texp = 1
differential_images, single_images = wfsc.iefc_1dm.take_measurement(c, 
                                                           probe_modes, probe_amp, 
                                                           return_all=True)
ims = differential_images.reshape(2, c.npsf, c.npsf)
misc.imshow3(ims[0], ims[1], ims[0]-ims[1], wspace=0.35)

# %%
reload(wfsc.iefc_1dm)
c.reset_dms()
response_matrix, response_cube = wfsc.iefc_1dm.calibrate(c, 
                                                         control_mask.ravel(),
                                                         probe_amp, probe_modes, 
                                                         calib_amp, calib_modes,
                                                         return_all=True)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 280 in 1.489s
# 	Calibrated mode 2 / 280 in 2.888s
# 	Calibrated mode 3 / 280 in 4.314s
# 	Calibrated mode 4 / 280 in 5.723s
# 	Calibrated mode 5 / 280 in 7.138s
# 	Calibrated mode 6 / 280 in 8.538s
# 	Calibrated mode 7 / 280 in 9.942s
# 	Calibrated mode 8 / 280 in 11.352s
# 	Calibrated mode 9 / 280 in 12.769s
# 	Calibrated mode 10 / 280 in 14.179s
# 	Calibrated mode 11 / 280 in 15.583s
# 	Calibrated mode 12 / 280 in 16.992s
# 	Calibrated mode 13 / 280 in 18.400s
# 	Calibrated mode 14 / 280 in 19.810s
# 	Calibrated mode 15 / 280 in 21.221s
# 	Calibrated mode 16 / 280 in 22.631s
# 	Calibrated mode 17 / 280 in 24.047s
# 	Calibrated mode 18 / 280 in 25.459s
# 	Calibrated mode 19 / 280 in 26.866s
# 	Calibrated mode 20 / 280 in 28.270s
# 	Calibrated mode 21 / 280 in 29.678s
# 	Calibrated mode 22 / 280 in 31.087s
# 	Calibrated mode 23 / 280 in 32.500s
# 	Calibrated mode 24 / 280 in 33.910s
# 	Calibrated mode 25 / 280 in 35.323s
# 	Calibrated mode 26 / 280 in 36.743s
# 	Calibrated mode 27 / 280 in 38.159s
# 	Calibrated mode 28 / 280 in 39.563s
# 	Calibrated mode 29 / 280 in 40.970s
# 	Calibrated mode 30 / 280 in 42.379s
# 	Calibrated mode 31 / 280 in 43.793s
# 	Calibrated mode 32 / 280 in 45.208s
# 	Calibrated mode 33 / 280 in 46.625s
# 	Calibrated mode 34 / 280 in 48.033s
# 	Calibrated mode 35 / 280 in 49.437s
# 	Calibrated mode 36 / 280 in 50.849s
# 	Calibrated mode 37 / 280 in 52.257s
# 	Calibrated mode 38 / 280 in 53.674s
# 	Calibrated mode 39 / 280 in 55.090s
# 	Calibrated mode 40 / 280 in 56.504s
# 	Calibrated mode 41 / 280 in 57.912s
# 	Calibrated mode 42 / 280 in 59.316s
# 	Calibrated mode 43 / 280 in 60.727s
# 	Calibrated mode 44 / 280 in 62.140s
# 	Calibrated mode 45 / 280 in 63.552s
# 	Calibrated mode 46 / 280 in 64.968s
# 	Calibrated mode 47 / 280 in 66.378s
# 	Calibrated mode 48 / 280 in 67.787s
# 	Calibrated mode 49 / 280 in 69.193s
# 	Calibrated mode 50 / 280 in 70.605s
# 	Calibrated mode 51 / 280 in 72.014s
# 	Calibrated mode 52 / 280 in 73.419s
# 	Calibrated mode 53 / 280 in 74.830s
# 	Calibrated mode 54 / 280 in 76.240s
# 	Calibrated mode 55 / 280 in 77.641s
# 	Calibrated mode 56 / 280 in 79.053s
# 	Calibrated mode 57 / 280 in 80.464s
# 	Calibrated mode 58 / 280 in 81.874s
# 	Calibrated mode 59 / 280 in 83.290s
# 	Calibrated mode 60 / 280 in 84.702s
# 	Calibrated mode 61 / 280 in 86.117s
# 	Calibrated mode 62 / 280 in 87.535s
# 	Calibrated mode 63 / 280 in 88.938s
# 	Calibrated mode 64 / 280 in 90.347s
# 	Calibrated mode 65 / 280 in 91.759s
# 	Calibrated mode 66 / 280 in 93.178s
# 	Calibrated mode 67 / 280 in 94.598s
# 	Calibrated mode 68 / 280 in 96.013s
# 	Calibrated mode 69 / 280 in 97.435s
# 	Calibrated mode 70 / 280 in 98.852s
# 	Calibrated mode 71 / 280 in 100.266s
# 	Calibrated mode 72 / 280 in 101.668s
# 	Calibrated mode 73 / 280 in 103.080s
# 	Calibrated mode 74 / 280 in 104.489s
# 	Calibrated mode 75 / 280 in 105.898s
# 	Calibrated mode 76 / 280 in 107.305s
# 	Calibrated mode 77 / 280 in 108.722s
# 	Calibrated mode 78 / 280 in 110.132s
# 	Calibrated mode 79 / 280 in 111.544s
# 	Calibrated mode 80 / 280 in 112.946s
# 	Calibrated mode 81 / 280 in 114.355s
# 	Calibrated mode 82 / 280 in 115.764s
# 	Calibrated mode 83 / 280 in 117.166s
# 	Calibrated mode 84 / 280 in 118.566s
# 	Calibrated mode 85 / 280 in 119.965s
# 	Calibrated mode 86 / 280 in 121.358s
# 	Calibrated mode 87 / 280 in 122.758s
# 	Calibrated mode 88 / 280 in 124.168s
# 	Calibrated mode 89 / 280 in 125.568s
# 	Calibrated mode 90 / 280 in 126.971s
# 	Calibrated mode 91 / 280 in 128.371s
# 	Calibrated mode 92 / 280 in 129.771s
# 	Calibrated mode 93 / 280 in 131.177s
# 	Calibrated mode 94 / 280 in 132.577s
# 	Calibrated mode 95 / 280 in 133.978s
# 	Calibrated mode 96 / 280 in 135.381s
# 	Calibrated mode 97 / 280 in 136.781s
# 	Calibrated mode 98 / 280 in 138.200s
# 	Calibrated mode 99 / 280 in 139.601s
# 	Calibrated mode 100 / 280 in 140.994s
# 	Calibrated mode 101 / 280 in 142.396s
# 	Calibrated mode 102 / 280 in 143.800s
# 	Calibrated mode 103 / 280 in 145.188s
# 	Calibrated mode 104 / 280 in 146.588s
# 	Calibrated mode 105 / 280 in 147.981s
# 	Calibrated mode 106 / 280 in 149.377s
# 	Calibrated mode 107 / 280 in 150.768s
# 	Calibrated mode 108 / 280 in 152.155s
# 	Calibrated mode 109 / 280 in 153.557s
# 	Calibrated mode 110 / 280 in 154.952s
# 	Calibrated mode 111 / 280 in 156.345s
# 	Calibrated mode 112 / 280 in 157.738s
# 	Calibrated mode 113 / 280 in 159.134s
# 	Calibrated mode 114 / 280 in 160.524s
# 	Calibrated mode 115 / 280 in 161.922s
# 	Calibrated mode 116 / 280 in 163.319s
# 	Calibrated mode 117 / 280 in 164.714s
# 	Calibrated mode 118 / 280 in 166.106s
# 	Calibrated mode 119 / 280 in 167.507s
# 	Calibrated mode 120 / 280 in 168.895s
# 	Calibrated mode 121 / 280 in 170.283s
# 	Calibrated mode 122 / 280 in 171.676s
# 	Calibrated mode 123 / 280 in 173.087s
# 	Calibrated mode 124 / 280 in 174.500s
# 	Calibrated mode 125 / 280 in 175.921s
# 	Calibrated mode 253 / 280 in 354.281s
# 	Calibrated mode 254 / 280 in 355.654s
# 	Calibrated mode 255 / 280 in 357.037s
# 	Calibrated mode 256 / 280 in 358.407s
# 	Calibrated mode 257 / 280 in 359.790s
# 	Calibrated mode 258 / 280 in 361.167s
# 	Calibrated mode 259 / 280 in 362.546s
# 	Calibrated mode 260 / 280 in 363.908s
# 	Calibrated mode 261 / 280 in 365.287s
# 	Calibrated mode 262 / 280 in 366.663s
# 	Calibrated mode 263 / 280 in 368.028s
# 	Calibrated mode 264 / 280 in 369.393s
# 	Calibrated mode 265 / 280 in 370.768s
# 	Calibrated mode 266 / 280 in 372.148s
# 	Calibrated mode 267 / 280 in 373.535s
# 	Calibrated mode 268 / 280 in 374.911s
# 	Calibrated mode 269 / 280 in 376.281s
# 	Calibrated mode 270 / 280 in 377.659s
# 	Calibrated mode 271 / 280 in 379.044s
# 	Calibrated mode 272 / 280 in 380.417s
# 	Calibrated mode 273 / 280 in 381.789s
# 	Calibrated mode 274 / 280 in 383.167s
# 	Calibrated mode 275 / 280 in 384.550s
# 	Calibrated mode 276 / 280 in 385.923s
# 	Calibrated mode 277 / 280 in 387.300s
# 	Calibrated mode 278 / 280 in 388.684s
# 	Calibrated mode 279 / 280 in 390.070s
# 	Calibrated mode 280 / 280 in 391.449s
# Calibration complete.

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
wfsc.imshow1(response_sum.reshape(npsf,npsf))

# %%
misc.save_fits('response_matrix_1dm.fits', response_matrix)
misc.save_fits('response_cube_1dm.fits', response_cube)
# Out:
# Saved data to:  response_matrix_1dm.fits
# Saved data to:  response_cube_1dm.fits

# %%
response_cube.shape
# Out:
# (356, 2, 4096)

# %%
cm_tik = wfsc.utils.TikhonovInverse(response_matrix, rcond=1e-1)

Wmatrix = np.diag(np.concatenate((weight_map[control_mask], weight_map[control_mask])))
cm_wls = wfsc.utils.WeightedLeastSquares(response_matrix, Wmatrix, rcond=1e-1)

# %%
reload(wfsc.iefc_1dm)

c.reset_dms()

images, dm_commands_1 = wfsc.iefc_1dm.run(c, 
                                          cm_wls,
                                          probe_modes, 
                                          probe_amp, 
                                          calib_modes,
                                          weight_map, 
                                          num_iterations=20, 
                                          loop_gain=0.5, leakage=0.0,
                                          display_all=True,
                                         )
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 20
# 	Closed-loop iteration 2 / 20
# 	Closed-loop iteration 3 / 20
# 	Closed-loop iteration 4 / 20
# 	Closed-loop iteration 5 / 20
# 	Closed-loop iteration 6 / 20
# 	Closed-loop iteration 7 / 20
# 	Closed-loop iteration 8 / 20
# 	Closed-loop iteration 9 / 20
# 	Closed-loop iteration 10 / 20
# 	Closed-loop iteration 11 / 20
# 	Closed-loop iteration 12 / 20
# 	Closed-loop iteration 13 / 20
# 	Closed-loop iteration 14 / 20
# 	Closed-loop iteration 15 / 20
# 	Closed-loop iteration 16 / 20
# 	Closed-loop iteration 17 / 20
# 	Closed-loop iteration 18 / 20
# 	Closed-loop iteration 19 / 20
# 	Closed-loop iteration 20 / 20
# 	Closed-loop iteration 21 / 20
# I-EFC loop completed in 31.145s.
