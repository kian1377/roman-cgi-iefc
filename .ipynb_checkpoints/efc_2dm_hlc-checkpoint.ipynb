# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import efc_2dm as efc
from wfsc import utils

dm1_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(cgi.data_dir/'dm-acts'/'flatmaps'/'hlc_flattened_dm2.fits')

# %%
reload(cgi)
sys = cgi.CGI(cgi_mode='hlc', 
              use_fpm=False,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )

unocc_psf = sys.snap()

misc.myimshow(unocc_psf, lognorm=True)
Imax_unocc = unocc_psf.max()
print(Imax_unocc)
# Out:
# 0.020081468425845

# %%
reload(cgi)
sys = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
sys.show_dms()

npsf = sys.npsf
Nact = sys.Nact

ref_psf = sys.snap()

misc.myimshow(ref_psf, lognorm=True)

# %% [markdown]
# # Create the dark-hole mask

# %%
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * sys.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 0
iwa = 3
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
#     'direction' : '+x',
    'rotation':rot,
    'full':True
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params)

nmask = dh_mask.sum()

misc.myimshow2(dh_mask, ref_psf*dh_mask,  
               pxscl1=sys.psf_pixelscale_lamD, pxscl2=sys.psf_pixelscale_lamD,
               lognorm2=True)

# %%
# reload(efc)

# epsilon = 1e-9 # poke amplitudes (DM surface)
# jac = efc.build_jacobian(hlc, epsilon, dh_mask.flatten(), display=False)

# %%
# jac_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/jacobians')
# # fname = 'hlc_39_opds_flatmaps_2dm'
# fname = 'hlc_2dm'

# misc.save_pickle(jac_dir/fname, jac, quiet=False)

# %%
jac_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data/jacobians')
fname = 'hlc_39_opds_flatmaps_2dm'
# fname = 'hlc_2dm'

jac = misc.load_pickle(jac_dir/fname)
jac.shape, jac[:,:Nact**2].shape, jac[:,Nact**2:].shape
# Out:
# ((2296, 4608), (2296, 2304), (2296, 2304))

# %%
nmask*2
# Out:
# 2296

# %% [markdown]
# # Invert the Jacobian to get the control matrix

# %%
reload(utils)
reg_fun = utils.beta_reg
# reg_conds = np.array([[0, 10, 20, 30, 40, 50],
#                       [-3, -5, -1, -3, -4, -5]])
reg_conds = np.array([[0, 20, 25, 60, 65],
                      [0, -4, 0, -2, 0]])

# %% [markdown]
# # Run EFC with perfect model

# %%
reload(efc)
sys.reset_dms()
dm1_commands1, dm2_commands1, efields1 = efc.run_efc_perfect(sys,
                                                             jac,
                                                             reg_fun,
                                                             reg_conds,
                                                             dh_mask, 
                                                             Imax_unocc,
                                                             iterations=80, 
#                                                              display_all=True, 
                                                             plot_sms=True)
# Out:
# 	Running iteration 72/80.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 reload(efc)
#       2 sys.reset_dms()
# ----> 3 dm1_commands1, dm2_commands1, efields1 = efc.run_efc_perfect(sys,
#       4                                                              jac,
#       5                                                              reg_fun,
#       6                                                              reg_conds,
#       7                                                              dh_mask,
#       8                                                              Imax_unocc,
#       9                                                              iterations=80,
#      10 #                                                              display_all=True,
#      11                                                              plot_sms=True)
#
# File ~/Documents/roman-cgi-iefc/wfsc/efc_2dm.py:234, in run_efc_perfect(sysi, jac, reg_fun, reg_conds, dark_mask, Imax_unocc, efc_loop_gain, iterations, display_all, display_current, plot_sms)
#     232 sysi.set_dm1(dm1_ref + dm1_command)
#     233 sysi.set_dm2(dm2_ref + dm2_command)
# --> 234 psf = sysi.calc_psf()
#     235 electric_field = psf.wavefront.get()
#     237 dm1_commands.append(sysi.get_dm1())
#
# File ~/src/cgi-phasec-poppy/cgi_phasec_poppy/cgi.py:428, in CGI.calc_psf(self, quiet)
#     426 self.init_inwave()
#     427 if self.cgi_mode=='hlc':
# --> 428     wfs = hlc.run(self, return_intermediates=False)
#     429 else:
#     430     wfs = spc.run(self, return_intermediates=False)
#
# File ~/src/cgi-phasec-poppy/cgi_phasec_poppy/hlc.py:229, in run(HLC, return_intermediates)
#     224     fosys2.add_optic(HLC.detector, distance=d_fold4_image)
#     226 #     fosys2.add_optic(HLC.detector, distance=d_lens_2_pp2_fold4 + d_fold4_image)
#     227
#     228     # Calculate a psf from the first optical system to retrieve the final wavefront at the FPM plane
# --> 229     fpm_hdu, wfs_to_fpm = fosys1.calc_psf(wavelength=HLC.wavelength, inwave=HLC.inwave,
#     230                                           return_final=True, return_intermediates=return_intermediates)
#     231     inwave2 = copy.deepcopy(wfs_to_fpm[-1]) # copy Wavefront object for use in the post FPM system
#     233     if HLC.use_fpm:
#
# File ~/src/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/src/poppy/poppy/poppy_core.py:1743, in BaseOpticalSystem.calc_psf(self, wavelength, weight, save_intermediates, save_intermediates_what, display, return_intermediates, return_final, source, normalize, display_intermediates, inwave)
#    1741     plt.clf()
#    1742 for wlen, wave_weight in zip(wavelength, normwts):
# -> 1743     mono_psf, mono_intermediate_wfs = self.propagate_mono(
#    1744         wlen,
#    1745         retain_intermediates=retain_intermediates,
#    1746         retain_final=return_final,
#    1747         display_intermediates=display_intermediates,
#    1748         normalize=normalize,
#    1749         inwave=inwave
#    1750     )
#    1752     if outfits is None:
#    1753         # for the first wavelength processed, set up the arrays where we accumulate the output
#    1754         outfits = mono_psf
#
# File ~/src/poppy/poppy/utils.py:1436, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1432 # Call the original function with any equivalencies in force.
#    1433 with add_enabled_equivalencies(self.equivalencies):
#    1434     # print("Args:   {}".format(bound_args.args))
#    1435     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1436     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/src/poppy/poppy/poppy_core.py:1881, in BaseOpticalSystem.propagate_mono(self, wavelength, normalize, retain_intermediates, retain_final, display_intermediates, inwave)
#    1879     wavefront, intermediate_wfs = self.propagate(wavefront, **kwargs)
#    1880 else:
# -> 1881     wavefront = self.propagate(wavefront, **kwargs)
#    1882     intermediate_wfs = []
#    1884 if (not retain_intermediates) & retain_final:  # return the full complex wavefront of the last plane.
#
# File ~/src/poppy/poppy/fresnel.py:1431, in FresnelOpticalSystem.propagate(self, wavefront, normalize, return_intermediates, display_intermediates)
#    1429 # The actual propagation:
#    1430 wavefront.propagate_to(optic, distance)
# -> 1431 wavefront *= optic
#    1433 # Normalize if appropriate:
#    1434 if normalize.lower() == 'first' and wavefront.current_plane_index == 1:  # set entrance plane to 1.
#
# File ~/src/poppy/poppy/fresnel.py:918, in FresnelWavefront.__imul__(self, optic)
#     913 """Multiply a Wavefront by an OpticalElement or scalar"""
#     914 if isinstance(optic, QuadraticLens):
#     915     # Special case: if we have a lens, call the routine for that,
#     916     # which will modify the properties of this wavefront more fundamentally
#     917     # than most other optics, adjusting beam parameters and so forth
# --> 918     self.apply_lens_power(optic)
#     919     return self
#     920 elif isinstance(optic, FixedSamplingImagePlaneElement):
#     921     # Special case: if we have an FPM, call the routine for that,
#     922     # which will apply an amplitude transmission to the wavefront.
#
# File ~/src/poppy/poppy/fresnel.py:984, in FresnelWavefront.apply_lens_power(self, optic, ignore_wavefront)
#     981 else:
#     982     self.z_w0 = -r_output_beam / (
#     983         1.0 + (self.wavelength * r_output_beam / (np.pi * spot_radius ** 2)) ** 2) + self.z
# --> 984     self.w_0 = spot_radius / np.sqrt(1.0 + (np.pi * spot_radius ** 2 / (self.wavelength * r_output_beam)) ** 2)
#     985     _log.debug(str(optic.name) + " has a curvature of ={0:0.2e}".format(r_output_beam))
#     986     _log.debug(str(optic.name) + " has a curved output wavefront, with waist at {}".format(self.z_w0))
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/quantity.py:1123, in Quantity.__mul__(self, other)
#    1120     except UnitsError:  # let other try to deal with it
#    1121         return NotImplemented
# -> 1123 return super().__mul__(other)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/quantity.py:593, in Quantity.__array_ufunc__(self, function, method, *inputs, **kwargs)
#     571 """Wrap numpy ufuncs, taking care of units.
#     572
#     573 Parameters
#    (...)
#     587     Results of the ufunc, with the unit set properly.
#     588 """
#     589 # Determine required conversion functions -- to bring the unit of the
#     590 # input to that expected (e.g., radian for np.sin), or to get
#     591 # consistent units between two inputs (e.g., in np.add) --
#     592 # and the unit of the result (or tuple of units for nout > 1).
# --> 593 converters, unit = converters_and_unit(function, method, *inputs)
#     595 out = kwargs.get('out', None)
#     596 # Avoid loop back by turning any Quantity output into array views.
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/quantity_helper/converters.py:174, in converters_and_unit(function, method, *args)
#     171 units = [getattr(arg, 'unit', None) for arg in args]
#     173 # Determine possible conversion functions, and the result unit.
# --> 174 converters, result_unit = ufunc_helper(function, *units)
#     176 if any(converter is False for converter in converters):
#     177     # for multi-argument ufuncs with a quantity and a non-quantity,
#     178     # the quantity normally needs to be dimensionless, *except*
#    (...)
#     181     # can just have the unit of the quantity
#     182     # (this allows, e.g., `q > 0.` independent of unit)
#     183     try:
#     184         # Don't fold this loop in the test above: this rare case
#     185         # should not make the common case slower.
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/quantity_helper/helpers.py:205, in helper_multiplication(f, unit1, unit2)
#     204 def helper_multiplication(f, unit1, unit2):
# --> 205     return [None, None], _d(unit1) * _d(unit2)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/core.py:827, in UnitBase.__mul__(self, m)
#     825     elif self.is_unity():
#     826         return m
# --> 827     return CompositeUnit(1, [self, m], [1, 1], _error_check=False)
#     829 # Cannot handle this as Unit, re-try as Quantity.
#     830 try:
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/core.py:2268, in CompositeUnit.__init__(self, scale, bases, powers, decompose, decompose_bases, _error_check)
#    2266 self._bases = bases
#    2267 self._powers = powers
# -> 2268 self._expand_and_gather(decompose=decompose,
#    2269                         bases=decompose_bases)
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/core.py:2333, in CompositeUnit._expand_and_gather(self, decompose, bases)
#    2331             scale = add_unit(b_sub, a * b, scale)
#    2332     else:
# -> 2333         scale = add_unit(b, p, scale)
#    2335 new_parts = [x for x in new_parts.items() if x[1] != 0]
#    2336 new_parts.sort(key=lambda x: (-x[1], getattr(x[0], 'name', '')))
#
# File ~/.conda/envs/poppy39-exp-env/lib/python3.9/site-packages/astropy/units/core.py:2314, in CompositeUnit._expand_and_gather.<locals>.add_unit(unit, power, scale)
#    2311             break
#    2313 if unit in new_parts:
# -> 2314     a, b = resolve_fractions(new_parts[unit], power)
#    2315     new_parts[unit] = a + b
#    2316 else:
#
# KeyboardInterrupt:
