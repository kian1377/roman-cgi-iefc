# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_2dm as iefc
from wfsc import utils

dm_dir = cgi.data_dir/'dm-acts'

dm1_flat = 2*fits.getdata(dm_dir/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(dm_dir/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')

# %%
cgi.__file__
# Out:
# '/home/u21/kianmilani/src/cgi-phasec-poppy/cgi_phasec_poppy/__init__.py'

# %%
reload(cgi)
hlc = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
hlc.show_dms()

npsf = hlc.npsf
Nact = hlc.Nact

ref_psf = hlc.snap()

misc.myimshow(ref_psf, lognorm=True)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(utils)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlc.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1
iwa = 3
owa = 6
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
    'full':True,
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
    'rotation':rot,
    'full':True,
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95
weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask

misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=hlc.psf_pixelscale_lamD, pxscl2=hlc.psf_pixelscale_lamD, pxscl3=hlc.psf_pixelscale_lamD)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(iefc)
probe_modes = iefc.create_probe_poke_modes(Nact, 
                                           xinds=[Nact//4, Nact//4+1],
                                           yinds=[Nact//4, Nact//4], 
                                           display=True)

calibration_modes, fx, fy = iefc.create_fourier_modes(xfp, 
                                                      control_mask.reshape((npsf,npsf)), 
                                                      Nact, 
                                                      circular_mask=False)
calibration_modes[:] *= hlc.dm_mask.flatten()

nmodes = calibration_modes.shape[0]
print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow(calibration_modes[0].reshape(Nact,Nact))

calibration_amplitude = 0.006 * hlc.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * hlc.wavelength_c.to(u.m).value
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 272

# %%
reload(iefc)
hlc.reset_dms()
differential_images, single_images = iefc.take_measurement(hlc, probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(hlc, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, calibration_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 272 in 5.207s
# 	Calibrated mode 2 / 272 in 10.273s
# 	Calibrated mode 3 / 272 in 15.358s
# 	Calibrated mode 4 / 272 in 20.437s
# 	Calibrated mode 5 / 272 in 25.512s
# 	Calibrated mode 6 / 272 in 30.604s
# 	Calibrated mode 7 / 272 in 35.710s
# 	Calibrated mode 8 / 272 in 40.801s
# 	Calibrated mode 9 / 272 in 45.974s
# 	Calibrated mode 10 / 272 in 51.154s
# 	Calibrated mode 11 / 272 in 56.229s
# 	Calibrated mode 12 / 272 in 61.279s
# 	Calibrated mode 13 / 272 in 66.246s
# 	Calibrated mode 14 / 272 in 71.217s
# 	Calibrated mode 15 / 272 in 76.255s
# 	Calibrated mode 16 / 272 in 81.408s
# 	Calibrated mode 17 / 272 in 86.567s
# 	Calibrated mode 18 / 272 in 91.617s
# 	Calibrated mode 19 / 272 in 96.669s
# 	Calibrated mode 20 / 272 in 101.758s
# 	Calibrated mode 21 / 272 in 106.813s
# 	Calibrated mode 22 / 272 in 111.957s
# 	Calibrated mode 23 / 272 in 117.039s
# 	Calibrated mode 24 / 272 in 122.088s
# 	Calibrated mode 25 / 272 in 127.162s
# 	Calibrated mode 26 / 272 in 132.228s
# 	Calibrated mode 27 / 272 in 137.301s
# 	Calibrated mode 28 / 272 in 142.505s
# 	Calibrated mode 29 / 272 in 147.602s
# 	Calibrated mode 30 / 272 in 152.667s
# 	Calibrated mode 31 / 272 in 157.727s
# 	Calibrated mode 32 / 272 in 162.794s
# 	Calibrated mode 33 / 272 in 167.864s
# 	Calibrated mode 34 / 272 in 172.953s
# 	Calibrated mode 35 / 272 in 178.154s
# 	Calibrated mode 36 / 272 in 183.224s
# 	Calibrated mode 37 / 272 in 188.292s
# 	Calibrated mode 38 / 272 in 193.370s
# 	Calibrated mode 39 / 272 in 198.433s
# 	Calibrated mode 40 / 272 in 203.492s
# 	Calibrated mode 41 / 272 in 208.549s
# 	Calibrated mode 42 / 272 in 213.622s
# 	Calibrated mode 43 / 272 in 218.758s
# 	Calibrated mode 44 / 272 in 223.829s
# 	Calibrated mode 45 / 272 in 228.890s
# 	Calibrated mode 46 / 272 in 233.969s
# 	Calibrated mode 47 / 272 in 239.052s
# 	Calibrated mode 48 / 272 in 244.121s
# 	Calibrated mode 49 / 272 in 249.201s
# 	Calibrated mode 50 / 272 in 254.368s
# 	Calibrated mode 51 / 272 in 259.437s
# 	Calibrated mode 52 / 272 in 264.516s
# 	Calibrated mode 53 / 272 in 269.584s
# 	Calibrated mode 54 / 272 in 274.679s
# 	Calibrated mode 55 / 272 in 279.821s
# 	Calibrated mode 56 / 272 in 284.880s
# 	Calibrated mode 57 / 272 in 289.943s
# 	Calibrated mode 58 / 272 in 295.027s
# 	Calibrated mode 59 / 272 in 300.120s
# 	Calibrated mode 60 / 272 in 305.194s
# 	Calibrated mode 61 / 272 in 310.293s
# 	Calibrated mode 62 / 272 in 315.460s
# 	Calibrated mode 63 / 272 in 320.534s
# 	Calibrated mode 64 / 272 in 325.601s
# 	Calibrated mode 65 / 272 in 330.826s
# 	Calibrated mode 66 / 272 in 335.955s
# 	Calibrated mode 67 / 272 in 340.978s
# 	Calibrated mode 68 / 272 in 345.971s
# 	Calibrated mode 69 / 272 in 351.100s
# 	Calibrated mode 70 / 272 in 356.174s
# 	Calibrated mode 71 / 272 in 361.257s
# 	Calibrated mode 72 / 272 in 366.335s
# 	Calibrated mode 73 / 272 in 371.421s
# 	Calibrated mode 74 / 272 in 376.497s
# 	Calibrated mode 75 / 272 in 381.593s
# 	Calibrated mode 76 / 272 in 386.686s
# 	Calibrated mode 77 / 272 in 391.880s
# 	Calibrated mode 78 / 272 in 396.944s
# 	Calibrated mode 79 / 272 in 402.031s
# 	Calibrated mode 80 / 272 in 407.153s
# 	Calibrated mode 81 / 272 in 412.329s
# 	Calibrated mode 82 / 272 in 417.451s
# 	Calibrated mode 83 / 272 in 422.512s
# 	Calibrated mode 84 / 272 in 427.662s
# 	Calibrated mode 85 / 272 in 432.731s
# 	Calibrated mode 86 / 272 in 437.824s
# 	Calibrated mode 87 / 272 in 442.918s
# 	Calibrated mode 88 / 272 in 448.015s
# 	Calibrated mode 89 / 272 in 453.182s
# 	Calibrated mode 90 / 272 in 458.270s
# 	Calibrated mode 91 / 272 in 463.346s
# 	Calibrated mode 92 / 272 in 468.422s
# 	Calibrated mode 93 / 272 in 473.513s
# 	Calibrated mode 94 / 272 in 478.670s
# 	Calibrated mode 95 / 272 in 483.759s
# 	Calibrated mode 96 / 272 in 488.950s
# 	Calibrated mode 97 / 272 in 494.021s
# 	Calibrated mode 98 / 272 in 499.402s
# 	Calibrated mode 99 / 272 in 504.479s
# 	Calibrated mode 100 / 272 in 509.567s
# 	Calibrated mode 101 / 272 in 514.729s
# 	Calibrated mode 102 / 272 in 519.922s
# 	Calibrated mode 103 / 272 in 525.036s
# 	Calibrated mode 104 / 272 in 530.097s
# 	Calibrated mode 105 / 272 in 535.159s
# 	Calibrated mode 106 / 272 in 540.236s
# 	Calibrated mode 107 / 272 in 545.320s
# 	Calibrated mode 108 / 272 in 550.381s
# 	Calibrated mode 109 / 272 in 555.450s
# 	Calibrated mode 110 / 272 in 560.575s
# 	Calibrated mode 111 / 272 in 565.742s
# 	Calibrated mode 112 / 272 in 570.806s
# 	Calibrated mode 113 / 272 in 575.895s
# 	Calibrated mode 114 / 272 in 581.005s
# 	Calibrated mode 115 / 272 in 586.118s
# 	Calibrated mode 116 / 272 in 591.190s
# 	Calibrated mode 117 / 272 in 596.257s
# 	Calibrated mode 118 / 272 in 601.424s
# 	Calibrated mode 119 / 272 in 606.525s
# 	Calibrated mode 120 / 272 in 611.602s
# 	Calibrated mode 121 / 272 in 616.687s
# 	Calibrated mode 122 / 272 in 621.769s
# 	Calibrated mode 123 / 272 in 626.908s
# 	Calibrated mode 124 / 272 in 631.990s
# 	Calibrated mode 125 / 272 in 637.059s
# 	Calibrated mode 126 / 272 in 642.122s
# 	Calibrated mode 127 / 272 in 647.176s
# 	Calibrated mode 128 / 272 in 652.244s
# 	Calibrated mode 129 / 272 in 657.320s
# 	Calibrated mode 130 / 272 in 662.477s
# 	Calibrated mode 131 / 272 in 667.550s
# 	Calibrated mode 132 / 272 in 672.620s
# 	Calibrated mode 133 / 272 in 677.682s
# 	Calibrated mode 134 / 272 in 682.767s
# 	Calibrated mode 135 / 272 in 687.852s
# 	Calibrated mode 136 / 272 in 692.989s
# 	Calibrated mode 137 / 272 in 698.055s
# 	Calibrated mode 138 / 272 in 703.111s
# 	Calibrated mode 139 / 272 in 708.173s
# 	Calibrated mode 140 / 272 in 713.235s
# 	Calibrated mode 141 / 272 in 718.309s
# 	Calibrated mode 142 / 272 in 723.383s
# 	Calibrated mode 143 / 272 in 728.461s
# 	Calibrated mode 144 / 272 in 733.604s
# 	Calibrated mode 145 / 272 in 738.768s
# 	Calibrated mode 146 / 272 in 743.826s
# 	Calibrated mode 147 / 272 in 748.886s
# 	Calibrated mode 148 / 272 in 753.975s
# 	Calibrated mode 149 / 272 in 759.054s
# 	Calibrated mode 150 / 272 in 764.112s
# 	Calibrated mode 151 / 272 in 769.183s
# 	Calibrated mode 152 / 272 in 774.329s
# 	Calibrated mode 153 / 272 in 779.394s
# 	Calibrated mode 154 / 272 in 784.562s
# 	Calibrated mode 155 / 272 in 789.622s
# 	Calibrated mode 156 / 272 in 794.708s
# 	Calibrated mode 157 / 272 in 801.445s
# 	Calibrated mode 158 / 272 in 806.484s
# 	Calibrated mode 159 / 272 in 811.544s
# 	Calibrated mode 160 / 272 in 816.597s
# 	Calibrated mode 161 / 272 in 821.680s
# 	Calibrated mode 162 / 272 in 826.748s
# 	Calibrated mode 163 / 272 in 831.892s
# 	Calibrated mode 164 / 272 in 837.032s
# 	Calibrated mode 165 / 272 in 842.115s
# 	Calibrated mode 166 / 272 in 847.195s
# 	Calibrated mode 167 / 272 in 852.281s
# 	Calibrated mode 168 / 272 in 857.350s
# 	Calibrated mode 169 / 272 in 862.489s
# 	Calibrated mode 170 / 272 in 867.632s
# 	Calibrated mode 171 / 272 in 872.728s
# 	Calibrated mode 172 / 272 in 877.822s
# 	Calibrated mode 173 / 272 in 882.891s
# 	Calibrated mode 174 / 272 in 887.965s
# 	Calibrated mode 175 / 272 in 893.038s
# 	Calibrated mode 176 / 272 in 898.171s
# 	Calibrated mode 177 / 272 in 903.234s
# 	Calibrated mode 178 / 272 in 908.300s
# 	Calibrated mode 179 / 272 in 913.457s
# 	Calibrated mode 180 / 272 in 918.625s
# 	Calibrated mode 181 / 272 in 923.703s
# 	Calibrated mode 182 / 272 in 928.774s
# 	Calibrated mode 183 / 272 in 933.844s
# 	Calibrated mode 184 / 272 in 938.898s
# 	Calibrated mode 185 / 272 in 943.976s
# 	Calibrated mode 186 / 272 in 949.136s
# 	Calibrated mode 187 / 272 in 954.233s
# 	Calibrated mode 188 / 272 in 959.527s
# 	Calibrated mode 189 / 272 in 964.597s
# 	Calibrated mode 190 / 272 in 969.681s
# 	Calibrated mode 191 / 272 in 974.827s
# 	Calibrated mode 192 / 272 in 979.954s
# 	Calibrated mode 193 / 272 in 985.015s
# 	Calibrated mode 194 / 272 in 990.078s
# 	Calibrated mode 195 / 272 in 995.152s
# 	Calibrated mode 196 / 272 in 1000.218s
# 	Calibrated mode 197 / 272 in 1005.361s
# 	Calibrated mode 198 / 272 in 1010.425s
# 	Calibrated mode 199 / 272 in 1015.484s
# 	Calibrated mode 200 / 272 in 1020.565s
# 	Calibrated mode 201 / 272 in 1025.642s
# 	Calibrated mode 202 / 272 in 1030.706s
# 	Calibrated mode 203 / 272 in 1035.782s
# 	Calibrated mode 204 / 272 in 1040.934s
# 	Calibrated mode 205 / 272 in 1046.012s
# 	Calibrated mode 206 / 272 in 1051.065s
# 	Calibrated mode 207 / 272 in 1056.143s
# 	Calibrated mode 208 / 272 in 1061.253s
# 	Calibrated mode 209 / 272 in 1066.354s
# 	Calibrated mode 210 / 272 in 1071.468s
# 	Calibrated mode 211 / 272 in 1076.541s
# 	Calibrated mode 212 / 272 in 1081.683s
# 	Calibrated mode 213 / 272 in 1086.734s
# 	Calibrated mode 214 / 272 in 1091.933s
# 	Calibrated mode 215 / 272 in 1097.012s
# 	Calibrated mode 216 / 272 in 1102.099s
# 	Calibrated mode 217 / 272 in 1107.151s
# 	Calibrated mode 218 / 272 in 1112.219s
# 	Calibrated mode 219 / 272 in 1117.401s
# 	Calibrated mode 220 / 272 in 1122.499s
# 	Calibrated mode 221 / 272 in 1127.556s
# 	Calibrated mode 222 / 272 in 1132.634s
# 	Calibrated mode 223 / 272 in 1137.777s
# 	Calibrated mode 224 / 272 in 1142.941s
# 	Calibrated mode 225 / 272 in 1147.988s
# 	Calibrated mode 226 / 272 in 1153.058s
# 	Calibrated mode 227 / 272 in 1158.128s
# 	Calibrated mode 228 / 272 in 1163.221s
# 	Calibrated mode 229 / 272 in 1168.432s
# 	Calibrated mode 230 / 272 in 1173.614s
# 	Calibrated mode 231 / 272 in 1178.791s
# 	Calibrated mode 232 / 272 in 1183.890s
# 	Calibrated mode 233 / 272 in 1188.979s
# 	Calibrated mode 234 / 272 in 1194.088s
# 	Calibrated mode 235 / 272 in 1199.188s
# 	Calibrated mode 236 / 272 in 1204.279s
# 	Calibrated mode 237 / 272 in 1209.362s
# 	Calibrated mode 238 / 272 in 1214.521s
# 	Calibrated mode 239 / 272 in 1219.604s
# 	Calibrated mode 240 / 272 in 1224.670s
# 	Calibrated mode 241 / 272 in 1229.733s
# 	Calibrated mode 242 / 272 in 1234.788s
# 	Calibrated mode 243 / 272 in 1239.978s
# 	Calibrated mode 244 / 272 in 1245.059s
# 	Calibrated mode 245 / 272 in 1250.121s
# 	Calibrated mode 246 / 272 in 1255.310s
# 	Calibrated mode 247 / 272 in 1260.388s
# 	Calibrated mode 248 / 272 in 1265.362s
# 	Calibrated mode 249 / 272 in 1270.334s
# 	Calibrated mode 250 / 272 in 1275.423s
# 	Calibrated mode 251 / 272 in 1280.499s
# 	Calibrated mode 252 / 272 in 1285.696s
# 	Calibrated mode 253 / 272 in 1290.820s
# 	Calibrated mode 254 / 272 in 1295.860s
# 	Calibrated mode 255 / 272 in 1301.062s
# 	Calibrated mode 256 / 272 in 1306.357s
# 	Calibrated mode 257 / 272 in 1311.434s
# 	Calibrated mode 258 / 272 in 1316.579s
# 	Calibrated mode 259 / 272 in 1321.645s
# 	Calibrated mode 260 / 272 in 1326.717s
# 	Calibrated mode 261 / 272 in 1331.799s
# 	Calibrated mode 262 / 272 in 1336.879s
# 	Calibrated mode 263 / 272 in 1342.103s
# 	Calibrated mode 264 / 272 in 1347.161s
# 	Calibrated mode 265 / 272 in 1352.297s
# 	Calibrated mode 266 / 272 in 1357.382s
# 	Calibrated mode 267 / 272 in 1362.456s
# 	Calibrated mode 268 / 272 in 1367.547s
# 	Calibrated mode 269 / 272 in 1372.639s
# 	Calibrated mode 270 / 272 in 1377.747s
# 	Calibrated mode 271 / 272 in 1382.810s
# 	Calibrated mode 272 / 272 in 1387.937s
# Calibration complete.

# %%
fname = 'hlc_2dm_annular_36'
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

# %%
import os
os.mkdir(str(iefc_dir/'test_dir'))

# %%
misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_2dm_annular_36
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_2dm_annular_36

# %%
response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), 
                                               rcond1=1e-2,
                                               rcond2=1e-2,
                                               nprobes=probe_modes.shape[0], pca_modes=None)
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC

# %%
reload(iefc)

hlc.reset_dms()

images, dm1_commands, dm2_commands = iefc.run(hlc, 
                                              control_matrix, 
                                              probe_modes, 
                                              probe_amplitude, 
                                              calibration_modes, 
                                              weights, 
                                              num_iterations=10, 
                                              gain=-0.5, leakage=0.0,
                                              display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 10
# 	Closed-loop iteration 2 / 10
# 	Closed-loop iteration 3 / 10
# 	Closed-loop iteration 4 / 10
# 	Closed-loop iteration 5 / 10
# 	Closed-loop iteration 6 / 10
# 	Closed-loop iteration 7 / 10
# 	Closed-loop iteration 8 / 10
# 	Closed-loop iteration 9 / 10
# 	Closed-loop iteration 10 / 10
# I-EFC loop completed in 19.573s.

# %%
dm1 = hlc.get_dm1()

misc.myimshow(dm1-dm1_flat)

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
