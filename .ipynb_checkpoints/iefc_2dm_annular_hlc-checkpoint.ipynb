# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('INFO')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import cgi_phasec_poppy as cgi
from cgi_phasec_poppy import misc

from wfsc import iefc_2dm as iefc
from wfsc import utils

dm_dir = cgi.data_dir/'dm-acts'

dm1_flat = 2*fits.getdata(dm_dir/'flatmaps'/'hlc_flattened_dm1.fits')
dm2_flat = 2*fits.getdata(dm_dir/'flatmaps'/'hlc_flattened_dm2.fits')

# dm1_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm1.fits')
# dm2_flat = fits.getdata(cgi.dm_dir/'flatmaps'/'hlc_flattened_with_pattern_dm2.fits')
# Out:
# INFO:numexpr.utils:Note: detected 96 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 96 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.

# %%
cgi.__file__
# Out:
# '/home/u21/kianmilani/src/cgi-phasec-poppy/cgi_phasec_poppy/__init__.py'

# %%
reload(cgi)
hlc = cgi.CGI(cgi_mode='hlc', 
              use_fpm=True,
              use_pupil_defocus=False, 
              polaxis=0,
              use_opds=True,
              dm1_ref=dm1_flat, dm2_ref=dm2_flat,
             )
hlc.show_dms()

npsf = hlc.npsf
Nact = hlc.Nact

ref_psf = hlc.snap()

misc.myimshow(ref_psf, lognorm=True)

# %% [markdown]
# # Create dark hole ROI to calibrate and control

# %%
reload(utils)
xfp = np.linspace(-0.5, 0.5, npsf) * npsf * hlc.psf_pixelscale_lamD
xf,yf = np.meshgrid(xfp,xfp)

edge = 1
iwa = 3
owa = 9
rot = 0

# Create the mask that is used to select which region to make dark.
dh_params = {
    'inner_radius' : iwa,
    'outer_radius' : owa,
    'edge_position' : edge,
    'direction' : '+x',
    'rotation':rot,
    'full':True,
}
dh_mask = utils.create_annular_focal_plane_mask(xf, yf, dh_params).ravel()

#Create the mask that is used to select which region to make dark.
control_params = {
    'inner_radius' : iwa-0.2,
    'outer_radius' : owa+0.7,
    'edge_position' : edge,
    'rotation':rot,
    'full':True,
}
control_mask = utils.create_annular_focal_plane_mask(xf, yf, control_params).ravel()

relative_weight = 0.95
weights = dh_mask * relative_weight + (1 - relative_weight) * control_mask

misc.myimshow3(dh_mask.reshape(npsf,npsf),
               control_mask.reshape(npsf,npsf), 
               weights.reshape(npsf,npsf),
               lognorm3=True,
               pxscl1=hlc.psf_pixelscale_lamD, pxscl2=hlc.psf_pixelscale_lamD, pxscl3=hlc.psf_pixelscale_lamD)

# %% [markdown]
# # Create probe and fourier modes

# %%
reload(iefc)
probe_modes = iefc.create_probe_poke_modes(Nact, 
                                           xinds=[Nact//4, Nact//4-1],
                                           yinds=[Nact//4, Nact//4], 
                                           display=True)

calibration_modes, fx, fy = iefc.create_fourier_modes(xfp, 
                                                      control_mask.reshape((npsf,npsf)), 
                                                      Nact, 
                                                      circular_mask=False)
calibration_modes = calibration_modes[:calibration_modes.shape[0]//2]
calibration_modes[:] *= hlc.dm_mask.flatten()

nmodes = calibration_modes.shape[0]
print('Calibration modes required: {:d}'.format(nmodes))
misc.myimshow(calibration_modes[0].reshape(Nact,Nact))

calibration_amplitude = 0.006 * hlc.wavelength_c.to(u.m).value
probe_amplitude = 0.05 * hlc.wavelength_c.to(u.m).value
# Out:
# Creating Fourier modes:  (64, 64)
# Calibration modes required: 296

# %%
reload(iefc)
hlc.reset_dms()
differential_images, single_images = iefc.take_measurement(hlc, probe_modes, probe_amplitude, 
                                                           return_all=True, display=True)

# %% [markdown]
# # Calibrate IEFC (or load in previous calibration data)

# %%
reload(iefc)
response_cube, calibration_cube = iefc.calibrate(hlc, probe_amplitude, probe_modes, 
                                                 calibration_amplitude, calibration_modes, start_mode=0)
# Out:
# Calibrating I-EFC...
# 	Calibrated mode 1 / 296 in 5.026s
# 	Calibrated mode 2 / 296 in 10.039s
# 	Calibrated mode 3 / 296 in 15.381s
# 	Calibrated mode 4 / 296 in 20.400s
# 	Calibrated mode 5 / 296 in 25.423s
# 	Calibrated mode 6 / 296 in 30.446s
# 	Calibrated mode 7 / 296 in 35.437s
# 	Calibrated mode 8 / 296 in 40.467s
# 	Calibrated mode 9 / 296 in 45.482s
# 	Calibrated mode 10 / 296 in 50.501s
# 	Calibrated mode 11 / 296 in 55.681s
# 	Calibrated mode 12 / 296 in 60.683s
# 	Calibrated mode 13 / 296 in 65.676s
# 	Calibrated mode 14 / 296 in 70.683s
# 	Calibrated mode 15 / 296 in 75.691s
# 	Calibrated mode 16 / 296 in 80.780s
# 	Calibrated mode 17 / 296 in 85.810s
# 	Calibrated mode 18 / 296 in 90.840s
# 	Calibrated mode 19 / 296 in 95.874s
# 	Calibrated mode 20 / 296 in 100.898s
# 	Calibrated mode 21 / 296 in 106.005s
# 	Calibrated mode 22 / 296 in 111.037s
# 	Calibrated mode 23 / 296 in 116.069s
# 	Calibrated mode 24 / 296 in 121.115s
# 	Calibrated mode 25 / 296 in 126.155s
# 	Calibrated mode 26 / 296 in 131.274s
# 	Calibrated mode 27 / 296 in 136.327s
# 	Calibrated mode 28 / 296 in 141.383s
# 	Calibrated mode 29 / 296 in 146.420s
# 	Calibrated mode 30 / 296 in 151.471s
# 	Calibrated mode 31 / 296 in 156.515s
# 	Calibrated mode 32 / 296 in 161.634s
# 	Calibrated mode 33 / 296 in 166.647s
# 	Calibrated mode 34 / 296 in 171.672s
# 	Calibrated mode 35 / 296 in 176.689s
# 	Calibrated mode 36 / 296 in 181.705s
# 	Calibrated mode 37 / 296 in 186.723s
# 	Calibrated mode 38 / 296 in 191.733s
# 	Calibrated mode 39 / 296 in 196.837s
# 	Calibrated mode 40 / 296 in 201.850s
# 	Calibrated mode 41 / 296 in 206.881s
# 	Calibrated mode 42 / 296 in 211.911s
# 	Calibrated mode 43 / 296 in 216.939s
# 	Calibrated mode 44 / 296 in 221.954s
# 	Calibrated mode 45 / 296 in 227.052s
# 	Calibrated mode 46 / 296 in 232.073s
# 	Calibrated mode 47 / 296 in 237.101s
# 	Calibrated mode 48 / 296 in 242.153s
# 	Calibrated mode 49 / 296 in 247.297s
# 	Calibrated mode 50 / 296 in 252.331s
# 	Calibrated mode 51 / 296 in 257.373s
# 	Calibrated mode 52 / 296 in 262.427s
# 	Calibrated mode 53 / 296 in 267.475s
# 	Calibrated mode 54 / 296 in 272.523s
# 	Calibrated mode 55 / 296 in 277.652s
# 	Calibrated mode 56 / 296 in 282.694s
# 	Calibrated mode 57 / 296 in 287.737s
# 	Calibrated mode 58 / 296 in 292.792s
# 	Calibrated mode 59 / 296 in 297.832s
# 	Calibrated mode 60 / 296 in 302.881s
# 	Calibrated mode 61 / 296 in 308.025s
# 	Calibrated mode 62 / 296 in 313.072s
# 	Calibrated mode 63 / 296 in 318.119s
# 	Calibrated mode 64 / 296 in 323.175s
# 	Calibrated mode 65 / 296 in 328.211s
# 	Calibrated mode 66 / 296 in 333.258s
# 	Calibrated mode 67 / 296 in 338.307s
# 	Calibrated mode 68 / 296 in 343.428s
# 	Calibrated mode 69 / 296 in 348.479s
# 	Calibrated mode 70 / 296 in 353.511s
# 	Calibrated mode 71 / 296 in 358.565s
# 	Calibrated mode 72 / 296 in 363.607s
# 	Calibrated mode 73 / 296 in 368.650s
# 	Calibrated mode 74 / 296 in 373.800s
# 	Calibrated mode 75 / 296 in 378.826s
# 	Calibrated mode 76 / 296 in 383.872s
# 	Calibrated mode 77 / 296 in 388.930s
# 	Calibrated mode 78 / 296 in 394.053s
# 	Calibrated mode 79 / 296 in 399.098s
# 	Calibrated mode 80 / 296 in 404.127s
# 	Calibrated mode 81 / 296 in 409.167s
# 	Calibrated mode 82 / 296 in 414.231s
# 	Calibrated mode 83 / 296 in 419.277s
# 	Calibrated mode 84 / 296 in 424.419s
# 	Calibrated mode 85 / 296 in 429.449s
# 	Calibrated mode 86 / 296 in 434.489s
# 	Calibrated mode 87 / 296 in 439.532s
# 	Calibrated mode 88 / 296 in 444.571s
# 	Calibrated mode 89 / 296 in 449.723s
# 	Calibrated mode 90 / 296 in 454.773s
# 	Calibrated mode 91 / 296 in 459.818s
# 	Calibrated mode 92 / 296 in 464.851s
# 	Calibrated mode 93 / 296 in 469.908s
# 	Calibrated mode 94 / 296 in 474.965s
# 	Calibrated mode 95 / 296 in 480.013s
# 	Calibrated mode 96 / 296 in 485.150s
# 	Calibrated mode 97 / 296 in 490.190s
# 	Calibrated mode 98 / 296 in 495.248s
# 	Calibrated mode 99 / 296 in 500.284s
# 	Calibrated mode 100 / 296 in 505.343s
# 	Calibrated mode 101 / 296 in 510.387s
# 	Calibrated mode 102 / 296 in 515.506s
# 	Calibrated mode 103 / 296 in 520.542s
# 	Calibrated mode 104 / 296 in 525.588s
# 	Calibrated mode 105 / 296 in 530.628s
# 	Calibrated mode 106 / 296 in 535.758s
# 	Calibrated mode 107 / 296 in 540.792s
# 	Calibrated mode 108 / 296 in 545.847s
# 	Calibrated mode 109 / 296 in 550.890s
# 	Calibrated mode 110 / 296 in 555.935s
# 	Calibrated mode 111 / 296 in 560.980s
# 	Calibrated mode 112 / 296 in 566.109s
# 	Calibrated mode 113 / 296 in 571.147s
# 	Calibrated mode 114 / 296 in 576.217s
# 	Calibrated mode 115 / 296 in 581.252s
# 	Calibrated mode 116 / 296 in 586.296s
# 	Calibrated mode 117 / 296 in 591.339s
# 	Calibrated mode 118 / 296 in 596.465s
# 	Calibrated mode 119 / 296 in 601.491s
# 	Calibrated mode 120 / 296 in 606.508s
# 	Calibrated mode 121 / 296 in 611.519s
# 	Calibrated mode 122 / 296 in 616.532s
# 	Calibrated mode 123 / 296 in 621.548s
# 	Calibrated mode 124 / 296 in 626.569s
# 	Calibrated mode 125 / 296 in 631.685s
# 	Calibrated mode 126 / 296 in 636.697s
# 	Calibrated mode 127 / 296 in 641.728s
# 	Calibrated mode 128 / 296 in 646.754s
# 	Calibrated mode 129 / 296 in 651.783s
# 	Calibrated mode 130 / 296 in 656.815s
# 	Calibrated mode 131 / 296 in 661.947s
# 	Calibrated mode 132 / 296 in 666.975s
# 	Calibrated mode 133 / 296 in 672.009s
# 	Calibrated mode 134 / 296 in 677.159s
# 	Calibrated mode 135 / 296 in 682.286s
# 	Calibrated mode 136 / 296 in 687.308s
# 	Calibrated mode 137 / 296 in 692.350s
# 	Calibrated mode 138 / 296 in 697.380s
# 	Calibrated mode 139 / 296 in 702.416s
# 	Calibrated mode 140 / 296 in 707.454s
# 	Calibrated mode 141 / 296 in 712.566s
# 	Calibrated mode 142 / 296 in 717.590s
# 	Calibrated mode 143 / 296 in 722.614s
# 	Calibrated mode 144 / 296 in 727.649s
# 	Calibrated mode 145 / 296 in 732.677s
# 	Calibrated mode 146 / 296 in 737.784s
# 	Calibrated mode 147 / 296 in 742.806s
# 	Calibrated mode 148 / 296 in 747.827s
# 	Calibrated mode 149 / 296 in 752.864s
# 	Calibrated mode 150 / 296 in 757.893s
# 	Calibrated mode 151 / 296 in 762.924s
# 	Calibrated mode 152 / 296 in 767.962s
# 	Calibrated mode 153 / 296 in 773.067s
# 	Calibrated mode 154 / 296 in 778.095s
# 	Calibrated mode 155 / 296 in 783.124s
# 	Calibrated mode 156 / 296 in 788.116s
# 	Calibrated mode 157 / 296 in 793.108s
# 	Calibrated mode 158 / 296 in 798.095s
# 	Calibrated mode 159 / 296 in 803.182s
# 	Calibrated mode 160 / 296 in 808.166s
# 	Calibrated mode 161 / 296 in 813.177s
# 	Calibrated mode 162 / 296 in 818.175s
# 	Calibrated mode 163 / 296 in 823.273s
# 	Calibrated mode 164 / 296 in 828.260s
# 	Calibrated mode 165 / 296 in 833.285s
# 	Calibrated mode 166 / 296 in 838.284s
# 	Calibrated mode 167 / 296 in 843.283s
# 	Calibrated mode 168 / 296 in 848.290s
# 	Calibrated mode 169 / 296 in 853.380s
# 	Calibrated mode 170 / 296 in 858.382s
# 	Calibrated mode 171 / 296 in 863.391s
# 	Calibrated mode 172 / 296 in 868.390s
# 	Calibrated mode 173 / 296 in 873.529s
# 	Calibrated mode 174 / 296 in 878.590s
# 	Calibrated mode 175 / 296 in 883.687s
# 	Calibrated mode 176 / 296 in 888.685s
# 	Calibrated mode 177 / 296 in 893.685s
# 	Calibrated mode 178 / 296 in 899.021s
# 	Calibrated mode 179 / 296 in 904.405s
# 	Calibrated mode 180 / 296 in 909.441s
# 	Calibrated mode 181 / 296 in 914.484s
# 	Calibrated mode 182 / 296 in 919.574s
# 	Calibrated mode 183 / 296 in 924.596s
# 	Calibrated mode 184 / 296 in 944.456s
# 	Calibrated mode 185 / 296 in 950.954s
# 	Calibrated mode 186 / 296 in 957.110s
# 	Calibrated mode 187 / 296 in 963.341s
# 	Calibrated mode 188 / 296 in 969.905s
# 	Calibrated mode 189 / 296 in 976.503s
# 	Calibrated mode 190 / 296 in 982.965s
# 	Calibrated mode 191 / 296 in 989.450s
# 	Calibrated mode 192 / 296 in 996.123s
# 	Calibrated mode 193 / 296 in 1002.834s
# 	Calibrated mode 194 / 296 in 1009.163s
# 	Calibrated mode 195 / 296 in 1015.768s
# 	Calibrated mode 196 / 296 in 1022.092s
# 	Calibrated mode 197 / 296 in 1028.056s
# 	Calibrated mode 198 / 296 in 1033.061s
# 	Calibrated mode 199 / 296 in 1038.157s
# 	Calibrated mode 200 / 296 in 1043.169s
# 	Calibrated mode 201 / 296 in 1048.160s
# 	Calibrated mode 202 / 296 in 1053.170s
# 	Calibrated mode 203 / 296 in 1058.159s
# 	Calibrated mode 204 / 296 in 1063.161s
# 	Calibrated mode 205 / 296 in 1068.246s
# 	Calibrated mode 206 / 296 in 1073.225s
# 	Calibrated mode 207 / 296 in 1078.226s
# 	Calibrated mode 208 / 296 in 1083.226s
# 	Calibrated mode 209 / 296 in 1088.324s
# 	Calibrated mode 210 / 296 in 1093.334s
# 	Calibrated mode 211 / 296 in 1098.335s
# 	Calibrated mode 212 / 296 in 1103.331s
# 	Calibrated mode 213 / 296 in 1108.331s
# 	Calibrated mode 214 / 296 in 1113.335s
# 	Calibrated mode 215 / 296 in 1118.446s
# 	Calibrated mode 216 / 296 in 1123.461s
# 	Calibrated mode 217 / 296 in 1128.467s
# 	Calibrated mode 218 / 296 in 1133.460s
# 	Calibrated mode 219 / 296 in 1138.472s
# 	Calibrated mode 220 / 296 in 1143.483s
# 	Calibrated mode 221 / 296 in 1148.579s
# 	Calibrated mode 222 / 296 in 1153.585s
# 	Calibrated mode 223 / 296 in 1158.596s
# 	Calibrated mode 224 / 296 in 1163.598s
# 	Calibrated mode 225 / 296 in 1168.599s
# 	Calibrated mode 226 / 296 in 1173.613s
# 	Calibrated mode 227 / 296 in 1178.620s
# 	Calibrated mode 228 / 296 in 1183.722s
# 	Calibrated mode 229 / 296 in 1188.719s
# 	Calibrated mode 230 / 296 in 1193.720s
# 	Calibrated mode 231 / 296 in 1198.720s
# 	Calibrated mode 232 / 296 in 1203.726s
# 	Calibrated mode 233 / 296 in 1208.726s
# 	Calibrated mode 234 / 296 in 1213.821s
# 	Calibrated mode 235 / 296 in 1218.818s
# 	Calibrated mode 236 / 296 in 1223.827s
# 	Calibrated mode 237 / 296 in 1228.825s
# 	Calibrated mode 238 / 296 in 1233.903s
# 	Calibrated mode 239 / 296 in 1238.894s
# 	Calibrated mode 240 / 296 in 1243.920s
# 	Calibrated mode 241 / 296 in 1248.924s
# 	Calibrated mode 242 / 296 in 1253.939s
# 	Calibrated mode 243 / 296 in 1258.922s
# 	Calibrated mode 244 / 296 in 1264.005s
# 	Calibrated mode 245 / 296 in 1268.992s
# 	Calibrated mode 246 / 296 in 1273.979s
# 	Calibrated mode 247 / 296 in 1278.971s
# 	Calibrated mode 248 / 296 in 1283.961s
# 	Calibrated mode 249 / 296 in 1289.032s
# 	Calibrated mode 250 / 296 in 1294.030s
# 	Calibrated mode 251 / 296 in 1299.017s
# 	Calibrated mode 252 / 296 in 1304.015s
# 	Calibrated mode 253 / 296 in 1309.002s
# 	Calibrated mode 254 / 296 in 1314.004s
# 	Calibrated mode 255 / 296 in 1319.000s
# 	Calibrated mode 256 / 296 in 1324.096s
# 	Calibrated mode 257 / 296 in 1329.101s
# 	Calibrated mode 258 / 296 in 1334.105s
# 	Calibrated mode 259 / 296 in 1339.104s
# 	Calibrated mode 260 / 296 in 1344.117s
# 	Calibrated mode 261 / 296 in 1349.120s
# 	Calibrated mode 262 / 296 in 1354.225s
# 	Calibrated mode 263 / 296 in 1359.230s
# 	Calibrated mode 264 / 296 in 1364.240s
# 	Calibrated mode 265 / 296 in 1369.243s
# 	Calibrated mode 266 / 296 in 1374.339s
# 	Calibrated mode 267 / 296 in 1379.343s
# 	Calibrated mode 268 / 296 in 1384.360s
# 	Calibrated mode 269 / 296 in 1389.357s
# 	Calibrated mode 270 / 296 in 1394.361s
# 	Calibrated mode 271 / 296 in 1399.484s
# 	Calibrated mode 272 / 296 in 1404.587s
# 	Calibrated mode 273 / 296 in 1409.599s
# 	Calibrated mode 274 / 296 in 1414.620s
# 	Calibrated mode 275 / 296 in 1419.626s
# 	Calibrated mode 276 / 296 in 1424.642s
# 	Calibrated mode 277 / 296 in 1429.662s
# 	Calibrated mode 278 / 296 in 1434.760s
# 	Calibrated mode 279 / 296 in 1439.777s
# 	Calibrated mode 280 / 296 in 1444.804s
# 	Calibrated mode 281 / 296 in 1449.813s
# 	Calibrated mode 282 / 296 in 1454.815s
# 	Calibrated mode 283 / 296 in 1459.823s
# 	Calibrated mode 284 / 296 in 1464.835s
# 	Calibrated mode 285 / 296 in 1469.949s
# 	Calibrated mode 286 / 296 in 1474.963s
# 	Calibrated mode 287 / 296 in 1479.979s
# 	Calibrated mode 288 / 296 in 1485.005s
# 	Calibrated mode 289 / 296 in 1490.030s
# 	Calibrated mode 290 / 296 in 1495.063s
# 	Calibrated mode 291 / 296 in 1500.171s
# 	Calibrated mode 292 / 296 in 1505.190s
# 	Calibrated mode 293 / 296 in 1510.214s
# 	Calibrated mode 294 / 296 in 1515.236s
# 	Calibrated mode 295 / 296 in 1520.338s
# 	Calibrated mode 296 / 296 in 1525.349s
# Calibration complete.

# %%
fname = 'hlc_2dm_annular_36'
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

misc.save_pickle(iefc_dir/'response-data'/fname, response_cube)
misc.save_pickle(iefc_dir/'calibration-data'/fname, calibration_cube)
# Out:
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/response-data/hlc_2dm_annular_36
# Saved data to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/calibration-data/hlc_2dm_annular_36

# %%
fname = 'hlc_2dm_annular_36'
iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')

response_cube = misc.load_pickle(iefc_dir/'response-data'/fname)
calibration_cube = misc.load_pickle(iefc_dir/'calibration-data'/fname)

# %%
response_sum = np.sum(abs(response_cube), axis=(0,1))
misc.myimshow(response_sum.reshape(64,64))

# %% [markdown]
# # Create control matrix

# %%
reload(iefc)
# OPTIONAL: Filter the calibration files by subtracting PCA modes
# npca = 3
# filtered_response_cube, pca_modes = iefc.remove_k_pca_modes(response_cube, k=npca)

control_matrix = iefc.construct_control_matrix(response_cube, 
                                               weights.flatten(), 
                                               rcond1=1e-2,
                                               rcond2=1e-2,
                                               nprobes=probe_modes.shape[0], pca_modes=None)
# Out:
# Using Weighted Least Squares

# %% [markdown]
# # Run IEFC

# %%
reload(iefc)

hlc.reset_dms()

images, dm1_commands, dm2_commands = iefc.run(hlc, 
                                              control_matrix, 
                                              probe_modes, 
                                              probe_amplitude, 
                                              calibration_modes, 
                                              weights, 
                                              num_iterations=10, 
                                              gain=-0.5, leakage=0.0,
                                              display=True)
# Out:
# Running I-EFC...
# 	Closed-loop iteration 1 / 10
# 	Closed-loop iteration 2 / 10
# 	Closed-loop iteration 3 / 10
# 	Closed-loop iteration 4 / 10
# 	Closed-loop iteration 5 / 10
# 	Closed-loop iteration 6 / 10
# 	Closed-loop iteration 7 / 10
# 	Closed-loop iteration 8 / 10
# 	Closed-loop iteration 9 / 10
# 	Closed-loop iteration 10 / 10
# I-EFC loop completed in 19.577s.

# %%
dm1 = hlc.get_dm1()

misc.myimshow(dm1-dm1_flat)

# %%
iefcu.save_pickle(data_dir/'image-results'/fname, images)
iefcu.save_pickle(data_dir/'dm-results'/fname, dm_commands)
# Out:
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/image-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
# Saved wavefronts to:  /groups/douglase/kians-data-files/roman-cgi-iefc-data/dm-results/dshaped_Yopds_polaxis0_iwa3.0_owa6.0
