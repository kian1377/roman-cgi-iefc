# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import poppy

from roman_cgi_iefc_2.poppy_roman_cgi_phasec import cgi
from roman_cgi_iefc_2 import iefc_utils as iefcu
from roman_cgi_iefc_2 import iefc_sim as iefc

import misc

data_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
flatmaps_dir = Path.home()/'src/pyfalco/roman/flatmaps'

dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')

def reset(quiet=False):
    reload(iefcu)
    reload(iefc)
    reload(cgi)
    hlci = cgi.CGI_POPPY(polaxis=0, use_opds=False, use_fieldstop=True, quiet=quiet, ngpus=1/4)
#     hlci.set_dm1(dm1_flatmap)
#     hlci.set_dm2(dm2_flatmap)
    return hlci

hlci = reset()
ref_psf = hlci.calc_psf()[-1]
misc.myimshow2(ref_psf.intensity.get(), ref_psf.phase.get(), lognorm1=True)

npsf = hlci.npsf
Nact = hlci.Nact

dm_wf = poppy.FresnelWavefront(beam_radius=hlci.dm_diam/2, npix=hlci.npix, oversample=hlci.oversample)
# Out:
# Propagating wavelength 575.000 nm.
# PSF calculated in 0.45s

# %%
def fft2d(arr):
    return cp.fft.fftshift(cp.fft.fft2(cp.fft.fftshift(arr)))
def ifft2d(arr):
    return cp.fft.ifftshift(cp.fft.ifft2(cp.fft.ifftshift(arr)))

def create_probe(DM, desired_focal, num_iterations=5):
    for i in range(num_iterations):
        hlci.set_surface
        pupil = DM.get_phasor(dm_wf)
        focal = fft2d(pupil)
        misc.myimshow2(cp.abs(focal), cp.angle(focal), npix1=64, npix2=64)
        misc.myimshow2(cp.abs(desired_focal), cp.angle(desired_focal), npix1=64, npix2=64)
        new_focal = focal + cp.exp(1j*desired_focal)
        
        pupil = ifft2d(new_focal)
    return pupil

poke_modes = hlci.wavelength_c.value/2 * iefcu.create_probe_poke_modes(Nact, 2*Nact//4, Nact//2, 2*Nact//4-1, Nact//2)
hlci = reset()
# hlci.set_dm1(poke_modes[1])

dm1_phasor = hlci.DM1.get_phasor(dm_wf)
dm1_phasor = dm1_phasor/dm1_phasor.sum()
misc.myimshow2(cp.abs(dm1_phasor), cp.angle(dm1_phasor), npix1=hlci.npix, npix2=hlci.npix)

fp_pixelscale = (hlci.wavelength_c/hlci.pupil_diam/(hlci.oversample)).value / rad_per_lamD.value
xfp = np.linspace(-0.5, 0.5, 1024) * 1024 * fp_pixelscale
xf,yf = np.meshgrid(xfp,xfp)

circ_params = { 'inner_radius':0, 'outer_radius':10, 'edge_position':0, 'direction':'' }
circ_focal = cp.array(iefcu.create_annular_focal_plane_mask(xf, yf, circ_params).astype(int))
rect_params = { 'x0':0, 'y0':0, 'w':10, 'h':20,}
rect_focal = cp.array(iefcu.create_box_focal_plane_mask(xf, yf, rect_params).astype(int))

desired_focal = circ_focal*cp.exp(1j*cp.pi*circ_focal)

misc.myimshow2(cp.abs(desired_focal), cp.angle(desired_focal))

# %%
probe = create_probe(hlci.DM1, desired_focal, 3)
misc.myimshow2(probe.real, probe.imag, npix1=hlci.npix, npix2=hlci.npix)
